# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the activation functions
def linear(x):
    return x

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return np.tanh(x)

def relu(x):
    return np.maximum(0, x)

def leaky_relu(x):
    return np.maximum(0.1 * x, x)

def elu(x, alpha=1.0):
    return np.where(x > 0, x, alpha * (np.exp(x) - 1))

def swish(x):
    return x * sigmoid(x)

def softmax(x):
    e_x = np.exp(x - np.max(x))  # Subtract max for numerical stability
    return e_x / e_x.sum(axis=0)

def logistic(x):
    return sigmoid(x)

def step(x):
    return np.where(x >= 0, 1, 0)

# Generate values for x-axis
x = np.linspace(-10, 10, 400)

# Compute the corresponding y-values for each activation function
y_linear = linear(x)
y_sigmoid = sigmoid(x)
y_tanh = tanh(x)
y_relu = relu(x)
y_leaky_relu = leaky_relu(x)
y_elu = elu(x)
y_swish = swish(x)
y_logistic = logistic(x)
y_step = step(x)

# Plot each activation function
plt.figure(figsize=(8, 4))

plt.subplot(2, 3, 1)
plt.plot(x, y_linear)
plt.title('Linear')

plt.subplot(2, 3, 2)
plt.plot(x, y_sigmoid)
plt.title('Sigmoid')

plt.subplot(2, 3, 3)
plt.plot(x, y_relu)
plt.title('ReLU')

plt.subplot(2, 3, 4)
plt.plot(x, y_leaky_relu)
plt.title('Leaky ReLU')

plt.subplot(2, 3, 5)
plt.plot(x, y_elu)
plt.title('ELU')


plt.subplot(2, 3, 6)
plt.plot(x, y_step)
plt.title('Step')

plt.tight_layout()
plt.savefig("activations.pdf", format="pdf", bbox_inches='tight') 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def f(x):
    return x**2

def grad_f(x):
    return 2*x

# Gradient Descent parameters
learning_rate = 0.1
n_iterations = 20
initial_x = 5  # Starting point

# Lists to store the values for plotting
x_values = [initial_x]
y_values = [f(initial_x)]

# Gradient Descent Algorithm
x = initial_x
for _ in range(n_iterations):
    gradient = grad_f(x)
    x = x - learning_rate * gradient  # Update step
    x_values.append(x)
    y_values.append(f(x))

# Plotting the function
x_plot = np.linspace(-6, 6, 100)
y_plot = f(x_plot)

plt.figure(figsize=(10, 6))
plt.plot(x_plot, y_plot, label=r'$f(x) = x^2$')
plt.scatter(x_values, y_values, color='red', label='Gradient Descent Steps')
plt.plot(x_values, y_values, color='red', linestyle='--')
plt.title('Gradient Descent on $f(x) = x^2$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function and its gradient
def f(x, y):
    return x**2 + y**2

def grad_f(x, y):
    return np.array([2*x, 2*y])

# Gradient Descent parameters
learning_rate = 0.1
n_iterations = 30
initial_point = np.array([4.0, 4.0])  # Starting point

# Lists to store the values for plotting
points = [initial_point]
z_values = [f(initial_point[0], initial_point[1])]

# Gradient Descent Algorithm
point = initial_point
for _ in range(n_iterations):
    gradient = grad_f(point[0], point[1])
    point = point - learning_rate * gradient  # Update step
    points.append(point)
    z_values.append(f(point[0], point[1]))

# Convert points to arrays for easier handling
points = np.array(points)

# Creating the meshgrid for plotting the surface
x_plot = np.linspace(-5, 5, 100)
y_plot = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x_plot, y_plot)
Z = f(X, Y)

# Plotting the 3D surface and the gradient descent path
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.7)

# Plotting the gradient descent path
ax.plot(points[:, 0], points[:, 1], z_values, color='red', marker='o', markersize=5, label='Gradient Descent Path')

# Labels and Title
ax.set_title('Stochastic Gradient Descent', fontsize=15)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.grid(False)
ax.set_zlabel('f(x, y)')

# Showing the plot
plt.legend()
plt.savefig("gd.png", bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the functions and gradients
def f_2d(x):
    return x**2

def grad_f_2d(x):
    return 2*x

def f_3d(x, y):
    return x**2 + y**2

def grad_f_3d(x, y):
    return np.array([2*x, 2*y])

# Gradient Descent parameters
learning_rate = 0.1
n_iterations = 20

# For 2D plot (f(x) = x^2)
initial_x = 5
x_values = [initial_x]
y_values = [f_2d(initial_x)]

x = initial_x
for _ in range(n_iterations):
    gradient = grad_f_2d(x)
    x = x - learning_rate * gradient
    x_values.append(x)
    y_values.append(f_2d(x))

# For 3D plot (f(x, y) = x^2 + y^2)
initial_point = np.array([4.0, 4.0])
points = [initial_point]
z_values = [f_3d(initial_point[0], initial_point[1])]

point = initial_point
for _ in range(n_iterations):
    gradient = grad_f_3d(point[0], point[1])
    point = point - learning_rate * gradient
    points.append(point)
    z_values.append(f_3d(point[0], point[1]))

points = np.array(points)

# Creating the meshgrid for plotting the 3D surface
x_plot = np.linspace(-5, 5, 100)
y_plot = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x_plot, y_plot)
Z = f_3d(X, Y)

# Creating a figure with 2 subplots: 3D surface and 2D curve
fig = plt.figure(figsize=(8, 4))

# 3D Plot
ax1 = fig.add_subplot(121, projection='3d')
ax1.plot_surface(X, Y, Z, cmap='viridis', alpha=0.7)
ax1.plot(points[:, 0], points[:, 1], z_values, color='red', marker='o', markersize=5, label='Gradient Descent Path')
ax1.set_title('Gradient Descent on $f(x, y) = x^2 + y^2$', fontsize=15)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('f(x, y)')
ax1.legend()

# 2D Plot
ax2 = fig.add_subplot(122)
x_plot_2d = np.linspace(-6, 6, 100)
y_plot_2d = f_2d(x_plot_2d)
ax2.plot(x_plot_2d, y_plot_2d, label=r'$f(x) = x^2$')
ax2.scatter(x_values, y_values, color='red', label='Gradient Descent Steps')
ax2.plot(x_values, y_values, color='red', linestyle='--')
ax2.set_title('Gradient Descent on $f(x) = x^2$', fontsize=15)
ax2.set_xlabel('x')
ax2.set_ylabel('f(x)')
ax2.legend()
ax2.grid(False)

plt.tight_layout()
plt.savefig("gd.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %%
import numpy as np
import torch
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms

import shap

batch_size = 128
num_epochs = 2
device = torch.device("cpu")


class Net(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv_layers = nn.Sequential(
            nn.Conv2d(1, 10, kernel_size=5),
            nn.MaxPool2d(2),
            nn.ReLU(),
            nn.Conv2d(10, 20, kernel_size=5),
            nn.Dropout(),
            nn.MaxPool2d(2),
            nn.ReLU(),
        )
        self.fc_layers = nn.Sequential(
            nn.Linear(320, 50),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(50, 10),
            nn.Softmax(dim=1),
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = x.view(-1, 320)
        x = self.fc_layers(x)
        return x


def train(model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output.log(), target)
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print(
                f"Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)}"
                f" ({100.0 * batch_idx / len(train_loader):.0f}%)]"
                f"\tLoss: {loss.item():.6f}"
            )


def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output.log(), target).item()  # sum up batch loss
            pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    print(
        f"\nTest set: Average loss: {test_loss:.4f},"
        f" Accuracy: {correct}/{len(test_loader.dataset)}"
        f" ({100.0 * correct / len(test_loader.dataset):.0f}%)\n"
    )


train_loader = torch.utils.data.DataLoader(
    datasets.MNIST(
        "mnist_data",
        train=True,
        download=True,
        transform=transforms.Compose([transforms.ToTensor()]),
    ),
    batch_size=batch_size,
    shuffle=True,
)

test_loader = torch.utils.data.DataLoader(
    datasets.MNIST("mnist_data", train=False, transform=transforms.Compose([transforms.ToTensor()])),
    batch_size=batch_size,
    shuffle=True,
)

model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

for epoch in range(1, num_epochs + 1):
    train(model, device, train_loader, optimizer, epoch)
    test(model, device, test_loader)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.318239
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 2.043583
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 1.064806
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.884785
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.692940
#
# Test set: Average loss: 0.0046, Accuracy: 9012/10000 (90%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.571241
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.483829
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.377749
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.499372
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.520408
#
# Test set: Average loss: 0.0027, Accuracy: 9335/10000 (93%)

# %%
# since shuffle=True, this is a random sample of test data
batch = next(iter(test_loader))
images, _ = batch

background = images[:100]
test_images = images[100:103]

e = shap.DeepExplainer(model, background)
shap_values = e.shap_values(test_images)

# %%
shap_numpy = list(np.transpose(shap_values, (4, 0, 2, 3, 1)))
test_numpy = np.swapaxes(np.swapaxes(test_images.numpy(), 1, -1), 1, 2)

# %%
import matplotlib.pyplot as plt
# plot the feature attributions
shap.image_plot(shap_numpy, -test_numpy)
plt.show()
plt.savefig("shap")

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# Load the MNIST dataset
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Function to display a grid of images from the dataset
def display_mnist_images(images, labels, num_images=20):
    plt.figure(figsize=(8, 4))  # Adjust the figure size to fit the grid
    num_columns = 10  # Set the number of columns to 10
    num_rows = num_images // num_columns  # Set the number of rows to 2
    for i in range(num_images):
        plt.subplot(num_rows, num_columns, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(labels[i])
    
    # Adjust the layout to reduce white space
    plt.subplots_adjust(wspace=0.1, hspace=0)
    plt.savefig("mnist_sample.pdf", format="pdf", bbox_inches='tight')
    plt.show()

# Display the first 20 images from the training set
display_mnist_images(train_images, train_labels, num_images=20)

# %%
import torch
import random
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

# Load MNIST dataset
transform = transforms.Compose([transforms.ToTensor()])
trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)

# Load the original MNIST dataset for comparison
original_trainset = datasets.MNIST(root='./data', train=True, download=True)

# Define a function to swap pixels in the images of specified digits
def swap_pixels_in_image(dataset, digits_to_modify, num_features_to_swap=500):
    for idx in range(len(dataset.targets)):
        if dataset.targets[idx].item() in digits_to_modify:
            h, w = dataset.data[idx].shape
            swap_indices = random.sample(range(h * w), num_features_to_swap)
            for swap_idx in swap_indices:
                y, x = divmod(swap_idx, w)
                swap_y, swap_x = random.randint(0, h-1), random.randint(0, w-1)
                dataset.data[idx, y, x], dataset.data[idx, swap_y, swap_x] = dataset.data[idx, swap_y, swap_x], dataset.data[idx, y, x]

# Choose digits to modify
digits_to_modify = [3, 8, 5, 6]

# Modify the dataset
swap_pixels_in_image(trainset, digits_to_modify)

# Plot the original and modified images for the specified digits
def plot_images_comparison(original_dataset, modified_dataset, digits_to_modify, num_images_per_digit=5):
    plt.figure(figsize=(15, 10))
    count = 0
    for idx in range(len(original_dataset.targets)):
        if original_dataset.targets[idx].item() in digits_to_modify:
            ax = plt.subplot(len(digits_to_modify), num_images_per_digit * 2, count + 1)
            image_original = original_dataset.data[idx].numpy()
            ax.set_title(f"Original {original_dataset.targets[idx].item()}")
            plt.imshow(image_original, cmap="gray")
            plt.axis("off")
            
            ax = plt.subplot(len(digits_to_modify), num_images_per_digit * 2, count + 2)
            image_modified = modified_dataset.data[idx].numpy()
            ax.set_title(f"Modified {modified_dataset.targets[idx].item()}")
            plt.imshow(image_modified, cmap="gray")
            plt.axis("off")
            
            count += 2
            if count >= len(digits_to_modify) * num_images_per_digit * 2:
                break
    plt.show()

# Plot the original and modified images
plot_images_comparison(original_trainset, trainset, digits_to_modify, num_images_per_digit=5)
# Out:
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████| 9912422/9912422 [00:01<00:00, 5243517.16it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████| 28881/28881 [00:00<00:00, 152014.37it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████| 1648877/1648877 [00:01<00:00, 1447477.85it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████| 4542/4542 [00:00<00:00, 2283688.42it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
def plot_images_comparison(original_dataset, modified_dataset, digits_to_modify, num_images_per_digit=5):
    plt.figure(figsize=(8, 4))
    count = 0
    rows_to_display = 2  # Only show two rows
    for idx in range(len(original_dataset.targets)):
        if original_dataset.targets[idx].item() in digits_to_modify:
            ax = plt.subplot(rows_to_display, num_images_per_digit * 2, count + 1)
            image_original = original_dataset.data[idx].numpy()
            ax.set_title(f"Original {original_dataset.targets[idx].item()}")
            plt.imshow(image_original, cmap="gray")
            plt.axis("off")
            
            ax = plt.subplot(rows_to_display, num_images_per_digit * 2, count + 2)
            image_modified = modified_dataset.data[idx].numpy()
            ax.set_title(f"Modified {modified_dataset.targets[idx].item()}")
            plt.imshow(image_modified, cmap="gray")
            plt.axis("off")
            
            count += 2
            if count >= rows_to_display * num_images_per_digit * 2:
            
                break

    plt.savefig("swapnoise.pdf", format="pdf", bbox_inches='tight')
    plt.show()

# Plot the original and modified images with only two rows
plot_images_comparison(original_trainset, trainset, digits_to_modify, num_images_per_digit=5)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate sample data
np.random.seed(42)
sample1 = np.random.normal(loc=0, scale=1, size=1000)  # Sample 1: normal distribution with mean=0, std=1
sample2 = np.random.normal(loc=0.5, scale=1.5, size=1000)  # Sample 2: normal distribution with mean=0.5, std=1.5

# Sort the samples
sample1_sorted = np.sort(sample1)
sample2_sorted = np.sort(sample2)

# Calculate CDFs
cdf1 = np.arange(1, len(sample1_sorted) + 1) / len(sample1_sorted)
cdf2 = np.arange(1, len(sample2_sorted) + 1) / len(sample2_sorted)

# Find the points where the CDFs differ the most
all_values = np.sort(np.concatenate([sample1_sorted, sample2_sorted]))
cdf1_interp = np.interp(all_values, sample1_sorted, cdf1)
cdf2_interp = np.interp(all_values, sample2_sorted, cdf2)
max_diff_index = np.argmax(np.abs(cdf1_interp - cdf2_interp))

# Plot the CDFs
plt.plot(sample1_sorted, cdf1, label='CDF of Sample 1')
plt.plot(sample2_sorted, cdf2, label='CDF of Sample 2')

# Highlight the maximum difference
plt.plot([all_values[max_diff_index], all_values[max_diff_index]], [cdf1_interp[max_diff_index], cdf2_interp[max_diff_index]],
         'ro--', label='Max Difference')

# Annotate the maximum difference
plt.text(all_values[max_diff_index], (cdf1_interp[max_diff_index] + cdf2_interp[max_diff_index]) / 2,
         f'Max Diff: {np.abs(cdf1_interp[max_diff_index] - cdf2_interp[max_diff_index]):.2f}', color='red')

plt.title('CDF Comparison and Maximum Difference')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(False)
plt.savefig("cdfcomparison.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %%
import numpy as np
import torch
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms

import shap


batch_size = 128
num_epochs = 2
device = torch.device("cpu")


class Net(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv_layers = nn.Sequential(
            nn.Conv2d(1, 10, kernel_size=5),
            nn.MaxPool2d(2),
            nn.ReLU(),
            nn.Conv2d(10, 20, kernel_size=5),
            nn.Dropout(),
            nn.MaxPool2d(2),
            nn.ReLU(),
        )
        self.fc_layers = nn.Sequential(
            nn.Linear(320, 50),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(50, 10),
            nn.Softmax(dim=1),
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = x.view(-1, 320)
        x = self.fc_layers(x)
        return x


def train(model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output.log(), target)
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print(
                f"Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)}"
                f" ({100.0 * batch_idx / len(train_loader):.0f}%)]"
                f"\tLoss: {loss.item():.6f}"
            )


def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output.log(), target).item()  # sum up batch loss
            pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    print(
        f"\nTest set: Average loss: {test_loss:.4f},"
        f" Accuracy: {correct}/{len(test_loader.dataset)}"
        f" ({100.0 * correct / len(test_loader.dataset):.0f}%)\n"
    )


train_loader = torch.utils.data.DataLoader(
    datasets.MNIST(
        "mnist_data",
        train=True,
        download=True,
        transform=transforms.Compose([transforms.ToTensor()]),
    ),
    batch_size=batch_size,
    shuffle=True,
)

test_loader = torch.utils.data.DataLoader(
    datasets.MNIST("mnist_data", train=False, transform=transforms.Compose([transforms.ToTensor()])),
    batch_size=batch_size,
    shuffle=True,
)

model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

for epoch in range(1, num_epochs + 1):
    train(model, device, train_loader, optimizer, epoch)
    test(model, device, test_loader)
# Out:
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████| 9912422/9912422 [00:00<00:00, 33051209.41it/s]
# Extracting mnist_data/MNIST/raw/train-images-idx3-ubyte.gz to mnist_data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████| 28881/28881 [00:00<00:00, 1053289.75it/s]
# Extracting mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz to mnist_data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████| 1648877/1648877 [00:00<00:00, 9110946.08it/s]
# Extracting mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz to mnist_data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████| 4542/4542 [00:00<00:00, 2031406.35it/s]
# Extracting mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to mnist_data/MNIST/raw
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.314661
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 2.263923
# ...

# %%
# since shuffle=True, this is a random sample of test data
batch = next(iter(test_loader))
images, _ = batch

background = images[:100]
test_images = images[100:103]

e = shap.DeepExplainer(model, background)
shap_values = e.shap_values(test_images)

# %%
shap_numpy = list(np.transpose(shap_values, (4, 0, 2, 3, 1)))
test_numpy = np.swapaxes(np.swapaxes(test_images.numpy(), 1, -1), 1, 2)

# %%
# plot the feature attributions
shap.image_plot(shap_numpy, -test_numpy)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.linear_model import LogisticRegression

# Set random seed for reproducibility
np.random.seed(42)

# Generate sample data
n_samples = 100
X = np.random.normal(0, 1, (n_samples, 2))
y = np.array([0 if x[0] + x[1] > 0 else 1 for x in X])

# Define a function to plot the decision boundary
def plot_decision_boundary(clf, X, y, title, ax):
    # Create a mesh grid for plotting
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                         np.arange(y_min, y_max, 0.02))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Plot the decision boundary
    ax.contourf(xx, yy, Z, alpha=0.3, cmap=ListedColormap(['blue', 'red']))
    ax.contour(xx, yy, Z, colors='k', levels=[0.5], linestyles='--')
    ax.scatter(X[y == 0, 0], X[y == 0, 1], color='blue', label='Class 0')
    ax.scatter(X[y == 1, 0], X[y == 1, 1], color='red', label='Class 1')
    ax.set_title(title)
    ax.legend()

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(8, 4))

# Type ɪ Drift (Change in P(X))
X_drift = X + np.random.normal(0.5, 0.5, X.shape)
clf_type1 = LogisticRegression()
clf_type1.fit(X_drift, y)
plot_decision_boundary(clf_type1, X_drift, y, 'Type ɪ Drift:\n Change in P(X)', axs[0])

# Type ɪɪ Drift (Change in P(y|X))
y_drift = np.array([0 if x[0] - x[1] > 0 else 1 for x in X])
clf_type2 = LogisticRegression()
clf_type2.fit(X, y_drift)
plot_decision_boundary(clf_type2, X, y_drift, 'Type ɪɪ Drift:\n Change in P(y|X)', axs[1])

# Type ɪɪɪ Drift (Change in both P(X) and P(y|X))
X_drift_combined = X + np.random.normal(0.5, 0.5, X.shape)
y_drift_combined = np.array([0 if x[0] - x[1] > 0 else 1 for x in X_drift_combined])
clf_type3 = LogisticRegression()
clf_type3.fit(X_drift_combined, y_drift_combined)
plot_decision_boundary(clf_type3, X_drift_combined, y_drift_combined, 'Type ɪɪɪ Drift:\n Change in P(X) and P(y|X)', axs[2])

# Display the plots
plt.tight_layout()
plt.savefig("drifttype.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.linear_model import LogisticRegression
from matplotlib.lines import Line2D

# Set random seed for reproducibility
np.random.seed(42)

# Generate sample data
n_samples = 100
X = np.random.normal(0, 1, (n_samples, 2))
y = np.array([0 if x[0] + x[1] > 0 else 1 for x in X])

# Define a function to plot the decision boundary and original vs. drifted data
def plot_decision_boundary(clf, X, y, X_orig, title, ax):
    # Create a mesh grid for plotting
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                         np.arange(y_min, y_max, 0.02))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Plot the decision boundary
    ax.contourf(xx, yy, Z, alpha=0.3, cmap=ListedColormap(['blue', 'red']))
    ax.contour(xx, yy, Z, colors='k', levels=[0.5], linestyles='--')

    # Plot original and drifted data points with distinct colors
    ax.scatter(X_orig[y == 0, 0], X_orig[y == 0, 1], color='green', label='Original Class 0', alpha=0.7)
    ax.scatter(X_orig[y == 1, 0], X_orig[y == 1, 1], color='orange', label='Original Class 1', alpha=0.7)
    ax.scatter(X[y == 0, 0], X[y == 0, 1], color='blue', label='Drifted Class 0')
    ax.scatter(X[y == 1, 0], X[y == 1, 1], color='red', label='Drifted Class 1')

    ax.set_title(title)

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(8, 4))

# Type ɪ Drift (Change in P(X))
X_drift = X + np.random.normal(0.5, 0.5, X.shape)
clf_type1 = LogisticRegression()
clf_type1.fit(X_drift, y)
plot_decision_boundary(clf_type1, X_drift, y, X, 'Type ɪ Drift:\n Change in P(X)', axs[0])

# Type ɪɪ Drift (Change in P(y|X))
y_drift = np.array([0 if x[0] - x[1] > 0 else 1 for x in X])
clf_type2 = LogisticRegression()
clf_type2.fit(X, y_drift)
plot_decision_boundary(clf_type2, X, y_drift, X, 'Type ɪɪ Drift:\n Change in P(y|X)', axs[1])

# Type ɪɪɪ Drift (Change in both P(X) and P(y|X))
X_drift_combined = X + np.random.normal(1.0, 0.8, X.shape)  # Increased drift for visibility
y_drift_combined = np.array([0 if x[0] - x[1] > 0 else 1 for x in X_drift_combined])
clf_type3 = LogisticRegression()
clf_type3.fit(X_drift_combined, y_drift_combined)
plot_decision_boundary(clf_type3, X_drift_combined, y_drift_combined, X, 'Type ɪɪɪ Drift:\n Change in P(X) and P(y|X)', axs[2])

# Create custom legend elements
legend_elements = [
    Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', label='Original Class 0', markersize=8),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='red', label='Original Class 1', markersize=8),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='green', label='Drifted Class 0', markersize=8),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='orange', label='Drifted Class 1', markersize=8)
]

# Add a legend below the subplots for class color indication
fig.legend(handles=legend_elements, loc='lower center', ncol=4, fontsize=10)

# Display the plots
plt.tight_layout()
plt.subplots_adjust(bottom=0.2)  # Adjust bottom to make space for the legend
plt.savefig("drifttype_combined_legend_bottom.pdf", format="pdf", bbox_inches='tight')
plt.show()
