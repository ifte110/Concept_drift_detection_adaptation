# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import shap
from scipy.stats import mannwhitneyu, ttest_ind, ks_2samp, ttest_ind_from_stats
import copy
import random
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split

# %%
# Set seed for reproducibility
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# Define the model architecture
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.fc1 = nn.Linear(64 * 5 * 5, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = torch.relu(self.conv2(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = x.view(-1, 64 * 5 * 5)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return torch.log_softmax(x, dim=1)

# Function to simulate client training with MNIST data
def client_training(train_loader, model, criterion, optimizer, num_epochs=1):
    model.train()
    for epoch in range(num_epochs):
        total_loss, correct, total = 0.0, 0.0, 0.0
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        accuracy = correct / total
        print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss}, Accuracy: {accuracy}")
        
    return total_loss
    

# Function to test the trained model on client data
def client_testing(test_loader, model):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total

# %%
# Federated learning process with multiple global model
def federated_learning(num_clients=5, num_local_epochs=5, num_global_epochs=5):
    
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
    trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)

    partition_size = len(trainset) // num_clients
    lengths = [partition_size] * num_clients
    datasets = random_split(trainset, lengths)
    
    client_indices = [dataset.indices for dataset in datasets]
    
    # clients that will experience concept drift
    # drift_clients = [2,6,9]
    # drift_clients = [12, 30, 31, 0, 32, 20, 53, 15, 5, 13, 42, 10, 55, 35, 41, 48, 58, 40, 38, 9, 21, 14, 24, 43, 6, 57, 37, 4, 46, 47, 50, 11, 34, 59, 2, 51, 1, 23, 28, 56, 19, 16]
    # drift_clients = [6, 50, 20, 5, 37, 42, 47, 13, 28, 15, 57, 10, 9, 31, 2, 41, 35, 1, 23, 58, 38, 46, 21, 48, 24, 43, 32, 4, 51, 56]

    # ground_truth_clients = [2, 6, 9, 10, 13, 15, 21, 23, 28, 35, 37, 41, 43, 47, 51, 56]
    drift_clients = [2, 6, 9, 28, 41, 56]

    # Initialize global model
    global_model = CNN().to(device)
    drastic_change_factor = 3  # Example threshold for drastic change
    previous_client_losses = [[] for _ in range(num_clients)]
    drastic_change_detected = [False] * num_clients
    sustained_high_loss = [False] * num_clients
    
    
    # Initialize detected drift clients
    detected_drift_clients = []
    fixed_detected_drift_clients = []
    global_model_sdrift = CNN().to(device)

    
    # Initialize counters for drift detection performance
    true_positives = 0
    true_negatives = 0
    false_positives = 0
    false_negatives = 0


    # Federated learning process
    for global_epoch in range(num_global_epochs):
        print(f"Global Epoch {global_epoch + 1}/{num_global_epochs}")

        # Swap classes if the current global epoch is more than half
        if global_epoch == 10: # (num_global_epochs // 2):
            print("Swapping classes 3 and 8 in the train dataset for selected clients")
            for client_id in drift_clients:
                indices = client_indices[client_id]
                for idx in indices:
                    if trainset.targets[idx] == 8:
                        trainset.targets[idx] = 3
                    elif trainset.targets[idx] == 3:
                        trainset.targets[idx] = 8
                        
                    elif trainset.targets[idx] == 5:
                        trainset.targets[idx] = 6
                    elif trainset.targets[idx] == 6:
                        trainset.targets[idx] = 5
                    
                    
        client_train_loaders = [torch.utils.data.DataLoader(torch.utils.data.Subset(trainset, indices), batch_size=32, shuffle=True) for indices in client_indices]
        client_test_loaders = [torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False) for _ in range(num_clients)]
        # Distribute the respective global models back to the clients
        client_models = []

        for i in range(num_clients):
            if i in fixed_detected_drift_clients:
                client_models.append(copy.deepcopy(global_model_sdrift))
            else:
                client_models.append(copy.deepcopy(global_model))


        # Perform local training and optimize drifted clients classifier
        client_losses = []
        
        for i, train_loader in enumerate(client_train_loaders):
            print(f"\tTraining Client {i + 1}/{num_clients}")
            criterion = nn.CrossEntropyLoss()
            
            # Change beta1 and beta2 if concept drift detected
#             if i in fixed_detected_drift_clients :
#                 print(f"initiating optimization for client {i+1}")
#                 optimizer = optim.Adam(client_models[i].parameters(), lr=0.001, betas=(0.8, 0.999))
#                 loss = client_training(train_loader, client_models[i], criterion, optimizer, num_local_epochs)
#             else:
            optimizer = optim.Adam(client_models[i].parameters(), lr=0.001)
            loss = client_training(train_loader, client_models[i], criterion, optimizer, num_local_epochs)
                
            client_losses.append(loss)
            
            
            # Update previous client losses
            previous_client_losses[i].append(loss)

           
        # concept drift detection and performance metrics
        if global_epoch >= 5:
            for i in range(num_clients):
                prev_loss = previous_client_losses[i][-2]
                if not drastic_change_detected[i]:
                    if client_losses[i] > (prev_loss * drastic_change_factor):
                        drastic_change_detected[i] = True
                else:
                    if client_losses[i] >= 4:
                        sustained_high_loss[i] = True
                    else:
                        drastic_change_detected[i] = False
                        sustained_high_loss[i] = False

            detected_drift_clients = [
                i for i, (drastic, sustained) in enumerate(zip(drastic_change_detected, sustained_high_loss))
                if drastic and sustained
            ]
            
            if detected_drift_clients and not fixed_detected_drift_clients:
                fixed_detected_drift_clients = detected_drift_clients
            

            for client_id in range(num_clients):
                ground_truth_drift = (client_id in drift_clients) and (global_epoch>=10)
                detected_drift = client_id in detected_drift_clients

                if detected_drift and ground_truth_drift:
                    true_positives += 1
                elif not detected_drift and not ground_truth_drift:
                    true_negatives += 1
                elif detected_drift and not ground_truth_drift:
                    false_positives += 1
                elif not detected_drift and ground_truth_drift:
                    false_negatives += 1

                if detected_drift == ground_truth_drift:
                    print(f"Global Epoch {global_epoch + 1}, Client {client_id + 1}: Drift detection is accurate.")
                else:
                    print(f"Global Epoch {global_epoch + 1}, Client {client_id + 1}: Drift detection is inaccurate.")
                    


                    
        # Aggregate client models into global model
        print("\tAggregating client models")
        drifted_client_models = [client_models[i] for i in fixed_detected_drift_clients]
        non_drifted_client_models = [client_models[i] for i in range(num_clients) if i not in fixed_detected_drift_clients]

        if drifted_client_models:
            global_model_sdrift = aggregate_models(global_model_sdrift, drifted_client_models)

        if non_drifted_client_models:
            global_model = aggregate_models(global_model, non_drifted_client_models)
            


    # Test models on each client
    accuracies = []
    for i, test_loader in enumerate(client_test_loaders):
        print(f"Testing Client {i + 1}/{num_clients}")
        accuracy = client_testing(test_loader, global_model)
        accuracies.append(accuracy)
        print(f"\tAccuracy for Client {i + 1}/{num_clients}: {accuracy}")
        
    # Calculate performance metrics of drift detection
    accuracy = (true_positives + true_negatives) / (true_positives + true_negatives + false_positives + false_negatives)
    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
    f1_score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

    print(f"Drift Detection metircs::: true_positives:{true_positives},true_negatives:{true_negatives},false_positives:{false_positives},false_negatives:{false_negatives}")
    print(f"Drift Detection Performance:\nAccuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1_score}")
        

    return accuracies

# Aggregation of models' weights using FedAvg
def aggregate_models(global_model, client_models):
    global_dict = global_model.state_dict()
    for k in global_dict.keys():
        global_dict[k] = torch.stack([client_model.state_dict()[k].float() for client_model in client_models], 0).mean(0)
    global_model.load_state_dict(global_dict)
    return global_model


# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Example usage
if __name__ == "__main__":
    client_accuracies=federated_learning(num_clients=60, num_local_epochs=1, num_global_epochs=40)
    print("Client Accuracies:", client_accuracies)
# Out:
# Global Epoch 1/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 50.54583424329758, Accuracy: 0.523
# 	Training Client 2/60
# Epoch 1/1, Loss: 55.41438293457031, Accuracy: 0.451
# 	Training Client 3/60
# Epoch 1/1, Loss: 49.73745948076248, Accuracy: 0.518
# 	Training Client 4/60
# Epoch 1/1, Loss: 56.56654405593872, Accuracy: 0.466
# 	Training Client 5/60
# Epoch 1/1, Loss: 53.078854858875275, Accuracy: 0.466
# 	Training Client 6/60
# Epoch 1/1, Loss: 53.16413390636444, Accuracy: 0.45
# 	Training Client 7/60
# Epoch 1/1, Loss: 54.305288553237915, Accuracy: 0.451
# 	Training Client 8/60
# Epoch 1/1, Loss: 56.43608808517456, Accuracy: 0.434
# 	Training Client 9/60
# Epoch 1/1, Loss: 51.65361696481705, Accuracy: 0.506
# 	Training Client 10/60
# Epoch 1/1, Loss: 52.701732099056244, Accuracy: 0.463
# 	Training Client 11/60
# Epoch 1/1, Loss: 52.24538081884384, Accuracy: 0.52
# 	Training Client 12/60
# Epoch 1/1, Loss: 58.476162135601044, Accuracy: 0.396
# 	Training Client 13/60
# Epoch 1/1, Loss: 51.254629135131836, Accuracy: 0.478
# 	Training Client 14/60
# Epoch 1/1, Loss: 50.71700972318649, Accuracy: 0.498
# 	Training Client 15/60
# Epoch 1/1, Loss: 53.38670068979263, Accuracy: 0.482
# 	Training Client 16/60
# Epoch 1/1, Loss: 51.2330567240715, Accuracy: 0.503
# 	Training Client 17/60
# Epoch 1/1, Loss: 53.95204704999924, Accuracy: 0.452
# 	Training Client 18/60
# Epoch 1/1, Loss: 50.86166477203369, Accuracy: 0.489
# 	Training Client 19/60
# Epoch 1/1, Loss: 54.52226620912552, Accuracy: 0.455
# 	Training Client 20/60
# Epoch 1/1, Loss: 49.29246485233307, Accuracy: 0.517
# 	Training Client 21/60
# Epoch 1/1, Loss: 53.523066997528076, Accuracy: 0.486
# 	Training Client 22/60
# Epoch 1/1, Loss: 51.38920909166336, Accuracy: 0.495
# 	Training Client 23/60
# Epoch 1/1, Loss: 51.10307538509369, Accuracy: 0.555
# 	Training Client 24/60
# Epoch 1/1, Loss: 53.689059138298035, Accuracy: 0.46
# 	Training Client 25/60
# Epoch 1/1, Loss: 54.395534217357635, Accuracy: 0.449
# 	Training Client 26/60
# Epoch 1/1, Loss: 53.63766744732857, Accuracy: 0.444
# 	Training Client 27/60
# Epoch 1/1, Loss: 52.56039023399353, Accuracy: 0.505
# 	Training Client 28/60
# Epoch 1/1, Loss: 54.596439361572266, Accuracy: 0.458
# 	Training Client 29/60
# Epoch 1/1, Loss: 56.279855728149414, Accuracy: 0.436
# 	Training Client 30/60
# Epoch 1/1, Loss: 53.68248224258423, Accuracy: 0.526
# 	Training Client 31/60
# Epoch 1/1, Loss: 55.98169434070587, Accuracy: 0.435
# 	Training Client 32/60
# Epoch 1/1, Loss: 56.9592399597168, Accuracy: 0.464
# 	Training Client 33/60
# Epoch 1/1, Loss: 53.99943643808365, Accuracy: 0.497
# 	Training Client 34/60
# Epoch 1/1, Loss: 54.87376856803894, Accuracy: 0.44
# 	Training Client 35/60
# Epoch 1/1, Loss: 52.39343225955963, Accuracy: 0.501
# 	Training Client 36/60
# Epoch 1/1, Loss: 53.61659801006317, Accuracy: 0.466
# 	Training Client 37/60
# Epoch 1/1, Loss: 51.66790759563446, Accuracy: 0.509
# 	Training Client 38/60
# Epoch 1/1, Loss: 53.669275879859924, Accuracy: 0.507
# 	Training Client 39/60
# Epoch 1/1, Loss: 52.173470079898834, Accuracy: 0.501
# 	Training Client 40/60
# Epoch 1/1, Loss: 49.293174028396606, Accuracy: 0.542
# 	Training Client 41/60
# Epoch 1/1, Loss: 52.98848348855972, Accuracy: 0.498
# 	Training Client 42/60
# Epoch 1/1, Loss: 56.90500605106354, Accuracy: 0.453
# 	Training Client 43/60
# Epoch 1/1, Loss: 52.93321055173874, Accuracy: 0.488
# 	Training Client 44/60
# Epoch 1/1, Loss: 53.04268151521683, Accuracy: 0.467
# 	Training Client 45/60
# Epoch 1/1, Loss: 51.02990931272507, Accuracy: 0.476
# 	Training Client 46/60
# Epoch 1/1, Loss: 54.10770308971405, Accuracy: 0.462
# 	Training Client 47/60
# Epoch 1/1, Loss: 55.86410665512085, Accuracy: 0.434
# 	Training Client 48/60
# Epoch 1/1, Loss: 53.145379066467285, Accuracy: 0.499
# 	Training Client 49/60
# Epoch 1/1, Loss: 57.12174612283707, Accuracy: 0.434
# 	Training Client 50/60
# Epoch 1/1, Loss: 53.3612676858902, Accuracy: 0.463
# 	Training Client 51/60
# Epoch 1/1, Loss: 54.82150048017502, Accuracy: 0.483
# 	Training Client 52/60
# Epoch 1/1, Loss: 54.298646450042725, Accuracy: 0.448
# 	Training Client 53/60
# Epoch 1/1, Loss: 54.53812795877457, Accuracy: 0.464
# 	Training Client 54/60
# Epoch 1/1, Loss: 51.65592294931412, Accuracy: 0.476
# 	Training Client 55/60
# Epoch 1/1, Loss: 52.06686043739319, Accuracy: 0.511
# 	Training Client 56/60
# Epoch 1/1, Loss: 58.47491776943207, Accuracy: 0.435
# 	Training Client 57/60
# Epoch 1/1, Loss: 53.10760897397995, Accuracy: 0.513
# 	Training Client 58/60
# Epoch 1/1, Loss: 54.16420352458954, Accuracy: 0.474
# 	Training Client 59/60
# Epoch 1/1, Loss: 53.504952788352966, Accuracy: 0.49
# 	Training Client 60/60
# Epoch 1/1, Loss: 51.631367206573486, Accuracy: 0.498
# 	Aggregating client models
# Global Epoch 2/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 21.182131379842758, Accuracy: 0.807
# 	Training Client 2/60
# Epoch 1/1, Loss: 21.893886506557465, Accuracy: 0.787
# 	Training Client 3/60
# Epoch 1/1, Loss: 19.083442866802216, Accuracy: 0.813
# 	Training Client 4/60
# Epoch 1/1, Loss: 19.357324056327343, Accuracy: 0.804
# 	Training Client 5/60
# Epoch 1/1, Loss: 20.69620807468891, Accuracy: 0.791
# 	Training Client 6/60
# Epoch 1/1, Loss: 20.622425466775894, Accuracy: 0.802
# 	Training Client 7/60
# Epoch 1/1, Loss: 21.16495841741562, Accuracy: 0.792
# 	Training Client 8/60
# Epoch 1/1, Loss: 18.6280108243227, Accuracy: 0.813
# 	Training Client 9/60
# Epoch 1/1, Loss: 19.610547959804535, Accuracy: 0.817
# 	Training Client 10/60
# Epoch 1/1, Loss: 17.839858129620552, Accuracy: 0.821
# 	Training Client 11/60
# Epoch 1/1, Loss: 17.84968540072441, Accuracy: 0.827
# 	Training Client 12/60
# Epoch 1/1, Loss: 19.49981364607811, Accuracy: 0.815
# 	Training Client 13/60
# Epoch 1/1, Loss: 20.333437114953995, Accuracy: 0.806
# 	Training Client 14/60
# Epoch 1/1, Loss: 19.21718692779541, Accuracy: 0.813
# 	Training Client 15/60
# Epoch 1/1, Loss: 18.39130076766014, Accuracy: 0.827
# 	Training Client 16/60
# Epoch 1/1, Loss: 20.020797103643417, Accuracy: 0.81
# 	Training Client 17/60
# Epoch 1/1, Loss: 20.68813544511795, Accuracy: 0.804
# 	Training Client 18/60
# Epoch 1/1, Loss: 21.602251440286636, Accuracy: 0.782
# 	Training Client 19/60
# Epoch 1/1, Loss: 20.473404586315155, Accuracy: 0.783
# 	Training Client 20/60
# Epoch 1/1, Loss: 16.333444997668266, Accuracy: 0.852
# 	Training Client 21/60
# Epoch 1/1, Loss: 19.80624207854271, Accuracy: 0.811
# 	Training Client 22/60
# Epoch 1/1, Loss: 20.612820774316788, Accuracy: 0.808
# 	Training Client 23/60
# Epoch 1/1, Loss: 19.436357229948044, Accuracy: 0.826
# 	Training Client 24/60
# Epoch 1/1, Loss: 17.77760736644268, Accuracy: 0.835
# 	Training Client 25/60
# Epoch 1/1, Loss: 20.787269949913025, Accuracy: 0.788
# 	Training Client 26/60
# Epoch 1/1, Loss: 21.220472112298012, Accuracy: 0.786
# 	Training Client 27/60
# Epoch 1/1, Loss: 20.85556636750698, Accuracy: 0.78
# 	Training Client 28/60
# Epoch 1/1, Loss: 19.680362716317177, Accuracy: 0.81
# 	Training Client 29/60
# Epoch 1/1, Loss: 20.43026491254568, Accuracy: 0.784
# 	Training Client 30/60
# Epoch 1/1, Loss: 18.570386692881584, Accuracy: 0.833
# 	Training Client 31/60
# Epoch 1/1, Loss: 18.090332508087158, Accuracy: 0.831
# 	Training Client 32/60
# Epoch 1/1, Loss: 19.694734543561935, Accuracy: 0.801
# 	Training Client 33/60
# Epoch 1/1, Loss: 19.677450850605965, Accuracy: 0.822
# 	Training Client 34/60
# Epoch 1/1, Loss: 19.748037949204445, Accuracy: 0.817
# 	Training Client 35/60
# Epoch 1/1, Loss: 20.26008638739586, Accuracy: 0.809
# 	Training Client 36/60
# Epoch 1/1, Loss: 20.931862972676754, Accuracy: 0.791
# 	Training Client 37/60
# Epoch 1/1, Loss: 19.795003980398178, Accuracy: 0.817
# 	Training Client 38/60
# Epoch 1/1, Loss: 20.00121535360813, Accuracy: 0.813
# 	Training Client 39/60
# Epoch 1/1, Loss: 19.392907097935677, Accuracy: 0.816
# 	Training Client 40/60
# Epoch 1/1, Loss: 18.925616800785065, Accuracy: 0.804
# 	Training Client 41/60
# Epoch 1/1, Loss: 19.18833838403225, Accuracy: 0.833
# 	Training Client 42/60
# Epoch 1/1, Loss: 20.795887768268585, Accuracy: 0.809
# 	Training Client 43/60
# Epoch 1/1, Loss: 20.579911798238754, Accuracy: 0.814
# 	Training Client 44/60
# Epoch 1/1, Loss: 21.83865863084793, Accuracy: 0.782
# 	Training Client 45/60
# Epoch 1/1, Loss: 17.218024522066116, Accuracy: 0.851
# 	Training Client 46/60
# Epoch 1/1, Loss: 19.272482320666313, Accuracy: 0.822
# 	Training Client 47/60
# Epoch 1/1, Loss: 20.721008002758026, Accuracy: 0.79
# 	Training Client 48/60
# Epoch 1/1, Loss: 18.60848942399025, Accuracy: 0.821
# 	Training Client 49/60
# Epoch 1/1, Loss: 19.397340714931488, Accuracy: 0.811
# 	Training Client 50/60
# Epoch 1/1, Loss: 20.90944403409958, Accuracy: 0.799
# 	Training Client 51/60
# Epoch 1/1, Loss: 17.081171199679375, Accuracy: 0.843
# 	Training Client 52/60
# Epoch 1/1, Loss: 20.009763568639755, Accuracy: 0.81
# 	Training Client 53/60
# Epoch 1/1, Loss: 21.36844351887703, Accuracy: 0.8
# 	Training Client 54/60
# Epoch 1/1, Loss: 18.399905785918236, Accuracy: 0.824
# 	Training Client 55/60
# Epoch 1/1, Loss: 20.27735608816147, Accuracy: 0.795
# 	Training Client 56/60
# Epoch 1/1, Loss: 21.408012956380844, Accuracy: 0.79
# 	Training Client 57/60
# Epoch 1/1, Loss: 19.3194627314806, Accuracy: 0.821
# 	Training Client 58/60
# Epoch 1/1, Loss: 18.764446303248405, Accuracy: 0.819
# 	Training Client 59/60
# Epoch 1/1, Loss: 21.54051712155342, Accuracy: 0.797
# 	Training Client 60/60
# Epoch 1/1, Loss: 19.201147690415382, Accuracy: 0.796
# 	Aggregating client models
# Global Epoch 3/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 12.761242911219597, Accuracy: 0.897
# 	Training Client 2/60
# Epoch 1/1, Loss: 11.487784788012505, Accuracy: 0.886
# 	Training Client 3/60
# Epoch 1/1, Loss: 10.89658785611391, Accuracy: 0.898
# 	Training Client 4/60
# Epoch 1/1, Loss: 11.737873531877995, Accuracy: 0.888
# 	Training Client 5/60
# Epoch 1/1, Loss: 11.271233353763819, Accuracy: 0.891
# 	Training Client 6/60
# Epoch 1/1, Loss: 11.082404270768166, Accuracy: 0.888
# 	Training Client 7/60
# Epoch 1/1, Loss: 12.097267046570778, Accuracy: 0.888
# 	Training Client 8/60
# Epoch 1/1, Loss: 10.854189798235893, Accuracy: 0.889
# 	Training Client 9/60
# Epoch 1/1, Loss: 12.588041260838509, Accuracy: 0.882
# 	Training Client 10/60
# Epoch 1/1, Loss: 11.21679838001728, Accuracy: 0.896
# 	Training Client 11/60
# Epoch 1/1, Loss: 10.964009068906307, Accuracy: 0.895
# 	Training Client 12/60
# Epoch 1/1, Loss: 12.90114338696003, Accuracy: 0.882
# 	Training Client 13/60
# Epoch 1/1, Loss: 11.690066538751125, Accuracy: 0.898
# 	Training Client 14/60
# Epoch 1/1, Loss: 11.07634238153696, Accuracy: 0.89
# 	Training Client 15/60
# Epoch 1/1, Loss: 11.081132888793945, Accuracy: 0.891
# 	Training Client 16/60
# Epoch 1/1, Loss: 11.657689675688744, Accuracy: 0.892
# 	Training Client 17/60
# Epoch 1/1, Loss: 13.140876725316048, Accuracy: 0.876
# 	Training Client 18/60
# Epoch 1/1, Loss: 11.2937518581748, Accuracy: 0.885
# 	Training Client 19/60
# Epoch 1/1, Loss: 10.978984288871288, Accuracy: 0.897
# 	Training Client 20/60
# Epoch 1/1, Loss: 10.837792739272118, Accuracy: 0.897
# 	Training Client 21/60
# Epoch 1/1, Loss: 13.486471101641655, Accuracy: 0.883
# 	Training Client 22/60
# Epoch 1/1, Loss: 11.277029797434807, Accuracy: 0.903
# 	Training Client 23/60
# Epoch 1/1, Loss: 11.648987844586372, Accuracy: 0.894
# 	Training Client 24/60
# Epoch 1/1, Loss: 9.865708597004414, Accuracy: 0.906
# 	Training Client 25/60
# Epoch 1/1, Loss: 12.27270957827568, Accuracy: 0.872
# 	Training Client 26/60
# Epoch 1/1, Loss: 13.313818126916885, Accuracy: 0.881
# 	Training Client 27/60
# Epoch 1/1, Loss: 12.075802609324455, Accuracy: 0.883
# 	Training Client 28/60
# Epoch 1/1, Loss: 12.754258744418621, Accuracy: 0.88
# 	Training Client 29/60
# Epoch 1/1, Loss: 11.884996134787798, Accuracy: 0.878
# 	Training Client 30/60
# Epoch 1/1, Loss: 9.899344369769096, Accuracy: 0.904
# 	Training Client 31/60
# Epoch 1/1, Loss: 9.817446894943714, Accuracy: 0.901
# 	Training Client 32/60
# Epoch 1/1, Loss: 11.950663015246391, Accuracy: 0.889
# 	Training Client 33/60
# Epoch 1/1, Loss: 10.943832900375128, Accuracy: 0.892
# 	Training Client 34/60
# Epoch 1/1, Loss: 11.118822485208511, Accuracy: 0.895
# 	Training Client 35/60
# Epoch 1/1, Loss: 12.582005098462105, Accuracy: 0.875
# 	Training Client 36/60
# Epoch 1/1, Loss: 12.88644489645958, Accuracy: 0.874
# 	Training Client 37/60
# Epoch 1/1, Loss: 10.898119986057281, Accuracy: 0.898
# 	Training Client 38/60
# Epoch 1/1, Loss: 12.628747582435608, Accuracy: 0.887
# 	Training Client 39/60
# Epoch 1/1, Loss: 11.973081670701504, Accuracy: 0.892
# 	Training Client 40/60
# Epoch 1/1, Loss: 10.401846125721931, Accuracy: 0.893
# 	Training Client 41/60
# Epoch 1/1, Loss: 10.673483483493328, Accuracy: 0.893
# 	Training Client 42/60
# Epoch 1/1, Loss: 13.083454824984074, Accuracy: 0.898
# 	Training Client 43/60
# Epoch 1/1, Loss: 12.006597630679607, Accuracy: 0.9
# 	Training Client 44/60
# Epoch 1/1, Loss: 13.472954466938972, Accuracy: 0.861
# 	Training Client 45/60
# Epoch 1/1, Loss: 9.414653047919273, Accuracy: 0.906
# 	Training Client 46/60
# Epoch 1/1, Loss: 10.483238965272903, Accuracy: 0.897
# 	Training Client 47/60
# Epoch 1/1, Loss: 11.013727344572544, Accuracy: 0.896
# 	Training Client 48/60
# Epoch 1/1, Loss: 10.142514050006866, Accuracy: 0.903
# 	Training Client 49/60
# Epoch 1/1, Loss: 11.605983339250088, Accuracy: 0.876
# 	Training Client 50/60
# Epoch 1/1, Loss: 11.808638766407967, Accuracy: 0.889
# 	Training Client 51/60
# Epoch 1/1, Loss: 10.56153005361557, Accuracy: 0.898
# 	Training Client 52/60
# Epoch 1/1, Loss: 12.23336011171341, Accuracy: 0.895
# 	Training Client 53/60
# Epoch 1/1, Loss: 13.617910780012608, Accuracy: 0.864
# 	Training Client 54/60
# Epoch 1/1, Loss: 13.304872244596481, Accuracy: 0.876
# 	Training Client 55/60
# Epoch 1/1, Loss: 13.092291545122862, Accuracy: 0.883
# 	Training Client 56/60
# Epoch 1/1, Loss: 11.60768973082304, Accuracy: 0.889
# 	Training Client 57/60
# Epoch 1/1, Loss: 10.349342614412308, Accuracy: 0.899
# 	Training Client 58/60
# Epoch 1/1, Loss: 11.811695754528046, Accuracy: 0.885
# 	Training Client 59/60
# Epoch 1/1, Loss: 12.257542431354523, Accuracy: 0.88
# 	Training Client 60/60
# Epoch 1/1, Loss: 9.261538121849298, Accuracy: 0.905
# 	Aggregating client models
# Global Epoch 4/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 9.28609411418438, Accuracy: 0.916
# 	Training Client 2/60
# Epoch 1/1, Loss: 7.947814900428057, Accuracy: 0.921
# 	Training Client 3/60
# Epoch 1/1, Loss: 7.423947937786579, Accuracy: 0.919
# 	Training Client 4/60
# Epoch 1/1, Loss: 7.195970457047224, Accuracy: 0.93
# 	Training Client 5/60
# Epoch 1/1, Loss: 8.036719135940075, Accuracy: 0.926
# 	Training Client 6/60
# Epoch 1/1, Loss: 8.553474396467209, Accuracy: 0.906
# 	Training Client 7/60
# Epoch 1/1, Loss: 7.696192869916558, Accuracy: 0.919
# 	Training Client 8/60
# Epoch 1/1, Loss: 9.209354318678379, Accuracy: 0.925
# 	Training Client 9/60
# Epoch 1/1, Loss: 8.841301769018173, Accuracy: 0.91
# 	Training Client 10/60
# Epoch 1/1, Loss: 7.343439169228077, Accuracy: 0.93
# 	Training Client 11/60
# Epoch 1/1, Loss: 8.519582465291023, Accuracy: 0.924
# 	Training Client 12/60
# Epoch 1/1, Loss: 7.809269599616528, Accuracy: 0.93
# 	Training Client 13/60
# Epoch 1/1, Loss: 7.882198417559266, Accuracy: 0.923
# 	Training Client 14/60
# Epoch 1/1, Loss: 7.4895647354424, Accuracy: 0.923
# 	Training Client 15/60
# Epoch 1/1, Loss: 9.089398205280304, Accuracy: 0.912
# 	Training Client 16/60
# Epoch 1/1, Loss: 8.034659706056118, Accuracy: 0.93
# 	Training Client 17/60
# Epoch 1/1, Loss: 8.97249710559845, Accuracy: 0.912
# 	Training Client 18/60
# Epoch 1/1, Loss: 8.062541648745537, Accuracy: 0.92
# 	Training Client 19/60
# Epoch 1/1, Loss: 7.911726199090481, Accuracy: 0.922
# 	Training Client 20/60
# Epoch 1/1, Loss: 6.659967817366123, Accuracy: 0.938
# 	Training Client 21/60
# Epoch 1/1, Loss: 9.05867494083941, Accuracy: 0.902
# 	Training Client 22/60
# Epoch 1/1, Loss: 8.693076878786087, Accuracy: 0.918
# 	Training Client 23/60
# Epoch 1/1, Loss: 8.089549139142036, Accuracy: 0.927
# 	Training Client 24/60
# Epoch 1/1, Loss: 7.572885110974312, Accuracy: 0.927
# 	Training Client 25/60
# Epoch 1/1, Loss: 9.860892839729786, Accuracy: 0.897
# 	Training Client 26/60
# Epoch 1/1, Loss: 9.576181784272194, Accuracy: 0.904
# 	Training Client 27/60
# Epoch 1/1, Loss: 9.139866165816784, Accuracy: 0.919
# 	Training Client 28/60
# Epoch 1/1, Loss: 8.791104473173618, Accuracy: 0.921
# 	Training Client 29/60
# Epoch 1/1, Loss: 8.13400874659419, Accuracy: 0.913
# 	Training Client 30/60
# Epoch 1/1, Loss: 7.826218284666538, Accuracy: 0.93
# 	Training Client 31/60
# Epoch 1/1, Loss: 6.2770813489332795, Accuracy: 0.928
# 	Training Client 32/60
# Epoch 1/1, Loss: 10.06315578520298, Accuracy: 0.909
# 	Training Client 33/60
# Epoch 1/1, Loss: 7.844800025224686, Accuracy: 0.93
# 	Training Client 34/60
# Epoch 1/1, Loss: 8.277355447411537, Accuracy: 0.913
# 	Training Client 35/60
# Epoch 1/1, Loss: 9.750112779438496, Accuracy: 0.902
# 	Training Client 36/60
# Epoch 1/1, Loss: 9.559669218957424, Accuracy: 0.912
# 	Training Client 37/60
# Epoch 1/1, Loss: 7.822311885654926, Accuracy: 0.929
# 	Training Client 38/60
# Epoch 1/1, Loss: 8.38611501827836, Accuracy: 0.929
# 	Training Client 39/60
# Epoch 1/1, Loss: 8.288219574838877, Accuracy: 0.926
# 	Training Client 40/60
# Epoch 1/1, Loss: 7.367884915322065, Accuracy: 0.934
# 	Training Client 41/60
# Epoch 1/1, Loss: 8.174731373786926, Accuracy: 0.915
# 	Training Client 42/60
# Epoch 1/1, Loss: 10.053292036056519, Accuracy: 0.906
# 	Training Client 43/60
# Epoch 1/1, Loss: 8.716679785400629, Accuracy: 0.928
# 	Training Client 44/60
# Epoch 1/1, Loss: 10.084692403674126, Accuracy: 0.896
# 	Training Client 45/60
# Epoch 1/1, Loss: 6.6391198374331, Accuracy: 0.936
# 	Training Client 46/60
# Epoch 1/1, Loss: 8.760664597153664, Accuracy: 0.927
# 	Training Client 47/60
# Epoch 1/1, Loss: 8.825787752866745, Accuracy: 0.921
# 	Training Client 48/60
# Epoch 1/1, Loss: 7.564565535634756, Accuracy: 0.926
# 	Training Client 49/60
# Epoch 1/1, Loss: 7.950518906116486, Accuracy: 0.914
# 	Training Client 50/60
# Epoch 1/1, Loss: 8.708599962294102, Accuracy: 0.926
# 	Training Client 51/60
# Epoch 1/1, Loss: 8.001490417867899, Accuracy: 0.93
# 	Training Client 52/60
# Epoch 1/1, Loss: 8.446072332561016, Accuracy: 0.922
# 	Training Client 53/60
# Epoch 1/1, Loss: 9.285326831042767, Accuracy: 0.92
# 	Training Client 54/60
# Epoch 1/1, Loss: 8.997427500784397, Accuracy: 0.917
# 	Training Client 55/60
# Epoch 1/1, Loss: 8.869686529040337, Accuracy: 0.911
# 	Training Client 56/60
# Epoch 1/1, Loss: 9.009014829993248, Accuracy: 0.92
# 	Training Client 57/60
# Epoch 1/1, Loss: 7.669505678117275, Accuracy: 0.934
# 	Training Client 58/60
# Epoch 1/1, Loss: 7.98109633103013, Accuracy: 0.929
# 	Training Client 59/60
# Epoch 1/1, Loss: 9.6183403134346, Accuracy: 0.915
# 	Training Client 60/60
# Epoch 1/1, Loss: 6.688281483948231, Accuracy: 0.922
# 	Aggregating client models
# Global Epoch 5/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 7.5875471122562885, Accuracy: 0.915
# 	Training Client 2/60
# Epoch 1/1, Loss: 6.713443271815777, Accuracy: 0.935
# 	Training Client 3/60
# Epoch 1/1, Loss: 6.123489014804363, Accuracy: 0.941
# 	Training Client 4/60
# Epoch 1/1, Loss: 5.953039828687906, Accuracy: 0.943
# 	Training Client 5/60
# Epoch 1/1, Loss: 7.063655778765678, Accuracy: 0.927
# 	Training Client 6/60
# Epoch 1/1, Loss: 7.034136399626732, Accuracy: 0.931
# 	Training Client 7/60
# Epoch 1/1, Loss: 6.241005973890424, Accuracy: 0.933
# 	Training Client 8/60
# Epoch 1/1, Loss: 6.813528656959534, Accuracy: 0.935
# 	Training Client 9/60
# Epoch 1/1, Loss: 7.155256886035204, Accuracy: 0.93
# 	Training Client 10/60
# Epoch 1/1, Loss: 6.602388806641102, Accuracy: 0.936
# 	Training Client 11/60
# Epoch 1/1, Loss: 7.062277160584927, Accuracy: 0.939
# 	Training Client 12/60
# Epoch 1/1, Loss: 6.276929289102554, Accuracy: 0.948
# 	Training Client 13/60
# Epoch 1/1, Loss: 6.47811846062541, Accuracy: 0.938
# 	Training Client 14/60
# Epoch 1/1, Loss: 6.269506100565195, Accuracy: 0.941
# 	Training Client 15/60
# Epoch 1/1, Loss: 5.930569554679096, Accuracy: 0.942
# 	Training Client 16/60
# Epoch 1/1, Loss: 6.952025879174471, Accuracy: 0.937
# 	Training Client 17/60
# Epoch 1/1, Loss: 7.198877051472664, Accuracy: 0.947
# 	Training Client 18/60
# Epoch 1/1, Loss: 6.402336001396179, Accuracy: 0.933
# 	Training Client 19/60
# Epoch 1/1, Loss: 6.622033227235079, Accuracy: 0.94
# 	Training Client 20/60
# Epoch 1/1, Loss: 5.326767509337515, Accuracy: 0.949
# 	Training Client 21/60
# Epoch 1/1, Loss: 7.775201421231031, Accuracy: 0.923
# 	Training Client 22/60
# Epoch 1/1, Loss: 7.55980559065938, Accuracy: 0.939
# 	Training Client 23/60
# Epoch 1/1, Loss: 6.68287349306047, Accuracy: 0.941
# 	Training Client 24/60
# Epoch 1/1, Loss: 6.546743232756853, Accuracy: 0.944
# 	Training Client 25/60
# Epoch 1/1, Loss: 7.691682334989309, Accuracy: 0.926
# 	Training Client 26/60
# Epoch 1/1, Loss: 7.8855010233819485, Accuracy: 0.928
# 	Training Client 27/60
# Epoch 1/1, Loss: 7.816949907690287, Accuracy: 0.935
# 	Training Client 28/60
# Epoch 1/1, Loss: 8.091010227799416, Accuracy: 0.919
# 	Training Client 29/60
# Epoch 1/1, Loss: 6.732742367312312, Accuracy: 0.934
# 	Training Client 30/60
# Epoch 1/1, Loss: 6.614686265587807, Accuracy: 0.938
# 	Training Client 31/60
# Epoch 1/1, Loss: 5.669079527258873, Accuracy: 0.942
# 	Training Client 32/60
# Epoch 1/1, Loss: 7.722145017236471, Accuracy: 0.929
# 	Training Client 33/60
# Epoch 1/1, Loss: 6.368956472724676, Accuracy: 0.936
# 	Training Client 34/60
# Epoch 1/1, Loss: 6.313985947519541, Accuracy: 0.936
# 	Training Client 35/60
# Epoch 1/1, Loss: 6.541679538786411, Accuracy: 0.939
# 	Training Client 36/60
# Epoch 1/1, Loss: 8.217122845351696, Accuracy: 0.929
# 	Training Client 37/60
# Epoch 1/1, Loss: 5.988066807389259, Accuracy: 0.941
# 	Training Client 38/60
# Epoch 1/1, Loss: 6.319928668439388, Accuracy: 0.943
# 	Training Client 39/60
# Epoch 1/1, Loss: 6.712207289412618, Accuracy: 0.944
# 	Training Client 40/60
# Epoch 1/1, Loss: 6.167172541841865, Accuracy: 0.943
# 	Training Client 41/60
# Epoch 1/1, Loss: 5.816228896379471, Accuracy: 0.943
# 	Training Client 42/60
# Epoch 1/1, Loss: 7.291743401437998, Accuracy: 0.938
# 	Training Client 43/60
# Epoch 1/1, Loss: 7.826387453824282, Accuracy: 0.931
# 	Training Client 44/60
# Epoch 1/1, Loss: 8.079710885882378, Accuracy: 0.918
# 	Training Client 45/60
# Epoch 1/1, Loss: 4.835720576345921, Accuracy: 0.953
# 	Training Client 46/60
# Epoch 1/1, Loss: 6.650849113240838, Accuracy: 0.94
# 	Training Client 47/60
# Epoch 1/1, Loss: 6.528796654194593, Accuracy: 0.932
# 	Training Client 48/60
# Epoch 1/1, Loss: 5.746004547923803, Accuracy: 0.944
# 	Training Client 49/60
# Epoch 1/1, Loss: 6.545512869954109, Accuracy: 0.936
# 	Training Client 50/60
# Epoch 1/1, Loss: 8.35057009011507, Accuracy: 0.926
# 	Training Client 51/60
# Epoch 1/1, Loss: 7.167294332291931, Accuracy: 0.926
# 	Training Client 52/60
# Epoch 1/1, Loss: 6.805652257055044, Accuracy: 0.931
# 	Training Client 53/60
# Epoch 1/1, Loss: 7.012927882373333, Accuracy: 0.939
# 	Training Client 54/60
# Epoch 1/1, Loss: 8.105932805687189, Accuracy: 0.93
# 	Training Client 55/60
# Epoch 1/1, Loss: 6.87759830057621, Accuracy: 0.93
# 	Training Client 56/60
# Epoch 1/1, Loss: 7.342272236943245, Accuracy: 0.933
# 	Training Client 57/60
# Epoch 1/1, Loss: 6.390384549275041, Accuracy: 0.934
# 	Training Client 58/60
# Epoch 1/1, Loss: 6.543583679944277, Accuracy: 0.937
# 	Training Client 59/60
# Epoch 1/1, Loss: 7.6597541607916355, Accuracy: 0.925
# 	Training Client 60/60
# Epoch 1/1, Loss: 4.847973497584462, Accuracy: 0.947
# 	Aggregating client models
# Global Epoch 6/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 6.056651148945093, Accuracy: 0.946
# 	Training Client 2/60
# Epoch 1/1, Loss: 7.402528624981642, Accuracy: 0.943
# 	Training Client 3/60
# Epoch 1/1, Loss: 4.887465972453356, Accuracy: 0.958
# 	Training Client 4/60
# Epoch 1/1, Loss: 5.393591899424791, Accuracy: 0.949
# 	Training Client 5/60
# Epoch 1/1, Loss: 5.637334566563368, Accuracy: 0.945
# 	Training Client 6/60
# Epoch 1/1, Loss: 6.529099582694471, Accuracy: 0.933
# 	Training Client 7/60
# Epoch 1/1, Loss: 4.947950331494212, Accuracy: 0.952
# 	Training Client 8/60
# Epoch 1/1, Loss: 6.281777087599039, Accuracy: 0.931
# 	Training Client 9/60
# Epoch 1/1, Loss: 6.178397571668029, Accuracy: 0.936
# 	Training Client 10/60
# Epoch 1/1, Loss: 4.528883257880807, Accuracy: 0.956
# 	Training Client 11/60
# Epoch 1/1, Loss: 5.910269118845463, Accuracy: 0.95
# 	Training Client 12/60
# Epoch 1/1, Loss: 4.774961325339973, Accuracy: 0.956
# 	Training Client 13/60
# Epoch 1/1, Loss: 5.626134727150202, Accuracy: 0.95
# 	Training Client 14/60
# Epoch 1/1, Loss: 5.3324203453958035, Accuracy: 0.958
# 	Training Client 15/60
# Epoch 1/1, Loss: 4.83169115241617, Accuracy: 0.951
# 	Training Client 16/60
# Epoch 1/1, Loss: 6.247507352381945, Accuracy: 0.945
# 	Training Client 17/60
# Epoch 1/1, Loss: 6.698069293051958, Accuracy: 0.939
# 	Training Client 18/60
# Epoch 1/1, Loss: 5.865532616153359, Accuracy: 0.94
# 	Training Client 19/60
# Epoch 1/1, Loss: 5.330645842477679, Accuracy: 0.951
# 	Training Client 20/60
# Epoch 1/1, Loss: 4.789221445098519, Accuracy: 0.957
# 	Training Client 21/60
# Epoch 1/1, Loss: 7.342408148571849, Accuracy: 0.93
# 	Training Client 22/60
# Epoch 1/1, Loss: 5.913649350404739, Accuracy: 0.945
# 	Training Client 23/60
# Epoch 1/1, Loss: 6.488561891019344, Accuracy: 0.944
# 	Training Client 24/60
# Epoch 1/1, Loss: 5.166799116879702, Accuracy: 0.951
# 	Training Client 25/60
# Epoch 1/1, Loss: 6.802308566868305, Accuracy: 0.933
# 	Training Client 26/60
# Epoch 1/1, Loss: 6.800799857825041, Accuracy: 0.942
# 	Training Client 27/60
# Epoch 1/1, Loss: 6.1482858173549175, Accuracy: 0.952
# 	Training Client 28/60
# Epoch 1/1, Loss: 6.130956057459116, Accuracy: 0.936
# 	Training Client 29/60
# Epoch 1/1, Loss: 4.971425914205611, Accuracy: 0.955
# 	Training Client 30/60
# Epoch 1/1, Loss: 5.53765007853508, Accuracy: 0.945
# 	Training Client 31/60
# Epoch 1/1, Loss: 4.275135334581137, Accuracy: 0.958
# 	Training Client 32/60
# Epoch 1/1, Loss: 7.297917369753122, Accuracy: 0.926
# 	Training Client 33/60
# Epoch 1/1, Loss: 5.76875757239759, Accuracy: 0.943
# 	Training Client 34/60
# Epoch 1/1, Loss: 5.813129022717476, Accuracy: 0.948
# 	Training Client 35/60
# Epoch 1/1, Loss: 6.447870193049312, Accuracy: 0.93
# 	Training Client 36/60
# Epoch 1/1, Loss: 5.933210354298353, Accuracy: 0.938
# 	Training Client 37/60
# Epoch 1/1, Loss: 5.647871881723404, Accuracy: 0.953
# 	Training Client 38/60
# Epoch 1/1, Loss: 5.992730859667063, Accuracy: 0.947
# 	Training Client 39/60
# Epoch 1/1, Loss: 5.05483961943537, Accuracy: 0.952
# 	Training Client 40/60
# Epoch 1/1, Loss: 5.160894395783544, Accuracy: 0.951
# 	Training Client 41/60
# Epoch 1/1, Loss: 5.080487077473663, Accuracy: 0.957
# 	Training Client 42/60
# Epoch 1/1, Loss: 7.175345189869404, Accuracy: 0.943
# 	Training Client 43/60
# Epoch 1/1, Loss: 6.797437623143196, Accuracy: 0.938
# 	Training Client 44/60
# Epoch 1/1, Loss: 7.052868977189064, Accuracy: 0.933
# 	Training Client 45/60
# Epoch 1/1, Loss: 5.0610817559063435, Accuracy: 0.947
# 	Training Client 46/60
# Epoch 1/1, Loss: 5.90544243901968, Accuracy: 0.95
# 	Training Client 47/60
# Epoch 1/1, Loss: 5.2336466535925865, Accuracy: 0.953
# 	Training Client 48/60
# Epoch 1/1, Loss: 5.07959704939276, Accuracy: 0.955
# 	Training Client 49/60
# Epoch 1/1, Loss: 6.125512983649969, Accuracy: 0.941
# 	Training Client 50/60
# Epoch 1/1, Loss: 7.044234201312065, Accuracy: 0.938
# 	Training Client 51/60
# Epoch 1/1, Loss: 5.945388332940638, Accuracy: 0.942
# 	Training Client 52/60
# Epoch 1/1, Loss: 5.4021916296333075, Accuracy: 0.949
# 	Training Client 53/60
# Epoch 1/1, Loss: 6.676172982901335, Accuracy: 0.936
# 	Training Client 54/60
# Epoch 1/1, Loss: 6.75264959782362, Accuracy: 0.943
# 	Training Client 55/60
# Epoch 1/1, Loss: 5.076904494315386, Accuracy: 0.946
# 	Training Client 56/60
# Epoch 1/1, Loss: 6.057891054078937, Accuracy: 0.936
# 	Training Client 57/60
# Epoch 1/1, Loss: 4.951454264111817, Accuracy: 0.956
# 	Training Client 58/60
# Epoch 1/1, Loss: 5.274133745580912, Accuracy: 0.95
# 	Training Client 59/60
# Epoch 1/1, Loss: 6.23863335698843, Accuracy: 0.944
# 	Training Client 60/60
# Epoch 1/1, Loss: 4.096827244386077, Accuracy: 0.954
# Global Epoch 6, Client 1: Drift detection is accurate.
# Global Epoch 6, Client 2: Drift detection is accurate.
# Global Epoch 6, Client 3: Drift detection is accurate.
# Global Epoch 6, Client 4: Drift detection is accurate.
# Global Epoch 6, Client 5: Drift detection is accurate.
# Global Epoch 6, Client 6: Drift detection is accurate.
# Global Epoch 6, Client 7: Drift detection is accurate.
# Global Epoch 6, Client 8: Drift detection is accurate.
# Global Epoch 6, Client 9: Drift detection is accurate.
# Global Epoch 6, Client 10: Drift detection is accurate.
# Global Epoch 6, Client 11: Drift detection is accurate.
# Global Epoch 6, Client 12: Drift detection is accurate.
# Global Epoch 6, Client 13: Drift detection is accurate.
# Global Epoch 6, Client 14: Drift detection is accurate.
# Global Epoch 6, Client 15: Drift detection is accurate.
# Global Epoch 6, Client 16: Drift detection is accurate.
# Global Epoch 6, Client 17: Drift detection is accurate.
# Global Epoch 6, Client 18: Drift detection is accurate.
# Global Epoch 6, Client 19: Drift detection is accurate.
# Global Epoch 6, Client 20: Drift detection is accurate.
# Global Epoch 6, Client 21: Drift detection is accurate.
# Global Epoch 6, Client 22: Drift detection is accurate.
# Global Epoch 6, Client 23: Drift detection is accurate.
# Global Epoch 6, Client 24: Drift detection is accurate.
# Global Epoch 6, Client 25: Drift detection is accurate.
# Global Epoch 6, Client 26: Drift detection is accurate.
# Global Epoch 6, Client 27: Drift detection is accurate.
# Global Epoch 6, Client 28: Drift detection is accurate.
# Global Epoch 6, Client 29: Drift detection is accurate.
# Global Epoch 6, Client 30: Drift detection is accurate.
# Global Epoch 6, Client 31: Drift detection is accurate.
# Global Epoch 6, Client 32: Drift detection is accurate.
# Global Epoch 6, Client 33: Drift detection is accurate.
# Global Epoch 6, Client 34: Drift detection is accurate.
# Global Epoch 6, Client 35: Drift detection is accurate.
# Global Epoch 6, Client 36: Drift detection is accurate.
# Global Epoch 6, Client 37: Drift detection is accurate.
# Global Epoch 6, Client 38: Drift detection is accurate.
# Global Epoch 6, Client 39: Drift detection is accurate.
# Global Epoch 6, Client 40: Drift detection is accurate.
# Global Epoch 6, Client 41: Drift detection is accurate.
# Global Epoch 6, Client 42: Drift detection is accurate.
# Global Epoch 6, Client 43: Drift detection is accurate.
# Global Epoch 6, Client 44: Drift detection is accurate.
# Global Epoch 6, Client 45: Drift detection is accurate.
# Global Epoch 6, Client 46: Drift detection is accurate.
# Global Epoch 6, Client 47: Drift detection is accurate.
# Global Epoch 6, Client 48: Drift detection is accurate.
# Global Epoch 6, Client 49: Drift detection is accurate.
# Global Epoch 6, Client 50: Drift detection is accurate.
# Global Epoch 6, Client 51: Drift detection is accurate.
# Global Epoch 6, Client 52: Drift detection is accurate.
# Global Epoch 6, Client 53: Drift detection is accurate.
# Global Epoch 6, Client 54: Drift detection is accurate.
# Global Epoch 6, Client 55: Drift detection is accurate.
# Global Epoch 6, Client 56: Drift detection is accurate.
# Global Epoch 6, Client 57: Drift detection is accurate.
# Global Epoch 6, Client 58: Drift detection is accurate.
# Global Epoch 6, Client 59: Drift detection is accurate.
# Global Epoch 6, Client 60: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 7/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 5.698128630872816, Accuracy: 0.942
# 	Training Client 2/60
# Epoch 1/1, Loss: 4.826965192332864, Accuracy: 0.951
# 	Training Client 3/60
# Epoch 1/1, Loss: 4.373303657397628, Accuracy: 0.957
# 	Training Client 4/60
# Epoch 1/1, Loss: 4.584555551409721, Accuracy: 0.961
# 	Training Client 5/60
# Epoch 1/1, Loss: 5.867724683135748, Accuracy: 0.942
# 	Training Client 6/60
# Epoch 1/1, Loss: 5.96559233777225, Accuracy: 0.941
# 	Training Client 7/60
# Epoch 1/1, Loss: 4.004329118877649, Accuracy: 0.963
# 	Training Client 8/60
# Epoch 1/1, Loss: 5.938091546297073, Accuracy: 0.952
# 	Training Client 9/60
# Epoch 1/1, Loss: 5.310400128364563, Accuracy: 0.949
# 	Training Client 10/60
# Epoch 1/1, Loss: 4.899367944337428, Accuracy: 0.948
# 	Training Client 11/60
# Epoch 1/1, Loss: 5.23795273900032, Accuracy: 0.956
# 	Training Client 12/60
# Epoch 1/1, Loss: 4.366801181342453, Accuracy: 0.956
# 	Training Client 13/60
# Epoch 1/1, Loss: 5.008310828357935, Accuracy: 0.958
# 	Training Client 14/60
# Epoch 1/1, Loss: 4.607624851167202, Accuracy: 0.958
# 	Training Client 15/60
# Epoch 1/1, Loss: 4.471903937868774, Accuracy: 0.959
# 	Training Client 16/60
# Epoch 1/1, Loss: 5.913788769394159, Accuracy: 0.943
# 	Training Client 17/60
# Epoch 1/1, Loss: 5.387773493304849, Accuracy: 0.949
# 	Training Client 18/60
# Epoch 1/1, Loss: 5.431561233475804, Accuracy: 0.948
# 	Training Client 19/60
# Epoch 1/1, Loss: 4.760177720338106, Accuracy: 0.948
# 	Training Client 20/60
# Epoch 1/1, Loss: 3.903412126004696, Accuracy: 0.962
# 	Training Client 21/60
# Epoch 1/1, Loss: 5.610483970027417, Accuracy: 0.939
# 	Training Client 22/60
# Epoch 1/1, Loss: 5.4126877365633845, Accuracy: 0.946
# 	Training Client 23/60
# Epoch 1/1, Loss: 5.309462022036314, Accuracy: 0.949
# 	Training Client 24/60
# Epoch 1/1, Loss: 5.016834124922752, Accuracy: 0.953
# 	Training Client 25/60
# Epoch 1/1, Loss: 5.583200540393591, Accuracy: 0.944
# 	Training Client 26/60
# Epoch 1/1, Loss: 6.248141212388873, Accuracy: 0.94
# 	Training Client 27/60
# Epoch 1/1, Loss: 6.188805026933551, Accuracy: 0.953
# 	Training Client 28/60
# Epoch 1/1, Loss: 5.416313334833831, Accuracy: 0.942
# 	Training Client 29/60
# Epoch 1/1, Loss: 4.64141240157187, Accuracy: 0.953
# 	Training Client 30/60
# Epoch 1/1, Loss: 4.490320912562311, Accuracy: 0.952
# 	Training Client 31/60
# Epoch 1/1, Loss: 4.274397162720561, Accuracy: 0.954
# 	Training Client 32/60
# Epoch 1/1, Loss: 6.124631782993674, Accuracy: 0.942
# 	Training Client 33/60
# Epoch 1/1, Loss: 4.6650029653683305, Accuracy: 0.955
# 	Training Client 34/60
# Epoch 1/1, Loss: 5.139807764440775, Accuracy: 0.947
# 	Training Client 35/60
# Epoch 1/1, Loss: 5.539093749597669, Accuracy: 0.942
# 	Training Client 36/60
# Epoch 1/1, Loss: 5.795013731112704, Accuracy: 0.946
# 	Training Client 37/60
# Epoch 1/1, Loss: 4.243292259983718, Accuracy: 0.962
# 	Training Client 38/60
# Epoch 1/1, Loss: 5.510918609797955, Accuracy: 0.951
# 	Training Client 39/60
# Epoch 1/1, Loss: 5.150126580148935, Accuracy: 0.951
# 	Training Client 40/60
# Epoch 1/1, Loss: 5.093250432983041, Accuracy: 0.951
# 	Training Client 41/60
# Epoch 1/1, Loss: 5.345451938919723, Accuracy: 0.953
# 	Training Client 42/60
# Epoch 1/1, Loss: 5.362694362178445, Accuracy: 0.946
# 	Training Client 43/60
# Epoch 1/1, Loss: 6.542986910790205, Accuracy: 0.942
# 	Training Client 44/60
# Epoch 1/1, Loss: 7.106142394244671, Accuracy: 0.931
# 	Training Client 45/60
# Epoch 1/1, Loss: 3.9450488444417715, Accuracy: 0.957
# 	Training Client 46/60
# Epoch 1/1, Loss: 5.044234290719032, Accuracy: 0.951
# 	Training Client 47/60
# Epoch 1/1, Loss: 5.0968643464148045, Accuracy: 0.95
# 	Training Client 48/60
# Epoch 1/1, Loss: 3.753546460531652, Accuracy: 0.963
# 	Training Client 49/60
# Epoch 1/1, Loss: 5.3034095875918865, Accuracy: 0.938
# 	Training Client 50/60
# Epoch 1/1, Loss: 5.676957003772259, Accuracy: 0.955
# 	Training Client 51/60
# Epoch 1/1, Loss: 5.157836098223925, Accuracy: 0.952
# 	Training Client 52/60
# Epoch 1/1, Loss: 5.506065782159567, Accuracy: 0.948
# 	Training Client 53/60
# Epoch 1/1, Loss: 6.335719525814056, Accuracy: 0.944
# 	Training Client 54/60
# Epoch 1/1, Loss: 6.287568282335997, Accuracy: 0.945
# 	Training Client 55/60
# Epoch 1/1, Loss: 5.172262672334909, Accuracy: 0.959
# 	Training Client 56/60
# Epoch 1/1, Loss: 5.804607011377811, Accuracy: 0.943
# 	Training Client 57/60
# Epoch 1/1, Loss: 4.89655289798975, Accuracy: 0.95
# 	Training Client 58/60
# Epoch 1/1, Loss: 5.484068062156439, Accuracy: 0.941
# 	Training Client 59/60
# Epoch 1/1, Loss: 5.585827399045229, Accuracy: 0.947
# 	Training Client 60/60
# Epoch 1/1, Loss: 4.02483980730176, Accuracy: 0.95
# Global Epoch 7, Client 1: Drift detection is accurate.
# Global Epoch 7, Client 2: Drift detection is accurate.
# Global Epoch 7, Client 3: Drift detection is accurate.
# Global Epoch 7, Client 4: Drift detection is accurate.
# Global Epoch 7, Client 5: Drift detection is accurate.
# Global Epoch 7, Client 6: Drift detection is accurate.
# Global Epoch 7, Client 7: Drift detection is accurate.
# Global Epoch 7, Client 8: Drift detection is accurate.
# Global Epoch 7, Client 9: Drift detection is accurate.
# Global Epoch 7, Client 10: Drift detection is accurate.
# Global Epoch 7, Client 11: Drift detection is accurate.
# Global Epoch 7, Client 12: Drift detection is accurate.
# Global Epoch 7, Client 13: Drift detection is accurate.
# Global Epoch 7, Client 14: Drift detection is accurate.
# Global Epoch 7, Client 15: Drift detection is accurate.
# Global Epoch 7, Client 16: Drift detection is accurate.
# Global Epoch 7, Client 17: Drift detection is accurate.
# Global Epoch 7, Client 18: Drift detection is accurate.
# Global Epoch 7, Client 19: Drift detection is accurate.
# Global Epoch 7, Client 20: Drift detection is accurate.
# Global Epoch 7, Client 21: Drift detection is accurate.
# Global Epoch 7, Client 22: Drift detection is accurate.
# Global Epoch 7, Client 23: Drift detection is accurate.
# Global Epoch 7, Client 24: Drift detection is accurate.
# Global Epoch 7, Client 25: Drift detection is accurate.
# Global Epoch 7, Client 26: Drift detection is accurate.
# Global Epoch 7, Client 27: Drift detection is accurate.
# Global Epoch 7, Client 28: Drift detection is accurate.
# Global Epoch 7, Client 29: Drift detection is accurate.
# Global Epoch 7, Client 30: Drift detection is accurate.
# Global Epoch 7, Client 31: Drift detection is accurate.
# Global Epoch 7, Client 32: Drift detection is accurate.
# Global Epoch 7, Client 33: Drift detection is accurate.
# Global Epoch 7, Client 34: Drift detection is accurate.
# Global Epoch 7, Client 35: Drift detection is accurate.
# Global Epoch 7, Client 36: Drift detection is accurate.
# Global Epoch 7, Client 37: Drift detection is accurate.
# Global Epoch 7, Client 38: Drift detection is accurate.
# Global Epoch 7, Client 39: Drift detection is accurate.
# Global Epoch 7, Client 40: Drift detection is accurate.
# Global Epoch 7, Client 41: Drift detection is accurate.
# Global Epoch 7, Client 42: Drift detection is accurate.
# Global Epoch 7, Client 43: Drift detection is accurate.
# Global Epoch 7, Client 44: Drift detection is accurate.
# Global Epoch 7, Client 45: Drift detection is accurate.
# Global Epoch 7, Client 46: Drift detection is accurate.
# Global Epoch 7, Client 47: Drift detection is accurate.
# Global Epoch 7, Client 48: Drift detection is accurate.
# Global Epoch 7, Client 49: Drift detection is accurate.
# Global Epoch 7, Client 50: Drift detection is accurate.
# Global Epoch 7, Client 51: Drift detection is accurate.
# Global Epoch 7, Client 52: Drift detection is accurate.
# Global Epoch 7, Client 53: Drift detection is accurate.
# Global Epoch 7, Client 54: Drift detection is accurate.
# Global Epoch 7, Client 55: Drift detection is accurate.
# Global Epoch 7, Client 56: Drift detection is accurate.
# Global Epoch 7, Client 57: Drift detection is accurate.
# Global Epoch 7, Client 58: Drift detection is accurate.
# Global Epoch 7, Client 59: Drift detection is accurate.
# Global Epoch 7, Client 60: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 8/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 5.148654383141547, Accuracy: 0.954
# 	Training Client 2/60
# Epoch 1/1, Loss: 5.919879037886858, Accuracy: 0.944
# 	Training Client 3/60
# Epoch 1/1, Loss: 4.420849245041609, Accuracy: 0.959
# 	Training Client 4/60
# Epoch 1/1, Loss: 4.5531676560640335, Accuracy: 0.951
# 	Training Client 5/60
# Epoch 1/1, Loss: 4.814264182001352, Accuracy: 0.953
# 	Training Client 6/60
# Epoch 1/1, Loss: 5.214847274124622, Accuracy: 0.958
# 	Training Client 7/60
# Epoch 1/1, Loss: 3.995474113151431, Accuracy: 0.957
# 	Training Client 8/60
# Epoch 1/1, Loss: 5.452281221747398, Accuracy: 0.954
# 	Training Client 9/60
# Epoch 1/1, Loss: 5.1992292776703835, Accuracy: 0.952
# 	Training Client 10/60
# Epoch 1/1, Loss: 3.8631139993667603, Accuracy: 0.959
# 	Training Client 11/60
# Epoch 1/1, Loss: 4.543038811534643, Accuracy: 0.956
# 	Training Client 12/60
# Epoch 1/1, Loss: 3.8577264631167054, Accuracy: 0.96
# 	Training Client 13/60
# Epoch 1/1, Loss: 4.89812733232975, Accuracy: 0.957
# 	Training Client 14/60
# Epoch 1/1, Loss: 4.984178872779012, Accuracy: 0.958
# 	Training Client 15/60
# Epoch 1/1, Loss: 4.769478217698634, Accuracy: 0.952
# 	Training Client 16/60
# Epoch 1/1, Loss: 5.13248104788363, Accuracy: 0.957
# 	Training Client 17/60
# Epoch 1/1, Loss: 4.921429431065917, Accuracy: 0.959
# 	Training Client 18/60
# Epoch 1/1, Loss: 4.779022306203842, Accuracy: 0.959
# 	Training Client 19/60
# Epoch 1/1, Loss: 3.848194516263902, Accuracy: 0.962
# 	Training Client 20/60
# Epoch 1/1, Loss: 3.4090143400244415, Accuracy: 0.965
# 	Training Client 21/60
# Epoch 1/1, Loss: 5.026347110047936, Accuracy: 0.948
# 	Training Client 22/60
# Epoch 1/1, Loss: 4.927493784576654, Accuracy: 0.952
# 	Training Client 23/60
# Epoch 1/1, Loss: 5.034024449065328, Accuracy: 0.957
# 	Training Client 24/60
# Epoch 1/1, Loss: 4.247670932672918, Accuracy: 0.96
# 	Training Client 25/60
# Epoch 1/1, Loss: 4.765769994817674, Accuracy: 0.954
# 	Training Client 26/60
# Epoch 1/1, Loss: 5.739601669833064, Accuracy: 0.946
# 	Training Client 27/60
# Epoch 1/1, Loss: 5.186253291554749, Accuracy: 0.958
# 	Training Client 28/60
# Epoch 1/1, Loss: 5.477612207643688, Accuracy: 0.947
# 	Training Client 29/60
# Epoch 1/1, Loss: 4.380927790887654, Accuracy: 0.958
# 	Training Client 30/60
# Epoch 1/1, Loss: 4.499432992190123, Accuracy: 0.96
# 	Training Client 31/60
# Epoch 1/1, Loss: 3.411357793956995, Accuracy: 0.963
# 	Training Client 32/60
# Epoch 1/1, Loss: 5.745071376673877, Accuracy: 0.945
# 	Training Client 33/60
# Epoch 1/1, Loss: 4.7222136771306396, Accuracy: 0.961
# 	Training Client 34/60
# Epoch 1/1, Loss: 4.5551250241696835, Accuracy: 0.954
# 	Training Client 35/60
# Epoch 1/1, Loss: 5.837504407390952, Accuracy: 0.947
# 	Training Client 36/60
# Epoch 1/1, Loss: 5.700129072880372, Accuracy: 0.948
# 	Training Client 37/60
# Epoch 1/1, Loss: 3.6482145693153143, Accuracy: 0.964
# 	Training Client 38/60
# Epoch 1/1, Loss: 4.832331306301057, Accuracy: 0.958
# 	Training Client 39/60
# Epoch 1/1, Loss: 5.182321663014591, Accuracy: 0.957
# 	Training Client 40/60
# Epoch 1/1, Loss: 4.124148425646126, Accuracy: 0.963
# 	Training Client 41/60
# Epoch 1/1, Loss: 4.025074454024434, Accuracy: 0.965
# 	Training Client 42/60
# Epoch 1/1, Loss: 5.593230618163943, Accuracy: 0.948
# 	Training Client 43/60
# Epoch 1/1, Loss: 5.124058023095131, Accuracy: 0.958
# 	Training Client 44/60
# Epoch 1/1, Loss: 5.475271362811327, Accuracy: 0.945
# 	Training Client 45/60
# Epoch 1/1, Loss: 3.7275435691699386, Accuracy: 0.969
# 	Training Client 46/60
# Epoch 1/1, Loss: 4.779928399249911, Accuracy: 0.962
# 	Training Client 47/60
# Epoch 1/1, Loss: 4.228077438659966, Accuracy: 0.964
# 	Training Client 48/60
# Epoch 1/1, Loss: 3.9090539808385074, Accuracy: 0.963
# 	Training Client 49/60
# Epoch 1/1, Loss: 4.468754607252777, Accuracy: 0.953
# 	Training Client 50/60
# Epoch 1/1, Loss: 5.208410760387778, Accuracy: 0.959
# 	Training Client 51/60
# Epoch 1/1, Loss: 4.159448770806193, Accuracy: 0.954
# 	Training Client 52/60
# Epoch 1/1, Loss: 4.719427675008774, Accuracy: 0.955
# 	Training Client 53/60
# Epoch 1/1, Loss: 5.047321103513241, Accuracy: 0.964
# 	Training Client 54/60
# Epoch 1/1, Loss: 5.917950171977282, Accuracy: 0.949
# 	Training Client 55/60
# Epoch 1/1, Loss: 4.156524556688964, Accuracy: 0.969
# 	Training Client 56/60
# Epoch 1/1, Loss: 4.467674205079675, Accuracy: 0.951
# 	Training Client 57/60
# Epoch 1/1, Loss: 4.405741170048714, Accuracy: 0.961
# 	Training Client 58/60
# Epoch 1/1, Loss: 4.206094231456518, Accuracy: 0.961
# 	Training Client 59/60
# Epoch 1/1, Loss: 5.30530790053308, Accuracy: 0.946
# 	Training Client 60/60
# Epoch 1/1, Loss: 3.928943654987961, Accuracy: 0.964
# Global Epoch 8, Client 1: Drift detection is accurate.
# Global Epoch 8, Client 2: Drift detection is accurate.
# Global Epoch 8, Client 3: Drift detection is accurate.
# Global Epoch 8, Client 4: Drift detection is accurate.
# Global Epoch 8, Client 5: Drift detection is accurate.
# Global Epoch 8, Client 6: Drift detection is accurate.
# Global Epoch 8, Client 7: Drift detection is accurate.
# Global Epoch 8, Client 8: Drift detection is accurate.
# Global Epoch 8, Client 9: Drift detection is accurate.
# Global Epoch 8, Client 10: Drift detection is accurate.
# Global Epoch 8, Client 11: Drift detection is accurate.
# Global Epoch 8, Client 12: Drift detection is accurate.
# Global Epoch 8, Client 13: Drift detection is accurate.
# Global Epoch 8, Client 14: Drift detection is accurate.
# Global Epoch 8, Client 15: Drift detection is accurate.
# Global Epoch 8, Client 16: Drift detection is accurate.
# Global Epoch 8, Client 17: Drift detection is accurate.
# Global Epoch 8, Client 18: Drift detection is accurate.
# Global Epoch 8, Client 19: Drift detection is accurate.
# Global Epoch 8, Client 20: Drift detection is accurate.
# Global Epoch 8, Client 21: Drift detection is accurate.
# Global Epoch 8, Client 22: Drift detection is accurate.
# Global Epoch 8, Client 23: Drift detection is accurate.
# Global Epoch 8, Client 24: Drift detection is accurate.
# Global Epoch 8, Client 25: Drift detection is accurate.
# Global Epoch 8, Client 26: Drift detection is accurate.
# Global Epoch 8, Client 27: Drift detection is accurate.
# Global Epoch 8, Client 28: Drift detection is accurate.
# Global Epoch 8, Client 29: Drift detection is accurate.
# Global Epoch 8, Client 30: Drift detection is accurate.
# Global Epoch 8, Client 31: Drift detection is accurate.
# Global Epoch 8, Client 32: Drift detection is accurate.
# Global Epoch 8, Client 33: Drift detection is accurate.
# Global Epoch 8, Client 34: Drift detection is accurate.
# Global Epoch 8, Client 35: Drift detection is accurate.
# Global Epoch 8, Client 36: Drift detection is accurate.
# Global Epoch 8, Client 37: Drift detection is accurate.
# Global Epoch 8, Client 38: Drift detection is accurate.
# Global Epoch 8, Client 39: Drift detection is accurate.
# Global Epoch 8, Client 40: Drift detection is accurate.
# Global Epoch 8, Client 41: Drift detection is accurate.
# Global Epoch 8, Client 42: Drift detection is accurate.
# Global Epoch 8, Client 43: Drift detection is accurate.
# Global Epoch 8, Client 44: Drift detection is accurate.
# Global Epoch 8, Client 45: Drift detection is accurate.
# Global Epoch 8, Client 46: Drift detection is accurate.
# Global Epoch 8, Client 47: Drift detection is accurate.
# Global Epoch 8, Client 48: Drift detection is accurate.
# Global Epoch 8, Client 49: Drift detection is accurate.
# Global Epoch 8, Client 50: Drift detection is accurate.
# Global Epoch 8, Client 51: Drift detection is accurate.
# Global Epoch 8, Client 52: Drift detection is accurate.
# Global Epoch 8, Client 53: Drift detection is accurate.
# Global Epoch 8, Client 54: Drift detection is accurate.
# Global Epoch 8, Client 55: Drift detection is accurate.
# Global Epoch 8, Client 56: Drift detection is accurate.
# Global Epoch 8, Client 57: Drift detection is accurate.
# Global Epoch 8, Client 58: Drift detection is accurate.
# Global Epoch 8, Client 59: Drift detection is accurate.
# Global Epoch 8, Client 60: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 9/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 4.629267001524568, Accuracy: 0.962
# 	Training Client 2/60
# Epoch 1/1, Loss: 4.705242224037647, Accuracy: 0.957
# 	Training Client 3/60
# Epoch 1/1, Loss: 4.1660254849120975, Accuracy: 0.959
# 	Training Client 4/60
# Epoch 1/1, Loss: 3.3342211511917412, Accuracy: 0.971
# 	Training Client 5/60
# Epoch 1/1, Loss: 4.289444729685783, Accuracy: 0.952
# 	Training Client 6/60
# Epoch 1/1, Loss: 4.794595513492823, Accuracy: 0.95
# 	Training Client 7/60
# Epoch 1/1, Loss: 3.4063100470229983, Accuracy: 0.966
# 	Training Client 8/60
# Epoch 1/1, Loss: 5.240185208618641, Accuracy: 0.956
# 	Training Client 9/60
# Epoch 1/1, Loss: 5.4111667685210705, Accuracy: 0.951
# 	Training Client 10/60
# Epoch 1/1, Loss: 3.9874981963075697, Accuracy: 0.96
# 	Training Client 11/60
# Epoch 1/1, Loss: 4.614316301885992, Accuracy: 0.961
# 	Training Client 12/60
# Epoch 1/1, Loss: 3.764607882127166, Accuracy: 0.966
# 	Training Client 13/60
# Epoch 1/1, Loss: 4.583420319017023, Accuracy: 0.961
# 	Training Client 14/60
# Epoch 1/1, Loss: 4.2124813962727785, Accuracy: 0.964
# 	Training Client 15/60
# Epoch 1/1, Loss: 3.9221204286441207, Accuracy: 0.963
# 	Training Client 16/60
# Epoch 1/1, Loss: 4.501126672606915, Accuracy: 0.967
# 	Training Client 17/60
# Epoch 1/1, Loss: 4.189951342530549, Accuracy: 0.966
# 	Training Client 18/60
# Epoch 1/1, Loss: 4.6606637459481135, Accuracy: 0.944
# 	Training Client 19/60
# Epoch 1/1, Loss: 3.955181579804048, Accuracy: 0.965
# 	Training Client 20/60
# Epoch 1/1, Loss: 3.516285188496113, Accuracy: 0.961
# 	Training Client 21/60
# Epoch 1/1, Loss: 4.508019509725273, Accuracy: 0.962
# 	Training Client 22/60
# ...
# Global Epoch 35, Client 25: Drift detection is accurate.
# Global Epoch 35, Client 26: Drift detection is accurate.
# Global Epoch 35, Client 27: Drift detection is accurate.
# Global Epoch 35, Client 28: Drift detection is accurate.
# Global Epoch 35, Client 29: Drift detection is inaccurate.
# Global Epoch 35, Client 30: Drift detection is accurate.
# Global Epoch 35, Client 31: Drift detection is accurate.
# Global Epoch 35, Client 32: Drift detection is accurate.
# Global Epoch 35, Client 33: Drift detection is accurate.
# Global Epoch 35, Client 34: Drift detection is accurate.
# Global Epoch 35, Client 35: Drift detection is accurate.
# Global Epoch 35, Client 36: Drift detection is accurate.
# Global Epoch 35, Client 37: Drift detection is accurate.
# Global Epoch 35, Client 38: Drift detection is accurate.
# Global Epoch 35, Client 39: Drift detection is accurate.
# Global Epoch 35, Client 40: Drift detection is accurate.
# Global Epoch 35, Client 41: Drift detection is accurate.
# Global Epoch 35, Client 42: Drift detection is inaccurate.
# Global Epoch 35, Client 43: Drift detection is accurate.
# Global Epoch 35, Client 44: Drift detection is accurate.
# Global Epoch 35, Client 45: Drift detection is accurate.
# Global Epoch 35, Client 46: Drift detection is accurate.
# Global Epoch 35, Client 47: Drift detection is accurate.
# Global Epoch 35, Client 48: Drift detection is accurate.
# Global Epoch 35, Client 49: Drift detection is accurate.
# Global Epoch 35, Client 50: Drift detection is accurate.
# Global Epoch 35, Client 51: Drift detection is accurate.
# Global Epoch 35, Client 52: Drift detection is accurate.
# Global Epoch 35, Client 53: Drift detection is accurate.
# Global Epoch 35, Client 54: Drift detection is accurate.
# Global Epoch 35, Client 55: Drift detection is accurate.
# Global Epoch 35, Client 56: Drift detection is accurate.
# Global Epoch 35, Client 57: Drift detection is inaccurate.
# Global Epoch 35, Client 58: Drift detection is accurate.
# Global Epoch 35, Client 59: Drift detection is accurate.
# Global Epoch 35, Client 60: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 36/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 2.3900160137127386, Accuracy: 0.974
# 	Training Client 2/60
# Epoch 1/1, Loss: 1.8835536908809445, Accuracy: 0.982
# 	Training Client 3/60
# Epoch 1/1, Loss: 0.4370414176212307, Accuracy: 0.996
# 	Training Client 4/60
# Epoch 1/1, Loss: 1.7078984178951941, Accuracy: 0.988
# 	Training Client 5/60
# Epoch 1/1, Loss: 2.271034414836322, Accuracy: 0.98
# 	Training Client 6/60
# Epoch 1/1, Loss: 1.4944898428511806, Accuracy: 0.986
# 	Training Client 7/60
# Epoch 1/1, Loss: 0.31766725334570367, Accuracy: 0.994
# 	Training Client 8/60
# Epoch 1/1, Loss: 2.4409844784531742, Accuracy: 0.976
# 	Training Client 9/60
# Epoch 1/1, Loss: 2.3236936403263826, Accuracy: 0.976
# 	Training Client 10/60
# Epoch 1/1, Loss: 0.3397071444321682, Accuracy: 0.998
# 	Training Client 11/60
# Epoch 1/1, Loss: 1.5886681396514177, Accuracy: 0.988
# 	Training Client 12/60
# Epoch 1/1, Loss: 1.8172015803866088, Accuracy: 0.988
# 	Training Client 13/60
# Epoch 1/1, Loss: 1.772147945361212, Accuracy: 0.984
# 	Training Client 14/60
# Epoch 1/1, Loss: 1.0403361629250867, Accuracy: 0.985
# 	Training Client 15/60
# Epoch 1/1, Loss: 2.478430440532975, Accuracy: 0.98
# 	Training Client 16/60
# Epoch 1/1, Loss: 2.010277171502821, Accuracy: 0.98
# 	Training Client 17/60
# Epoch 1/1, Loss: 1.6670173458987847, Accuracy: 0.98
# 	Training Client 18/60
# Epoch 1/1, Loss: 1.9073988863747218, Accuracy: 0.98
# 	Training Client 19/60
# Epoch 1/1, Loss: 1.3805640991777182, Accuracy: 0.984
# 	Training Client 20/60
# Epoch 1/1, Loss: 0.8859309522158583, Accuracy: 0.992
# 	Training Client 21/60
# Epoch 1/1, Loss: 2.122828852952807, Accuracy: 0.984
# 	Training Client 22/60
# Epoch 1/1, Loss: 2.0840705400914885, Accuracy: 0.983
# 	Training Client 23/60
# Epoch 1/1, Loss: 2.249386069830507, Accuracy: 0.983
# 	Training Client 24/60
# Epoch 1/1, Loss: 1.4832426255452447, Accuracy: 0.985
# 	Training Client 25/60
# Epoch 1/1, Loss: 2.035231071029557, Accuracy: 0.978
# 	Training Client 26/60
# Epoch 1/1, Loss: 2.261931161978282, Accuracy: 0.984
# 	Training Client 27/60
# Epoch 1/1, Loss: 2.325567210384179, Accuracy: 0.98
# 	Training Client 28/60
# Epoch 1/1, Loss: 1.7036796088214032, Accuracy: 0.981
# 	Training Client 29/60
# Epoch 1/1, Loss: 0.6799444855251124, Accuracy: 0.993
# 	Training Client 30/60
# Epoch 1/1, Loss: 1.1421013307699468, Accuracy: 0.987
# 	Training Client 31/60
# Epoch 1/1, Loss: 1.2056686260184506, Accuracy: 0.988
# 	Training Client 32/60
# Epoch 1/1, Loss: 1.8368579070956912, Accuracy: 0.983
# 	Training Client 33/60
# Epoch 1/1, Loss: 1.8083392765256576, Accuracy: 0.985
# 	Training Client 34/60
# Epoch 1/1, Loss: 1.699746858837898, Accuracy: 0.982
# 	Training Client 35/60
# Epoch 1/1, Loss: 1.3850143215386197, Accuracy: 0.983
# 	Training Client 36/60
# Epoch 1/1, Loss: 2.4671696234872798, Accuracy: 0.984
# 	Training Client 37/60
# Epoch 1/1, Loss: 1.5036727522820001, Accuracy: 0.991
# 	Training Client 38/60
# Epoch 1/1, Loss: 2.360532600316219, Accuracy: 0.977
# 	Training Client 39/60
# Epoch 1/1, Loss: 2.4412205372354947, Accuracy: 0.981
# 	Training Client 40/60
# Epoch 1/1, Loss: 1.949860711072688, Accuracy: 0.982
# 	Training Client 41/60
# Epoch 1/1, Loss: 2.034317908565754, Accuracy: 0.985
# 	Training Client 42/60
# Epoch 1/1, Loss: 1.0186853009327024, Accuracy: 0.992
# 	Training Client 43/60
# Epoch 1/1, Loss: 2.3641779413446784, Accuracy: 0.978
# 	Training Client 44/60
# Epoch 1/1, Loss: 2.5039479602783103, Accuracy: 0.979
# 	Training Client 45/60
# Epoch 1/1, Loss: 1.5037710662872996, Accuracy: 0.987
# 	Training Client 46/60
# Epoch 1/1, Loss: 2.2216750041807245, Accuracy: 0.979
# 	Training Client 47/60
# Epoch 1/1, Loss: 1.8292777372989804, Accuracy: 0.981
# 	Training Client 48/60
# Epoch 1/1, Loss: 1.7509965660865419, Accuracy: 0.988
# 	Training Client 49/60
# Epoch 1/1, Loss: 1.9033909250283614, Accuracy: 0.98
# 	Training Client 50/60
# Epoch 1/1, Loss: 2.1279828455881216, Accuracy: 0.985
# 	Training Client 51/60
# Epoch 1/1, Loss: 1.6387356878549326, Accuracy: 0.982
# 	Training Client 52/60
# Epoch 1/1, Loss: 1.627831525169313, Accuracy: 0.989
# 	Training Client 53/60
# Epoch 1/1, Loss: 2.149402971221207, Accuracy: 0.982
# 	Training Client 54/60
# Epoch 1/1, Loss: 2.059168523410335, Accuracy: 0.977
# 	Training Client 55/60
# Epoch 1/1, Loss: 1.91441504782415, Accuracy: 0.983
# 	Training Client 56/60
# Epoch 1/1, Loss: 1.5567249113373691, Accuracy: 0.985
# 	Training Client 57/60
# Epoch 1/1, Loss: 0.07030221935724512, Accuracy: 0.999
# 	Training Client 58/60
# Epoch 1/1, Loss: 1.9155398930306546, Accuracy: 0.979
# 	Training Client 59/60
# Epoch 1/1, Loss: 1.692308203317225, Accuracy: 0.984
# 	Training Client 60/60
# Epoch 1/1, Loss: 1.433183692744933, Accuracy: 0.985
# Global Epoch 36, Client 1: Drift detection is accurate.
# Global Epoch 36, Client 2: Drift detection is accurate.
# Global Epoch 36, Client 3: Drift detection is inaccurate.
# Global Epoch 36, Client 4: Drift detection is accurate.
# Global Epoch 36, Client 5: Drift detection is accurate.
# Global Epoch 36, Client 6: Drift detection is accurate.
# Global Epoch 36, Client 7: Drift detection is inaccurate.
# Global Epoch 36, Client 8: Drift detection is accurate.
# Global Epoch 36, Client 9: Drift detection is accurate.
# Global Epoch 36, Client 10: Drift detection is inaccurate.
# Global Epoch 36, Client 11: Drift detection is accurate.
# Global Epoch 36, Client 12: Drift detection is accurate.
# Global Epoch 36, Client 13: Drift detection is accurate.
# Global Epoch 36, Client 14: Drift detection is accurate.
# Global Epoch 36, Client 15: Drift detection is accurate.
# Global Epoch 36, Client 16: Drift detection is accurate.
# Global Epoch 36, Client 17: Drift detection is accurate.
# Global Epoch 36, Client 18: Drift detection is accurate.
# Global Epoch 36, Client 19: Drift detection is accurate.
# Global Epoch 36, Client 20: Drift detection is accurate.
# Global Epoch 36, Client 21: Drift detection is accurate.
# Global Epoch 36, Client 22: Drift detection is accurate.
# Global Epoch 36, Client 23: Drift detection is accurate.
# Global Epoch 36, Client 24: Drift detection is accurate.
# Global Epoch 36, Client 25: Drift detection is accurate.
# Global Epoch 36, Client 26: Drift detection is accurate.
# Global Epoch 36, Client 27: Drift detection is accurate.
# Global Epoch 36, Client 28: Drift detection is accurate.
# Global Epoch 36, Client 29: Drift detection is inaccurate.
# Global Epoch 36, Client 30: Drift detection is accurate.
# Global Epoch 36, Client 31: Drift detection is accurate.
# Global Epoch 36, Client 32: Drift detection is accurate.
# Global Epoch 36, Client 33: Drift detection is accurate.
# Global Epoch 36, Client 34: Drift detection is accurate.
# Global Epoch 36, Client 35: Drift detection is accurate.
# Global Epoch 36, Client 36: Drift detection is accurate.
# Global Epoch 36, Client 37: Drift detection is accurate.
# Global Epoch 36, Client 38: Drift detection is accurate.
# Global Epoch 36, Client 39: Drift detection is accurate.
# Global Epoch 36, Client 40: Drift detection is accurate.
# Global Epoch 36, Client 41: Drift detection is accurate.
# Global Epoch 36, Client 42: Drift detection is inaccurate.
# Global Epoch 36, Client 43: Drift detection is accurate.
# Global Epoch 36, Client 44: Drift detection is accurate.
# Global Epoch 36, Client 45: Drift detection is accurate.
# Global Epoch 36, Client 46: Drift detection is accurate.
# Global Epoch 36, Client 47: Drift detection is accurate.
# Global Epoch 36, Client 48: Drift detection is accurate.
# Global Epoch 36, Client 49: Drift detection is accurate.
# Global Epoch 36, Client 50: Drift detection is accurate.
# Global Epoch 36, Client 51: Drift detection is accurate.
# Global Epoch 36, Client 52: Drift detection is accurate.
# Global Epoch 36, Client 53: Drift detection is accurate.
# Global Epoch 36, Client 54: Drift detection is accurate.
# Global Epoch 36, Client 55: Drift detection is accurate.
# Global Epoch 36, Client 56: Drift detection is accurate.
# Global Epoch 36, Client 57: Drift detection is inaccurate.
# Global Epoch 36, Client 58: Drift detection is accurate.
# Global Epoch 36, Client 59: Drift detection is accurate.
# Global Epoch 36, Client 60: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 37/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 1.9714371867012233, Accuracy: 0.981
# 	Training Client 2/60
# Epoch 1/1, Loss: 1.436780354284565, Accuracy: 0.983
# 	Training Client 3/60
# Epoch 1/1, Loss: 0.3488635015496584, Accuracy: 0.995
# 	Training Client 4/60
# Epoch 1/1, Loss: 1.1058532595052384, Accuracy: 0.989
# 	Training Client 5/60
# Epoch 1/1, Loss: 2.047515587473754, Accuracy: 0.983
# 	Training Client 6/60
# Epoch 1/1, Loss: 1.506554736970429, Accuracy: 0.984
# 	Training Client 7/60
# Epoch 1/1, Loss: 0.27243648743979065, Accuracy: 0.996
# 	Training Client 8/60
# Epoch 1/1, Loss: 2.2168880549870664, Accuracy: 0.983
# 	Training Client 9/60
# Epoch 1/1, Loss: 2.2303355515468866, Accuracy: 0.982
# 	Training Client 10/60
# Epoch 1/1, Loss: 0.11672521794571367, Accuracy: 0.999
# 	Training Client 11/60
# Epoch 1/1, Loss: 1.1925936241459567, Accuracy: 0.988
# 	Training Client 12/60
# Epoch 1/1, Loss: 1.5211978144943714, Accuracy: 0.989
# 	Training Client 13/60
# Epoch 1/1, Loss: 1.7747617935820017, Accuracy: 0.985
# 	Training Client 14/60
# Epoch 1/1, Loss: 1.075061905576149, Accuracy: 0.987
# 	Training Client 15/60
# Epoch 1/1, Loss: 1.8534591416828334, Accuracy: 0.977
# 	Training Client 16/60
# Epoch 1/1, Loss: 1.732464394212002, Accuracy: 0.985
# 	Training Client 17/60
# Epoch 1/1, Loss: 1.2611152781464625, Accuracy: 0.983
# 	Training Client 18/60
# Epoch 1/1, Loss: 2.325581576937111, Accuracy: 0.983
# 	Training Client 19/60
# Epoch 1/1, Loss: 1.44251801379869, Accuracy: 0.989
# 	Training Client 20/60
# Epoch 1/1, Loss: 1.0894401893820032, Accuracy: 0.989
# 	Training Client 21/60
# Epoch 1/1, Loss: 1.9968552906648256, Accuracy: 0.983
# 	Training Client 22/60
# Epoch 1/1, Loss: 2.1300645992159843, Accuracy: 0.978
# 	Training Client 23/60
# Epoch 1/1, Loss: 1.981271962635219, Accuracy: 0.984
# 	Training Client 24/60
# Epoch 1/1, Loss: 1.5979209614743013, Accuracy: 0.986
# 	Training Client 25/60
# Epoch 1/1, Loss: 1.1623079137993955, Accuracy: 0.991
# 	Training Client 26/60
# Epoch 1/1, Loss: 1.6641238874726696, Accuracy: 0.982
# 	Training Client 27/60
# Epoch 1/1, Loss: 2.2558708862634376, Accuracy: 0.977
# 	Training Client 28/60
# Epoch 1/1, Loss: 1.5256064292043447, Accuracy: 0.987
# 	Training Client 29/60
# Epoch 1/1, Loss: 1.0200370717607257, Accuracy: 0.991
# 	Training Client 30/60
# Epoch 1/1, Loss: 1.367464700519804, Accuracy: 0.986
# 	Training Client 31/60
# Epoch 1/1, Loss: 1.2051672596862772, Accuracy: 0.989
# 	Training Client 32/60
# Epoch 1/1, Loss: 2.4624527683481574, Accuracy: 0.979
# 	Training Client 33/60
# Epoch 1/1, Loss: 1.7990759114036337, Accuracy: 0.979
# 	Training Client 34/60
# Epoch 1/1, Loss: 2.3197447856146027, Accuracy: 0.981
# 	Training Client 35/60
# Epoch 1/1, Loss: 1.3798453119816259, Accuracy: 0.986
# 	Training Client 36/60
# Epoch 1/1, Loss: 2.187261985614896, Accuracy: 0.982
# 	Training Client 37/60
# Epoch 1/1, Loss: 1.533750838803826, Accuracy: 0.985
# 	Training Client 38/60
# Epoch 1/1, Loss: 2.196764948661439, Accuracy: 0.983
# 	Training Client 39/60
# Epoch 1/1, Loss: 1.9442749922163785, Accuracy: 0.981
# 	Training Client 40/60
# Epoch 1/1, Loss: 1.62193021888379, Accuracy: 0.982
# 	Training Client 41/60
# Epoch 1/1, Loss: 1.374177652367507, Accuracy: 0.993
# 	Training Client 42/60
# Epoch 1/1, Loss: 0.8935058654060413, Accuracy: 0.992
# 	Training Client 43/60
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 190
#     188 # Example usage
#     189 if __name__ == "__main__":
# --> 190     client_accuracies=federated_learning(num_clients=60, num_local_epochs=1, num_global_epochs=40)
#     191     print("Client Accuracies:", client_accuracies)
#
# Cell In[6], line 90, in federated_learning(num_clients, num_local_epochs, num_global_epochs)
#      83             # Change beta1 and beta2 if concept drift detected
#      84 #             if i in fixed_detected_drift_clients :
#      85 #                 print(f"initiating optimization for client {i+1}")
#      86 #                 optimizer = optim.Adam(client_models[i].parameters(), lr=0.001, betas=(0.8, 0.999))
#      87 #                 loss = client_training(train_loader, client_models[i], criterion, optimizer, num_local_epochs)
#      88 #             else:
#      89             optimizer = optim.Adam(client_models[i].parameters(), lr=0.001)
# ---> 90             loss = client_training(train_loader, client_models[i], criterion, optimizer, num_local_epochs)
#      92             client_losses.append(loss)
#      95             # Update previous client losses
#
# Cell In[4], line 29, in client_training(train_loader, model, criterion, optimizer, num_epochs)
#      27 labels = labels.to(device)
#      28 optimizer.zero_grad()
# ---> 29 outputs = model(images)
#      30 loss = criterion(outputs, labels)
#      31 loss.backward()
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[4], line 16, in CNN.forward(self, x)
#      14 x = torch.max_pool2d(x, kernel_size=2, stride=2)
#      15 x = x.view(-1, 64 * 5 * 5)
# ---> 16 x = torch.relu(self.fc1(x))
#      17 x = self.fc2(x)
#      18 return torch.log_softmax(x, dim=1)
#
# KeyboardInterrupt:
