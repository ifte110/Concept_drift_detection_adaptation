# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import shap
from scipy.stats import mannwhitneyu, ttest_ind, ks_2samp, ttest_ind_from_stats
import copy
import random
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split

# %%
# Define the model architecture
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.fc1 = nn.Linear(64 * 5 * 5, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = torch.relu(self.conv2(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = x.view(-1, 64 * 5 * 5)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return torch.log_softmax(x, dim=1)

# Function to simulate client training with MNIST data
def client_training(train_loader, model, criterion, optimizer, num_epochs=1):
    model.train()
    for epoch in range(num_epochs):
        total_loss, correct, total = 0.0, 0.0, 0.0
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        accuracy = correct / total
        print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss}, Accuracy: {accuracy}")
        
    return total_loss

# Function to test the trained model on client data
def client_testing(test_loader, model):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total

# %%
# Function to compute SHAP values
def compute_shap_values(model, shap_data, background):
    explainer = shap.DeepExplainer(model, background)
    x, labels = explainer.shap_values(shap_data, ranked_outputs=1, check_additivity=False)
    
    x_shap_value = np.array(x[0])
    shap_values_reshaped = x_shap_value.reshape(x_shap_value.shape[0], -1)
    features = [f'Feature_{i}' for i in range(shap_values_reshaped.shape[1])]
    shap_mean_values = np.mean(shap_values_reshaped, axis=0)
    
    valid_indices = np.sum(np.abs(shap_values_reshaped), axis=0) >= 5
    filtered_shap_values = shap_mean_values[valid_indices]
    filtered_features = [feature for i, feature in enumerate(features) if valid_indices[i]]
    
    return filtered_shap_values, filtered_features

# %%
# Federated learning process with shap analysis
def federated_learning(num_clients=5, num_local_epochs=5, num_global_epochs=5):
    
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
    trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)
    
    partition_size = len(trainset) // num_clients
    lengths = [partition_size] * num_clients
    datasets = random_split(trainset, lengths)
    
    client_indices = [dataset.indices for dataset in datasets]
    
    # clients that will experience concept drift
    drift_clients = [2,6,9]

    # Initialize global model
    global_model = CNN().to(device)
    previous_shap_values_per_client = [None] * num_clients
    previous_shap_features_per_client = [None] * num_clients
    drastic_change_factor = 3  # Example threshold for drastic change
    previous_client_losses = [0.0] * num_clients
    drastic_change_detected = [False] * num_clients
    sustained_high_loss = [False] * num_clients
    
    # Initialize feature occurrence dictionary
    feature_occurrence_dict = {}
    frequent_features = []

    # Initialize counters for drift detection performance
    true_positives = 0
    true_negatives = 0
    false_positives = 0
    false_negatives = 0

    # Federated learning process
    for global_epoch in range(num_global_epochs):
        print(f"Global Epoch {global_epoch + 1}/{num_global_epochs}")

#         # Swap features if the current global epoch is more than half
#         if global_epoch == 10: # (num_global_epochs // 2):
#             print("Swapping features for classes 3, 8, 5, and 6 in the train dataset for each client")
#             for client_id in drift_clients:
#                 indices = client_indices[client_id]
#                 for idx in indices:
#                     if trainset.targets[idx] in [5,6]:
#                         trainset.data[idx] = torch.flip(trainset.data[idx], [0, 1])
                        
        if global_epoch == 10:  # (num_global_epochs // 2):
            print("Swapping 100 features between classes 3 and 8, 5 and 6 in the train dataset for each client")
            for client_id in drift_clients:
                indices = client_indices[client_id]
                for idx in indices:
                    if trainset.targets[idx] in [3, 8, 5, 6]:
                        # Choose 100 random pixels to swap
                        h, w = trainset.data[idx].shape
                        num_features_to_swap = 700
                        swap_indices = random.sample(range(h * w), num_features_to_swap)
                        for swap_idx in swap_indices:
                            y, x = divmod(swap_idx, w)
                            # Swap the pixel value with another pixel within the same image
                            swap_y, swap_x = random.randint(0, h-1), random.randint(0, w-1)
                            trainset.data[idx, y, x], trainset.data[idx, swap_y, swap_x] = trainset.data[idx, swap_y, swap_x], trainset.data[idx, y, x]
                    
        client_train_loaders = [torch.utils.data.DataLoader(torch.utils.data.Subset(trainset, indices), batch_size=32, shuffle=True) for indices in client_indices]
        client_test_loaders = [torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False) for _ in range(num_clients)]
        client_models = [copy.deepcopy(global_model) for _ in range(num_clients)]

        # Perform local training and compute SHAP values
        shap_values_per_client = []
        shap_features_per_client = []
        client_losses = []
        
        for i, train_loader in enumerate(client_train_loaders):
            print(f"\tTraining Client {i + 1}/{num_clients}")
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(client_models[i].parameters(), lr=0.001)
            loss = client_training(train_loader, client_models[i], criterion, optimizer, num_local_epochs)
            client_losses.append(loss)   

            client_shap_data = []
            client_shap_labels = []
            client_class_count = {i: 0 for i in range(10)}

            for batch_idx, (images, labels) in enumerate(train_loader):
                for img, lbl in zip(images, labels):
                    if client_class_count[lbl.item()] < 10:  # Accumulate up to num images per class
                        client_shap_data.append(img)
                        client_shap_labels.append(lbl)
                        client_class_count[lbl.item()] += 1

                # Check if we've accumulated 10 images for each class
                if all(count >= 10 for count in client_class_count.values()):
                    break
            
            if all(count >= 10 for count in client_class_count.values()):
                shap_data = torch.stack(client_shap_data).to(device)
                shap_labels = torch.stack(client_shap_labels).to(device)

                # Split shap_data into 90% and 10% sets
                num_samples = shap_data.size(0)
                split_idx = int(num_samples * 0.9)
                background = shap_data[split_idx:].to(device)  # 10% of data for background
                shap_data = shap_data[:split_idx].to(device)  # 90% of data for SHAP computation
                shap_labels = shap_labels[:split_idx].to(device)  # Corresponding labels

                # Compute SHAP values by class
                print(f"\t\tComputed SHAP values for Client {i + 1}/{num_clients}")
                shap_values, shap_features = compute_shap_values(client_models[i], shap_data, background)
                shap_values_per_client.append(shap_values)
                shap_features_per_client.append(shap_features)

        # Perform Kolmogorov-Smirnov test on SHAP values
        print("\tPerforming Kolmogorov–Smirnov test for SHAP values")
        p_values = []
        for i, (shap_values_client, shap_features_client) in enumerate(zip(shap_values_per_client, shap_features_per_client)):
            if previous_shap_values_per_client[i] is not None:
                if global_epoch >= 5 and frequent_features:
                    common_features = list(set(shap_features_client) & set(previous_shap_features_per_client[i]) & set(frequent_features))
                else:
                    common_features = list(set(shap_features_client) & set(previous_shap_features_per_client[i]))
                if common_features:
                    current_indices = [shap_features_client.index(feature) for feature in common_features]
                    previous_indices = [previous_shap_features_per_client[i].index(feature) for feature in common_features]
                    if current_indices and previous_indices:
                        stat, p_value = ks_2samp(shap_values_client[current_indices], previous_shap_values_per_client[i][previous_indices])
                        p_values.append(p_value)
                else:
                    p_values.append(1.0)
            else:
                p_values.append(1.0)
        
        # Update SHAP values and feature occurrence dictionary
        for i, (shap_values, shap_features) in enumerate(zip(shap_values_per_client, shap_features_per_client)):
            previous_shap_values_per_client[i] = shap_values
            previous_shap_features_per_client[i] = shap_features
            for feature in shap_features:
                feature_occurrence_dict[feature] = feature_occurrence_dict.get(feature, 0) + 1

        frequent_features = [feature for feature, count in feature_occurrence_dict.items() if count >= 20]
#         print(f"\tFrequent Features: {frequent_features}")
        

        # Detect Concept Drift using p-values and other metrics
        if global_epoch>=5:
            detected_drift_clients = [i for i, p_value in enumerate(p_values) if p_value <= 0.005]

            # Calculate federated accuracy for each client model
            for client_id in range(num_clients):
                ground_truth_drift = (client_id in drift_clients) and (global_epoch>=10)
                detected_drift = client_id in detected_drift_clients

                if detected_drift and ground_truth_drift:
                    true_positives += 1
                elif not detected_drift and not ground_truth_drift:
                    true_negatives += 1
                elif detected_drift and not ground_truth_drift:
                    false_positives += 1
                elif not detected_drift and ground_truth_drift:
                    false_negatives += 1

                if detected_drift == ground_truth_drift:
                    print(f"Global Epoch {global_epoch + 1}, Client {client_id + 1}: Drift detection is accurate.")
                else:
                    print(f"Global Epoch {global_epoch + 1}, Client {client_id + 1}: Drift detection is inaccurate.")

                    
    
        # Aggregate client models into global model
        print("\tAggregating client models")
        global_model = aggregate_models(global_model, client_models)

    # Test models on each client
    accuracies = []
    for i, test_loader in enumerate(client_test_loaders):
        print(f"Testing Client {i + 1}/{num_clients}")
        accuracy = client_testing(test_loader, global_model)
        accuracies.append(accuracy)
        print(f"\tAccuracy for Client {i + 1}/{num_clients}: {accuracy}")
        
    # Calculate performance metrics of drift detection
    accuracy = (true_positives + true_negatives) / (true_positives + true_negatives + false_positives + false_negatives)
    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
    f1_score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

    print(f"Drift Detection metircs::: true_positives:{true_positives},true_negatives:{true_negatives},false_positives:{false_positives},false_negatives:{false_negatives}")
    print(f"Drift Detection Performance:\nAccuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1_score}")
        

    return accuracies

# Aggregation of models' weights using FedAvg
def aggregate_models(global_model, client_models):
    global_dict = global_model.state_dict()
    for k in global_dict.keys():
        global_dict[k] = torch.stack([client_model.state_dict()[k].float() for client_model in client_models], 0).mean(0)
    global_model.load_state_dict(global_dict)
    return global_model


# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Example usage
if __name__ == "__main__":
    client_accuracies=federated_learning(num_clients=10, num_local_epochs=1, num_global_epochs=20)
    print("Client Accuracies:", client_accuracies)
# Out:
# Global Epoch 1/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 110.54682398214936, Accuracy: 0.8206666666666667
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 106.04906145483255, Accuracy: 0.824
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 108.55197816714644, Accuracy: 0.8243333333333334
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 109.73743585497141, Accuracy: 0.8206666666666667
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 100.90648332238197, Accuracy: 0.8366666666666667
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 103.60011716187, Accuracy: 0.8321666666666667
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 100.37193609774113, Accuracy: 0.8361666666666666
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 103.87043135985732, Accuracy: 0.8251666666666667
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 110.34378460422158, Accuracy: 0.8178333333333333
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 101.54963349550962, Accuracy: 0.831
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# 	Aggregating client models
# Global Epoch 2/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 33.66873789392412, Accuracy: 0.9496666666666667
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 33.09340955223888, Accuracy: 0.949
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 31.20454262336716, Accuracy: 0.9481666666666667
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 32.711294521577656, Accuracy: 0.9476666666666667
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 32.91583124175668, Accuracy: 0.9468333333333333
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 33.65801520925015, Accuracy: 0.9465
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 30.394970102235675, Accuracy: 0.9521666666666667
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 31.685144503600895, Accuracy: 0.9458333333333333
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 32.36145322397351, Accuracy: 0.9476666666666667
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 28.99538928689435, Accuracy: 0.954
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# 	Aggregating client models
# Global Epoch 3/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 20.311718041542917, Accuracy: 0.9653333333333334
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 21.499310831539333, Accuracy: 0.9653333333333334
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 20.665173143846914, Accuracy: 0.9663333333333334
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 21.19504699949175, Accuracy: 0.9615
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 22.274149117525667, Accuracy: 0.9613333333333334
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 22.90994416270405, Accuracy: 0.9643333333333334
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 19.940252869855613, Accuracy: 0.9676666666666667
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 20.556267444510013, Accuracy: 0.9643333333333334
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 20.689529518596828, Accuracy: 0.9676666666666667
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 17.570419987896457, Accuracy: 0.9726666666666667
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# 	Aggregating client models
# Global Epoch 4/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 16.705095403594896, Accuracy: 0.973
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 16.649615553440526, Accuracy: 0.9705
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 15.872489420813508, Accuracy: 0.9721666666666666
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 15.943779728200752, Accuracy: 0.974
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 16.625153031083755, Accuracy: 0.9715
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 17.410480190301314, Accuracy: 0.9713333333333334
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 15.954477822931949, Accuracy: 0.9761666666666666
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 15.749921177164651, Accuracy: 0.9731666666666666
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 17.693347733234987, Accuracy: 0.9731666666666666
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 14.811838681343943, Accuracy: 0.9761666666666666
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# 	Aggregating client models
# Global Epoch 5/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 12.729070884292014, Accuracy: 0.9765
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 13.903773466474377, Accuracy: 0.9793333333333333
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 12.928453770029591, Accuracy: 0.978
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 13.330517986905761, Accuracy: 0.9798333333333333
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 13.7365056311246, Accuracy: 0.9776666666666667
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 14.780617653625086, Accuracy: 0.9763333333333334
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 13.703083780070301, Accuracy: 0.9798333333333333
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 11.771173730725423, Accuracy: 0.9788333333333333
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 13.384767414187081, Accuracy: 0.9796666666666667
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 11.73445022397209, Accuracy: 0.9786666666666667
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# 	Aggregating client models
# Global Epoch 6/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 11.132723555143457, Accuracy: 0.9796666666666667
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 11.208167771343142, Accuracy: 0.982
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 11.453540753078414, Accuracy: 0.9833333333333333
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 12.507358411559835, Accuracy: 0.9795
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 11.54377125040628, Accuracy: 0.9806666666666667
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 12.067372789257206, Accuracy: 0.9805
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 10.590350721497089, Accuracy: 0.9816666666666667
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 10.694573417509673, Accuracy: 0.9826666666666667
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 13.070832633267855, Accuracy: 0.9805
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 10.832526206271723, Accuracy: 0.9816666666666667
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 6, Client 1: Drift detection is inaccurate.
# Global Epoch 6, Client 2: Drift detection is inaccurate.
# Global Epoch 6, Client 3: Drift detection is accurate.
# Global Epoch 6, Client 4: Drift detection is accurate.
# Global Epoch 6, Client 5: Drift detection is accurate.
# Global Epoch 6, Client 6: Drift detection is accurate.
# Global Epoch 6, Client 7: Drift detection is accurate.
# Global Epoch 6, Client 8: Drift detection is accurate.
# Global Epoch 6, Client 9: Drift detection is accurate.
# Global Epoch 6, Client 10: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 7/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 10.35884148342302, Accuracy: 0.983
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 10.58735975952004, Accuracy: 0.9826666666666667
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 10.994844004802871, Accuracy: 0.9813333333333333
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 11.214956983865704, Accuracy: 0.9816666666666667
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 10.799946741375607, Accuracy: 0.9825
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 12.116428142238874, Accuracy: 0.981
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 9.305409307969967, Accuracy: 0.985
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 10.491325242561288, Accuracy: 0.983
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 11.11593221174553, Accuracy: 0.9843333333333333
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 8.494241599197267, Accuracy: 0.9858333333333333
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 7, Client 1: Drift detection is accurate.
# Global Epoch 7, Client 2: Drift detection is accurate.
# Global Epoch 7, Client 3: Drift detection is accurate.
# Global Epoch 7, Client 4: Drift detection is accurate.
# Global Epoch 7, Client 5: Drift detection is accurate.
# Global Epoch 7, Client 6: Drift detection is accurate.
# Global Epoch 7, Client 7: Drift detection is accurate.
# Global Epoch 7, Client 8: Drift detection is accurate.
# Global Epoch 7, Client 9: Drift detection is accurate.
# Global Epoch 7, Client 10: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 8/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 9.532902837992879, Accuracy: 0.984
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 9.59039676914108, Accuracy: 0.9836666666666667
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 8.741748618747806, Accuracy: 0.9848333333333333
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 9.753084944997681, Accuracy: 0.9836666666666667
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 10.111024299025303, Accuracy: 0.9838333333333333
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 9.999150726624066, Accuracy: 0.9835
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 9.497790135792457, Accuracy: 0.9853333333333333
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 8.396422610123409, Accuracy: 0.9868333333333333
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 9.714817774132825, Accuracy: 0.9853333333333333
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 8.2212825716706, Accuracy: 0.9865
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 8, Client 1: Drift detection is accurate.
# Global Epoch 8, Client 2: Drift detection is accurate.
# Global Epoch 8, Client 3: Drift detection is accurate.
# Global Epoch 8, Client 4: Drift detection is accurate.
# Global Epoch 8, Client 5: Drift detection is accurate.
# Global Epoch 8, Client 6: Drift detection is accurate.
# Global Epoch 8, Client 7: Drift detection is accurate.
# Global Epoch 8, Client 8: Drift detection is accurate.
# Global Epoch 8, Client 9: Drift detection is accurate.
# Global Epoch 8, Client 10: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 9/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 7.811738911725115, Accuracy: 0.9858333333333333
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 8.387022879425786, Accuracy: 0.9855
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 7.601025850948645, Accuracy: 0.985
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 8.83871753817948, Accuracy: 0.9855
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 8.538489037542604, Accuracy: 0.9851666666666666
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 9.704085504708928, Accuracy: 0.9861666666666666
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 7.6834596419357695, Accuracy: 0.9873333333333333
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 7.70557691873546, Accuracy: 0.9856666666666667
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 9.278726351520163, Accuracy: 0.9855
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 6.60430366888977, Accuracy: 0.9886666666666667
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 9, Client 1: Drift detection is accurate.
# Global Epoch 9, Client 2: Drift detection is accurate.
# Global Epoch 9, Client 3: Drift detection is accurate.
# Global Epoch 9, Client 4: Drift detection is accurate.
# Global Epoch 9, Client 5: Drift detection is accurate.
# Global Epoch 9, Client 6: Drift detection is accurate.
# Global Epoch 9, Client 7: Drift detection is accurate.
# Global Epoch 9, Client 8: Drift detection is accurate.
# Global Epoch 9, Client 9: Drift detection is accurate.
# Global Epoch 9, Client 10: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 10/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 8.189730243233498, Accuracy: 0.9866666666666667
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 8.572141684424423, Accuracy: 0.9843333333333333
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 7.152873337894562, Accuracy: 0.9881666666666666
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 7.315641760680592, Accuracy: 0.9885
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 7.424531493583345, Accuracy: 0.9878333333333333
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 8.732348569188616, Accuracy: 0.9856666666666667
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 7.573015854664845, Accuracy: 0.9883333333333333
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 7.400411895650905, Accuracy: 0.9868333333333333
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 8.562833691743435, Accuracy: 0.9873333333333333
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 6.208514246347477, Accuracy: 0.9901666666666666
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 10, Client 1: Drift detection is accurate.
# Global Epoch 10, Client 2: Drift detection is accurate.
# Global Epoch 10, Client 3: Drift detection is inaccurate.
# Global Epoch 10, Client 4: Drift detection is accurate.
# Global Epoch 10, Client 5: Drift detection is accurate.
# Global Epoch 10, Client 6: Drift detection is accurate.
# Global Epoch 10, Client 7: Drift detection is accurate.
# Global Epoch 10, Client 8: Drift detection is accurate.
# Global Epoch 10, Client 9: Drift detection is inaccurate.
# Global Epoch 10, Client 10: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 11/20
# Swapping 100 features between classes 3 and 8, 5 and 6 in the train dataset for each client
# 	Training Client 1/10
# Epoch 1/1, Loss: 7.043472643606947, Accuracy: 0.9868333333333333
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 7.1188648521201685, Accuracy: 0.9878333333333333
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 107.00606122612953, Accuracy: 0.7448333333333333
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 8.276769937918289, Accuracy: 0.9875
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 7.3333172592683695, Accuracy: 0.9868333333333333
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 7.74951793490618, Accuracy: 0.9873333333333333
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 104.18025885522366, Accuracy: 0.7563333333333333
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 6.384094669119804, Accuracy: 0.9881666666666666
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 8.44413477931812, Accuracy: 0.9868333333333333
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 101.871877014637, Accuracy: 0.7606666666666667
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 11, Client 1: Drift detection is accurate.
# Global Epoch 11, Client 2: Drift detection is accurate.
# Global Epoch 11, Client 3: Drift detection is inaccurate.
# Global Epoch 11, Client 4: Drift detection is accurate.
# Global Epoch 11, Client 5: Drift detection is accurate.
# Global Epoch 11, Client 6: Drift detection is accurate.
# Global Epoch 11, Client 7: Drift detection is inaccurate.
# Global Epoch 11, Client 8: Drift detection is accurate.
# Global Epoch 11, Client 9: Drift detection is accurate.
# Global Epoch 11, Client 10: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 12/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 7.218997584586759, Accuracy: 0.9885
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 7.093595658669074, Accuracy: 0.9885
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 103.40109086036682, Accuracy: 0.7535
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 7.585655229195254, Accuracy: 0.9861666666666666
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 7.2624211988877505, Accuracy: 0.9888333333333333
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 7.581380091345636, Accuracy: 0.987
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 99.14925490319729, Accuracy: 0.764
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 7.045852575349272, Accuracy: 0.9898333333333333
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 7.103583764022915, Accuracy: 0.9883333333333333
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 97.9384800940752, Accuracy: 0.766
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 12, Client 1: Drift detection is accurate.
# Global Epoch 12, Client 2: Drift detection is accurate.
# Global Epoch 12, Client 3: Drift detection is inaccurate.
# Global Epoch 12, Client 4: Drift detection is accurate.
# Global Epoch 12, Client 5: Drift detection is accurate.
# Global Epoch 12, Client 6: Drift detection is accurate.
# Global Epoch 12, Client 7: Drift detection is inaccurate.
# Global Epoch 12, Client 8: Drift detection is accurate.
# Global Epoch 12, Client 9: Drift detection is accurate.
# Global Epoch 12, Client 10: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 13/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 6.262381166292471, Accuracy: 0.9881666666666666
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 7.098874078197696, Accuracy: 0.9878333333333333
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 98.45531229674816, Accuracy: 0.7666666666666667
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 7.102980811425368, Accuracy: 0.9898333333333333
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 6.9049757156317355, Accuracy: 0.9876666666666667
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 7.586816380857272, Accuracy: 0.9885
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 97.01552023738623, Accuracy: 0.7735
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 5.808121018380916, Accuracy: 0.991
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 7.712548200019228, Accuracy: 0.987
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 96.16589412093163, Accuracy: 0.7696666666666667
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 13, Client 1: Drift detection is accurate.
# Global Epoch 13, Client 2: Drift detection is accurate.
# Global Epoch 13, Client 3: Drift detection is accurate.
# Global Epoch 13, Client 4: Drift detection is accurate.
# Global Epoch 13, Client 5: Drift detection is accurate.
# Global Epoch 13, Client 6: Drift detection is accurate.
# Global Epoch 13, Client 7: Drift detection is inaccurate.
# Global Epoch 13, Client 8: Drift detection is accurate.
# Global Epoch 13, Client 9: Drift detection is accurate.
# Global Epoch 13, Client 10: Drift detection is inaccurate.
# 	Aggregating client models
# Global Epoch 14/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 5.740923617453518, Accuracy: 0.9896666666666667
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 5.679124894370034, Accuracy: 0.9913333333333333
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 96.07513228058815, Accuracy: 0.7661666666666667
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 6.714348062145291, Accuracy: 0.9881666666666666
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 5.959602540351625, Accuracy: 0.9905
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 6.9534418709044985, Accuracy: 0.9896666666666667
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 95.19644096493721, Accuracy: 0.7743333333333333
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 6.274521042101696, Accuracy: 0.9883333333333333
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 7.3751848492020144, Accuracy: 0.9885
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 94.25092139840126, Accuracy: 0.7766666666666666
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 14, Client 1: Drift detection is accurate.
# Global Epoch 14, Client 2: Drift detection is accurate.
# Global Epoch 14, Client 3: Drift detection is inaccurate.
# Global Epoch 14, Client 4: Drift detection is accurate.
# Global Epoch 14, Client 5: Drift detection is accurate.
# Global Epoch 14, Client 6: Drift detection is accurate.
# Global Epoch 14, Client 7: Drift detection is accurate.
# Global Epoch 14, Client 8: Drift detection is accurate.
# Global Epoch 14, Client 9: Drift detection is accurate.
# Global Epoch 14, Client 10: Drift detection is inaccurate.
# 	Aggregating client models
# Global Epoch 15/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 5.686734232622257, Accuracy: 0.9891666666666666
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 5.657505239661987, Accuracy: 0.9905
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 96.41853904724121, Accuracy: 0.7745
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 6.368364315123472, Accuracy: 0.9901666666666666
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 6.7122499056349625, Accuracy: 0.9883333333333333
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 5.83464368372006, Accuracy: 0.9893333333333333
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 94.53096528351307, Accuracy: 0.783
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 5.932595948295784, Accuracy: 0.9905
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 6.468205132492585, Accuracy: 0.9886666666666667
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 91.8065528422594, Accuracy: 0.7791666666666667
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 15, Client 1: Drift detection is accurate.
# Global Epoch 15, Client 2: Drift detection is inaccurate.
# Global Epoch 15, Client 3: Drift detection is accurate.
# Global Epoch 15, Client 4: Drift detection is accurate.
# Global Epoch 15, Client 5: Drift detection is accurate.
# Global Epoch 15, Client 6: Drift detection is inaccurate.
# Global Epoch 15, Client 7: Drift detection is accurate.
# Global Epoch 15, Client 8: Drift detection is accurate.
# Global Epoch 15, Client 9: Drift detection is accurate.
# Global Epoch 15, Client 10: Drift detection is inaccurate.
# 	Aggregating client models
# Global Epoch 16/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 5.7970088193756055, Accuracy: 0.9901666666666666
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 5.93676499436333, Accuracy: 0.9903333333333333
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 95.23538632690907, Accuracy: 0.7758333333333334
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 6.139240490134398, Accuracy: 0.9896666666666667
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 5.246878695023042, Accuracy: 0.9915
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 6.018393850295979, Accuracy: 0.99
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 92.77883902192116, Accuracy: 0.7831666666666667
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 5.221850938685748, Accuracy: 0.9908333333333333
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 5.981895443008398, Accuracy: 0.9906666666666667
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 90.33636347949505, Accuracy: 0.7931666666666667
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 16, Client 1: Drift detection is accurate.
# Global Epoch 16, Client 2: Drift detection is accurate.
# Global Epoch 16, Client 3: Drift detection is accurate.
# Global Epoch 16, Client 4: Drift detection is inaccurate.
# Global Epoch 16, Client 5: Drift detection is accurate.
# Global Epoch 16, Client 6: Drift detection is accurate.
# Global Epoch 16, Client 7: Drift detection is inaccurate.
# Global Epoch 16, Client 8: Drift detection is accurate.
# Global Epoch 16, Client 9: Drift detection is accurate.
# Global Epoch 16, Client 10: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 17/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 5.188445957103795, Accuracy: 0.9898333333333333
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 5.6122534758524125, Accuracy: 0.9913333333333333
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 92.16322433948517, Accuracy: 0.786
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 5.564192877724054, Accuracy: 0.9895
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 6.0266416356698755, Accuracy: 0.9906666666666667
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 5.875800191719463, Accuracy: 0.9908333333333333
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 91.49471713602543, Accuracy: 0.7865
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 4.946393444853584, Accuracy: 0.9915
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 6.085497360084446, Accuracy: 0.9895
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 89.38014476001263, Accuracy: 0.794
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 17, Client 1: Drift detection is accurate.
# Global Epoch 17, Client 2: Drift detection is inaccurate.
# Global Epoch 17, Client 3: Drift detection is inaccurate.
# Global Epoch 17, Client 4: Drift detection is accurate.
# Global Epoch 17, Client 5: Drift detection is accurate.
# Global Epoch 17, Client 6: Drift detection is accurate.
# Global Epoch 17, Client 7: Drift detection is inaccurate.
# Global Epoch 17, Client 8: Drift detection is accurate.
# Global Epoch 17, Client 9: Drift detection is accurate.
# Global Epoch 17, Client 10: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 18/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 5.446117705127108, Accuracy: 0.9916666666666667
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 4.850516727491367, Accuracy: 0.9936666666666667
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 92.67704726755619, Accuracy: 0.7855
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 5.253634908309323, Accuracy: 0.9921666666666666
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 5.137618371343706, Accuracy: 0.9918333333333333
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 6.274804777980535, Accuracy: 0.9908333333333333
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 90.79271700978279, Accuracy: 0.7881666666666667
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 5.20603617425877, Accuracy: 0.9918333333333333
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 6.4839086285137455, Accuracy: 0.9911666666666666
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 88.52639332413673, Accuracy: 0.7951666666666667
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 18, Client 1: Drift detection is accurate.
# Global Epoch 18, Client 2: Drift detection is accurate.
# Global Epoch 18, Client 3: Drift detection is inaccurate.
# Global Epoch 18, Client 4: Drift detection is accurate.
# Global Epoch 18, Client 5: Drift detection is accurate.
# Global Epoch 18, Client 6: Drift detection is accurate.
# Global Epoch 18, Client 7: Drift detection is inaccurate.
# Global Epoch 18, Client 8: Drift detection is accurate.
# Global Epoch 18, Client 9: Drift detection is accurate.
# Global Epoch 18, Client 10: Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 19/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 4.769155599580699, Accuracy: 0.9918333333333333
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 4.576575268391025, Accuracy: 0.993
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 90.88683679699898, Accuracy: 0.7888333333333334
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 5.86107814391471, Accuracy: 0.9905
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 5.142895805186981, Accuracy: 0.9915
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 5.353289488592964, Accuracy: 0.9925
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 89.01894060522318, Accuracy: 0.7928333333333333
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 4.1736236374490545, Accuracy: 0.9923333333333333
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 6.112098672496359, Accuracy: 0.9896666666666667
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 88.3388237208128, Accuracy: 0.7941666666666667
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 19, Client 1: Drift detection is inaccurate.
# Global Epoch 19, Client 2: Drift detection is accurate.
# Global Epoch 19, Client 3: Drift detection is inaccurate.
# Global Epoch 19, Client 4: Drift detection is accurate.
# Global Epoch 19, Client 5: Drift detection is accurate.
# Global Epoch 19, Client 6: Drift detection is accurate.
# Global Epoch 19, Client 7: Drift detection is inaccurate.
# Global Epoch 19, Client 8: Drift detection is accurate.
# Global Epoch 19, Client 9: Drift detection is inaccurate.
# Global Epoch 19, Client 10: Drift detection is inaccurate.
# 	Aggregating client models
# Global Epoch 20/20
# 	Training Client 1/10
# Epoch 1/1, Loss: 4.356100785423223, Accuracy: 0.9923333333333333
# 		Computed SHAP values for Client 1/10
# 	Training Client 2/10
# Epoch 1/1, Loss: 4.333660833886597, Accuracy: 0.992
# 		Computed SHAP values for Client 2/10
# 	Training Client 3/10
# Epoch 1/1, Loss: 90.4126316010952, Accuracy: 0.7918333333333333
# 		Computed SHAP values for Client 3/10
# 	Training Client 4/10
# Epoch 1/1, Loss: 4.888301298268743, Accuracy: 0.9921666666666666
# 		Computed SHAP values for Client 4/10
# 	Training Client 5/10
# Epoch 1/1, Loss: 5.8530941147196245, Accuracy: 0.9913333333333333
# 		Computed SHAP values for Client 5/10
# 	Training Client 6/10
# Epoch 1/1, Loss: 4.471453824562559, Accuracy: 0.9943333333333333
# 		Computed SHAP values for Client 6/10
# 	Training Client 7/10
# Epoch 1/1, Loss: 88.8343326896429, Accuracy: 0.798
# 		Computed SHAP values for Client 7/10
# 	Training Client 8/10
# Epoch 1/1, Loss: 4.423710412757828, Accuracy: 0.9933333333333333
# 		Computed SHAP values for Client 8/10
# 	Training Client 9/10
# Epoch 1/1, Loss: 4.933044197885465, Accuracy: 0.9915
# 		Computed SHAP values for Client 9/10
# 	Training Client 10/10
# Epoch 1/1, Loss: 87.1635000705719, Accuracy: 0.8006666666666666
# 		Computed SHAP values for Client 10/10
# 	Performing Kolmogorov–Smirnov test for SHAP values
# Global Epoch 20, Client 1: Drift detection is accurate.
# Global Epoch 20, Client 2: Drift detection is accurate.
# Global Epoch 20, Client 3: Drift detection is inaccurate.
# Global Epoch 20, Client 4: Drift detection is accurate.
# Global Epoch 20, Client 5: Drift detection is accurate.
# Global Epoch 20, Client 6: Drift detection is accurate.
# Global Epoch 20, Client 7: Drift detection is inaccurate.
# Global Epoch 20, Client 8: Drift detection is accurate.
# Global Epoch 20, Client 9: Drift detection is accurate.
# Global Epoch 20, Client 10: Drift detection is inaccurate.
# 	Aggregating client models
# Testing Client 1/10
# 	Accuracy for Client 1/10: 0.9919
# Testing Client 2/10
# 	Accuracy for Client 2/10: 0.9919
# Testing Client 3/10
# 	Accuracy for Client 3/10: 0.9919
# Testing Client 4/10
# 	Accuracy for Client 4/10: 0.9919
# Testing Client 5/10
# 	Accuracy for Client 5/10: 0.9919
# Testing Client 6/10
# 	Accuracy for Client 6/10: 0.9919
# Testing Client 7/10
# 	Accuracy for Client 7/10: 0.9919
# Testing Client 8/10
# 	Accuracy for Client 8/10: 0.9919
# Testing Client 9/10
# 	Accuracy for Client 9/10: 0.9919
# Testing Client 10/10
# 	Accuracy for Client 10/10: 0.9919
# Drift Detection metircs::: true_positives:10,true_negatives:110,false_positives:10,false_negatives:20
# Drift Detection Performance:
# Accuracy: 0.8
# Precision: 0.5
# Recall: 0.3333333333333333
# F1 Score: 0.4
# Client Accuracies: [0.9919, 0.9919, 0.9919, 0.9919, 0.9919, 0.9919, 0.9919, 0.9919, 0.9919, 0.9919]
