# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from scipy.ndimage import rotate
import shap
from scipy.stats import mannwhitneyu, ttest_ind, ks_2samp, ttest_ind_from_stats
import copy
import random
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split

# %%
# Set seed for reproducibility
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# Define the model architecture
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.fc1 = nn.Linear(64 * 5 * 5, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = torch.relu(self.conv2(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = x.view(-1, 64 * 5 * 5)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return torch.log_softmax(x, dim=1)

# Function to simulate client training with MNIST data
def client_training(train_loader, model, criterion, optimizer, num_epochs=1):
    model.train()
    for epoch in range(num_epochs):
        total_loss, correct, total = 0.0, 0.0, 0.0
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        accuracy = correct / total
        print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss}, Accuracy: {accuracy}")
        
    return total_loss, accuracy

# Function to test the trained model on client data
def client_testing(model,test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total

# %%
# Function to apply gradual rotation drift
def apply_rotation_drift(images, current_epoch, max_rotation, start_epoch, end_epoch, total_epochs):
    if current_epoch < start_epoch:
        rotation_angle = 0
    elif start_epoch <= current_epoch <= end_epoch:
        transition_progress = (current_epoch - start_epoch) / (end_epoch - start_epoch)
        rotation_angle = transition_progress * max_rotation
    else:
        rotation_angle = 0
    
    fraction_rotated = (current_epoch - start_epoch + 1) / (end_epoch - start_epoch + 1)
    num_images_to_rotate = int(fraction_rotated * len(images))
    
    drifted_images = images.clone()
    if num_images_to_rotate > 0 and fraction_rotated<=1:
        indices_to_rotate = torch.randperm(len(images))[:num_images_to_rotate]
        for idx in indices_to_rotate:
            drifted_images[idx] = torch.tensor(rotate(images[idx].numpy(), rotation_angle, reshape=False))
    
    return drifted_images

# %%
def create_global_optimum_model(global_model, global_model_sdrift, global_model_gdrift, global_model_mdrift, alpha_s, alpha_g, alpha_m):
    global_optimum_model = copy.deepcopy(global_model)
    global_dict = global_optimum_model.state_dict()
    
    for k in global_dict.keys():
        global_dict[k] = alpha_s * global_model_sdrift.state_dict()[k] + alpha_g * global_model_gdrift.state_dict()[k] + alpha_m * global_model_mdrift.state_dict()[k] + (1 - alpha_s - alpha_g - alpha_m) * global_model.state_dict()[k]
    
    global_optimum_model.load_state_dict(global_dict)
    return global_optimum_model

# %%
### replacing global model with opt model

def federated_learning(num_clients=60, num_local_epochs=5, num_global_epochs=40):
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,),(0.5,))])
    trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)

    partition_size = len(trainset) // num_clients
    lengths = [partition_size] * num_clients
    datasets = random_split(trainset, lengths)

    client_indices = [dataset.indices for dataset in datasets]

    # Clients that will experience rotation drift
    rotation_drift_clients = [5, 25, 13, 15, 29, 6, 1, 11, 8, 23, 18, 16, 19, 27, 20]

    # Clients that will experience class swap drift
#     class_swap_drift_clients = [5, 25, 13, 15, 29, 6, 1, 11, 8, 49, 48, 33, 42, 47, 54, 39, 38, 43, 37, 36, 51, 34, 41, 55]
    class_swap_drift_clients = [49, 48, 33, 42, 47, 54, 39, 38, 43, 37, 36, 51, 34, 41, 55]

    # Initialize global model
    global_model = CNN().to(device)
    previous_client_losses = [[] for _ in range(num_clients)]
    drastic_change_detected = [False] * num_clients
    sustained_high_loss = [False] * num_clients
    drastic_change = [False] * num_clients
    sustained_high = [False] * num_clients
    fixed_long_averages = [None] * num_clients  # Store fixed long window averages after drift detection

    # Initialize detected drift clients
    fixed_detected_drift_clients = {'sudden': [], 'gradual': []}
    global_model_sdrift = CNN().to(device)
    global_model_gdrift = CNN().to(device)
    global_model_mdrift = CNN().to(device)

    # Dictionary to track how many epochs each client has been detected for drift
    drift_count = {i: 0 for i in range(num_clients)}
    epoch_drift_detected = {i: [] for i in range(num_clients)}  # Track when drifts were detected
    no_drift_epochs = 0
    no_drift_epochs_th = 20

    # Define window sizes
    short_window = 15
    long_window = 20

    # Define factor for drastic change detection
    drastic_change_factor = 3

    # Initialize counters for drift detection performance
    true_positives = 0
    true_negatives = 0
    false_positives = 0
    false_negatives = 0
    
    
    disable_detection = False

    # Select indices in the test set for applying drift
    drifted_test_indices = np.random.choice(len(testset), size=int(1 * len(testset)), replace=False)

    # Initialize drifted_testset as a deep copy of the testset
    drifted_testset = copy.deepcopy(testset)

    # Federated learning process
    for global_epoch in range(num_global_epochs):
        # Reset the no_drift_detected flag
        no_drift_detected = False  # Assume no drift until proven otherwise
        
        print(f"Global Epoch {global_epoch + 1}/{num_global_epochs}")

        # Apply rotation drift gradually starting from a certain epoch
        if global_epoch in range(10, 31):  # Example threshold for starting drift
            print("Applying rotation drift to specific clients")
            for client_id in rotation_drift_clients:
                indices = client_indices[client_id]
                images = trainset.data[indices]
                drifted_images = apply_rotation_drift(images, global_epoch, max_rotation=30, start_epoch=10, end_epoch=30, total_epochs=num_global_epochs)
                trainset.data[indices] = drifted_images

            drifted_test_images = apply_rotation_drift(testset.data, global_epoch, max_rotation=30, start_epoch=10, end_epoch=30, total_epochs=num_global_epochs)
            drifted_testset.data = drifted_test_images

        # Apply class swap drift at a specific epoch
        if global_epoch == 10:
            print("Swapping classes 3 and 8 in the train dataset for selected clients")
            for client_id in class_swap_drift_clients:
                indices = client_indices[client_id]
                for idx in indices:
                    if trainset.targets[idx] == 8:
                        trainset.targets[idx] = 3
                    elif trainset.targets[idx] == 3:
                        trainset.targets[idx] = 8

            for idx in drifted_test_indices:
                if testset.targets[idx] == 8:
                    testset.targets[idx] = 3
                elif testset.targets[idx] == 3:
                    testset.targets[idx] = 8

        client_train_loaders = [torch.utils.data.DataLoader(torch.utils.data.Subset(trainset, indices), batch_size=32, shuffle=True) for indices in client_indices]
        client_test_loaders = [torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False) for _ in range(num_clients)]
        drifted_client_test_loaders = [torch.utils.data.DataLoader(drifted_testset, batch_size=64, shuffle=True) for _ in range(num_clients)]
        client_models = []

        # Assign client models based on detected drifts
        for i in range(num_clients):
            if no_drift_epochs >= no_drift_epochs_th or disable_detection:
                # Replace all models with the optimum global model if no drift for 20 epochs
                client_models.append(copy.deepcopy(global_model))
            else:
                if i in fixed_detected_drift_clients['gradual'] and i not in fixed_detected_drift_clients['sudden'] :
                    client_models.append(copy.deepcopy(global_model_gdrift))
                if i in fixed_detected_drift_clients['sudden'] and i not in fixed_detected_drift_clients['gradual'] :
                    client_models.append(copy.deepcopy(global_model_sdrift))
                if i in fixed_detected_drift_clients['sudden'] and i in fixed_detected_drift_clients['gradual']:
                    client_models.append(copy.deepcopy(global_model_mdrift))  # Presuming gdrift takes precedence
                if i not in fixed_detected_drift_clients['sudden'] and i not in fixed_detected_drift_clients['gradual']:
                    client_models.append(copy.deepcopy(global_model))

        client_losses = []
        client_acc = []
        for i, train_loader in enumerate(client_train_loaders):
            print(f"\tTraining Client {i + 1}/{num_clients}")
            criterion = nn.CrossEntropyLoss()
            
            if not disable_detection:

                # Check for gradual drift only
                if i in fixed_detected_drift_clients['gradual'] and i not in fixed_detected_drift_clients['sudden']:
                    optimizer = optim.Adam(client_models[i].parameters(), lr=0.001, betas=(0.6, 0.7))

                # Check for both sudden and gradual drifts
                if i in fixed_detected_drift_clients['sudden'] and i in fixed_detected_drift_clients['gradual']:
                    optimizer = optim.Adam(client_models[i].parameters(), lr=0.001, betas=(0.6, 0.7))

                # Check for sudden drift only
                if i in fixed_detected_drift_clients['sudden'] and i not in fixed_detected_drift_clients['gradual']:
                    optimizer = optim.Adam(client_models[i].parameters(), lr=0.001)

                # Default case for no drift
                if i not in fixed_detected_drift_clients['sudden'] and i not in fixed_detected_drift_clients['gradual']:
                    optimizer = optim.Adam(client_models[i].parameters(), lr=0.001)
                    
            else:
                optimizer = optim.Adam(client_models[i].parameters(), lr=0.001, betas=(0.6, 0.7))
                
            loss, acc = client_training(train_loader, client_models[i], criterion, optimizer, num_local_epochs)
            client_losses.append(loss)
            client_acc.append(acc)
            previous_client_losses[i].append(loss)
            if len(previous_client_losses[i]) > long_window:
                previous_client_losses[i].pop(0)

        # Concept drift detection for sudden drift
        if (global_epoch >= 5) and not disable_detection:
            for i in range(num_clients):
                prev_loss = previous_client_losses[i][-2]
                if not drastic_change[i]:
                    if client_losses[i] > (prev_loss * drastic_change_factor):
                        drastic_change[i] = True
                else:
                    if client_losses[i] >= 4:
                        sustained_high[i] = True
                    else:
                        drastic_change[i] = False
                        sustained_high[i] = False

            detected_drift_clients_1 = [
                i for i, (drastic, sustained) in enumerate(zip(drastic_change, sustained_high))
                if drastic and sustained
            ]
            
            print(f'sdrft_client{detected_drift_clients_1}')
            
        # Concept drift detection and performance metrics
        if (global_epoch >= 5) and not disable_detection: #in range(5, 29):
            # Gradual detection using moving averages
            for i in range(num_clients):
                if len(previous_client_losses[i]) >= long_window:
                    short_avg = np.mean(previous_client_losses[i][-short_window:])
                    
                    if fixed_long_averages[i] is None:
                        long_avg = np.mean(previous_client_losses[i][-long_window:])
                    else:
                        long_avg = fixed_long_averages[i]

                    if client_losses[i] > short_avg:
                        drastic_change_detected[i] = True
                    else:
                        drastic_change_detected[i] = False

                    if client_losses[i] > long_avg:
                        sustained_high_loss[i] = True
                        if fixed_long_averages[i] is None:
                            fixed_long_averages[i] = long_avg
                    else:
                        sustained_high_loss[i] = False

            detected_drift_clients_2 = [
                i for i, (drastic, sustained,d_change, s_high) in enumerate(
                    zip(drastic_change_detected, sustained_high_loss, drastic_change, sustained_high)
                ) if drastic and sustained #and (not d_change and not s_high)
            ]
            
            print(f'gdrft_client{detected_drift_clients_2}')

            detected_drift_clients = list(set(detected_drift_clients_1) | set(detected_drift_clients_2))

            # Update drift counts and track when drifts were detected
            for client in detected_drift_clients:
                drift_count[client] += 1
                if client not in epoch_drift_detected[client]:
                    epoch_drift_detected[client].append(global_epoch)
                    
                    
                    
            # Determine the maximum drift count among the fixed detected drift clients
            max_drift_count_sudden = max((drift_count[client] for client in fixed_detected_drift_clients['sudden']), default=0)
            max_drift_count_gradual = max((drift_count[client] for client in fixed_detected_drift_clients['gradual']), default=0)
            

        

            # Update detected drift clients for model assignment
            for client in detected_drift_clients_1:
                if client not in fixed_detected_drift_clients['sudden'] and drift_count[client] >= max_drift_count_sudden:
                    fixed_detected_drift_clients['sudden'].append(client)

            for client in detected_drift_clients_2:
                if client not in fixed_detected_drift_clients['gradual'] and drift_count[client] >= max_drift_count_gradual:
                    fixed_detected_drift_clients['gradual'].append(client)

                    
            for client_id in range(num_clients):
                ground_truth_drift = ((client_id in class_swap_drift_clients) and (global_epoch >= 10)) | ((client_id in rotation_drift_clients) and (global_epoch >= 19) and (global_epoch <= 29))
                detected_drift = client_id in detected_drift_clients

                if detected_drift and ground_truth_drift:
                    true_positives += 1
                elif not detected_drift and not ground_truth_drift:
                    true_negatives += 1
                elif detected_drift and not ground_truth_drift:
                    false_positives += 1
                elif not detected_drift and ground_truth_drift:
                    false_negatives += 1

                if detected_drift == ground_truth_drift:
                    if client_id in detected_drift_clients_1 and client_id in class_swap_drift_clients:
                        print(f"Global Epoch {global_epoch + 1}, Client {client_id + 1}: True Drift Detected, Drift Type: Sudden .")
                    if client_id in detected_drift_clients_2 and client_id in rotation_drift_clients:
                        print(f"Global Epoch {global_epoch + 1}, Client {client_id + 1}: True Drift Detected, Drift Type: Gradual .")
                else:
                    print(f"Global Epoch {global_epoch + 1}, Client {client_id + 1}: False Drift Detected.")                    
                    
                    
        # Model aggregation
        print("\tAggregating client models")
        sudden_clients = set(fixed_detected_drift_clients['sudden'])
        gradual_clients = set(fixed_detected_drift_clients['gradual'])
        print(f'fixed_detected_drift_clients:{fixed_detected_drift_clients}')
        
        
        # Determine if there are common clients between sudden and gradual drifts
        common_dclients = sudden_clients & gradual_clients
        print(f"common_dclients:{common_dclients}")
        all_dclients = sudden_clients | gradual_clients
            
            
        non_drifted_client_models = [client_models[i] for i in range(num_clients) if i not in all_dclients]
        

            
        # No drifts case: if no drifts for more than 20 consecutive epochs, replace all models
        # Check for drift detection
        counter = 0
        for i in range(num_clients):
            if client_acc[i]>=0.97: #0.98:
                counter += 1
        if (counter//num_clients) >= 1: #0.9:
            no_drift_detected = True  # At least one client detected drift

        # Update no_drift_epochs based on whether any drift was detected
        if no_drift_detected:
            no_drift_epochs += 1
        else:
            no_drift_epochs = 0
            
        print(f"no_drift_epochs:{no_drift_epochs}")
        
        if no_drift_epochs>=no_drift_epochs_th:
            disable_detection = True
            
            

            
        if no_drift_epochs == no_drift_epochs_th:
            
            mdrifted_client_models = [client_models[i] for i in common_dclients]
            sdrifted_client_models = [client_models[i] for i in sudden_clients if i not in common_dclients]
            gdrifted_client_models = [client_models[i] for i in gradual_clients if i not in common_dclients]
            if mdrifted_client_models:
                global_model_mdrift = aggregate_models(global_model_mdrift, mdrifted_client_models)
            if gdrifted_client_models:
                global_model_gdrift = aggregate_models(global_model_gdrift, gdrifted_client_models)
            if sdrifted_client_models:
                global_model_sdrift = aggregate_models(global_model_sdrift, sdrifted_client_models)
            if non_drifted_client_models:
                global_model = aggregate_models(global_model, non_drifted_client_models)

            
            print(f"No drifts detected for more than 20 epochs. Replacing all models with optimum model.")
            if mdrifted_client_models:
                global_model = create_global_optimum_model(global_model, global_model_sdrift, global_model_gdrift, global_model_mdrift, 0.13, 0.13, 0.13)
            if not mdrifted_client_models and sdrifted_client_models and gdrifted_client_models:
                global_model = create_global_optimum_model(global_model, global_model_sdrift, global_model_gdrift, global_model_mdrift, 0.05, 0.45, 0)
            if not mdrifted_client_models and sdrifted_client_models and not gdrifted_client_models:
                global_model = create_global_optimum_model(global_model, global_model_sdrift, global_model_gdrift, global_model_mdrift, 1, 0, 0)
            if not mdrifted_client_models and gdrifted_client_models and not sdrifted_client_models:
                global_model = create_global_optimum_model(global_model, global_model_sdrift, global_model_gdrift, global_model_mdrift, 0, 0.35, 0)
#             fixed_detected_drift_clients = {'sudden': [], 'gradual': []}


        if no_drift_epochs > no_drift_epochs_th or disable_detection:
            global_model = aggregate_models(global_model, client_models)
            
        if no_drift_epochs < no_drift_epochs_th and not disable_detection:

            if non_drifted_client_models:
                global_model = aggregate_models(global_model, non_drifted_client_models)

            if not common_dclients:
                sdrifted_client_models = [client_models[i] for i in sudden_clients]
                gdrifted_client_models = [client_models[i] for i in gradual_clients]
                if gdrifted_client_models:
                    global_model_gdrift = aggregate_models(global_model_gdrift, gdrifted_client_models)
                if sdrifted_client_models:
                    global_model_sdrift = aggregate_models(global_model_sdrift, sdrifted_client_models)


            if common_dclients:
                mdrifted_client_models = [client_models[i] for i in common_dclients]
                sdrifted_client_models = [client_models[i] for i in sudden_clients if i not in common_dclients]
                gdrifted_client_models = [client_models[i] for i in gradual_clients if i not in common_dclients]
                if mdrifted_client_models:
                    global_model_mdrift = aggregate_models(global_model_mdrift, mdrifted_client_models)
                if gdrifted_client_models:
                    global_model_gdrift = aggregate_models(global_model_gdrift, gdrifted_client_models)
                if sdrifted_client_models:
                    global_model_sdrift = aggregate_models(global_model_sdrift, sdrifted_client_models)



        # Evaluation on the global test dataset
#         if global_epoch ==80: 
#             for i, drifted_test_loader in enumerate(drifted_client_test_loaders):
#                 print("\tEvaluating models")
#                 if global_model:
#                     accuracy = client_testing(global_model, drifted_test_loader)
#                     print(f"Accuracy on non-drifted clients: {accuracy}%")
#                 if global_model_sdrift:
#                     accuracy_sudden = client_testing(global_model_sdrift, drifted_test_loader)
#                     print(f"Accuracy on sudden drift clients: {accuracy_sudden}%")
#                 if global_model_gdrift:
#                     accuracy_gradual = client_testing(global_model_gdrift, drifted_test_loader)
#                     print(f"Accuracy on gradual drift clients: {accuracy_gradual}%")
#                 if global_model_mdrift:
#                     accuracy_both = client_testing(global_model_mdrift, drifted_test_loader)
#                     print(f"Accuracy on both drift clients: {accuracy_both}%")

    # Calculate performance metrics of drift detection
    accuracy = (true_positives + true_negatives) / (true_positives + true_negatives + false_positives + false_negatives)
    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
    f1_score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

    print(f"Drift Detection metrics::: true_positives:{true_positives}, true_negatives:{true_negatives}, false_positives:{false_positives}, false_negatives:{false_negatives}")
    print(f"Drift Detection Performance:\nAccuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1_score}")



# Aggregation of models' weights using FedAvg
def aggregate_models(global_model, client_models):
    global_dict = global_model.state_dict()
    for k in global_dict.keys():
        global_dict[k] = torch.stack([client_model.state_dict()[k].float() for client_model in client_models], 0).mean(0)
    global_model.load_state_dict(global_dict)
    return global_model

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Example usage
if __name__ == "__main__":
    client_accuracies = federated_learning(num_clients=60,num_local_epochs=1, num_global_epochs=150)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 37127237.08it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 958063.98it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 8004272.33it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 2930850.58it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Global Epoch 1/150
# 	Training Client 1/60
# Epoch 1/1, Loss: 48.11705148220062, Accuracy: 0.507
# 	Training Client 2/60
# Epoch 1/1, Loss: 50.76106721162796, Accuracy: 0.508
# 	Training Client 3/60
# Epoch 1/1, Loss: 49.53202587366104, Accuracy: 0.496
# 	Training Client 4/60
# Epoch 1/1, Loss: 47.107761561870575, Accuracy: 0.559
# 	Training Client 5/60
# Epoch 1/1, Loss: 48.694124937057495, Accuracy: 0.526
# 	Training Client 6/60
# Epoch 1/1, Loss: 45.404584139585495, Accuracy: 0.547
# 	Training Client 7/60
# Epoch 1/1, Loss: 49.16079902648926, Accuracy: 0.489
# 	Training Client 8/60
# Epoch 1/1, Loss: 46.707472026348114, Accuracy: 0.57
# 	Training Client 9/60
# Epoch 1/1, Loss: 43.8530447781086, Accuracy: 0.58
# 	Training Client 10/60
# Epoch 1/1, Loss: 45.9372219145298, Accuracy: 0.549
# 	Training Client 11/60
# Epoch 1/1, Loss: 48.80280131101608, Accuracy: 0.531
# 	Training Client 12/60
# Epoch 1/1, Loss: 52.091247618198395, Accuracy: 0.516
# 	Training Client 13/60
# Epoch 1/1, Loss: 49.34970700740814, Accuracy: 0.508
# 	Training Client 14/60
# Epoch 1/1, Loss: 48.391703963279724, Accuracy: 0.498
# 	Training Client 15/60
# Epoch 1/1, Loss: 52.766641676425934, Accuracy: 0.454
# 	Training Client 16/60
# Epoch 1/1, Loss: 48.865757405757904, Accuracy: 0.549
# 	Training Client 17/60
# Epoch 1/1, Loss: 48.33956027030945, Accuracy: 0.514
# 	Training Client 18/60
# Epoch 1/1, Loss: 50.1932806968689, Accuracy: 0.493
# 	Training Client 19/60
# Epoch 1/1, Loss: 49.20001703500748, Accuracy: 0.543
# 	Training Client 20/60
# Epoch 1/1, Loss: 47.13121825456619, Accuracy: 0.538
# 	Training Client 21/60
# Epoch 1/1, Loss: 48.33850425481796, Accuracy: 0.523
# Epoch 1/1, Loss: 50.72658050060272, Accuracy: 0.514
# 	Training Client 56/60
# Epoch 1/1, Loss: 45.93517827987671, Accuracy: 0.573
# 	Training Client 57/60
# Epoch 1/1, Loss: 51.32834279537201, Accuracy: 0.467
# 	Training Client 58/60
# Epoch 1/1, Loss: 47.4404154419899, Accuracy: 0.541
# 	Training Client 59/60
# Epoch 1/1, Loss: 50.90949159860611, Accuracy: 0.472
# 	Training Client 60/60
# Epoch 1/1, Loss: 50.60614055395126, Accuracy: 0.498
# 	Aggregating client models
# fixed_detected_drift_clients:{'sudden': [], 'gradual': []}
# common_dclients:set()
# no_drift_epochs:0
# Global Epoch 2/150
# 	Training Client 1/60
# Epoch 1/1, Loss: 17.17786979675293, Accuracy: 0.833
# 	Training Client 2/60
# Epoch 1/1, Loss: 19.21730975806713, Accuracy: 0.82
# 	Training Client 3/60
# Epoch 1/1, Loss: 18.432172909379005, Accuracy: 0.819
# 	Training Client 4/60
# Epoch 1/1, Loss: 19.76297377049923, Accuracy: 0.805
# 	Training Client 5/60
# Epoch 1/1, Loss: 18.357597813010216, Accuracy: 0.815
# 	Training Client 6/60
# Epoch 1/1, Loss: 16.574738427996635, Accuracy: 0.837
# 	Training Client 7/60
# Epoch 1/1, Loss: 17.770029213279486, Accuracy: 0.839
# 	Training Client 8/60
# Epoch 1/1, Loss: 17.35341912508011, Accuracy: 0.843
# 	Training Client 9/60
# Epoch 1/1, Loss: 17.686907708644867, Accuracy: 0.839
# 	Training Client 10/60
# Epoch 1/1, Loss: 15.805284164845943, Accuracy: 0.837
# 	Training Client 11/60
# Epoch 1/1, Loss: 18.18847744166851, Accuracy: 0.812
# 	Training Client 12/60
# Epoch 1/1, Loss: 15.983044534921646, Accuracy: 0.845
# 	Training Client 13/60
# Epoch 1/1, Loss: 18.222528219223022, Accuracy: 0.826
# 	Training Client 14/60
# Epoch 1/1, Loss: 17.295765101909637, Accuracy: 0.819
# 	Training Client 15/60
# Epoch 1/1, Loss: 19.18882091343403, Accuracy: 0.808
# 	Training Client 16/60
# Epoch 1/1, Loss: 17.81539721786976, Accuracy: 0.84
# 	Training Client 17/60
# Epoch 1/1, Loss: 16.958679169416428, Accuracy: 0.827
# 	Training Client 18/60
# Epoch 1/1, Loss: 17.014177933335304, Accuracy: 0.833
# 	Training Client 19/60
# Epoch 1/1, Loss: 17.99313458800316, Accuracy: 0.813
# 	Training Client 20/60
# Epoch 1/1, Loss: 17.35092705488205, Accuracy: 0.828
# 	Training Client 21/60
# Epoch 1/1, Loss: 17.603681415319443, Accuracy: 0.832
# 	Training Client 22/60
# Epoch 1/1, Loss: 18.197359144687653, Accuracy: 0.825
# 	Training Client 23/60
# Epoch 1/1, Loss: 18.705046951770782, Accuracy: 0.831
# 	Training Client 24/60
# Epoch 1/1, Loss: 17.542602583765984, Accuracy: 0.834
# 	Training Client 25/60
# Epoch 1/1, Loss: 17.386131152510643, Accuracy: 0.826
# 	Training Client 26/60
# Epoch 1/1, Loss: 17.67735242843628, Accuracy: 0.821
# 	Training Client 27/60
# 	Aggregating client models
# fixed_detected_drift_clients:{'sudden': [], 'gradual': []}
# common_dclients:set()
# no_drift_epochs:0
# Global Epoch 3/150
# 	Training Client 1/60
# Epoch 1/1, Loss: 11.539180651307106, Accuracy: 0.89
# 	Training Client 2/60
# Epoch 1/1, Loss: 12.040517877787352, Accuracy: 0.889
# 	Training Client 3/60
# Epoch 1/1, Loss: 12.51486574858427, Accuracy: 0.87
# 	Training Client 4/60
# Epoch 1/1, Loss: 13.830180123448372, Accuracy: 0.87
# 	Training Client 5/60
# Epoch 1/1, Loss: 10.544557417742908, Accuracy: 0.891
# 	Training Client 6/60
# Epoch 1/1, Loss: 10.49931900948286, Accuracy: 0.898
# 	Training Client 7/60
# Epoch 1/1, Loss: 10.165763318538666, Accuracy: 0.904
# 	Training Client 8/60
# Epoch 1/1, Loss: 11.046351097524166, Accuracy: 0.895
# 	Training Client 9/60
# Epoch 1/1, Loss: 11.676219899207354, Accuracy: 0.891
# 	Training Client 10/60
# Epoch 1/1, Loss: 9.659407046623528, Accuracy: 0.902
# 	Training Client 11/60
# Epoch 1/1, Loss: 11.022711992263794, Accuracy: 0.89
# 	Training Client 12/60
# Epoch 1/1, Loss: 9.864651307463646, Accuracy: 0.905
# 	Training Client 13/60
# Epoch 1/1, Loss: 11.608606427907944, Accuracy: 0.89
# 	Training Client 14/60
# Epoch 1/1, Loss: 10.40898334980011, Accuracy: 0.899
# 	Training Client 15/60
# Epoch 1/1, Loss: 10.806911684572697, Accuracy: 0.904
# 	Training Client 16/60
# Epoch 1/1, Loss: 11.177482225000858, Accuracy: 0.885
# 	Training Client 17/60
# Epoch 1/1, Loss: 10.880774296820164, Accuracy: 0.889
# 	Training Client 18/60
# Epoch 1/1, Loss: 10.794798269867897, Accuracy: 0.895
# 	Training Client 19/60
# Epoch 1/1, Loss: 11.021036520600319, Accuracy: 0.909
# 	Training Client 20/60
# Epoch 1/1, Loss: 10.027684457600117, Accuracy: 0.911
# 	Training Client 21/60
# Epoch 1/1, Loss: 10.717552894726396, Accuracy: 0.901
# 	Training Client 22/60
# Epoch 1/1, Loss: 13.821693554520607, Accuracy: 0.873
# 	Training Client 23/60
# Epoch 1/1, Loss: 13.094012007117271, Accuracy: 0.88
# 	Training Client 24/60
# Epoch 1/1, Loss: 10.559567965567112, Accuracy: 0.905
# 	Training Client 25/60
# Epoch 1/1, Loss: 11.825128480792046, Accuracy: 0.888
# 	Training Client 26/60
# Epoch 1/1, Loss: 11.992333691567183, Accuracy: 0.884
# 	Training Client 27/60
# Epoch 1/1, Loss: 10.554633729159832, Accuracy: 0.901
# 	Training Client 28/60
# Epoch 1/1, Loss: 10.86686036735773, Accuracy: 0.904
# 	Training Client 29/60
# Epoch 1/1, Loss: 11.208357438445091, Accuracy: 0.896
# 	Training Client 30/60
# Epoch 1/1, Loss: 12.280692651867867, Accuracy: 0.895
# 	Training Client 31/60
# Epoch 1/1, Loss: 12.32431798428297, Accuracy: 0.888
# 	Training Client 32/60
# 	Training Client 38/60
# Epoch 1/1, Loss: 7.806934860534966, Accuracy: 0.921
# 	Training Client 39/60
# Epoch 1/1, Loss: 8.40805047005415, Accuracy: 0.918
# 	Training Client 40/60
# Epoch 1/1, Loss: 8.362831003963947, Accuracy: 0.918
# 	Training Client 41/60
# Epoch 1/1, Loss: 9.3041547909379, Accuracy: 0.911
# 	Training Client 42/60
# Epoch 1/1, Loss: 9.302139721810818, Accuracy: 0.908
# 	Training Client 43/60
# Epoch 1/1, Loss: 9.093794628977776, Accuracy: 0.912
# 	Training Client 44/60
# Epoch 1/1, Loss: 8.210552975535393, Accuracy: 0.911
# 	Training Client 45/60
# Epoch 1/1, Loss: 8.879089418798685, Accuracy: 0.917
# 	Training Client 46/60
# Epoch 1/1, Loss: 8.468107804656029, Accuracy: 0.916
# 	Training Client 47/60
# Epoch 1/1, Loss: 8.569710843265057, Accuracy: 0.922
# 	Training Client 48/60
# Epoch 1/1, Loss: 7.3844884522259235, Accuracy: 0.941
# 	Training Client 49/60
# Epoch 1/1, Loss: 8.460597179830074, Accuracy: 0.917
# 	Training Client 50/60
# Epoch 1/1, Loss: 9.561183661222458, Accuracy: 0.905
# 	Training Client 51/60
# Epoch 1/1, Loss: 8.548414275050163, Accuracy: 0.919
# 	Training Client 52/60
# Epoch 1/1, Loss: 7.185376279056072, Accuracy: 0.937
# 	Training Client 53/60
# Epoch 1/1, Loss: 9.067249089479446, Accuracy: 0.914
# 	Training Client 54/60
# Epoch 1/1, Loss: 8.513952618464828, Accuracy: 0.919
# 	Training Client 55/60
# Epoch 1/1, Loss: 8.140906888991594, Accuracy: 0.93
# 	Training Client 56/60
# Epoch 1/1, Loss: 9.348842300474644, Accuracy: 0.919
# 	Training Client 57/60
# Epoch 1/1, Loss: 10.89087836816907, Accuracy: 0.896
# 	Training Client 58/60
# Epoch 1/1, Loss: 9.077122375369072, Accuracy: 0.916
# 	Training Client 59/60
# Epoch 1/1, Loss: 8.060877539217472, Accuracy: 0.924
# 	Training Client 60/60
# Epoch 1/1, Loss: 7.926761258393526, Accuracy: 0.927
# 	Aggregating client models
# fixed_detected_drift_clients:{'sudden': [], 'gradual': []}
# common_dclients:set()
# no_drift_epochs:0
# Global Epoch 5/150
# 	Training Client 1/60
# Epoch 1/1, Loss: 7.323067208752036, Accuracy: 0.92
# 	Training Client 2/60
# Epoch 1/1, Loss: 7.426457863301039, Accuracy: 0.937
# 	Training Client 3/60
# Epoch 1/1, Loss: 7.286803610622883, Accuracy: 0.925
# 	Training Client 4/60
# Epoch 1/1, Loss: 7.460121359676123, Accuracy: 0.925
# 	Training Client 5/60
# Epoch 1/1, Loss: 6.318908920511603, Accuracy: 0.938
# 	Training Client 6/60
# Epoch 1/1, Loss: 6.858822191134095, Accuracy: 0.938
# 	Training Client 7/60
# Epoch 1/1, Loss: 6.137121237814426, Accuracy: 0.943
# 	Training Client 8/60
# Epoch 1/1, Loss: 7.251538656651974, Accuracy: 0.932
# 	Training Client 9/60
# 	Training Client 15/60
# Epoch 1/1, Loss: 5.369542956352234, Accuracy: 0.948
# 	Training Client 16/60
# Epoch 1/1, Loss: 5.213045466691256, Accuracy: 0.948
# 	Training Client 17/60
# Epoch 1/1, Loss: 5.537369407713413, Accuracy: 0.95
# 	Training Client 18/60
# Epoch 1/1, Loss: 6.037105280905962, Accuracy: 0.933
# 	Training Client 19/60
# Epoch 1/1, Loss: 5.114731483161449, Accuracy: 0.953
# 	Training Client 20/60
# Epoch 1/1, Loss: 5.913986928761005, Accuracy: 0.95
# 	Training Client 21/60
# Epoch 1/1, Loss: 6.23209217749536, Accuracy: 0.944
# 	Training Client 22/60
# Epoch 1/1, Loss: 7.700765520334244, Accuracy: 0.932
# 	Training Client 23/60
# Epoch 1/1, Loss: 6.429180230945349, Accuracy: 0.938
# 	Training Client 24/60
# Epoch 1/1, Loss: 5.221927210688591, Accuracy: 0.95
# 	Training Client 25/60
# Epoch 1/1, Loss: 5.591581717133522, Accuracy: 0.94
# 	Training Client 26/60
# Epoch 1/1, Loss: 6.82322832942009, Accuracy: 0.947
# 	Training Client 27/60
# Epoch 1/1, Loss: 6.000683952122927, Accuracy: 0.944
# 	Training Client 28/60
# Epoch 1/1, Loss: 6.268573608249426, Accuracy: 0.941
# 	Training Client 29/60
# Epoch 1/1, Loss: 6.422578237950802, Accuracy: 0.933
# 	Training Client 30/60
# Epoch 1/1, Loss: 5.7298501543700695, Accuracy: 0.939
# 	Training Client 31/60
# Epoch 1/1, Loss: 6.8182722590863705, Accuracy: 0.943
# 	Training Client 32/60
# Epoch 1/1, Loss: 5.8393498081713915, Accuracy: 0.941
# 	Training Client 33/60
# Epoch 1/1, Loss: 6.652871185913682, Accuracy: 0.939
# 	Training Client 34/60
# Epoch 1/1, Loss: 6.635892873629928, Accuracy: 0.934
# 	Training Client 35/60
# Epoch 1/1, Loss: 6.183511380106211, Accuracy: 0.936
# 	Training Client 36/60
# Epoch 1/1, Loss: 4.803791154175997, Accuracy: 0.95
# 	Training Client 37/60
# Epoch 1/1, Loss: 5.363514341413975, Accuracy: 0.944
# 	Training Client 38/60
# Epoch 1/1, Loss: 5.5621547512710094, Accuracy: 0.947
# 	Training Client 39/60
# Epoch 1/1, Loss: 6.566847782582045, Accuracy: 0.945
# 	Training Client 40/60
# Epoch 1/1, Loss: 6.373057239688933, Accuracy: 0.94
# 	Training Client 41/60
# Epoch 1/1, Loss: 6.694909438490868, Accuracy: 0.94
# 	Training Client 42/60
# Epoch 1/1, Loss: 5.930380959063768, Accuracy: 0.942
# 	Training Client 43/60
# Epoch 1/1, Loss: 7.090326071716845, Accuracy: 0.939
# 	Training Client 44/60
# Epoch 1/1, Loss: 7.144446149468422, Accuracy: 0.918
# 	Training Client 45/60
# Epoch 1/1, Loss: 6.626685995608568, Accuracy: 0.935
# 	Training Client 46/60
# Epoch 1/1, Loss: 6.244978040456772, Accuracy: 0.936
# 	Training Client 47/60
# Epoch 1/1, Loss: 5.33600137103349, Accuracy: 0.938
# 	Training Client 48/60
# Epoch 1/1, Loss: 6.195259392261505, Accuracy: 0.947
# 	Training Client 49/60
# Epoch 1/1, Loss: 6.410061676055193, Accuracy: 0.933
# 	Training Client 50/60
# Epoch 1/1, Loss: 7.560208290815353, Accuracy: 0.922
# 	Training Client 51/60
# Epoch 1/1, Loss: 7.172289565205574, Accuracy: 0.927
# 	Training Client 52/60
# Epoch 1/1, Loss: 6.305541697889566, Accuracy: 0.946
# 	Training Client 53/60
# Epoch 1/1, Loss: 6.450022839009762, Accuracy: 0.936
# 	Training Client 54/60
# Epoch 1/1, Loss: 6.656252114102244, Accuracy: 0.939
# 	Training Client 55/60
# Epoch 1/1, Loss: 6.4227898344397545, Accuracy: 0.951
# 	Training Client 56/60
# Epoch 1/1, Loss: 6.058570433408022, Accuracy: 0.946
# 	Training Client 57/60
# Epoch 1/1, Loss: 6.972449509426951, Accuracy: 0.93
# 	Training Client 58/60
# Epoch 1/1, Loss: 6.14586766064167, Accuracy: 0.939
# 	Training Client 59/60
# Epoch 1/1, Loss: 5.169192297384143, Accuracy: 0.945
# 	Training Client 60/60
# Epoch 1/1, Loss: 5.487671487033367, Accuracy: 0.951
# sdrft_client[]
# gdrft_client[]
# 	Aggregating client models
# fixed_detected_drift_clients:{'sudden': [], 'gradual': []}
# common_dclients:set()
# no_drift_epochs:0
# Global Epoch 7/150
# 	Training Client 1/60
# Epoch 1/1, Loss: 5.41242017224431, Accuracy: 0.943
# 	Training Client 2/60
# Epoch 1/1, Loss: 7.338080057874322, Accuracy: 0.948
# 	Training Client 3/60
# Epoch 1/1, Loss: 5.807588113471866, Accuracy: 0.949
# 	Training Client 4/60
# Epoch 1/1, Loss: 4.9697093944996595, Accuracy: 0.952
# 	Training Client 5/60
# Epoch 1/1, Loss: 5.177137926220894, Accuracy: 0.952
# 	Training Client 6/60
# Epoch 1/1, Loss: 5.4316789470613, Accuracy: 0.952
# 	Training Client 7/60
# Epoch 1/1, Loss: 4.716278240550309, Accuracy: 0.956
# 	Training Client 8/60
# Epoch 1/1, Loss: 5.168773235753179, Accuracy: 0.95
# 	Training Client 9/60
# Epoch 1/1, Loss: 5.482036177068949, Accuracy: 0.948
# 	Training Client 10/60
# Epoch 1/1, Loss: 4.547843070700765, Accuracy: 0.955
# 	Training Client 11/60
# Epoch 1/1, Loss: 5.3658158872276545, Accuracy: 0.945
# 	Training Client 12/60
# Epoch 1/1, Loss: 4.765052732080221, Accuracy: 0.95
# 	Training Client 13/60
# Epoch 1/1, Loss: 5.58450286462903, Accuracy: 0.944
# 	Training Client 14/60
# Epoch 1/1, Loss: 4.589299250394106, Accuracy: 0.959
# 	Training Client 15/60
# Epoch 1/1, Loss: 4.175412869080901, Accuracy: 0.962
# 	Training Client 16/60
# Epoch 1/1, Loss: 5.26250147074461, Accuracy: 0.957
# 	Training Client 17/60
# Epoch 1/1, Loss: 5.605241563171148, Accuracy: 0.946
# 	Training Client 18/60
# Epoch 1/1, Loss: 4.6721107815392315, Accuracy: 0.956
# 	Training Client 19/60
# 	Training Client 53/60
# Epoch 1/1, Loss: 5.914088015444577, Accuracy: 0.94
# 	Training Client 54/60
# Epoch 1/1, Loss: 5.181498721241951, Accuracy: 0.954
# 	Training Client 55/60
# Epoch 1/1, Loss: 5.358458813279867, Accuracy: 0.951
# 	Training Client 56/60
# Epoch 1/1, Loss: 5.70227974280715, Accuracy: 0.955
# 	Training Client 57/60
# Epoch 1/1, Loss: 6.0562540628015995, Accuracy: 0.94
# 	Training Client 58/60
# Epoch 1/1, Loss: 6.149451147764921, Accuracy: 0.949
# 	Training Client 59/60
# Epoch 1/1, Loss: 4.3170461896806955, Accuracy: 0.956
# 	Training Client 60/60
# Epoch 1/1, Loss: 4.87373405508697, Accuracy: 0.958
# sdrft_client[]
# gdrft_client[]
# 	Aggregating client models
# fixed_detected_drift_clients:{'sudden': [], 'gradual': []}
# common_dclients:set()
# no_drift_epochs:0
# Global Epoch 8/150
# 	Training Client 1/60
# Epoch 1/1, Loss: 5.497372688725591, Accuracy: 0.946
# 	Training Client 2/60
# Epoch 1/1, Loss: 6.168767681345344, Accuracy: 0.941
# 	Training Client 3/60
# Epoch 1/1, Loss: 4.731913926545531, Accuracy: 0.951
# 	Training Client 4/60
# Epoch 1/1, Loss: 5.196607079356909, Accuracy: 0.947
# 	Training Client 5/60
# Epoch 1/1, Loss: 4.273452138528228, Accuracy: 0.963
# 	Training Client 6/60
# Epoch 1/1, Loss: 5.123221388086677, Accuracy: 0.95
# 	Training Client 7/60
# Epoch 1/1, Loss: 5.0483333840966225, Accuracy: 0.96
# 	Training Client 8/60
# Epoch 1/1, Loss: 3.9498282382264733, Accuracy: 0.959
# 	Training Client 9/60
# Epoch 1/1, Loss: 4.86347290314734, Accuracy: 0.956
# 	Training Client 10/60
# Epoch 1/1, Loss: 4.563051592558622, Accuracy: 0.955
# 	Training Client 11/60
# Epoch 1/1, Loss: 4.946031030267477, Accuracy: 0.953
# 	Training Client 12/60
# Epoch 1/1, Loss: 5.1838944256305695, Accuracy: 0.957
# 	Training Client 13/60
# Epoch 1/1, Loss: 4.726446979679167, Accuracy: 0.948
# 	Training Client 14/60
# Epoch 1/1, Loss: 4.679627114906907, Accuracy: 0.957
# 	Training Client 15/60
# Epoch 1/1, Loss: 3.966077333316207, Accuracy: 0.96
# 	Training Client 16/60
# Epoch 1/1, Loss: 4.219839412951842, Accuracy: 0.961
# 	Training Client 17/60
# Epoch 1/1, Loss: 4.55668714735657, Accuracy: 0.954
# 	Training Client 18/60
# Epoch 1/1, Loss: 4.712095267139375, Accuracy: 0.952
# 	Training Client 19/60
# Epoch 1/1, Loss: 4.170442000031471, Accuracy: 0.966
# 	Training Client 20/60
# Epoch 1/1, Loss: 4.53627108130604, Accuracy: 0.954
# 	Training Client 21/60
# Epoch 1/1, Loss: 4.725693611428142, Accuracy: 0.959
# 	Training Client 22/60
# Epoch 1/1, Loss: 6.692006872966886, Accuracy: 0.946
# 	Training Client 23/60
# Epoch 1/1, Loss: 5.203607125207782, Accuracy: 0.953
# 	Training Client 24/60
# Epoch 1/1, Loss: 4.072447845712304, Accuracy: 0.958
# 	Training Client 25/60
# Epoch 1/1, Loss: 5.03055543359369, Accuracy: 0.952
# 	Training Client 26/60
# Epoch 1/1, Loss: 5.233628803864121, Accuracy: 0.952
# 	Training Client 27/60
# Epoch 1/1, Loss: 5.086987885646522, Accuracy: 0.951
# 	Training Client 28/60
# Epoch 1/1, Loss: 5.3610728569328785, Accuracy: 0.947
# 	Training Client 29/60
# Epoch 1/1, Loss: 4.728826952166855, Accuracy: 0.955
# 	Training Client 30/60
# Epoch 1/1, Loss: 4.6053793877363205, Accuracy: 0.957
# 	Training Client 31/60
# Epoch 1/1, Loss: 4.95198277104646, Accuracy: 0.959
# 	Training Client 32/60
# Epoch 1/1, Loss: 5.168397914618254, Accuracy: 0.949
# 	Training Client 33/60
# Epoch 1/1, Loss: 5.390066739171743, Accuracy: 0.957
# 	Training Client 34/60
# Epoch 1/1, Loss: 6.087552100419998, Accuracy: 0.948
# 	Training Client 35/60
# Epoch 1/1, Loss: 5.068512212485075, Accuracy: 0.958
# 	Training Client 36/60
# Epoch 1/1, Loss: 3.731354108080268, Accuracy: 0.965
# 	Training Client 37/60
# Epoch 1/1, Loss: 5.053600708954036, Accuracy: 0.957
# 	Training Client 38/60
# Epoch 1/1, Loss: 4.221843188628554, Accuracy: 0.964
# 	Training Client 39/60
# Epoch 1/1, Loss: 5.0369153171777725, Accuracy: 0.963
# 	Training Client 40/60
# Epoch 1/1, Loss: 4.665596348233521, Accuracy: 0.955
# 	Training Client 41/60
# Epoch 1/1, Loss: 4.97116463072598, Accuracy: 0.952
# 	Training Client 42/60
# Epoch 1/1, Loss: 4.6005907487124205, Accuracy: 0.956
# 	Training Client 43/60
# Epoch 1/1, Loss: 4.918580768629909, Accuracy: 0.95
# 	Training Client 44/60
# Epoch 1/1, Loss: 5.450089054182172, Accuracy: 0.947
# 	Training Client 45/60
# Epoch 1/1, Loss: 4.346998251974583, Accuracy: 0.955
# 	Training Client 46/60
# Epoch 1/1, Loss: 5.342353008687496, Accuracy: 0.951
# 	Training Client 47/60
# Epoch 1/1, Loss: 4.436741828918457, Accuracy: 0.961
# 	Training Client 48/60
# Epoch 1/1, Loss: 3.635913485661149, Accuracy: 0.958
# 	Training Client 49/60
# Epoch 1/1, Loss: 4.888379307463765, Accuracy: 0.944
# 	Training Client 50/60
# Epoch 1/1, Loss: 5.533577759750187, Accuracy: 0.943
# 	Training Client 51/60
# Epoch 1/1, Loss: 4.618630323559046, Accuracy: 0.95
# 	Training Client 52/60
# Epoch 1/1, Loss: 4.178260440006852, Accuracy: 0.958
# 	Training Client 53/60
# Epoch 1/1, Loss: 5.311028556898236, Accuracy: 0.955
# 	Training Client 54/60
# Epoch 1/1, Loss: 5.031249517574906, Accuracy: 0.956
# 	Training Client 55/60
# Epoch 1/1, Loss: 5.056314613670111, Accuracy: 0.955
# 	Training Client 56/60
# Epoch 1/1, Loss: 5.537571620196104, Accuracy: 0.954
# 	Training Client 57/60
# Epoch 1/1, Loss: 6.5610131695866585, Accuracy: 0.941
# 	Training Client 58/60
# Epoch 1/1, Loss: 4.768409194424748, Accuracy: 0.956
# 	Training Client 59/60
# Epoch 1/1, Loss: 3.822938196361065, Accuracy: 0.965
# 	Training Client 60/60
# Epoch 1/1, Loss: 4.828677775338292, Accuracy: 0.957
# sdrft_client[]
# gdrft_client[]
# 	Aggregating client models
# fixed_detected_drift_clients:{'sudden': [], 'gradual': []}
# common_dclients:set()
# no_drift_epochs:0
# Global Epoch 9/150
# 	Training Client 1/60
# Epoch 1/1, Loss: 4.128333207219839, Accuracy: 0.96
# 	Training Client 2/60
# Epoch 1/1, Loss: 5.7446154756471515, Accuracy: 0.95
# 	Training Client 3/60
# Epoch 1/1, Loss: 4.826117131859064, Accuracy: 0.957
# 	Training Client 4/60
# Epoch 1/1, Loss: 4.105174070224166, Accuracy: 0.95
# 	Training Client 5/60
# Epoch 1/1, Loss: 3.690671541262418, Accuracy: 0.965
# 	Training Client 6/60
# Epoch 1/1, Loss: 5.103295247070491, Accuracy: 0.959
# 	Training Client 7/60
# Epoch 1/1, Loss: 4.429610648192465, Accuracy: 0.958
# 	Training Client 8/60
# Epoch 1/1, Loss: 5.46302804723382, Accuracy: 0.953
# 	Training Client 9/60
# Epoch 1/1, Loss: 4.245001649484038, Accuracy: 0.963
# 	Training Client 10/60
# Epoch 1/1, Loss: 3.53836074937135, Accuracy: 0.978
# 	Training Client 11/60
# Epoch 1/1, Loss: 4.00677440315485, Accuracy: 0.964
# 	Training Client 12/60
# Epoch 1/1, Loss: 4.186093685217202, Accuracy: 0.959
# 	Training Client 13/60
# Epoch 1/1, Loss: 4.2136394483968616, Accuracy: 0.961
# 	Training Client 14/60
# Epoch 1/1, Loss: 3.6549574132077396, Accuracy: 0.963
# 	Training Client 15/60
# Epoch 1/1, Loss: 3.820110136643052, Accuracy: 0.965
# 	Training Client 16/60
# Epoch 1/1, Loss: 3.8092798916622996, Accuracy: 0.963
# 	Training Client 17/60
# Epoch 1/1, Loss: 3.813536616973579, Accuracy: 0.963
# 	Training Client 18/60
# Epoch 1/1, Loss: 4.015749507583678, Accuracy: 0.964
# 	Training Client 19/60
# Epoch 1/1, Loss: 4.126236727461219, Accuracy: 0.959
# 	Training Client 20/60
# Epoch 1/1, Loss: 3.7952269753441215, Accuracy: 0.964
# 	Training Client 21/60
# Epoch 1/1, Loss: 4.2351346062496305, Accuracy: 0.957
# 	Training Client 22/60
# Epoch 1/1, Loss: 6.353975288569927, Accuracy: 0.949
# 	Training Client 23/60
# Epoch 1/1, Loss: 4.883218487724662, Accuracy: 0.953
# 	Training Client 24/60
# Epoch 1/1, Loss: 3.6612877901643515, Accuracy: 0.957
# 	Training Client 25/60
# Epoch 1/1, Loss: 4.702098032459617, Accuracy: 0.957
# 	Training Client 26/60
# Epoch 1/1, Loss: 5.29946706071496, Accuracy: 0.947
# 	Training Client 27/60
# Epoch 1/1, Loss: 4.412274615839124, Accuracy: 0.955
# 	Training Client 28/60
# Epoch 1/1, Loss: 5.029074007645249, Accuracy: 0.948
# 	Training Client 29/60
# Epoch 1/1, Loss: 4.412424755748361, Accuracy: 0.954
# 	Training Client 30/60
# Epoch 1/1, Loss: 4.575024836696684, Accuracy: 0.957
# 	Training Client 31/60
# Epoch 1/1, Loss: 4.706711893901229, Accuracy: 0.957
# 	Training Client 32/60
# Epoch 1/1, Loss: 4.463962767273188, Accuracy: 0.957
# 	Training Client 33/60
# Epoch 1/1, Loss: 4.865613126195967, Accuracy: 0.955
# 	Training Client 34/60
# Epoch 1/1, Loss: 4.607920268550515, Accuracy: 0.959
# 	Training Client 35/60
# Epoch 1/1, Loss: 4.690458742901683, Accuracy: 0.958
# 	Training Client 36/60
# Epoch 1/1, Loss: 3.779115735553205, Accuracy: 0.956
# 	Training Client 37/60
# Epoch 1/1, Loss: 4.645680231973529, Accuracy: 0.954
# 	Training Client 38/60
# Epoch 1/1, Loss: 3.8865865413099527, Accuracy: 0.96
# 	Training Client 39/60
# Epoch 1/1, Loss: 4.638527262955904, Accuracy: 0.954
# 	Training Client 40/60
# Epoch 1/1, Loss: 5.387742990627885, Accuracy: 0.959
# 	Training Client 41/60
# Epoch 1/1, Loss: 4.685876410454512, Accuracy: 0.951
# 	Training Client 42/60
# Epoch 1/1, Loss: 4.732448251917958, Accuracy: 0.955
# 	Training Client 43/60
# Epoch 1/1, Loss: 4.866738459095359, Accuracy: 0.946
# 	Training Client 44/60
# Epoch 1/1, Loss: 4.633516475558281, Accuracy: 0.951
# 	Training Client 45/60
# Epoch 1/1, Loss: 4.0385449063032866, Accuracy: 0.965
# 	Training Client 46/60
# Epoch 1/1, Loss: 4.781650353223085, Accuracy: 0.948
# 	Training Client 47/60
# Epoch 1/1, Loss: 4.751502369530499, Accuracy: 0.961
# 	Training Client 48/60
# Epoch 1/1, Loss: 3.7243390057701617, Accuracy: 0.964
# 	Training Client 49/60
# Epoch 1/1, Loss: 5.6279146037995815, Accuracy: 0.946
# 	Training Client 50/60
# Epoch 1/1, Loss: 4.861862731166184, Accuracy: 0.957
# 	Training Client 51/60
# Epoch 1/1, Loss: 4.236921483650804, Accuracy: 0.954
# 	Training Client 52/60
# Epoch 1/1, Loss: 3.812191426753998, Accuracy: 0.965
# 	Training Client 53/60
# Epoch 1/1, Loss: 4.33810318261385, Accuracy: 0.954
# 	Training Client 54/60
# Epoch 1/1, Loss: 5.281609856523573, Accuracy: 0.956
# 	Training Client 55/60
# Epoch 1/1, Loss: 4.31606831215322, Accuracy: 0.964
# 	Training Client 56/60
# Epoch 1/1, Loss: 5.1639857199043036, Accuracy: 0.948
# 	Training Client 57/60
# Epoch 1/1, Loss: 5.323944372823462, Accuracy: 0.943
# 	Training Client 58/60
# Epoch 1/1, Loss: 3.9453258588910103, Accuracy: 0.956
# 	Training Client 59/60
# Epoch 1/1, Loss: 3.742629869841039, Accuracy: 0.964
# 	Training Client 60/60
# Epoch 1/1, Loss: 5.0463220458477736, Accuracy: 0.959
# sdrft_client[]
# gdrft_client[]
# 	Aggregating client models
# fixed_detected_drift_clients:{'sudden': [], 'gradual': []}
# common_dclients:set()
# no_drift_epochs:0
# Global Epoch 10/150
# 	Training Client 1/60
# Epoch 1/1, Loss: 4.423574578016996, Accuracy: 0.957
# 	Training Client 2/60
# Epoch 1/1, Loss: 4.762888449244201, Accuracy: 0.958
# 	Training Client 3/60
# Epoch 1/1, Loss: 4.159657981013879, Accuracy: 0.958
# 	Training Client 4/60
# Epoch 1/1, Loss: 4.183030502870679, Accuracy: 0.959
# 	Training Client 5/60
# Epoch 1/1, Loss: 3.810266640037298, Accuracy: 0.967
# 	Training Client 6/60
# Epoch 1/1, Loss: 4.129868682008237, Accuracy: 0.966
# 	Training Client 7/60
# Epoch 1/1, Loss: 3.162393242120743, Accuracy: 0.977
# 	Training Client 8/60
# Epoch 1/1, Loss: 4.3788752825930715, Accuracy: 0.96
# 	Training Client 9/60
# Epoch 1/1, Loss: 4.276865602238104, Accuracy: 0.968
# 	Training Client 10/60
# Epoch 1/1, Loss: 3.4839476384222507, Accuracy: 0.969
# 	Training Client 11/60
# Epoch 1/1, Loss: 3.562376717105508, Accuracy: 0.962
# 	Training Client 12/60
# Epoch 1/1, Loss: 3.8486444104928523, Accuracy: 0.955
# 	Training Client 13/60
# Epoch 1/1, Loss: 3.949482602532953, Accuracy: 0.964
# 	Training Client 14/60
# Epoch 1/1, Loss: 3.590538654476404, Accuracy: 0.96
# 	Training Client 15/60
# Epoch 1/1, Loss: 3.245071481913328, Accuracy: 0.967
# 	Training Client 16/60
# Epoch 1/1, Loss: 3.9574757553637028, Accuracy: 0.966
# 	Training Client 17/60
# Epoch 1/1, Loss: 3.919042487628758, Accuracy: 0.96
# 	Training Client 18/60
# Epoch 1/1, Loss: 3.860964499413967, Accuracy: 0.964
# 	Training Client 19/60
# Epoch 1/1, Loss: 3.780989752151072, Accuracy: 0.965
# 	Training Client 20/60
# Epoch 1/1, Loss: 4.382188148796558, Accuracy: 0.959
# 	Training Client 21/60
# Epoch 1/1, Loss: 4.172900990583003, Accuracy: 0.963
# 	Training Client 22/60
# Epoch 1/1, Loss: 5.305999170988798, Accuracy: 0.955
# 	Training Client 23/60
# Epoch 1/1, Loss: 4.312487246003002, Accuracy: 0.959
# 	Training Client 24/60
# Epoch 1/1, Loss: 3.061109649017453, Accuracy: 0.968
# 	Training Client 25/60
# Epoch 1/1, Loss: 3.714315080200322, Accuracy: 0.958
# 	Training Client 26/60
# Epoch 1/1, Loss: 5.245283362455666, Accuracy: 0.952
# 	Training Client 27/60
# Epoch 1/1, Loss: 4.598348085768521, Accuracy: 0.961
# 	Training Client 28/60
# Epoch 1/1, Loss: 4.669497221708298, Accuracy: 0.957
# 	Training Client 29/60
# Epoch 1/1, Loss: 4.235148916952312, Accuracy: 0.954
# 	Training Client 30/60
# Epoch 1/1, Loss: 4.277365579735488, Accuracy: 0.957
# 	Training Client 31/60
# Epoch 1/1, Loss: 4.302400311687961, Accuracy: 0.96
# 	Training Client 32/60
# Epoch 1/1, Loss: 4.334545358084142, Accuracy: 0.956
# 	Training Client 33/60
# Epoch 1/1, Loss: 4.514667268842459, Accuracy: 0.964
# 	Training Client 34/60
# Epoch 1/1, Loss: 4.523362109437585, Accuracy: 0.959
# 	Training Client 35/60
# Epoch 1/1, Loss: 4.142272901255637, Accuracy: 0.96
# 	Training Client 36/60
# Epoch 1/1, Loss: 3.1593117178417742, Accuracy: 0.964
# 	Training Client 37/60
# Epoch 1/1, Loss: 3.829663695767522, Accuracy: 0.962
# 	Training Client 38/60
# Epoch 1/1, Loss: 3.6914050206542015, Accuracy: 0.97
# 	Training Client 39/60
# Epoch 1/1, Loss: 4.322235260158777, Accuracy: 0.964
# 	Training Client 40/60
# Epoch 1/1, Loss: 4.211439434438944, Accuracy: 0.967
# 	Training Client 41/60
# Epoch 1/1, Loss: 4.449471598491073, Accuracy: 0.964
# 	Training Client 42/60
# Epoch 1/1, Loss: 4.155789125710726, Accuracy: 0.959
# 	Training Client 43/60
# Epoch 1/1, Loss: 4.204249242320657, Accuracy: 0.957
# 	Training Client 44/60
# Epoch 1/1, Loss: 4.451476823538542, Accuracy: 0.947
# 	Training Client 45/60
# Epoch 1/1, Loss: 3.8133183093741536, Accuracy: 0.96
# 	Training Client 46/60
# Epoch 1/1, Loss: 4.009619778953493, Accuracy: 0.962
# 	Training Client 47/60
# Epoch 1/1, Loss: 3.789514008909464, Accuracy: 0.961
# 	Training Client 48/60
# Epoch 1/1, Loss: 3.5933402199298143, Accuracy: 0.964
# 	Training Client 49/60
# Epoch 1/1, Loss: 4.357641648501158, Accuracy: 0.95
# 	Training Client 50/60
# Epoch 1/1, Loss: 4.679933795705438, Accuracy: 0.954
# 	Training Client 51/60
# ...
# 	Training Client 48/60
# Epoch 1/1, Loss: 4.470347558793719e-08, Accuracy: 1.0
# 	Training Client 49/60
# Epoch 1/1, Loss: 0.004734666204491811, Accuracy: 1.0
# 	Training Client 50/60
# Epoch 1/1, Loss: 0.4218373948538503, Accuracy: 0.998
# 	Training Client 51/60
# Epoch 1/1, Loss: 0.9226557791221239, Accuracy: 0.989
# 	Training Client 52/60
# Epoch 1/1, Loss: 5.960462834408986e-08, Accuracy: 1.0
# 	Training Client 53/60
# Epoch 1/1, Loss: 1.5839493138482794, Accuracy: 0.984
# 	Training Client 54/60
# Epoch 1/1, Loss: 1.6076295525126625, Accuracy: 0.986
# 	Training Client 55/60
# Epoch 1/1, Loss: 0.3787821544209167, Accuracy: 0.998
# 	Training Client 56/60
# Epoch 1/1, Loss: 0.5318061184896201, Accuracy: 0.999
# 	Training Client 57/60
# Epoch 1/1, Loss: 1.6287462703912752, Accuracy: 0.983
# 	Training Client 58/60
# Epoch 1/1, Loss: 1.0351292970681243, Accuracy: 0.99
# 	Training Client 59/60
# Epoch 1/1, Loss: 1.0176301836545463, Accuracy: 0.987
# 	Training Client 60/60
# Epoch 1/1, Loss: 2.215910426690243, Accuracy: 0.983
# 	Aggregating client models
# fixed_detected_drift_clients:{'sudden': [33, 34, 36, 37, 38, 39, 41, 42, 43, 47, 48, 49, 51, 54, 55], 'gradual': [1, 5, 6, 8, 11, 13, 15, 16, 18, 19, 20, 23, 25, 27, 29]}
# common_dclients:set()
# no_drift_epochs:1
# Global Epoch 148/150
# 	Training Client 1/60
# Epoch 1/1, Loss: 1.4157005104088967, Accuracy: 0.988
# 	Training Client 2/60
# Epoch 1/1, Loss: 0.2645236609975541, Accuracy: 0.996
# 	Training Client 3/60
# Epoch 1/1, Loss: 1.3164293488371186, Accuracy: 0.988
# 	Training Client 4/60
# Epoch 1/1, Loss: 1.4646024626272265, Accuracy: 0.984
# 	Training Client 5/60
# Epoch 1/1, Loss: 0.9930320519561064, Accuracy: 0.992
# 	Training Client 6/60
# Epoch 1/1, Loss: 0.9297992080076938, Accuracy: 0.99
# 	Training Client 7/60
# Epoch 1/1, Loss: 0.349023114240822, Accuracy: 0.995
# 	Training Client 8/60
# Epoch 1/1, Loss: 1.0704471103435935, Accuracy: 0.988
# 	Training Client 9/60
# Epoch 1/1, Loss: 0.6390513609153032, Accuracy: 0.995
# 	Training Client 10/60
# Epoch 1/1, Loss: 1.411863418026769, Accuracy: 0.985
# 	Training Client 11/60
# Epoch 1/1, Loss: 1.7788858158455696, Accuracy: 0.983
# 	Training Client 12/60
# Epoch 1/1, Loss: 0.303171309748393, Accuracy: 0.996
# 	Training Client 13/60
# Epoch 1/1, Loss: 1.343051569230738, Accuracy: 0.99
# 	Training Client 14/60
# Epoch 1/1, Loss: 0.28883191814716724, Accuracy: 0.995
# 	Training Client 15/60
# Epoch 1/1, Loss: 1.3708811008254997, Accuracy: 0.985
# 	Training Client 16/60
# Epoch 1/1, Loss: 0.11654847675606561, Accuracy: 0.999
# 	Training Client 17/60
# Epoch 1/1, Loss: 0.5154838649630875, Accuracy: 0.996
# 	Training Client 18/60
# Epoch 1/1, Loss: 1.6179805039428174, Accuracy: 0.983
# 	Training Client 19/60
# Epoch 1/1, Loss: 0.6643526476404702, Accuracy: 0.996
# 	Training Client 20/60
# Epoch 1/1, Loss: 0.4724317196978518, Accuracy: 0.994
# 	Training Client 21/60
# Epoch 1/1, Loss: 0.09246997596483197, Accuracy: 0.998
# 	Training Client 22/60
# Epoch 1/1, Loss: 2.2110634309938177, Accuracy: 0.985
# 	Training Client 23/60
# Epoch 1/1, Loss: 1.653528482245747, Accuracy: 0.982
# 	Training Client 24/60
# Epoch 1/1, Loss: 0.639522219326885, Accuracy: 0.994
# 	Training Client 25/60
# Epoch 1/1, Loss: 1.2011702845011314, Accuracy: 0.988
# 	Training Client 26/60
# Epoch 1/1, Loss: 0.1751033451699584, Accuracy: 0.998
# 	Training Client 27/60
# Epoch 1/1, Loss: 1.2048507300642086, Accuracy: 0.988
# 	Training Client 28/60
# Epoch 1/1, Loss: 0.8344057336981336, Accuracy: 0.991
# 	Training Client 29/60
# Epoch 1/1, Loss: 0.8073311375610501, Accuracy: 0.99
# 	Training Client 30/60
# Epoch 1/1, Loss: 0.13645300591952036, Accuracy: 0.998
# 	Training Client 31/60
# Epoch 1/1, Loss: 0.9142194525338709, Accuracy: 0.988
# 	Training Client 32/60
# Epoch 1/1, Loss: 1.5185584198479773, Accuracy: 0.985
# 	Training Client 33/60
# Epoch 1/1, Loss: 0.9653743097442202, Accuracy: 0.992
# 	Training Client 34/60
# Epoch 1/1, Loss: 6.522498287475642e-06, Accuracy: 1.0
# 	Training Client 35/60
# Epoch 1/1, Loss: 1.676379310922016e-07, Accuracy: 1.0
# 	Training Client 36/60
# Epoch 1/1, Loss: 0.3810756714674426, Accuracy: 0.996
# 	Training Client 37/60
# Epoch 1/1, Loss: 0.18988463554144186, Accuracy: 0.998
# 	Training Client 38/60
# Epoch 1/1, Loss: 3.3238276145430845e-05, Accuracy: 1.0
# 	Training Client 39/60
# Epoch 1/1, Loss: 6.332991420165968e-08, Accuracy: 1.0
# 	Training Client 40/60
# Epoch 1/1, Loss: 0.0002784012145604642, Accuracy: 1.0
# 	Training Client 41/60
# Epoch 1/1, Loss: 1.1889011172024766, Accuracy: 0.988
# 	Training Client 42/60
# Epoch 1/1, Loss: 0.0009720110568345319, Accuracy: 1.0
# 	Training Client 43/60
# Epoch 1/1, Loss: 1.1175862479895216e-07, Accuracy: 1.0
# 	Training Client 44/60
# Epoch 1/1, Loss: 2.0861613658773592e-07, Accuracy: 1.0
# 	Training Client 45/60
# Epoch 1/1, Loss: 0.9779356471335632, Accuracy: 0.988
# 	Training Client 46/60
# Epoch 1/1, Loss: 1.4098831756855361, Accuracy: 0.989
# 	Training Client 47/60
# Epoch 1/1, Loss: 1.088994348217966, Accuracy: 0.985
# 	Training Client 48/60
# Epoch 1/1, Loss: 3.762535651929966e-07, Accuracy: 1.0
# 	Training Client 49/60
# Epoch 1/1, Loss: 0.000444050267807361, Accuracy: 1.0
# 	Training Client 50/60
# Epoch 1/1, Loss: 0.001603294730546878, Accuracy: 1.0
# 	Training Client 51/60
# Epoch 1/1, Loss: 1.3942548734513593, Accuracy: 0.985
# 	Training Client 52/60
# Epoch 1/1, Loss: 7.450579042611594e-08, Accuracy: 1.0
# 	Training Client 53/60
# Epoch 1/1, Loss: 1.4955387042136863, Accuracy: 0.986
# 	Training Client 54/60
# Epoch 1/1, Loss: 1.3506819217000157, Accuracy: 0.988
# 	Training Client 55/60
# Epoch 1/1, Loss: 0.0015699426356607926, Accuracy: 1.0
# 	Training Client 56/60
# Epoch 1/1, Loss: 0.5134024005057092, Accuracy: 0.998
# 	Training Client 57/60
# Epoch 1/1, Loss: 1.9102899253466603, Accuracy: 0.978
# 	Training Client 58/60
# Epoch 1/1, Loss: 0.9303327244051616, Accuracy: 0.989
# 	Training Client 59/60
# Epoch 1/1, Loss: 0.8514828533225227, Accuracy: 0.994
# 	Training Client 60/60
# Epoch 1/1, Loss: 1.2733842083107447, Accuracy: 0.983
# 	Aggregating client models
# fixed_detected_drift_clients:{'sudden': [33, 34, 36, 37, 38, 39, 41, 42, 43, 47, 48, 49, 51, 54, 55], 'gradual': [1, 5, 6, 8, 11, 13, 15, 16, 18, 19, 20, 23, 25, 27, 29]}
# common_dclients:set()
# no_drift_epochs:0
# Global Epoch 149/150
# 	Training Client 1/60
# Epoch 1/1, Loss: 1.2001718106587305, Accuracy: 0.988
# 	Training Client 2/60
# Epoch 1/1, Loss: 0.486943630422104, Accuracy: 0.995
# 	Training Client 3/60
# Epoch 1/1, Loss: 1.4292059865183546, Accuracy: 0.989
# 	Training Client 4/60
# Epoch 1/1, Loss: 1.2664630009385291, Accuracy: 0.983
# 	Training Client 5/60
# Epoch 1/1, Loss: 0.5932171770164132, Accuracy: 0.994
# 	Training Client 6/60
# Epoch 1/1, Loss: 1.2597352691614665, Accuracy: 0.993
# 	Training Client 7/60
# Epoch 1/1, Loss: 0.5874235665920082, Accuracy: 0.997
# 	Training Client 8/60
# Epoch 1/1, Loss: 0.8082933227778994, Accuracy: 0.988
# 	Training Client 9/60
# Epoch 1/1, Loss: 0.3350064458655879, Accuracy: 0.998
# 	Training Client 10/60
# Epoch 1/1, Loss: 1.0779986132693011, Accuracy: 0.986
# 	Training Client 11/60
# Epoch 1/1, Loss: 2.224052093064529, Accuracy: 0.979
# 	Training Client 12/60
# Epoch 1/1, Loss: 0.30358883886957244, Accuracy: 0.995
# 	Training Client 13/60
# Epoch 1/1, Loss: 1.511253986027441, Accuracy: 0.985
# 	Training Client 14/60
# Epoch 1/1, Loss: 0.38382960535864186, Accuracy: 0.995
# 	Training Client 15/60
# Epoch 1/1, Loss: 1.3543146932133823, Accuracy: 0.983
# 	Training Client 16/60
# Epoch 1/1, Loss: 0.5685401907016381, Accuracy: 0.998
# 	Training Client 17/60
# Epoch 1/1, Loss: 0.33819418777579635, Accuracy: 0.996
# 	Training Client 18/60
# Epoch 1/1, Loss: 1.2063392037816811, Accuracy: 0.984
# 	Training Client 19/60
# Epoch 1/1, Loss: 0.4323386371178337, Accuracy: 0.997
# 	Training Client 20/60
# Epoch 1/1, Loss: 0.5714319944477211, Accuracy: 0.995
# 	Training Client 21/60
# Epoch 1/1, Loss: 0.2073691581399899, Accuracy: 0.999
# 	Training Client 22/60
# Epoch 1/1, Loss: 1.8655407316691708, Accuracy: 0.987
# 	Training Client 23/60
# Epoch 1/1, Loss: 1.9896054523132989, Accuracy: 0.981
# 	Training Client 24/60
# Epoch 1/1, Loss: 0.33447251305647185, Accuracy: 0.994
# 	Training Client 25/60
# Epoch 1/1, Loss: 1.3481509910488967, Accuracy: 0.981
# 	Training Client 26/60
# Epoch 1/1, Loss: 0.06323035446337855, Accuracy: 0.999
# 	Training Client 27/60
# Epoch 1/1, Loss: 1.1521255353636661, Accuracy: 0.989
# 	Training Client 28/60
# Epoch 1/1, Loss: 0.6280012239003554, Accuracy: 0.994
# 	Training Client 29/60
# Epoch 1/1, Loss: 0.9255163880079635, Accuracy: 0.989
# 	Training Client 30/60
# Epoch 1/1, Loss: 0.6452567720684712, Accuracy: 0.997
# 	Training Client 31/60
# Epoch 1/1, Loss: 0.9401588515320327, Accuracy: 0.986
# 	Training Client 32/60
# Epoch 1/1, Loss: 1.8844349685678026, Accuracy: 0.983
# 	Training Client 33/60
# Epoch 1/1, Loss: 1.312902311081416, Accuracy: 0.988
# 	Training Client 34/60
# Epoch 1/1, Loss: 1.6614693283401039e-06, Accuracy: 1.0
# 	Training Client 35/60
# Epoch 1/1, Loss: 7.4505797087454084e-09, Accuracy: 1.0
# 	Training Client 36/60
# Epoch 1/1, Loss: 0.5792552641669317, Accuracy: 0.994
# 	Training Client 37/60
# Epoch 1/1, Loss: 0.005555465222288003, Accuracy: 1.0
# 	Training Client 38/60
# Epoch 1/1, Loss: 1.4491158051299635e-06, Accuracy: 1.0
# 	Training Client 39/60
# Epoch 1/1, Loss: 0.10533471728519994, Accuracy: 0.999
# 	Training Client 40/60
# Epoch 1/1, Loss: 0.0007978129210852725, Accuracy: 1.0
# 	Training Client 41/60
# Epoch 1/1, Loss: 1.4273231349652633, Accuracy: 0.988
# 	Training Client 42/60
# Epoch 1/1, Loss: 0.006611386489566051, Accuracy: 1.0
# 	Training Client 43/60
# Epoch 1/1, Loss: 1.0058277033486718e-07, Accuracy: 1.0
# 	Training Client 44/60
# Epoch 1/1, Loss: 0.02568764422845149, Accuracy: 0.999
# 	Training Client 45/60
# Epoch 1/1, Loss: 1.3591120985147427, Accuracy: 0.989
# 	Training Client 46/60
# Epoch 1/1, Loss: 1.3612793545762543, Accuracy: 0.99
# 	Training Client 47/60
# Epoch 1/1, Loss: 1.1630660212322255, Accuracy: 0.991
# 	Training Client 48/60
# Epoch 1/1, Loss: 1.4901157641133977e-08, Accuracy: 1.0
# 	Training Client 49/60
# Epoch 1/1, Loss: 6.332992463775611e-08, Accuracy: 1.0
# 	Training Client 50/60
# Epoch 1/1, Loss: 0.046703395021230776, Accuracy: 0.999
# 	Training Client 51/60
# Epoch 1/1, Loss: 1.0544123300005595, Accuracy: 0.988
# 	Training Client 52/60
# Epoch 1/1, Loss: 4.284072967486452e-07, Accuracy: 1.0
# 	Training Client 53/60
# Epoch 1/1, Loss: 2.252762005722616, Accuracy: 0.984
# 	Training Client 54/60
# Epoch 1/1, Loss: 1.2087293958647933, Accuracy: 0.991
# 	Training Client 55/60
# Epoch 1/1, Loss: 0.24401084471276935, Accuracy: 0.999
# 	Training Client 56/60
# Epoch 1/1, Loss: 0.4349171000546075, Accuracy: 0.999
# 	Training Client 57/60
# Epoch 1/1, Loss: 1.778185837671117, Accuracy: 0.982
# 	Training Client 58/60
# Epoch 1/1, Loss: 0.8664931996827363, Accuracy: 0.993
# 	Training Client 59/60
# Epoch 1/1, Loss: 0.9749907308578258, Accuracy: 0.992
# 	Training Client 60/60
# Epoch 1/1, Loss: 1.1235168824205175, Accuracy: 0.986
# 	Aggregating client models
# fixed_detected_drift_clients:{'sudden': [33, 34, 36, 37, 38, 39, 41, 42, 43, 47, 48, 49, 51, 54, 55], 'gradual': [1, 5, 6, 8, 11, 13, 15, 16, 18, 19, 20, 23, 25, 27, 29]}
# common_dclients:set()
# no_drift_epochs:0
# Global Epoch 150/150
# 	Training Client 1/60
# Epoch 1/1, Loss: 1.4237277786014602, Accuracy: 0.986
# 	Training Client 2/60
# Epoch 1/1, Loss: 0.5607673513987947, Accuracy: 0.995
# 	Training Client 3/60
# Epoch 1/1, Loss: 1.2651324227190344, Accuracy: 0.985
# 	Training Client 4/60
# Epoch 1/1, Loss: 1.587446398800239, Accuracy: 0.983
# 	Training Client 5/60
# Epoch 1/1, Loss: 0.8616813828193699, Accuracy: 0.989
# 	Training Client 6/60
# Epoch 1/1, Loss: 1.1334916366852212, Accuracy: 0.994
# 	Training Client 7/60
# Epoch 1/1, Loss: 0.4838791725286029, Accuracy: 0.997
# 	Training Client 8/60
# Epoch 1/1, Loss: 0.9400393252399226, Accuracy: 0.99
# 	Training Client 9/60
# Epoch 1/1, Loss: 0.327440555718681, Accuracy: 0.997
# 	Training Client 10/60
# Epoch 1/1, Loss: 0.8401121415208763, Accuracy: 0.991
# 	Training Client 11/60
# Epoch 1/1, Loss: 1.8232255094771972, Accuracy: 0.984
# 	Training Client 12/60
# Epoch 1/1, Loss: 0.17633604358991306, Accuracy: 0.997
# 	Training Client 13/60
# Epoch 1/1, Loss: 0.9626095359999454, Accuracy: 0.986
# 	Training Client 14/60
# Epoch 1/1, Loss: 0.3205849832847605, Accuracy: 0.997
# 	Training Client 15/60
# Epoch 1/1, Loss: 1.4067569509206805, Accuracy: 0.985
# 	Training Client 16/60
# Epoch 1/1, Loss: 0.30494010987979436, Accuracy: 0.996
# 	Training Client 17/60
# Epoch 1/1, Loss: 0.11531248332798238, Accuracy: 0.999
# 	Training Client 18/60
# Epoch 1/1, Loss: 1.2756619242609304, Accuracy: 0.99
# 	Training Client 19/60
# Epoch 1/1, Loss: 0.23512295248059445, Accuracy: 0.997
# 	Training Client 20/60
# Epoch 1/1, Loss: 0.8155808876572337, Accuracy: 0.991
# 	Training Client 21/60
# Epoch 1/1, Loss: 1.0621572460969873, Accuracy: 0.995
# 	Training Client 22/60
# Epoch 1/1, Loss: 1.936530709368526, Accuracy: 0.988
# 	Training Client 23/60
# Epoch 1/1, Loss: 1.647572713874979, Accuracy: 0.985
# 	Training Client 24/60
# Epoch 1/1, Loss: 0.5547264260791849, Accuracy: 0.996
# 	Training Client 25/60
# Epoch 1/1, Loss: 0.7787973907470587, Accuracy: 0.992
# 	Training Client 26/60
# Epoch 1/1, Loss: 0.2756546941732836, Accuracy: 0.998
# 	Training Client 27/60
# Epoch 1/1, Loss: 0.8381731884214219, Accuracy: 0.989
# 	Training Client 28/60
# Epoch 1/1, Loss: 0.455671411719095, Accuracy: 0.997
# 	Training Client 29/60
# Epoch 1/1, Loss: 1.055255728715565, Accuracy: 0.992
# 	Training Client 30/60
# Epoch 1/1, Loss: 0.20277390277169616, Accuracy: 0.996
# 	Training Client 31/60
# Epoch 1/1, Loss: 1.5972620586981066, Accuracy: 0.986
# 	Training Client 32/60
# Epoch 1/1, Loss: 1.721399526228197, Accuracy: 0.986
# 	Training Client 33/60
# Epoch 1/1, Loss: 1.4898214116692543, Accuracy: 0.991
# 	Training Client 34/60
# Epoch 1/1, Loss: 1.2665981063975096e-07, Accuracy: 1.0
# 	Training Client 35/60
# Epoch 1/1, Loss: 2.0116536147973818e-07, Accuracy: 1.0
# 	Training Client 36/60
# Epoch 1/1, Loss: 0.34012345773408015, Accuracy: 0.996
# 	Training Client 37/60
# Epoch 1/1, Loss: 5.170307259882989e-06, Accuracy: 1.0
# 	Training Client 38/60
# Epoch 1/1, Loss: 3.0397167303242156e-06, Accuracy: 1.0
# 	Training Client 39/60
# Epoch 1/1, Loss: 6.580581958104403e-05, Accuracy: 1.0
# 	Training Client 40/60
# Epoch 1/1, Loss: 3.1925193366699745e-06, Accuracy: 1.0
# 	Training Client 41/60
# Epoch 1/1, Loss: 0.9470740742690396, Accuracy: 0.99
# 	Training Client 42/60
# Epoch 1/1, Loss: 0.023190143351643044, Accuracy: 0.999
# 	Training Client 43/60
# Epoch 1/1, Loss: 5.550645201246596e-07, Accuracy: 1.0
# 	Training Client 44/60
# Epoch 1/1, Loss: 5.21540552966826e-08, Accuracy: 1.0
# 	Training Client 45/60
# Epoch 1/1, Loss: 0.9401092598643572, Accuracy: 0.99
# 	Training Client 46/60
# Epoch 1/1, Loss: 1.2820928466717305, Accuracy: 0.985
# 	Training Client 47/60
# Epoch 1/1, Loss: 1.0653101858697482, Accuracy: 0.991
# 	Training Client 48/60
# Epoch 1/1, Loss: 7.4505797087454084e-09, Accuracy: 1.0
# 	Training Client 49/60
# Epoch 1/1, Loss: 8.530847028787036e-07, Accuracy: 1.0
# 	Training Client 50/60
# Epoch 1/1, Loss: 7.450567816036369e-07, Accuracy: 1.0
# 	Training Client 51/60
# Epoch 1/1, Loss: 0.9317361280263867, Accuracy: 0.99
# 	Training Client 52/60
# Epoch 1/1, Loss: 1.7136292651542817e-07, Accuracy: 1.0
# 	Training Client 53/60
# Epoch 1/1, Loss: 1.4676060440615402, Accuracy: 0.986
# 	Training Client 54/60
# Epoch 1/1, Loss: 1.1683139587112237, Accuracy: 0.989
# 	Training Client 55/60
# Epoch 1/1, Loss: 9.015133701772982e-07, Accuracy: 1.0
# 	Training Client 56/60
# Epoch 1/1, Loss: 0.014401496729887331, Accuracy: 1.0
# 	Training Client 57/60
# Epoch 1/1, Loss: 1.5226212148118066, Accuracy: 0.987
# 	Training Client 58/60
# Epoch 1/1, Loss: 1.3656893691158984, Accuracy: 0.986
# 	Training Client 59/60
# Epoch 1/1, Loss: 0.8866699355603487, Accuracy: 0.993
# 	Training Client 60/60
# Epoch 1/1, Loss: 1.5474166671410785, Accuracy: 0.989
# 	Aggregating client models
# fixed_detected_drift_clients:{'sudden': [33, 34, 36, 37, 38, 39, 41, 42, 43, 47, 48, 49, 51, 54, 55], 'gradual': [1, 5, 6, 8, 11, 13, 15, 16, 18, 19, 20, 23, 25, 27, 29]}
# common_dclients:set()
# no_drift_epochs:1
# Drift Detection metrics::: true_positives:219, true_negatives:3958, false_positives:92, false_negatives:1251
# Drift Detection Performance:
# Accuracy: 0.7567028985507246
# Precision: 0.7041800643086816
# Recall: 0.1489795918367347
# F1 Score: 0.24592925322852333

# %% [markdown]
# note: please ignore these results as it is not updated. latest results can be found in the log file dated 26102024
