# %%
# !pip install scikit-multiflow
# Out:
# Collecting scikit-multiflow
#   Downloading scikit-multiflow-0.5.3.tar.gz (450 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.6/450.6 kB 2.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sortedcontainers>=1.5.7 in /opt/conda/lib/python3.10/site-packages (from scikit-multiflow) (2.4.0)
# Requirement already satisfied: numpy>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from scikit-multiflow) (1.26.4)
# Requirement already satisfied: scipy>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-multiflow) (1.14.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-multiflow) (3.7.5)
# Requirement already satisfied: scikit-learn>=0.20 in /opt/conda/lib/python3.10/site-packages (from scikit-multiflow) (1.2.2)
# Requirement already satisfied: pandas>=0.25.3 in /opt/conda/lib/python3.10/site-packages (from scikit-multiflow) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->scikit-multiflow) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->scikit-multiflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->scikit-multiflow) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->scikit-multiflow) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->scikit-multiflow) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->scikit-multiflow) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->scikit-multiflow) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.0.0->scikit-multiflow) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25.3->scikit-multiflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25.3->scikit-multiflow) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20->scikit-multiflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20->scikit-multiflow) (3.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->scikit-multiflow) (1.16.0)
# Building wheels for collected packages: scikit-multiflow
#   Building wheel for scikit-multiflow (setup.py) ... done
#   Created wheel for scikit-multiflow: filename=scikit_multiflow-0.5.3-cp310-cp310-linux_x86_64.whl size=576330 sha256=9de41833016b48fdc6ebcb3ffdbb1fe2c3ac58f83048d9c47ae03f1b4a2a602b
#   Stored in directory: /root/.cache/pip/wheels/6e/1b/56/45b17a6cf203d98000a45976cb0dd0c4c3f11960e6a505f231
# Successfully built scikit-multiflow
# Installing collected packages: scikit-multiflow
# Successfully installed scikit-multiflow-0.5.3

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from scipy.ndimage import rotate
from scipy.stats import mannwhitneyu, ttest_ind, ks_2samp, ttest_ind_from_stats
import copy
import random
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split
from skmultiflow.drift_detection import ADWIN, DDM, EDDM, HDDM_W

# %%
# Set seed for reproducibility
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# Define the model architecture
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.fc1 = nn.Linear(64 * 5 * 5, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = torch.relu(self.conv2(x))
        x = torch.max_pool2d(x, kernel_size=2, stride=2)
        x = x.view(-1, 64 * 5 * 5)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return torch.log_softmax(x, dim=1)

# Function to simulate client training with MNIST data
def client_training(train_loader, model, criterion, optimizer, num_epochs=1):
    model.train()
    batch_losses = []
    for epoch in range(num_epochs):
        total_loss, correct, total = 0.0, 0.0, 0.0
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            batch_losses.append(loss.item())
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()        
        accuracy = correct / total
        print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss}, Accuracy: {accuracy}")
        
    return batch_losses

# Function to test the trained model on client data
def client_testing(test_loader, model):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total

# %%
# Function to apply gradual rotation drift
def apply_rotation_drift(images, current_epoch, max_rotation, start_epoch, end_epoch, total_epochs):
    if current_epoch < start_epoch:
        rotation_angle = 0
    elif start_epoch <= current_epoch <= end_epoch:
        transition_progress = (current_epoch - start_epoch) / (end_epoch - start_epoch)
        rotation_angle = transition_progress * max_rotation
    else:
        rotation_angle = 0
    
    fraction_rotated = (current_epoch - start_epoch + 1) / (end_epoch - start_epoch + 1)
    num_images_to_rotate = int(fraction_rotated * len(images))
    
    drifted_images = images.clone()
    if num_images_to_rotate > 0 and fraction_rotated<=1:
        indices_to_rotate = torch.randperm(len(images))[:num_images_to_rotate]
        for idx in indices_to_rotate:
            drifted_images[idx] = torch.tensor(rotate(images[idx].numpy(), rotation_angle, reshape=False))
    
    return drifted_images

# %%
#sudden

def federated_learning(num_clients=60, num_local_epochs=5, num_global_epochs=40):
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
    trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)

    partition_size = len(trainset) // num_clients
    lengths = [partition_size] * num_clients
    datasets = random_split(trainset, lengths)

    client_indices = [dataset.indices for dataset in datasets]

    # Clients that will experience rotation drift
#     rotation_drift_clients = [2, 6, 9,13,15,27]

    # Clients that will experience class swap drift
    class_swap_drift_clients = [2, 6, 9, 13, 20, 27, 33, 37, 41, 55]

    # Initialize global model
    global_model = CNN().to(device)
    previous_client_losses = [[] for _ in range(num_clients)]

    # Initialize ADWIN, DDM, EDDM detectors
    hddm_detectors = [HDDM_W(drift_confidence=0.001, warning_confidence=0.005, lambda_option=0.05, two_side_option=True) for _ in range(num_clients)]
    ddm_detectors = [DDM(min_num_instances=3, warning_level=1, out_control_level=3) for _ in range(num_clients)]
    # Create an instance of EDDM
    edddm = EDDM()

    # Modify parameters after initialization if necessary
    edddm.min_num_instances = 3
    edddm.warning_level = 1
    edddm.out_control_level = 3
    
    eddm_detectors = [edddm for _ in range(num_clients)]

    # Initialize counters for drift detection performance
    metrics = {
        'HDDM': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0},
        'DDM': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0},
        'EDDM': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0},
        'Combined': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
    }
    # Federated learning process
    for global_epoch in range(num_global_epochs):
        print(f"Global Epoch {global_epoch + 1}/{num_global_epochs}")

        # Apply rotation drift gradually starting from a certain epoch
#         if global_epoch in range(10, 31):  # Example threshold for starting drift
#             print("Applying rotation drift to specific clients")
#             for client_id in rotation_drift_clients:
#                 indices = client_indices[client_id]
#                 images = trainset.data[indices]
#                 drifted_images = apply_rotation_drift(images, global_epoch, max_rotation=30, start_epoch=10, end_epoch=30, total_epochs=num_global_epochs)
#                 trainset.data[indices] = drifted_images

        # Apply class swap drift at a specific epoch
        if global_epoch == 10:
            print("Swapping classes 3 and 8 in the train dataset for selected clients")
            for client_id in class_swap_drift_clients:
                indices = client_indices[client_id]
                for idx in indices:
                    if trainset.targets[idx] == 8:
                        trainset.targets[idx] = 3
                    elif trainset.targets[idx] == 3:
                        trainset.targets[idx] = 8
                        
                    elif trainset.targets[idx] == 5:
                        trainset.targets[idx] = 6
                    elif trainset.targets[idx] == 6:
                        trainset.targets[idx] = 5

        client_train_loaders = [torch.utils.data.DataLoader(torch.utils.data.Subset(trainset, indices), batch_size=32, shuffle=True) for indices in client_indices]
        client_test_loaders = [torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False) for _ in range(num_clients)]
        client_models = [copy.deepcopy(global_model) for _ in range(num_clients)]

        # Perform local training and compute SHAP values
        client_losses = []

        for i, train_loader in enumerate(client_train_loaders):
            print(f"\tTraining Client {i + 1}/{num_clients}")
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(client_models[i].parameters(), lr=0.001)
            loss = client_training(train_loader, client_models[i], criterion, optimizer, num_local_epochs)
            client_losses.append(loss)

            # Update previous client losses
            previous_client_losses[i].append(loss)
            
            
            

        # Concept drift detection using ADWIN, DDM, and EDDM
        if global_epoch >= 5:
            detected_drift_clients_ddm = []
            detected_drift_clients_eddm = []
            detected_drift_clients_hddm = []

            for i, losses in enumerate(client_losses):
                for loss in losses:
                    hddm_detectors[i].add_element(loss)
                    ddm_detectors[i].add_element(loss)
                    eddm_detectors[i].add_element(loss)

                    if hddm_detectors[i].detected_change():
                        detected_drift_clients_hddm.append(i)
                    if ddm_detectors[i].detected_change():
                        detected_drift_clients_ddm.append(i)
                    if eddm_detectors[i].detected_change():
                        detected_drift_clients_eddm.append(i)
                        
                        
                    
            detected_drift_clients_combined = list(set(  detected_drift_clients_hddm + detected_drift_clients_ddm + detected_drift_clients_eddm))
            print(f"ddm:{detected_drift_clients_ddm}, eddm:{detected_drift_clients_eddm}, hddm{detected_drift_clients_hddm}, combined{detected_drift_clients_combined}")
            print(f"metrics:{metrics}")
            


            for detector_name, detected_drift_clients in zip(['DDM', 'EDDM', 'HDDM', 'Combined'], [detected_drift_clients_ddm, detected_drift_clients_eddm, detected_drift_clients_hddm, detected_drift_clients_combined]):
                for client_id in range(num_clients):
                    ground_truth_drift = ((client_id in class_swap_drift_clients) and (global_epoch >= 10)) #| ((client_id in rotation_drift_clients) and (global_epoch >= 19) and (global_epoch <= 29))
                    detected_drift = client_id in detected_drift_clients

                    if detected_drift and ground_truth_drift:
                        metrics[detector_name]['TP'] += 1
                    elif not detected_drift and not ground_truth_drift:
                        metrics[detector_name]['TN'] += 1
                    elif detected_drift and not ground_truth_drift:
                        metrics[detector_name]['FP'] += 1
                    elif not detected_drift and ground_truth_drift:
                        metrics[detector_name]['FN'] += 1

                    if detected_drift == ground_truth_drift:
                        print(f"Global Epoch {global_epoch + 1}, Client {client_id + 1}: {detector_name} Drift detection is accurate.")
                    else:
                        print(f"Global Epoch {global_epoch + 1}, Client {client_id + 1}: {detector_name} Drift detection is inaccurate.")

        # Aggregate client models into global model
        print("\tAggregating client models")
        global_model = aggregate_models(global_model, client_models)

    # Test models on each client
    accuracies = []
    for i, test_loader in enumerate(client_test_loaders):
        print(f"Testing Client {i + 1}/{num_clients}")
        accuracy = client_testing(test_loader, global_model)
        accuracies.append(accuracy)
        print(f"\tAccuracy for Client {i + 1}/{num_clients}: {accuracy}")

    # Calculate performance metrics of drift detection
    for detector_name in ['DDM', 'EDDM','HDDM', 'Combined']:
        TP = metrics[detector_name]['TP']
        TN = metrics[detector_name]['TN']
        FP = metrics[detector_name]['FP']
        FN = metrics[detector_name]['FN']

        accuracy = (TP + TN) / (TP + TN + FP + FN)
        precision = TP / (TP + FP) if (TP + FP) > 0 else 0
        recall = TP / (TP + FN) if (TP + FN) > 0 else 0
        f1_score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
        
        print(f"Drift Detection metrics::: true_positives:{TP}, true_negatives:{TN}, false_positives:{FP}, false_negatives:{FN}")
        print(f"Drift Detection Performance ({detector_name}):\nAccuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1_score}")

    return accuracies

# Aggregation of models' weights using FedAvg
def aggregate_models(global_model, client_models):
    global_dict = global_model.state_dict()
    for k in global_dict.keys():
        global_dict[k] = torch.stack([client_model.state_dict()[k].float() for client_model in client_models], 0).mean(0)
    global_model.load_state_dict(global_dict)
    return global_model

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Example usage
if __name__ == "__main__":
    client_accuracies = federated_learning(num_clients=60, num_local_epochs=1, num_global_epochs=40)
    print("Client Accuracies:", client_accuracies)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 35938039.16it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 1035604.50it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 10481259.52it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 2733610.10it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Global Epoch 1/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 49.7998705804348, Accuracy: 0.507
# 	Training Client 2/60
# Epoch 1/1, Loss: 48.39897897839546, Accuracy: 0.551
# 	Training Client 3/60
# Epoch 1/1, Loss: 47.44576150178909, Accuracy: 0.507
# 	Training Client 4/60
# Epoch 1/1, Loss: 47.85296183824539, Accuracy: 0.533
# 	Training Client 5/60
# Epoch 1/1, Loss: 50.38479936122894, Accuracy: 0.516
# 	Training Client 6/60
# Epoch 1/1, Loss: 48.611885249614716, Accuracy: 0.528
# 	Training Client 7/60
# Epoch 1/1, Loss: 51.794359147548676, Accuracy: 0.464
# 	Training Client 8/60
# Epoch 1/1, Loss: 52.096949100494385, Accuracy: 0.494
# 	Training Client 9/60
# Epoch 1/1, Loss: 51.13297080993652, Accuracy: 0.525
# 	Training Client 10/60
# Epoch 1/1, Loss: 47.53140366077423, Accuracy: 0.56
# 	Training Client 11/60
# Epoch 1/1, Loss: 47.49449124932289, Accuracy: 0.564
# 	Training Client 12/60
# Epoch 1/1, Loss: 50.82881420850754, Accuracy: 0.507
# 	Training Client 13/60
# Epoch 1/1, Loss: 48.96703243255615, Accuracy: 0.523
# 	Training Client 14/60
# Epoch 1/1, Loss: 49.117168724536896, Accuracy: 0.519
# 	Training Client 15/60
# Epoch 1/1, Loss: 49.613831251859665, Accuracy: 0.525
# 	Training Client 16/60
# Epoch 1/1, Loss: 48.9167814552784, Accuracy: 0.529
# 	Training Client 17/60
# Epoch 1/1, Loss: 51.72508454322815, Accuracy: 0.49
# 	Training Client 18/60
# Epoch 1/1, Loss: 46.537873566150665, Accuracy: 0.545
# 	Training Client 19/60
# Epoch 1/1, Loss: 49.01320117712021, Accuracy: 0.527
# 	Training Client 20/60
# Epoch 1/1, Loss: 45.85374763607979, Accuracy: 0.561
# 	Training Client 21/60
# Epoch 1/1, Loss: 48.13542225956917, Accuracy: 0.564
# 	Training Client 22/60
# Epoch 1/1, Loss: 50.44376394152641, Accuracy: 0.551
# 	Training Client 23/60
# Epoch 1/1, Loss: 48.300307869911194, Accuracy: 0.519
# 	Training Client 24/60
# Epoch 1/1, Loss: 45.26660233736038, Accuracy: 0.584
# 	Training Client 25/60
# Epoch 1/1, Loss: 48.68524241447449, Accuracy: 0.531
# 	Training Client 26/60
# Epoch 1/1, Loss: 50.26375928521156, Accuracy: 0.529
# 	Training Client 27/60
# Epoch 1/1, Loss: 45.40280057489872, Accuracy: 0.546
# 	Training Client 28/60
# Epoch 1/1, Loss: 47.82523036003113, Accuracy: 0.544
# 	Training Client 29/60
# Epoch 1/1, Loss: 46.58313363790512, Accuracy: 0.547
# 	Training Client 30/60
# Epoch 1/1, Loss: 52.72194463014603, Accuracy: 0.481
# 	Training Client 31/60
# Epoch 1/1, Loss: 51.96819931268692, Accuracy: 0.494
# 	Training Client 32/60
# Epoch 1/1, Loss: 47.51566997170448, Accuracy: 0.536
# 	Training Client 33/60
# Epoch 1/1, Loss: 46.18019366264343, Accuracy: 0.549
# 	Training Client 34/60
# Epoch 1/1, Loss: 48.15187531709671, Accuracy: 0.54
# 	Training Client 35/60
# Epoch 1/1, Loss: 51.58582353591919, Accuracy: 0.505
# 	Training Client 36/60
# Epoch 1/1, Loss: 48.31639263033867, Accuracy: 0.531
# 	Training Client 37/60
# Epoch 1/1, Loss: 47.08530479669571, Accuracy: 0.546
# 	Training Client 38/60
# Epoch 1/1, Loss: 47.66308429837227, Accuracy: 0.53
# 	Training Client 39/60
# Epoch 1/1, Loss: 49.697618901729584, Accuracy: 0.508
# 	Training Client 40/60
# Epoch 1/1, Loss: 51.90636247396469, Accuracy: 0.492
# 	Training Client 41/60
# Epoch 1/1, Loss: 47.237168818712234, Accuracy: 0.548
# 	Training Client 42/60
# Epoch 1/1, Loss: 48.58057403564453, Accuracy: 0.539
# 	Training Client 43/60
# Epoch 1/1, Loss: 49.48986053466797, Accuracy: 0.523
# 	Training Client 44/60
# Epoch 1/1, Loss: 49.60144221782684, Accuracy: 0.517
# 	Training Client 45/60
# Epoch 1/1, Loss: 49.00686949491501, Accuracy: 0.558
# 	Training Client 46/60
# Epoch 1/1, Loss: 49.83794987201691, Accuracy: 0.495
# 	Training Client 47/60
# Epoch 1/1, Loss: 50.637565433979034, Accuracy: 0.516
# 	Training Client 48/60
# Epoch 1/1, Loss: 49.976088643074036, Accuracy: 0.512
# 	Training Client 49/60
# Epoch 1/1, Loss: 49.92930555343628, Accuracy: 0.533
# 	Training Client 50/60
# Epoch 1/1, Loss: 49.35827985405922, Accuracy: 0.504
# 	Training Client 51/60
# Epoch 1/1, Loss: 49.32155907154083, Accuracy: 0.499
# 	Training Client 52/60
# Epoch 1/1, Loss: 47.953457057476044, Accuracy: 0.522
# 	Training Client 53/60
# Epoch 1/1, Loss: 49.096336513757706, Accuracy: 0.525
# 	Training Client 54/60
# Epoch 1/1, Loss: 48.72912558913231, Accuracy: 0.53
# 	Training Client 55/60
# Epoch 1/1, Loss: 50.65841090679169, Accuracy: 0.502
# 	Training Client 56/60
# Epoch 1/1, Loss: 46.879148334264755, Accuracy: 0.548
# 	Training Client 57/60
# Epoch 1/1, Loss: 52.85367524623871, Accuracy: 0.489
# 	Training Client 58/60
# Epoch 1/1, Loss: 49.51780867576599, Accuracy: 0.525
# 	Training Client 59/60
# Epoch 1/1, Loss: 49.49495869874954, Accuracy: 0.544
# 	Training Client 60/60
# Epoch 1/1, Loss: 47.236832827329636, Accuracy: 0.551
# 	Aggregating client models
# Global Epoch 2/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 18.747329115867615, Accuracy: 0.822
# 	Training Client 2/60
# Epoch 1/1, Loss: 19.578819900751114, Accuracy: 0.81
# 	Training Client 3/60
# Epoch 1/1, Loss: 18.41065476834774, Accuracy: 0.817
# 	Training Client 4/60
# Epoch 1/1, Loss: 20.069906920194626, Accuracy: 0.819
# 	Training Client 5/60
# Epoch 1/1, Loss: 18.288382202386856, Accuracy: 0.816
# 	Training Client 6/60
# Epoch 1/1, Loss: 18.505726516246796, Accuracy: 0.825
# 	Training Client 7/60
# Epoch 1/1, Loss: 18.26301033049822, Accuracy: 0.81
# 	Training Client 8/60
# Epoch 1/1, Loss: 18.266528844833374, Accuracy: 0.822
# 	Training Client 9/60
# Epoch 1/1, Loss: 19.421951189637184, Accuracy: 0.799
# 	Training Client 10/60
# Epoch 1/1, Loss: 17.650615215301514, Accuracy: 0.815
# 	Training Client 11/60
# Epoch 1/1, Loss: 17.947282522916794, Accuracy: 0.81
# 	Training Client 12/60
# Epoch 1/1, Loss: 18.02963562309742, Accuracy: 0.84
# 	Training Client 13/60
# Epoch 1/1, Loss: 18.310375571250916, Accuracy: 0.833
# 	Training Client 14/60
# Epoch 1/1, Loss: 16.758917525410652, Accuracy: 0.831
# 	Training Client 15/60
# Epoch 1/1, Loss: 19.308261588215828, Accuracy: 0.81
# 	Training Client 16/60
# Epoch 1/1, Loss: 18.144258096814156, Accuracy: 0.81
# 	Training Client 17/60
# Epoch 1/1, Loss: 20.517715603113174, Accuracy: 0.802
# 	Training Client 18/60
# Epoch 1/1, Loss: 18.42021158337593, Accuracy: 0.815
# 	Training Client 19/60
# Epoch 1/1, Loss: 17.00630209594965, Accuracy: 0.827
# 	Training Client 20/60
# Epoch 1/1, Loss: 18.29637584090233, Accuracy: 0.814
# 	Training Client 21/60
# Epoch 1/1, Loss: 18.05847954750061, Accuracy: 0.827
# 	Training Client 22/60
# Epoch 1/1, Loss: 19.489416226744652, Accuracy: 0.82
# 	Training Client 23/60
# Epoch 1/1, Loss: 18.55821865797043, Accuracy: 0.827
# 	Training Client 24/60
# Epoch 1/1, Loss: 16.271729201078415, Accuracy: 0.847
# 	Training Client 25/60
# Epoch 1/1, Loss: 18.388835608959198, Accuracy: 0.81
# 	Training Client 26/60
# Epoch 1/1, Loss: 17.531817585229874, Accuracy: 0.844
# 	Training Client 27/60
# Epoch 1/1, Loss: 17.86878477036953, Accuracy: 0.828
# 	Training Client 28/60
# Epoch 1/1, Loss: 19.08134862780571, Accuracy: 0.818
# 	Training Client 29/60
# Epoch 1/1, Loss: 18.79690557718277, Accuracy: 0.816
# 	Training Client 30/60
# Epoch 1/1, Loss: 19.14837610721588, Accuracy: 0.809
# 	Training Client 31/60
# Epoch 1/1, Loss: 18.738821983337402, Accuracy: 0.814
# 	Training Client 32/60
# Epoch 1/1, Loss: 18.923307843506336, Accuracy: 0.808
# 	Training Client 33/60
# Epoch 1/1, Loss: 19.036626085639, Accuracy: 0.817
# 	Training Client 34/60
# Epoch 1/1, Loss: 18.58782795071602, Accuracy: 0.828
# 	Training Client 35/60
# Epoch 1/1, Loss: 18.708833307027817, Accuracy: 0.822
# 	Training Client 36/60
# Epoch 1/1, Loss: 18.932549715042114, Accuracy: 0.824
# 	Training Client 37/60
# Epoch 1/1, Loss: 17.924872390925884, Accuracy: 0.825
# 	Training Client 38/60
# Epoch 1/1, Loss: 15.42277979850769, Accuracy: 0.847
# 	Training Client 39/60
# Epoch 1/1, Loss: 18.657226085662842, Accuracy: 0.815
# 	Training Client 40/60
# Epoch 1/1, Loss: 17.569369480013847, Accuracy: 0.827
# 	Training Client 41/60
# Epoch 1/1, Loss: 18.57801929116249, Accuracy: 0.814
# 	Training Client 42/60
# Epoch 1/1, Loss: 18.728981092572212, Accuracy: 0.829
# 	Training Client 43/60
# Epoch 1/1, Loss: 18.799657322466373, Accuracy: 0.821
# 	Training Client 44/60
# Epoch 1/1, Loss: 17.49684238433838, Accuracy: 0.83
# 	Training Client 45/60
# Epoch 1/1, Loss: 18.835917189717293, Accuracy: 0.828
# 	Training Client 46/60
# Epoch 1/1, Loss: 18.927096590399742, Accuracy: 0.813
# 	Training Client 47/60
# Epoch 1/1, Loss: 18.90012226998806, Accuracy: 0.826
# 	Training Client 48/60
# Epoch 1/1, Loss: 16.487412083894014, Accuracy: 0.854
# 	Training Client 49/60
# Epoch 1/1, Loss: 19.229317247867584, Accuracy: 0.818
# 	Training Client 50/60
# Epoch 1/1, Loss: 19.587856620550156, Accuracy: 0.814
# 	Training Client 51/60
# Epoch 1/1, Loss: 19.208343774080276, Accuracy: 0.812
# 	Training Client 52/60
# Epoch 1/1, Loss: 16.852145433425903, Accuracy: 0.828
# 	Training Client 53/60
# Epoch 1/1, Loss: 19.231063038110733, Accuracy: 0.817
# 	Training Client 54/60
# Epoch 1/1, Loss: 17.974320590496063, Accuracy: 0.819
# 	Training Client 55/60
# Epoch 1/1, Loss: 18.64983706921339, Accuracy: 0.804
# 	Training Client 56/60
# Epoch 1/1, Loss: 20.53317752480507, Accuracy: 0.799
# 	Training Client 57/60
# Epoch 1/1, Loss: 18.441883623600006, Accuracy: 0.83
# 	Training Client 58/60
# Epoch 1/1, Loss: 18.81112563610077, Accuracy: 0.832
# 	Training Client 59/60
# Epoch 1/1, Loss: 18.702544257044792, Accuracy: 0.806
# 	Training Client 60/60
# Epoch 1/1, Loss: 17.888263180851936, Accuracy: 0.824
# 	Aggregating client models
# Global Epoch 3/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 12.295296251773834, Accuracy: 0.873
# 	Training Client 2/60
# Epoch 1/1, Loss: 13.045458748936653, Accuracy: 0.878
# 	Training Client 3/60
# Epoch 1/1, Loss: 12.837978817522526, Accuracy: 0.877
# 	Training Client 4/60
# Epoch 1/1, Loss: 12.26183108985424, Accuracy: 0.884
# 	Training Client 5/60
# Epoch 1/1, Loss: 11.925712034106255, Accuracy: 0.885
# 	Training Client 6/60
# Epoch 1/1, Loss: 11.875531256198883, Accuracy: 0.892
# 	Training Client 7/60
# Epoch 1/1, Loss: 10.861133888363838, Accuracy: 0.904
# 	Training Client 8/60
# Epoch 1/1, Loss: 10.803138956427574, Accuracy: 0.901
# 	Training Client 9/60
# Epoch 1/1, Loss: 11.465467996895313, Accuracy: 0.889
# 	Training Client 10/60
# Epoch 1/1, Loss: 10.346550039947033, Accuracy: 0.911
# 	Training Client 11/60
# Epoch 1/1, Loss: 11.08924002200365, Accuracy: 0.891
# 	Training Client 12/60
# Epoch 1/1, Loss: 10.252232272177935, Accuracy: 0.894
# 	Training Client 13/60
# Epoch 1/1, Loss: 12.224988147616386, Accuracy: 0.883
# 	Training Client 14/60
# Epoch 1/1, Loss: 9.946478731930256, Accuracy: 0.9
# 	Training Client 15/60
# Epoch 1/1, Loss: 10.602016057819128, Accuracy: 0.905
# 	Training Client 16/60
# Epoch 1/1, Loss: 10.49705721065402, Accuracy: 0.901
# 	Training Client 17/60
# Epoch 1/1, Loss: 10.624632447957993, Accuracy: 0.896
# 	Training Client 18/60
# Epoch 1/1, Loss: 10.904075011610985, Accuracy: 0.892
# 	Training Client 19/60
# Epoch 1/1, Loss: 10.03357869759202, Accuracy: 0.903
# 	Training Client 20/60
# Epoch 1/1, Loss: 11.92626667022705, Accuracy: 0.886
# 	Training Client 21/60
# Epoch 1/1, Loss: 12.266853645443916, Accuracy: 0.881
# 	Training Client 22/60
# Epoch 1/1, Loss: 12.444428406655788, Accuracy: 0.898
# 	Training Client 23/60
# Epoch 1/1, Loss: 12.96469134092331, Accuracy: 0.886
# 	Training Client 24/60
# Epoch 1/1, Loss: 10.53382059931755, Accuracy: 0.903
# 	Training Client 25/60
# Epoch 1/1, Loss: 10.735023111104965, Accuracy: 0.904
# 	Training Client 26/60
# Epoch 1/1, Loss: 10.751599768176675, Accuracy: 0.889
# 	Training Client 27/60
# Epoch 1/1, Loss: 9.84237965196371, Accuracy: 0.906
# 	Training Client 28/60
# Epoch 1/1, Loss: 11.805642507970333, Accuracy: 0.898
# 	Training Client 29/60
# Epoch 1/1, Loss: 11.035595960915089, Accuracy: 0.903
# 	Training Client 30/60
# Epoch 1/1, Loss: 12.58207406103611, Accuracy: 0.864
# 	Training Client 31/60
# Epoch 1/1, Loss: 10.654961884021759, Accuracy: 0.903
# 	Training Client 32/60
# Epoch 1/1, Loss: 12.660315945744514, Accuracy: 0.874
# 	Training Client 33/60
# Epoch 1/1, Loss: 11.827251598238945, Accuracy: 0.892
# 	Training Client 34/60
# Epoch 1/1, Loss: 13.478627562522888, Accuracy: 0.869
# 	Training Client 35/60
# Epoch 1/1, Loss: 12.964808873832226, Accuracy: 0.878
# 	Training Client 36/60
# Epoch 1/1, Loss: 9.672054670751095, Accuracy: 0.916
# 	Training Client 37/60
# Epoch 1/1, Loss: 11.71575117111206, Accuracy: 0.88
# 	Training Client 38/60
# Epoch 1/1, Loss: 11.087152428925037, Accuracy: 0.899
# 	Training Client 39/60
# Epoch 1/1, Loss: 12.656044155359268, Accuracy: 0.874
# 	Training Client 40/60
# Epoch 1/1, Loss: 11.664708957076073, Accuracy: 0.887
# 	Training Client 41/60
# Epoch 1/1, Loss: 12.56020137667656, Accuracy: 0.882
# 	Training Client 42/60
# Epoch 1/1, Loss: 11.471806704998016, Accuracy: 0.885
# 	Training Client 43/60
# Epoch 1/1, Loss: 10.76485200226307, Accuracy: 0.902
# 	Training Client 44/60
# Epoch 1/1, Loss: 10.954641669988632, Accuracy: 0.886
# 	Training Client 45/60
# Epoch 1/1, Loss: 10.915179833769798, Accuracy: 0.894
# 	Training Client 46/60
# Epoch 1/1, Loss: 12.63754153251648, Accuracy: 0.872
# 	Training Client 47/60
# Epoch 1/1, Loss: 11.193643018603325, Accuracy: 0.902
# 	Training Client 48/60
# Epoch 1/1, Loss: 10.85308887064457, Accuracy: 0.896
# 	Training Client 49/60
# Epoch 1/1, Loss: 11.87527385354042, Accuracy: 0.884
# 	Training Client 50/60
# Epoch 1/1, Loss: 12.178227664902806, Accuracy: 0.879
# 	Training Client 51/60
# Epoch 1/1, Loss: 12.032220214605331, Accuracy: 0.873
# 	Training Client 52/60
# Epoch 1/1, Loss: 10.383138246834278, Accuracy: 0.898
# 	Training Client 53/60
# Epoch 1/1, Loss: 12.562425196170807, Accuracy: 0.864
# 	Training Client 54/60
# Epoch 1/1, Loss: 11.59540756046772, Accuracy: 0.892
# 	Training Client 55/60
# Epoch 1/1, Loss: 11.69704519957304, Accuracy: 0.896
# 	Training Client 56/60
# Epoch 1/1, Loss: 11.304620392620564, Accuracy: 0.898
# 	Training Client 57/60
# Epoch 1/1, Loss: 12.637806601822376, Accuracy: 0.878
# 	Training Client 58/60
# Epoch 1/1, Loss: 11.410504475235939, Accuracy: 0.897
# 	Training Client 59/60
# Epoch 1/1, Loss: 11.766601651906967, Accuracy: 0.901
# 	Training Client 60/60
# Epoch 1/1, Loss: 11.623847112059593, Accuracy: 0.897
# 	Aggregating client models
# Global Epoch 4/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 8.914263814687729, Accuracy: 0.917
# 	Training Client 2/60
# Epoch 1/1, Loss: 9.7349346652627, Accuracy: 0.918
# 	Training Client 3/60
# Epoch 1/1, Loss: 9.166395630687475, Accuracy: 0.908
# 	Training Client 4/60
# Epoch 1/1, Loss: 9.942910708487034, Accuracy: 0.908
# 	Training Client 5/60
# Epoch 1/1, Loss: 8.022675212472677, Accuracy: 0.925
# 	Training Client 6/60
# Epoch 1/1, Loss: 8.181379422545433, Accuracy: 0.927
# 	Training Client 7/60
# Epoch 1/1, Loss: 8.313000690191984, Accuracy: 0.915
# 	Training Client 8/60
# Epoch 1/1, Loss: 7.907945550978184, Accuracy: 0.927
# 	Training Client 9/60
# Epoch 1/1, Loss: 8.440671555697918, Accuracy: 0.922
# 	Training Client 10/60
# Epoch 1/1, Loss: 7.174994356930256, Accuracy: 0.937
# 	Training Client 11/60
# Epoch 1/1, Loss: 8.11023709923029, Accuracy: 0.92
# 	Training Client 12/60
# Epoch 1/1, Loss: 7.446154298260808, Accuracy: 0.947
# 	Training Client 13/60
# Epoch 1/1, Loss: 8.477958805859089, Accuracy: 0.915
# 	Training Client 14/60
# Epoch 1/1, Loss: 7.221231575123966, Accuracy: 0.918
# 	Training Client 15/60
# Epoch 1/1, Loss: 7.970668189227581, Accuracy: 0.935
# 	Training Client 16/60
# Epoch 1/1, Loss: 7.963180832564831, Accuracy: 0.915
# 	Training Client 17/60
# Epoch 1/1, Loss: 7.887287802994251, Accuracy: 0.926
# 	Training Client 18/60
# Epoch 1/1, Loss: 8.774997930973768, Accuracy: 0.911
# 	Training Client 19/60
# Epoch 1/1, Loss: 7.957942567765713, Accuracy: 0.932
# 	Training Client 20/60
# Epoch 1/1, Loss: 7.999684475362301, Accuracy: 0.925
# 	Training Client 21/60
# Epoch 1/1, Loss: 8.433240033686161, Accuracy: 0.931
# 	Training Client 22/60
# Epoch 1/1, Loss: 9.91548117250204, Accuracy: 0.912
# 	Training Client 23/60
# Epoch 1/1, Loss: 9.525734171271324, Accuracy: 0.917
# 	Training Client 24/60
# Epoch 1/1, Loss: 7.8834074810147285, Accuracy: 0.93
# 	Training Client 25/60
# Epoch 1/1, Loss: 8.766502914950252, Accuracy: 0.917
# 	Training Client 26/60
# Epoch 1/1, Loss: 8.512636084109545, Accuracy: 0.917
# 	Training Client 27/60
# Epoch 1/1, Loss: 7.651088289916515, Accuracy: 0.916
# 	Training Client 28/60
# Epoch 1/1, Loss: 9.285648196935654, Accuracy: 0.927
# 	Training Client 29/60
# Epoch 1/1, Loss: 8.236347015947104, Accuracy: 0.926
# 	Training Client 30/60
# Epoch 1/1, Loss: 8.091017663478851, Accuracy: 0.924
# 	Training Client 31/60
# Epoch 1/1, Loss: 8.383674716576934, Accuracy: 0.922
# 	Training Client 32/60
# Epoch 1/1, Loss: 9.139249697327614, Accuracy: 0.915
# 	Training Client 33/60
# Epoch 1/1, Loss: 8.88526375591755, Accuracy: 0.923
# 	Training Client 34/60
# Epoch 1/1, Loss: 8.328273136168718, Accuracy: 0.919
# 	Training Client 35/60
# Epoch 1/1, Loss: 8.82106463238597, Accuracy: 0.916
# 	Training Client 36/60
# Epoch 1/1, Loss: 7.984014254063368, Accuracy: 0.922
# 	Training Client 37/60
# Epoch 1/1, Loss: 8.826857812702656, Accuracy: 0.92
# 	Training Client 38/60
# Epoch 1/1, Loss: 7.4731144569814205, Accuracy: 0.941
# 	Training Client 39/60
# Epoch 1/1, Loss: 7.975706767290831, Accuracy: 0.932
# 	Training Client 40/60
# Epoch 1/1, Loss: 8.40110931918025, Accuracy: 0.92
# 	Training Client 41/60
# Epoch 1/1, Loss: 9.566559843719006, Accuracy: 0.913
# 	Training Client 42/60
# Epoch 1/1, Loss: 8.300552900880575, Accuracy: 0.921
# 	Training Client 43/60
# Epoch 1/1, Loss: 9.159531638026237, Accuracy: 0.91
# 	Training Client 44/60
# Epoch 1/1, Loss: 8.916426293551922, Accuracy: 0.916
# 	Training Client 45/60
# Epoch 1/1, Loss: 8.240387681871653, Accuracy: 0.931
# 	Training Client 46/60
# Epoch 1/1, Loss: 9.441495111212134, Accuracy: 0.902
# 	Training Client 47/60
# Epoch 1/1, Loss: 8.270463641732931, Accuracy: 0.926
# 	Training Client 48/60
# Epoch 1/1, Loss: 7.579845332540572, Accuracy: 0.923
# 	Training Client 49/60
# Epoch 1/1, Loss: 9.086601465940475, Accuracy: 0.916
# 	Training Client 50/60
# Epoch 1/1, Loss: 10.300699949264526, Accuracy: 0.914
# 	Training Client 51/60
# Epoch 1/1, Loss: 9.903965540230274, Accuracy: 0.91
# 	Training Client 52/60
# Epoch 1/1, Loss: 7.841305606067181, Accuracy: 0.933
# 	Training Client 53/60
# Epoch 1/1, Loss: 9.340847969055176, Accuracy: 0.911
# 	Training Client 54/60
# Epoch 1/1, Loss: 9.288372475653887, Accuracy: 0.919
# 	Training Client 55/60
# Epoch 1/1, Loss: 8.141922727227211, Accuracy: 0.923
# 	Training Client 56/60
# Epoch 1/1, Loss: 9.151631511747837, Accuracy: 0.916
# 	Training Client 57/60
# Epoch 1/1, Loss: 9.051953479647636, Accuracy: 0.911
# 	Training Client 58/60
# Epoch 1/1, Loss: 10.02817665785551, Accuracy: 0.913
# 	Training Client 59/60
# Epoch 1/1, Loss: 7.059716641902924, Accuracy: 0.93
# 	Training Client 60/60
# Epoch 1/1, Loss: 8.059797249734402, Accuracy: 0.923
# 	Aggregating client models
# Global Epoch 5/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 7.774105276912451, Accuracy: 0.933
# 	Training Client 2/60
# Epoch 1/1, Loss: 9.01716004498303, Accuracy: 0.913
# 	Training Client 3/60
# Epoch 1/1, Loss: 6.852221896871924, Accuracy: 0.936
# 	Training Client 4/60
# Epoch 1/1, Loss: 7.599094962701201, Accuracy: 0.926
# 	Training Client 5/60
# Epoch 1/1, Loss: 5.870659276843071, Accuracy: 0.935
# 	Training Client 6/60
# Epoch 1/1, Loss: 7.113850947469473, Accuracy: 0.937
# 	Training Client 7/60
# Epoch 1/1, Loss: 6.085805482696742, Accuracy: 0.941
# 	Training Client 8/60
# Epoch 1/1, Loss: 6.847624845802784, Accuracy: 0.937
# 	Training Client 9/60
# Epoch 1/1, Loss: 6.915633991360664, Accuracy: 0.936
# 	Training Client 10/60
# Epoch 1/1, Loss: 6.136712286621332, Accuracy: 0.94
# 	Training Client 11/60
# Epoch 1/1, Loss: 6.699737932533026, Accuracy: 0.929
# 	Training Client 12/60
# Epoch 1/1, Loss: 6.2259892746806145, Accuracy: 0.946
# 	Training Client 13/60
# Epoch 1/1, Loss: 7.303414709866047, Accuracy: 0.927
# 	Training Client 14/60
# Epoch 1/1, Loss: 6.310938075184822, Accuracy: 0.935
# 	Training Client 15/60
# Epoch 1/1, Loss: 6.065560817718506, Accuracy: 0.948
# 	Training Client 16/60
# Epoch 1/1, Loss: 7.149277448654175, Accuracy: 0.945
# 	Training Client 17/60
# Epoch 1/1, Loss: 5.7967588528990746, Accuracy: 0.946
# 	Training Client 18/60
# Epoch 1/1, Loss: 6.293442647904158, Accuracy: 0.941
# 	Training Client 19/60
# Epoch 1/1, Loss: 6.305529396981001, Accuracy: 0.946
# 	Training Client 20/60
# Epoch 1/1, Loss: 5.683483435772359, Accuracy: 0.95
# 	Training Client 21/60
# Epoch 1/1, Loss: 7.542990427464247, Accuracy: 0.941
# 	Training Client 22/60
# Epoch 1/1, Loss: 7.765243865549564, Accuracy: 0.941
# 	Training Client 23/60
# Epoch 1/1, Loss: 6.685595940798521, Accuracy: 0.93
# 	Training Client 24/60
# Epoch 1/1, Loss: 6.371750175952911, Accuracy: 0.937
# 	Training Client 25/60
# Epoch 1/1, Loss: 7.070403225719929, Accuracy: 0.928
# 	Training Client 26/60
# Epoch 1/1, Loss: 6.7359291687607765, Accuracy: 0.922
# 	Training Client 27/60
# Epoch 1/1, Loss: 6.222724499180913, Accuracy: 0.931
# 	Training Client 28/60
# Epoch 1/1, Loss: 7.275445371866226, Accuracy: 0.933
# 	Training Client 29/60
# Epoch 1/1, Loss: 7.442729689180851, Accuracy: 0.921
# 	Training Client 30/60
# Epoch 1/1, Loss: 6.421743825078011, Accuracy: 0.936
# 	Training Client 31/60
# Epoch 1/1, Loss: 7.16829277575016, Accuracy: 0.936
# 	Training Client 32/60
# Epoch 1/1, Loss: 6.45246753282845, Accuracy: 0.944
# 	Training Client 33/60
# Epoch 1/1, Loss: 7.532169688493013, Accuracy: 0.938
# 	Training Client 34/60
# Epoch 1/1, Loss: 7.601455749943852, Accuracy: 0.927
# 	Training Client 35/60
# Epoch 1/1, Loss: 7.368849646300077, Accuracy: 0.93
# 	Training Client 36/60
# Epoch 1/1, Loss: 5.579421451315284, Accuracy: 0.943
# 	Training Client 37/60
# Epoch 1/1, Loss: 7.479570493102074, Accuracy: 0.932
# 	Training Client 38/60
# Epoch 1/1, Loss: 6.0862405970692635, Accuracy: 0.949
# 	Training Client 39/60
# Epoch 1/1, Loss: 7.1572599448263645, Accuracy: 0.934
# 	Training Client 40/60
# Epoch 1/1, Loss: 6.537221856415272, Accuracy: 0.935
# 	Training Client 41/60
# Epoch 1/1, Loss: 8.289316199719906, Accuracy: 0.92
# 	Training Client 42/60
# Epoch 1/1, Loss: 6.539851747453213, Accuracy: 0.93
# 	Training Client 43/60
# Epoch 1/1, Loss: 7.212056189775467, Accuracy: 0.927
# 	Training Client 44/60
# Epoch 1/1, Loss: 7.630407691001892, Accuracy: 0.922
# 	Training Client 45/60
# Epoch 1/1, Loss: 6.391421850770712, Accuracy: 0.941
# 	Training Client 46/60
# Epoch 1/1, Loss: 8.146764695644379, Accuracy: 0.921
# 	Training Client 47/60
# Epoch 1/1, Loss: 7.584826774895191, Accuracy: 0.934
# 	Training Client 48/60
# Epoch 1/1, Loss: 6.490717336535454, Accuracy: 0.936
# 	Training Client 49/60
# Epoch 1/1, Loss: 7.684645585715771, Accuracy: 0.924
# 	Training Client 50/60
# Epoch 1/1, Loss: 7.8027298003435135, Accuracy: 0.926
# 	Training Client 51/60
# Epoch 1/1, Loss: 6.7276424411684275, Accuracy: 0.933
# 	Training Client 52/60
# Epoch 1/1, Loss: 6.998314369469881, Accuracy: 0.934
# 	Training Client 53/60
# Epoch 1/1, Loss: 6.84547071158886, Accuracy: 0.935
# 	Training Client 54/60
# Epoch 1/1, Loss: 7.188080191612244, Accuracy: 0.927
# 	Training Client 55/60
# Epoch 1/1, Loss: 7.396577015519142, Accuracy: 0.94
# 	Training Client 56/60
# Epoch 1/1, Loss: 7.414220619946718, Accuracy: 0.934
# 	Training Client 57/60
# Epoch 1/1, Loss: 7.3478812500834465, Accuracy: 0.931
# 	Training Client 58/60
# Epoch 1/1, Loss: 7.601806670427322, Accuracy: 0.933
# 	Training Client 59/60
# Epoch 1/1, Loss: 6.203405454754829, Accuracy: 0.939
# 	Training Client 60/60
# Epoch 1/1, Loss: 7.217474486678839, Accuracy: 0.924
# 	Aggregating client models
# Global Epoch 6/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 6.363677324727178, Accuracy: 0.937
# 	Training Client 2/60
# Epoch 1/1, Loss: 6.641729420050979, Accuracy: 0.935
# 	Training Client 3/60
# Epoch 1/1, Loss: 6.432878136634827, Accuracy: 0.938
# 	Training Client 4/60
# Epoch 1/1, Loss: 6.345865083858371, Accuracy: 0.933
# 	Training Client 5/60
# Epoch 1/1, Loss: 5.212507588788867, Accuracy: 0.942
# 	Training Client 6/60
# Epoch 1/1, Loss: 6.178151153028011, Accuracy: 0.942
# 	Training Client 7/60
# Epoch 1/1, Loss: 6.25427483022213, Accuracy: 0.937
# 	Training Client 8/60
# Epoch 1/1, Loss: 7.080744728446007, Accuracy: 0.939
# 	Training Client 9/60
# Epoch 1/1, Loss: 5.7750733233988285, Accuracy: 0.95
# 	Training Client 10/60
# Epoch 1/1, Loss: 5.067729997448623, Accuracy: 0.95
# 	Training Client 11/60
# Epoch 1/1, Loss: 6.80338566750288, Accuracy: 0.933
# 	Training Client 12/60
# Epoch 1/1, Loss: 5.59979185461998, Accuracy: 0.946
# 	Training Client 13/60
# Epoch 1/1, Loss: 5.415284723043442, Accuracy: 0.951
# 	Training Client 14/60
# Epoch 1/1, Loss: 5.230284394696355, Accuracy: 0.953
# 	Training Client 15/60
# Epoch 1/1, Loss: 5.47905997466296, Accuracy: 0.947
# 	Training Client 16/60
# Epoch 1/1, Loss: 5.20901395380497, Accuracy: 0.944
# 	Training Client 17/60
# Epoch 1/1, Loss: 5.199578952044249, Accuracy: 0.947
# 	Training Client 18/60
# Epoch 1/1, Loss: 5.286968495696783, Accuracy: 0.953
# 	Training Client 19/60
# Epoch 1/1, Loss: 4.950258865952492, Accuracy: 0.956
# 	Training Client 20/60
# Epoch 1/1, Loss: 5.3221799954771996, Accuracy: 0.95
# 	Training Client 21/60
# Epoch 1/1, Loss: 6.245202410966158, Accuracy: 0.948
# 	Training Client 22/60
# Epoch 1/1, Loss: 8.525413952767849, Accuracy: 0.926
# 	Training Client 23/60
# Epoch 1/1, Loss: 7.297486549243331, Accuracy: 0.932
# 	Training Client 24/60
# Epoch 1/1, Loss: 5.248422736302018, Accuracy: 0.952
# 	Training Client 25/60
# Epoch 1/1, Loss: 6.264839123934507, Accuracy: 0.941
# 	Training Client 26/60
# Epoch 1/1, Loss: 5.952580569311976, Accuracy: 0.941
# 	Training Client 27/60
# Epoch 1/1, Loss: 5.676608670502901, Accuracy: 0.938
# 	Training Client 28/60
# Epoch 1/1, Loss: 6.4778848849236965, Accuracy: 0.937
# 	Training Client 29/60
# Epoch 1/1, Loss: 5.626107532531023, Accuracy: 0.936
# 	Training Client 30/60
# Epoch 1/1, Loss: 5.581090051680803, Accuracy: 0.946
# 	Training Client 31/60
# Epoch 1/1, Loss: 6.315743260085583, Accuracy: 0.943
# 	Training Client 32/60
# Epoch 1/1, Loss: 6.143984273076057, Accuracy: 0.942
# 	Training Client 33/60
# Epoch 1/1, Loss: 6.953668609261513, Accuracy: 0.945
# 	Training Client 34/60
# Epoch 1/1, Loss: 7.3164161667227745, Accuracy: 0.929
# 	Training Client 35/60
# Epoch 1/1, Loss: 6.309148656204343, Accuracy: 0.945
# 	Training Client 36/60
# Epoch 1/1, Loss: 4.744781915098429, Accuracy: 0.944
# 	Training Client 37/60
# Epoch 1/1, Loss: 5.66261599957943, Accuracy: 0.95
# 	Training Client 38/60
# Epoch 1/1, Loss: 5.144652120769024, Accuracy: 0.955
# 	Training Client 39/60
# Epoch 1/1, Loss: 6.39467203989625, Accuracy: 0.939
# 	Training Client 40/60
# Epoch 1/1, Loss: 6.619809027761221, Accuracy: 0.936
# 	Training Client 41/60
# Epoch 1/1, Loss: 7.010040000081062, Accuracy: 0.931
# 	Training Client 42/60
# Epoch 1/1, Loss: 6.893062941730022, Accuracy: 0.94
# 	Training Client 43/60
# Epoch 1/1, Loss: 6.265800379216671, Accuracy: 0.938
# 	Training Client 44/60
# Epoch 1/1, Loss: 5.654302418231964, Accuracy: 0.941
# 	Training Client 45/60
# Epoch 1/1, Loss: 6.459203574806452, Accuracy: 0.935
# 	Training Client 46/60
# Epoch 1/1, Loss: 6.588772788643837, Accuracy: 0.942
# 	Training Client 47/60
# Epoch 1/1, Loss: 5.5360570177435875, Accuracy: 0.941
# 	Training Client 48/60
# Epoch 1/1, Loss: 5.608031500130892, Accuracy: 0.946
# 	Training Client 49/60
# Epoch 1/1, Loss: 6.622958853840828, Accuracy: 0.938
# 	Training Client 50/60
# Epoch 1/1, Loss: 6.275463643018156, Accuracy: 0.937
# 	Training Client 51/60
# Epoch 1/1, Loss: 5.531059225089848, Accuracy: 0.942
# 	Training Client 52/60
# Epoch 1/1, Loss: 5.557939823716879, Accuracy: 0.946
# 	Training Client 53/60
# Epoch 1/1, Loss: 5.964796636253595, Accuracy: 0.946
# 	Training Client 54/60
# Epoch 1/1, Loss: 6.2830589059740305, Accuracy: 0.942
# 	Training Client 55/60
# Epoch 1/1, Loss: 5.929605823010206, Accuracy: 0.941
# 	Training Client 56/60
# Epoch 1/1, Loss: 6.761337131261826, Accuracy: 0.943
# 	Training Client 57/60
# Epoch 1/1, Loss: 7.183363690972328, Accuracy: 0.937
# 	Training Client 58/60
# Epoch 1/1, Loss: 6.714569892734289, Accuracy: 0.937
# 	Training Client 59/60
# Epoch 1/1, Loss: 5.165963713079691, Accuracy: 0.946
# 	Training Client 60/60
# Epoch 1/1, Loss: 6.37248345836997, Accuracy: 0.937
# ddm:[], eddm:[], hddm[], combined[]
# metrics:{'HDDM': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}, 'DDM': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}, 'EDDM': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}, 'Combined': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}}
# Global Epoch 6, Client 1: DDM Drift detection is accurate.
# Global Epoch 6, Client 2: DDM Drift detection is accurate.
# Global Epoch 6, Client 3: DDM Drift detection is accurate.
# Global Epoch 6, Client 4: DDM Drift detection is accurate.
# Global Epoch 6, Client 5: DDM Drift detection is accurate.
# Global Epoch 6, Client 6: DDM Drift detection is accurate.
# Global Epoch 6, Client 7: DDM Drift detection is accurate.
# Global Epoch 6, Client 8: DDM Drift detection is accurate.
# Global Epoch 6, Client 9: DDM Drift detection is accurate.
# Global Epoch 6, Client 10: DDM Drift detection is accurate.
# Global Epoch 6, Client 11: DDM Drift detection is accurate.
# Global Epoch 6, Client 12: DDM Drift detection is accurate.
# Global Epoch 6, Client 13: DDM Drift detection is accurate.
# Global Epoch 6, Client 14: DDM Drift detection is accurate.
# Global Epoch 6, Client 15: DDM Drift detection is accurate.
# Global Epoch 6, Client 16: DDM Drift detection is accurate.
# Global Epoch 6, Client 17: DDM Drift detection is accurate.
# Global Epoch 6, Client 18: DDM Drift detection is accurate.
# Global Epoch 6, Client 19: DDM Drift detection is accurate.
# Global Epoch 6, Client 20: DDM Drift detection is accurate.
# Global Epoch 6, Client 21: DDM Drift detection is accurate.
# Global Epoch 6, Client 22: DDM Drift detection is accurate.
# Global Epoch 6, Client 23: DDM Drift detection is accurate.
# Global Epoch 6, Client 24: DDM Drift detection is accurate.
# Global Epoch 6, Client 25: DDM Drift detection is accurate.
# Global Epoch 6, Client 26: DDM Drift detection is accurate.
# Global Epoch 6, Client 27: DDM Drift detection is accurate.
# Global Epoch 6, Client 28: DDM Drift detection is accurate.
# Global Epoch 6, Client 29: DDM Drift detection is accurate.
# Global Epoch 6, Client 30: DDM Drift detection is accurate.
# Global Epoch 6, Client 31: DDM Drift detection is accurate.
# Global Epoch 6, Client 32: DDM Drift detection is accurate.
# Global Epoch 6, Client 33: DDM Drift detection is accurate.
# Global Epoch 6, Client 34: DDM Drift detection is accurate.
# Global Epoch 6, Client 35: DDM Drift detection is accurate.
# Global Epoch 6, Client 36: DDM Drift detection is accurate.
# Global Epoch 6, Client 37: DDM Drift detection is accurate.
# Global Epoch 6, Client 38: DDM Drift detection is accurate.
# Global Epoch 6, Client 39: DDM Drift detection is accurate.
# Global Epoch 6, Client 40: DDM Drift detection is accurate.
# Global Epoch 6, Client 41: DDM Drift detection is accurate.
# Global Epoch 6, Client 42: DDM Drift detection is accurate.
# Global Epoch 6, Client 43: DDM Drift detection is accurate.
# Global Epoch 6, Client 44: DDM Drift detection is accurate.
# Global Epoch 6, Client 45: DDM Drift detection is accurate.
# Global Epoch 6, Client 46: DDM Drift detection is accurate.
# Global Epoch 6, Client 47: DDM Drift detection is accurate.
# Global Epoch 6, Client 48: DDM Drift detection is accurate.
# Global Epoch 6, Client 49: DDM Drift detection is accurate.
# Global Epoch 6, Client 50: DDM Drift detection is accurate.
# Global Epoch 6, Client 51: DDM Drift detection is accurate.
# Global Epoch 6, Client 52: DDM Drift detection is accurate.
# Global Epoch 6, Client 53: DDM Drift detection is accurate.
# Global Epoch 6, Client 54: DDM Drift detection is accurate.
# Global Epoch 6, Client 55: DDM Drift detection is accurate.
# Global Epoch 6, Client 56: DDM Drift detection is accurate.
# Global Epoch 6, Client 57: DDM Drift detection is accurate.
# Global Epoch 6, Client 58: DDM Drift detection is accurate.
# Global Epoch 6, Client 59: DDM Drift detection is accurate.
# Global Epoch 6, Client 60: DDM Drift detection is accurate.
# Global Epoch 6, Client 1: EDDM Drift detection is accurate.
# Global Epoch 6, Client 2: EDDM Drift detection is accurate.
# Global Epoch 6, Client 3: EDDM Drift detection is accurate.
# Global Epoch 6, Client 4: EDDM Drift detection is accurate.
# Global Epoch 6, Client 5: EDDM Drift detection is accurate.
# Global Epoch 6, Client 6: EDDM Drift detection is accurate.
# Global Epoch 6, Client 7: EDDM Drift detection is accurate.
# Global Epoch 6, Client 8: EDDM Drift detection is accurate.
# Global Epoch 6, Client 9: EDDM Drift detection is accurate.
# Global Epoch 6, Client 10: EDDM Drift detection is accurate.
# Global Epoch 6, Client 11: EDDM Drift detection is accurate.
# Global Epoch 6, Client 12: EDDM Drift detection is accurate.
# Global Epoch 6, Client 13: EDDM Drift detection is accurate.
# Global Epoch 6, Client 14: EDDM Drift detection is accurate.
# Global Epoch 6, Client 15: EDDM Drift detection is accurate.
# Global Epoch 6, Client 16: EDDM Drift detection is accurate.
# Global Epoch 6, Client 17: EDDM Drift detection is accurate.
# Global Epoch 6, Client 18: EDDM Drift detection is accurate.
# Global Epoch 6, Client 19: EDDM Drift detection is accurate.
# Global Epoch 6, Client 20: EDDM Drift detection is accurate.
# Global Epoch 6, Client 21: EDDM Drift detection is accurate.
# Global Epoch 6, Client 22: EDDM Drift detection is accurate.
# Global Epoch 6, Client 23: EDDM Drift detection is accurate.
# Global Epoch 6, Client 24: EDDM Drift detection is accurate.
# Global Epoch 6, Client 25: EDDM Drift detection is accurate.
# Global Epoch 6, Client 26: EDDM Drift detection is accurate.
# Global Epoch 6, Client 27: EDDM Drift detection is accurate.
# Global Epoch 6, Client 28: EDDM Drift detection is accurate.
# Global Epoch 6, Client 29: EDDM Drift detection is accurate.
# Global Epoch 6, Client 30: EDDM Drift detection is accurate.
# Global Epoch 6, Client 31: EDDM Drift detection is accurate.
# Global Epoch 6, Client 32: EDDM Drift detection is accurate.
# Global Epoch 6, Client 33: EDDM Drift detection is accurate.
# Global Epoch 6, Client 34: EDDM Drift detection is accurate.
# Global Epoch 6, Client 35: EDDM Drift detection is accurate.
# Global Epoch 6, Client 36: EDDM Drift detection is accurate.
# Global Epoch 6, Client 37: EDDM Drift detection is accurate.
# Global Epoch 6, Client 38: EDDM Drift detection is accurate.
# Global Epoch 6, Client 39: EDDM Drift detection is accurate.
# Global Epoch 6, Client 40: EDDM Drift detection is accurate.
# Global Epoch 6, Client 41: EDDM Drift detection is accurate.
# Global Epoch 6, Client 42: EDDM Drift detection is accurate.
# Global Epoch 6, Client 43: EDDM Drift detection is accurate.
# Global Epoch 6, Client 44: EDDM Drift detection is accurate.
# Global Epoch 6, Client 45: EDDM Drift detection is accurate.
# Global Epoch 6, Client 46: EDDM Drift detection is accurate.
# Global Epoch 6, Client 47: EDDM Drift detection is accurate.
# Global Epoch 6, Client 48: EDDM Drift detection is accurate.
# Global Epoch 6, Client 49: EDDM Drift detection is accurate.
# Global Epoch 6, Client 50: EDDM Drift detection is accurate.
# Global Epoch 6, Client 51: EDDM Drift detection is accurate.
# Global Epoch 6, Client 52: EDDM Drift detection is accurate.
# Global Epoch 6, Client 53: EDDM Drift detection is accurate.
# Global Epoch 6, Client 54: EDDM Drift detection is accurate.
# Global Epoch 6, Client 55: EDDM Drift detection is accurate.
# Global Epoch 6, Client 56: EDDM Drift detection is accurate.
# Global Epoch 6, Client 57: EDDM Drift detection is accurate.
# Global Epoch 6, Client 58: EDDM Drift detection is accurate.
# Global Epoch 6, Client 59: EDDM Drift detection is accurate.
# Global Epoch 6, Client 60: EDDM Drift detection is accurate.
# Global Epoch 6, Client 1: HDDM Drift detection is accurate.
# Global Epoch 6, Client 2: HDDM Drift detection is accurate.
# Global Epoch 6, Client 3: HDDM Drift detection is accurate.
# Global Epoch 6, Client 4: HDDM Drift detection is accurate.
# Global Epoch 6, Client 5: HDDM Drift detection is accurate.
# Global Epoch 6, Client 6: HDDM Drift detection is accurate.
# Global Epoch 6, Client 7: HDDM Drift detection is accurate.
# Global Epoch 6, Client 8: HDDM Drift detection is accurate.
# Global Epoch 6, Client 9: HDDM Drift detection is accurate.
# Global Epoch 6, Client 10: HDDM Drift detection is accurate.
# Global Epoch 6, Client 11: HDDM Drift detection is accurate.
# Global Epoch 6, Client 12: HDDM Drift detection is accurate.
# Global Epoch 6, Client 13: HDDM Drift detection is accurate.
# Global Epoch 6, Client 14: HDDM Drift detection is accurate.
# Global Epoch 6, Client 15: HDDM Drift detection is accurate.
# Global Epoch 6, Client 16: HDDM Drift detection is accurate.
# Global Epoch 6, Client 17: HDDM Drift detection is accurate.
# Global Epoch 6, Client 18: HDDM Drift detection is accurate.
# Global Epoch 6, Client 19: HDDM Drift detection is accurate.
# Global Epoch 6, Client 20: HDDM Drift detection is accurate.
# Global Epoch 6, Client 21: HDDM Drift detection is accurate.
# Global Epoch 6, Client 22: HDDM Drift detection is accurate.
# Global Epoch 6, Client 23: HDDM Drift detection is accurate.
# Global Epoch 6, Client 24: HDDM Drift detection is accurate.
# Global Epoch 6, Client 25: HDDM Drift detection is accurate.
# Global Epoch 6, Client 26: HDDM Drift detection is accurate.
# Global Epoch 6, Client 27: HDDM Drift detection is accurate.
# Global Epoch 6, Client 28: HDDM Drift detection is accurate.
# Global Epoch 6, Client 29: HDDM Drift detection is accurate.
# Global Epoch 6, Client 30: HDDM Drift detection is accurate.
# Global Epoch 6, Client 31: HDDM Drift detection is accurate.
# Global Epoch 6, Client 32: HDDM Drift detection is accurate.
# Global Epoch 6, Client 33: HDDM Drift detection is accurate.
# Global Epoch 6, Client 34: HDDM Drift detection is accurate.
# Global Epoch 6, Client 35: HDDM Drift detection is accurate.
# Global Epoch 6, Client 36: HDDM Drift detection is accurate.
# Global Epoch 6, Client 37: HDDM Drift detection is accurate.
# Global Epoch 6, Client 38: HDDM Drift detection is accurate.
# Global Epoch 6, Client 39: HDDM Drift detection is accurate.
# Global Epoch 6, Client 40: HDDM Drift detection is accurate.
# Global Epoch 6, Client 41: HDDM Drift detection is accurate.
# Global Epoch 6, Client 42: HDDM Drift detection is accurate.
# Global Epoch 6, Client 43: HDDM Drift detection is accurate.
# Global Epoch 6, Client 44: HDDM Drift detection is accurate.
# Global Epoch 6, Client 45: HDDM Drift detection is accurate.
# Global Epoch 6, Client 46: HDDM Drift detection is accurate.
# Global Epoch 6, Client 47: HDDM Drift detection is accurate.
# Global Epoch 6, Client 48: HDDM Drift detection is accurate.
# Global Epoch 6, Client 49: HDDM Drift detection is accurate.
# Global Epoch 6, Client 50: HDDM Drift detection is accurate.
# Global Epoch 6, Client 51: HDDM Drift detection is accurate.
# Global Epoch 6, Client 52: HDDM Drift detection is accurate.
# Global Epoch 6, Client 53: HDDM Drift detection is accurate.
# Global Epoch 6, Client 54: HDDM Drift detection is accurate.
# Global Epoch 6, Client 55: HDDM Drift detection is accurate.
# Global Epoch 6, Client 56: HDDM Drift detection is accurate.
# Global Epoch 6, Client 57: HDDM Drift detection is accurate.
# Global Epoch 6, Client 58: HDDM Drift detection is accurate.
# Global Epoch 6, Client 59: HDDM Drift detection is accurate.
# Global Epoch 6, Client 60: HDDM Drift detection is accurate.
# Global Epoch 6, Client 1: Combined Drift detection is accurate.
# Global Epoch 6, Client 2: Combined Drift detection is accurate.
# Global Epoch 6, Client 3: Combined Drift detection is accurate.
# Global Epoch 6, Client 4: Combined Drift detection is accurate.
# Global Epoch 6, Client 5: Combined Drift detection is accurate.
# Global Epoch 6, Client 6: Combined Drift detection is accurate.
# Global Epoch 6, Client 7: Combined Drift detection is accurate.
# Global Epoch 6, Client 8: Combined Drift detection is accurate.
# Global Epoch 6, Client 9: Combined Drift detection is accurate.
# Global Epoch 6, Client 10: Combined Drift detection is accurate.
# Global Epoch 6, Client 11: Combined Drift detection is accurate.
# Global Epoch 6, Client 12: Combined Drift detection is accurate.
# Global Epoch 6, Client 13: Combined Drift detection is accurate.
# Global Epoch 6, Client 14: Combined Drift detection is accurate.
# Global Epoch 6, Client 15: Combined Drift detection is accurate.
# Global Epoch 6, Client 16: Combined Drift detection is accurate.
# Global Epoch 6, Client 17: Combined Drift detection is accurate.
# Global Epoch 6, Client 18: Combined Drift detection is accurate.
# Global Epoch 6, Client 19: Combined Drift detection is accurate.
# Global Epoch 6, Client 20: Combined Drift detection is accurate.
# Global Epoch 6, Client 21: Combined Drift detection is accurate.
# Global Epoch 6, Client 22: Combined Drift detection is accurate.
# Global Epoch 6, Client 23: Combined Drift detection is accurate.
# Global Epoch 6, Client 24: Combined Drift detection is accurate.
# Global Epoch 6, Client 25: Combined Drift detection is accurate.
# Global Epoch 6, Client 26: Combined Drift detection is accurate.
# Global Epoch 6, Client 27: Combined Drift detection is accurate.
# Global Epoch 6, Client 28: Combined Drift detection is accurate.
# Global Epoch 6, Client 29: Combined Drift detection is accurate.
# Global Epoch 6, Client 30: Combined Drift detection is accurate.
# Global Epoch 6, Client 31: Combined Drift detection is accurate.
# Global Epoch 6, Client 32: Combined Drift detection is accurate.
# Global Epoch 6, Client 33: Combined Drift detection is accurate.
# Global Epoch 6, Client 34: Combined Drift detection is accurate.
# Global Epoch 6, Client 35: Combined Drift detection is accurate.
# Global Epoch 6, Client 36: Combined Drift detection is accurate.
# Global Epoch 6, Client 37: Combined Drift detection is accurate.
# Global Epoch 6, Client 38: Combined Drift detection is accurate.
# Global Epoch 6, Client 39: Combined Drift detection is accurate.
# Global Epoch 6, Client 40: Combined Drift detection is accurate.
# Global Epoch 6, Client 41: Combined Drift detection is accurate.
# Global Epoch 6, Client 42: Combined Drift detection is accurate.
# Global Epoch 6, Client 43: Combined Drift detection is accurate.
# Global Epoch 6, Client 44: Combined Drift detection is accurate.
# Global Epoch 6, Client 45: Combined Drift detection is accurate.
# Global Epoch 6, Client 46: Combined Drift detection is accurate.
# Global Epoch 6, Client 47: Combined Drift detection is accurate.
# Global Epoch 6, Client 48: Combined Drift detection is accurate.
# Global Epoch 6, Client 49: Combined Drift detection is accurate.
# Global Epoch 6, Client 50: Combined Drift detection is accurate.
# Global Epoch 6, Client 51: Combined Drift detection is accurate.
# Global Epoch 6, Client 52: Combined Drift detection is accurate.
# Global Epoch 6, Client 53: Combined Drift detection is accurate.
# Global Epoch 6, Client 54: Combined Drift detection is accurate.
# Global Epoch 6, Client 55: Combined Drift detection is accurate.
# Global Epoch 6, Client 56: Combined Drift detection is accurate.
# Global Epoch 6, Client 57: Combined Drift detection is accurate.
# Global Epoch 6, Client 58: Combined Drift detection is accurate.
# Global Epoch 6, Client 59: Combined Drift detection is accurate.
# Global Epoch 6, Client 60: Combined Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 7/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 5.4118113331496716, Accuracy: 0.944
# 	Training Client 2/60
# Epoch 1/1, Loss: 6.3397312350571156, Accuracy: 0.938
# 	Training Client 3/60
# Epoch 1/1, Loss: 5.946367513388395, Accuracy: 0.94
# 	Training Client 4/60
# Epoch 1/1, Loss: 5.481394208967686, Accuracy: 0.948
# 	Training Client 5/60
# Epoch 1/1, Loss: 4.271591464057565, Accuracy: 0.961
# 	Training Client 6/60
# Epoch 1/1, Loss: 6.040884837508202, Accuracy: 0.941
# 	Training Client 7/60
# Epoch 1/1, Loss: 4.459015596657991, Accuracy: 0.959
# 	Training Client 8/60
# Epoch 1/1, Loss: 5.532014515949413, Accuracy: 0.945
# 	Training Client 9/60
# Epoch 1/1, Loss: 4.623525104485452, Accuracy: 0.958
# 	Training Client 10/60
# Epoch 1/1, Loss: 4.101422791369259, Accuracy: 0.958
# 	Training Client 11/60
# Epoch 1/1, Loss: 4.936446614563465, Accuracy: 0.955
# 	Training Client 12/60
# Epoch 1/1, Loss: 5.341717334464192, Accuracy: 0.95
# 	Training Client 13/60
# Epoch 1/1, Loss: 5.135091163218021, Accuracy: 0.949
# 	Training Client 14/60
# Epoch 1/1, Loss: 4.419642163440585, Accuracy: 0.955
# 	Training Client 15/60
# Epoch 1/1, Loss: 4.73590750573203, Accuracy: 0.956
# 	Training Client 16/60
# Epoch 1/1, Loss: 4.7618870455771685, Accuracy: 0.961
# 	Training Client 17/60
# Epoch 1/1, Loss: 5.10338533250615, Accuracy: 0.957
# 	Training Client 18/60
# Epoch 1/1, Loss: 4.991641831584275, Accuracy: 0.954
# 	Training Client 19/60
# Epoch 1/1, Loss: 4.672539414837956, Accuracy: 0.955
# 	Training Client 20/60
# Epoch 1/1, Loss: 5.122693564742804, Accuracy: 0.945
# 	Training Client 21/60
# Epoch 1/1, Loss: 5.965230710804462, Accuracy: 0.943
# 	Training Client 22/60
# Epoch 1/1, Loss: 6.787252351641655, Accuracy: 0.943
# 	Training Client 23/60
# Epoch 1/1, Loss: 5.4998835902661085, Accuracy: 0.94
# 	Training Client 24/60
# Epoch 1/1, Loss: 4.284177593886852, Accuracy: 0.955
# 	Training Client 25/60
# Epoch 1/1, Loss: 5.067853845655918, Accuracy: 0.948
# 	Training Client 26/60
# Epoch 1/1, Loss: 5.603482914157212, Accuracy: 0.946
# 	Training Client 27/60
# Epoch 1/1, Loss: 5.453316053375602, Accuracy: 0.953
# 	Training Client 28/60
# Epoch 1/1, Loss: 5.546990990638733, Accuracy: 0.95
# 	Training Client 29/60
# Epoch 1/1, Loss: 5.885101541876793, Accuracy: 0.943
# 	Training Client 30/60
# Epoch 1/1, Loss: 5.2298514526337385, Accuracy: 0.942
# 	Training Client 31/60
# Epoch 1/1, Loss: 5.360101862810552, Accuracy: 0.95
# 	Training Client 32/60
# Epoch 1/1, Loss: 5.636919759213924, Accuracy: 0.949
# 	Training Client 33/60
# Epoch 1/1, Loss: 5.502225615084171, Accuracy: 0.953
# 	Training Client 34/60
# Epoch 1/1, Loss: 5.844246685504913, Accuracy: 0.945
# 	Training Client 35/60
# Epoch 1/1, Loss: 5.685020539909601, Accuracy: 0.952
# 	Training Client 36/60
# Epoch 1/1, Loss: 4.3543835915625095, Accuracy: 0.958
# 	Training Client 37/60
# Epoch 1/1, Loss: 5.448723245412111, Accuracy: 0.954
# 	Training Client 38/60
# Epoch 1/1, Loss: 4.07818637508899, Accuracy: 0.97
# 	Training Client 39/60
# Epoch 1/1, Loss: 6.242428825236857, Accuracy: 0.946
# 	Training Client 40/60
# Epoch 1/1, Loss: 5.9411020539700985, Accuracy: 0.939
# 	Training Client 41/60
# Epoch 1/1, Loss: 5.044107690453529, Accuracy: 0.947
# 	Training Client 42/60
# Epoch 1/1, Loss: 5.607373189181089, Accuracy: 0.947
# 	Training Client 43/60
# Epoch 1/1, Loss: 5.681517055258155, Accuracy: 0.942
# 	Training Client 44/60
# Epoch 1/1, Loss: 5.677078828215599, Accuracy: 0.943
# 	Training Client 45/60
# Epoch 1/1, Loss: 5.293145316652954, Accuracy: 0.946
# 	Training Client 46/60
# Epoch 1/1, Loss: 5.36605834774673, Accuracy: 0.952
# 	Training Client 47/60
# Epoch 1/1, Loss: 5.93381910584867, Accuracy: 0.95
# 	Training Client 48/60
# Epoch 1/1, Loss: 3.749983225017786, Accuracy: 0.963
# 	Training Client 49/60
# Epoch 1/1, Loss: 6.572003200650215, Accuracy: 0.942
# 	Training Client 50/60
# Epoch 1/1, Loss: 5.5630995742976665, Accuracy: 0.946
# 	Training Client 51/60
# ...
# Global Epoch 40, Client 5: EDDM Drift detection is accurate.
# Global Epoch 40, Client 6: EDDM Drift detection is accurate.
# Global Epoch 40, Client 7: EDDM Drift detection is inaccurate.
# Global Epoch 40, Client 8: EDDM Drift detection is accurate.
# Global Epoch 40, Client 9: EDDM Drift detection is accurate.
# Global Epoch 40, Client 10: EDDM Drift detection is inaccurate.
# Global Epoch 40, Client 11: EDDM Drift detection is accurate.
# Global Epoch 40, Client 12: EDDM Drift detection is accurate.
# Global Epoch 40, Client 13: EDDM Drift detection is accurate.
# Global Epoch 40, Client 14: EDDM Drift detection is inaccurate.
# Global Epoch 40, Client 15: EDDM Drift detection is accurate.
# Global Epoch 40, Client 16: EDDM Drift detection is accurate.
# Global Epoch 40, Client 17: EDDM Drift detection is accurate.
# Global Epoch 40, Client 18: EDDM Drift detection is accurate.
# Global Epoch 40, Client 19: EDDM Drift detection is accurate.
# Global Epoch 40, Client 20: EDDM Drift detection is accurate.
# Global Epoch 40, Client 21: EDDM Drift detection is inaccurate.
# Global Epoch 40, Client 22: EDDM Drift detection is accurate.
# Global Epoch 40, Client 23: EDDM Drift detection is accurate.
# Global Epoch 40, Client 24: EDDM Drift detection is accurate.
# Global Epoch 40, Client 25: EDDM Drift detection is accurate.
# Global Epoch 40, Client 26: EDDM Drift detection is accurate.
# Global Epoch 40, Client 27: EDDM Drift detection is accurate.
# Global Epoch 40, Client 28: EDDM Drift detection is inaccurate.
# Global Epoch 40, Client 29: EDDM Drift detection is accurate.
# Global Epoch 40, Client 30: EDDM Drift detection is accurate.
# Global Epoch 40, Client 31: EDDM Drift detection is accurate.
# Global Epoch 40, Client 32: EDDM Drift detection is accurate.
# Global Epoch 40, Client 33: EDDM Drift detection is accurate.
# Global Epoch 40, Client 34: EDDM Drift detection is inaccurate.
# Global Epoch 40, Client 35: EDDM Drift detection is accurate.
# Global Epoch 40, Client 36: EDDM Drift detection is accurate.
# Global Epoch 40, Client 37: EDDM Drift detection is accurate.
# Global Epoch 40, Client 38: EDDM Drift detection is inaccurate.
# Global Epoch 40, Client 39: EDDM Drift detection is accurate.
# Global Epoch 40, Client 40: EDDM Drift detection is accurate.
# Global Epoch 40, Client 41: EDDM Drift detection is accurate.
# Global Epoch 40, Client 42: EDDM Drift detection is inaccurate.
# Global Epoch 40, Client 43: EDDM Drift detection is accurate.
# Global Epoch 40, Client 44: EDDM Drift detection is accurate.
# Global Epoch 40, Client 45: EDDM Drift detection is accurate.
# Global Epoch 40, Client 46: EDDM Drift detection is accurate.
# Global Epoch 40, Client 47: EDDM Drift detection is accurate.
# Global Epoch 40, Client 48: EDDM Drift detection is accurate.
# Global Epoch 40, Client 49: EDDM Drift detection is accurate.
# Global Epoch 40, Client 50: EDDM Drift detection is accurate.
# Global Epoch 40, Client 51: EDDM Drift detection is accurate.
# Global Epoch 40, Client 52: EDDM Drift detection is accurate.
# Global Epoch 40, Client 53: EDDM Drift detection is accurate.
# Global Epoch 40, Client 54: EDDM Drift detection is accurate.
# Global Epoch 40, Client 55: EDDM Drift detection is accurate.
# Global Epoch 40, Client 56: EDDM Drift detection is inaccurate.
# Global Epoch 40, Client 57: EDDM Drift detection is accurate.
# Global Epoch 40, Client 58: EDDM Drift detection is accurate.
# Global Epoch 40, Client 59: EDDM Drift detection is accurate.
# Global Epoch 40, Client 60: EDDM Drift detection is accurate.
# Global Epoch 40, Client 1: HDDM Drift detection is accurate.
# Global Epoch 40, Client 2: HDDM Drift detection is accurate.
# Global Epoch 40, Client 3: HDDM Drift detection is accurate.
# Global Epoch 40, Client 4: HDDM Drift detection is accurate.
# Global Epoch 40, Client 5: HDDM Drift detection is accurate.
# Global Epoch 40, Client 6: HDDM Drift detection is accurate.
# Global Epoch 40, Client 7: HDDM Drift detection is accurate.
# Global Epoch 40, Client 8: HDDM Drift detection is accurate.
# Global Epoch 40, Client 9: HDDM Drift detection is accurate.
# Global Epoch 40, Client 10: HDDM Drift detection is accurate.
# Global Epoch 40, Client 11: HDDM Drift detection is accurate.
# Global Epoch 40, Client 12: HDDM Drift detection is accurate.
# Global Epoch 40, Client 13: HDDM Drift detection is accurate.
# Global Epoch 40, Client 14: HDDM Drift detection is inaccurate.
# Global Epoch 40, Client 15: HDDM Drift detection is accurate.
# Global Epoch 40, Client 16: HDDM Drift detection is accurate.
# Global Epoch 40, Client 17: HDDM Drift detection is accurate.
# Global Epoch 40, Client 18: HDDM Drift detection is accurate.
# Global Epoch 40, Client 19: HDDM Drift detection is accurate.
# Global Epoch 40, Client 20: HDDM Drift detection is accurate.
# Global Epoch 40, Client 21: HDDM Drift detection is inaccurate.
# Global Epoch 40, Client 22: HDDM Drift detection is accurate.
# Global Epoch 40, Client 23: HDDM Drift detection is accurate.
# Global Epoch 40, Client 24: HDDM Drift detection is accurate.
# Global Epoch 40, Client 25: HDDM Drift detection is accurate.
# Global Epoch 40, Client 26: HDDM Drift detection is accurate.
# Global Epoch 40, Client 27: HDDM Drift detection is accurate.
# Global Epoch 40, Client 28: HDDM Drift detection is accurate.
# Global Epoch 40, Client 29: HDDM Drift detection is accurate.
# Global Epoch 40, Client 30: HDDM Drift detection is accurate.
# Global Epoch 40, Client 31: HDDM Drift detection is accurate.
# Global Epoch 40, Client 32: HDDM Drift detection is accurate.
# Global Epoch 40, Client 33: HDDM Drift detection is accurate.
# Global Epoch 40, Client 34: HDDM Drift detection is accurate.
# Global Epoch 40, Client 35: HDDM Drift detection is accurate.
# Global Epoch 40, Client 36: HDDM Drift detection is accurate.
# Global Epoch 40, Client 37: HDDM Drift detection is accurate.
# Global Epoch 40, Client 38: HDDM Drift detection is inaccurate.
# Global Epoch 40, Client 39: HDDM Drift detection is accurate.
# Global Epoch 40, Client 40: HDDM Drift detection is accurate.
# Global Epoch 40, Client 41: HDDM Drift detection is accurate.
# Global Epoch 40, Client 42: HDDM Drift detection is accurate.
# Global Epoch 40, Client 43: HDDM Drift detection is accurate.
# Global Epoch 40, Client 44: HDDM Drift detection is accurate.
# Global Epoch 40, Client 45: HDDM Drift detection is accurate.
# Global Epoch 40, Client 46: HDDM Drift detection is accurate.
# Global Epoch 40, Client 47: HDDM Drift detection is accurate.
# Global Epoch 40, Client 48: HDDM Drift detection is accurate.
# Global Epoch 40, Client 49: HDDM Drift detection is accurate.
# Global Epoch 40, Client 50: HDDM Drift detection is accurate.
# Global Epoch 40, Client 51: HDDM Drift detection is accurate.
# Global Epoch 40, Client 52: HDDM Drift detection is accurate.
# Global Epoch 40, Client 53: HDDM Drift detection is accurate.
# Global Epoch 40, Client 54: HDDM Drift detection is accurate.
# Global Epoch 40, Client 55: HDDM Drift detection is accurate.
# Global Epoch 40, Client 56: HDDM Drift detection is inaccurate.
# Global Epoch 40, Client 57: HDDM Drift detection is accurate.
# Global Epoch 40, Client 58: HDDM Drift detection is accurate.
# Global Epoch 40, Client 59: HDDM Drift detection is accurate.
# Global Epoch 40, Client 60: HDDM Drift detection is accurate.
# Global Epoch 40, Client 1: Combined Drift detection is accurate.
# Global Epoch 40, Client 2: Combined Drift detection is accurate.
# Global Epoch 40, Client 3: Combined Drift detection is accurate.
# Global Epoch 40, Client 4: Combined Drift detection is accurate.
# Global Epoch 40, Client 5: Combined Drift detection is accurate.
# Global Epoch 40, Client 6: Combined Drift detection is accurate.
# Global Epoch 40, Client 7: Combined Drift detection is accurate.
# Global Epoch 40, Client 8: Combined Drift detection is accurate.
# Global Epoch 40, Client 9: Combined Drift detection is accurate.
# Global Epoch 40, Client 10: Combined Drift detection is accurate.
# Global Epoch 40, Client 11: Combined Drift detection is accurate.
# Global Epoch 40, Client 12: Combined Drift detection is accurate.
# Global Epoch 40, Client 13: Combined Drift detection is accurate.
# Global Epoch 40, Client 14: Combined Drift detection is inaccurate.
# Global Epoch 40, Client 15: Combined Drift detection is accurate.
# Global Epoch 40, Client 16: Combined Drift detection is accurate.
# Global Epoch 40, Client 17: Combined Drift detection is accurate.
# Global Epoch 40, Client 18: Combined Drift detection is accurate.
# Global Epoch 40, Client 19: Combined Drift detection is accurate.
# Global Epoch 40, Client 20: Combined Drift detection is accurate.
# Global Epoch 40, Client 21: Combined Drift detection is inaccurate.
# Global Epoch 40, Client 22: Combined Drift detection is accurate.
# Global Epoch 40, Client 23: Combined Drift detection is accurate.
# Global Epoch 40, Client 24: Combined Drift detection is accurate.
# Global Epoch 40, Client 25: Combined Drift detection is accurate.
# Global Epoch 40, Client 26: Combined Drift detection is accurate.
# Global Epoch 40, Client 27: Combined Drift detection is accurate.
# Global Epoch 40, Client 28: Combined Drift detection is accurate.
# Global Epoch 40, Client 29: Combined Drift detection is accurate.
# Global Epoch 40, Client 30: Combined Drift detection is accurate.
# Global Epoch 40, Client 31: Combined Drift detection is accurate.
# Global Epoch 40, Client 32: Combined Drift detection is accurate.
# Global Epoch 40, Client 33: Combined Drift detection is accurate.
# Global Epoch 40, Client 34: Combined Drift detection is accurate.
# Global Epoch 40, Client 35: Combined Drift detection is accurate.
# Global Epoch 40, Client 36: Combined Drift detection is accurate.
# Global Epoch 40, Client 37: Combined Drift detection is accurate.
# Global Epoch 40, Client 38: Combined Drift detection is inaccurate.
# Global Epoch 40, Client 39: Combined Drift detection is accurate.
# Global Epoch 40, Client 40: Combined Drift detection is accurate.
# Global Epoch 40, Client 41: Combined Drift detection is accurate.
# Global Epoch 40, Client 42: Combined Drift detection is accurate.
# Global Epoch 40, Client 43: Combined Drift detection is accurate.
# Global Epoch 40, Client 44: Combined Drift detection is accurate.
# Global Epoch 40, Client 45: Combined Drift detection is accurate.
# Global Epoch 40, Client 46: Combined Drift detection is accurate.
# Global Epoch 40, Client 47: Combined Drift detection is accurate.
# Global Epoch 40, Client 48: Combined Drift detection is accurate.
# Global Epoch 40, Client 49: Combined Drift detection is accurate.
# Global Epoch 40, Client 50: Combined Drift detection is accurate.
# Global Epoch 40, Client 51: Combined Drift detection is accurate.
# Global Epoch 40, Client 52: Combined Drift detection is accurate.
# Global Epoch 40, Client 53: Combined Drift detection is accurate.
# Global Epoch 40, Client 54: Combined Drift detection is accurate.
# Global Epoch 40, Client 55: Combined Drift detection is accurate.
# Global Epoch 40, Client 56: Combined Drift detection is inaccurate.
# Global Epoch 40, Client 57: Combined Drift detection is accurate.
# Global Epoch 40, Client 58: Combined Drift detection is accurate.
# Global Epoch 40, Client 59: Combined Drift detection is accurate.
# Global Epoch 40, Client 60: Combined Drift detection is accurate.
# 	Aggregating client models
# Testing Client 1/60
# 	Accuracy for Client 1/60: 0.9878
# Testing Client 2/60
# 	Accuracy for Client 2/60: 0.9878
# Testing Client 3/60
# 	Accuracy for Client 3/60: 0.9878
# Testing Client 4/60
# 	Accuracy for Client 4/60: 0.9878
# Testing Client 5/60
# 	Accuracy for Client 5/60: 0.9878
# Testing Client 6/60
# 	Accuracy for Client 6/60: 0.9878
# Testing Client 7/60
# 	Accuracy for Client 7/60: 0.9878
# Testing Client 8/60
# 	Accuracy for Client 8/60: 0.9878
# Testing Client 9/60
# 	Accuracy for Client 9/60: 0.9878
# Testing Client 10/60
# 	Accuracy for Client 10/60: 0.9878
# Testing Client 11/60
# 	Accuracy for Client 11/60: 0.9878
# Testing Client 12/60
# 	Accuracy for Client 12/60: 0.9878
# Testing Client 13/60
# 	Accuracy for Client 13/60: 0.9878
# Testing Client 14/60
# 	Accuracy for Client 14/60: 0.9878
# Testing Client 15/60
# 	Accuracy for Client 15/60: 0.9878
# Testing Client 16/60
# 	Accuracy for Client 16/60: 0.9878
# Testing Client 17/60
# 	Accuracy for Client 17/60: 0.9878
# Testing Client 18/60
# 	Accuracy for Client 18/60: 0.9878
# Testing Client 19/60
# 	Accuracy for Client 19/60: 0.9878
# Testing Client 20/60
# 	Accuracy for Client 20/60: 0.9878
# Testing Client 21/60
# 	Accuracy for Client 21/60: 0.9878
# Testing Client 22/60
# 	Accuracy for Client 22/60: 0.9878
# Testing Client 23/60
# 	Accuracy for Client 23/60: 0.9878
# Testing Client 24/60
# 	Accuracy for Client 24/60: 0.9878
# Testing Client 25/60
# 	Accuracy for Client 25/60: 0.9878
# Testing Client 26/60
# 	Accuracy for Client 26/60: 0.9878
# Testing Client 27/60
# 	Accuracy for Client 27/60: 0.9878
# Testing Client 28/60
# 	Accuracy for Client 28/60: 0.9878
# Testing Client 29/60
# 	Accuracy for Client 29/60: 0.9878
# Testing Client 30/60
# 	Accuracy for Client 30/60: 0.9878
# Testing Client 31/60
# 	Accuracy for Client 31/60: 0.9878
# Testing Client 32/60
# 	Accuracy for Client 32/60: 0.9878
# Testing Client 33/60
# 	Accuracy for Client 33/60: 0.9878
# Testing Client 34/60
# 	Accuracy for Client 34/60: 0.9878
# Testing Client 35/60
# 	Accuracy for Client 35/60: 0.9878
# Testing Client 36/60
# 	Accuracy for Client 36/60: 0.9878
# Testing Client 37/60
# 	Accuracy for Client 37/60: 0.9878
# Testing Client 38/60
# 	Accuracy for Client 38/60: 0.9878
# Testing Client 39/60
# 	Accuracy for Client 39/60: 0.9878
# Testing Client 40/60
# 	Accuracy for Client 40/60: 0.9878
# Testing Client 41/60
# 	Accuracy for Client 41/60: 0.9878
# Testing Client 42/60
# 	Accuracy for Client 42/60: 0.9878
# Testing Client 43/60
# 	Accuracy for Client 43/60: 0.9878
# Testing Client 44/60
# 	Accuracy for Client 44/60: 0.9878
# Testing Client 45/60
# 	Accuracy for Client 45/60: 0.9878
# Testing Client 46/60
# 	Accuracy for Client 46/60: 0.9878
# Testing Client 47/60
# 	Accuracy for Client 47/60: 0.9878
# Testing Client 48/60
# 	Accuracy for Client 48/60: 0.9878
# Testing Client 49/60
# 	Accuracy for Client 49/60: 0.9878
# Testing Client 50/60
# 	Accuracy for Client 50/60: 0.9878
# Testing Client 51/60
# 	Accuracy for Client 51/60: 0.9878
# Testing Client 52/60
# 	Accuracy for Client 52/60: 0.9878
# Testing Client 53/60
# 	Accuracy for Client 53/60: 0.9878
# Testing Client 54/60
# 	Accuracy for Client 54/60: 0.9878
# Testing Client 55/60
# 	Accuracy for Client 55/60: 0.9878
# Testing Client 56/60
# 	Accuracy for Client 56/60: 0.9878
# Testing Client 57/60
# 	Accuracy for Client 57/60: 0.9878
# Testing Client 58/60
# 	Accuracy for Client 58/60: 0.9878
# Testing Client 59/60
# 	Accuracy for Client 59/60: 0.9878
# Testing Client 60/60
# 	Accuracy for Client 60/60: 0.9878
# Drift Detection metrics::: true_positives:11, true_negatives:1800, false_positives:0, false_negatives:289
# Drift Detection Performance (DDM):
# Accuracy: 0.8623809523809524
# Precision: 1.0
# Recall: 0.03666666666666667
# F1 Score: 0.0707395498392283
# Drift Detection metrics::: true_positives:0, true_negatives:1800, false_positives:0, false_negatives:300
# Drift Detection Performance (EDDM):
# Accuracy: 0.8571428571428571
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# Drift Detection metrics::: true_positives:113, true_negatives:1800, false_positives:0, false_negatives:187
# Drift Detection Performance (HDDM):
# Accuracy: 0.910952380952381
# Precision: 1.0
# Recall: 0.37666666666666665
# F1 Score: 0.5472154963680387
# Drift Detection metrics::: true_positives:116, true_negatives:1800, false_positives:0, false_negatives:184
# Drift Detection Performance (Combined):
# Accuracy: 0.9123809523809524
# Precision: 1.0
# Recall: 0.38666666666666666
# F1 Score: 0.5576923076923077
# Client Accuracies: [0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878, 0.9878]

# %%
# incremental

#sudden

def federated_learning(num_clients=60, num_local_epochs=5, num_global_epochs=40):
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
    trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)

    partition_size = len(trainset) // num_clients
    lengths = [partition_size] * num_clients
    datasets = random_split(trainset, lengths)

    client_indices = [dataset.indices for dataset in datasets]

    # Clients that will experience rotation drift
    rotation_drift_clients = [6, 50, 20, 5, 37, 42, 47, 13, 28, 15, 57, 10, 9, 31, 2, 41, 35, 1, 23, 58, 38, 46, 21, 48, 24, 43, 32, 4, 51, 56]

    # Clients that will experience class swap drift
#     class_swap_drift_clients = [2, 6, 9, 13, 20, 27, 33, 37, 41, 55]
    
    #     drift_clients = [6, 50, 20, 5, 37, 42, 47, 13, 28, 15, 57, 10, 9, 31, 2, 41, 35, 1, 23, 58, 38, 46, 21, 48, 24, 43, 32, 4, 51, 56]

#     drift_clients = [2, 6, 9, 10, 13, 15, 21, 23, 28, 35, 37, 41, 43, 47, 51, 56]
#     drift_clients = [2, 6, 9, 28, 41, 56]

    # Initialize global model
    global_model = CNN().to(device)
    previous_client_losses = [[] for _ in range(num_clients)]

    # Initialize ADWIN, DDM, EDDM detectors
    hddm_detectors = [HDDM_W(drift_confidence=0.001, warning_confidence=0.005, lambda_option=0.05, two_side_option=True) for _ in range(num_clients)]
    ddm_detectors = [DDM(min_num_instances=3, warning_level=1, out_control_level=3) for _ in range(num_clients)]
    # Create an instance of EDDM
    edddm = EDDM()

    # Modify parameters after initialization if necessary
    edddm.min_num_instances = 3
    edddm.warning_level = 1
    edddm.out_control_level = 3
    
    eddm_detectors = [edddm for _ in range(num_clients)]

    # Initialize counters for drift detection performance
    metrics = {
        'HDDM': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0},
        'DDM': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0},
        'EDDM': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0},
        'Combined': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
    }
    # Federated learning process
    for global_epoch in range(num_global_epochs):
        print(f"Global Epoch {global_epoch + 1}/{num_global_epochs}")

        # Apply rotation drift gradually starting from a certain epoch
        if global_epoch in range(10, 31):  # Example threshold for starting drift
            print("Applying rotation drift to specific clients")
            for client_id in rotation_drift_clients:
                indices = client_indices[client_id]
                images = trainset.data[indices]
                drifted_images = apply_rotation_drift(images, global_epoch, max_rotation=30, start_epoch=10, end_epoch=30, total_epochs=num_global_epochs)
                trainset.data[indices] = drifted_images

#         # Apply class swap drift at a specific epoch
#         if global_epoch == 10:
#             print("Swapping classes 3 and 8 in the train dataset for selected clients")
#             for client_id in class_swap_drift_clients:
#                 indices = client_indices[client_id]
#                 for idx in indices:
#                     if trainset.targets[idx] == 8:
#                         trainset.targets[idx] = 3
#                     elif trainset.targets[idx] == 3:
#                         trainset.targets[idx] = 8
                        
#                     elif trainset.targets[idx] == 5:
#                         trainset.targets[idx] = 6
#                     elif trainset.targets[idx] == 6:
#                         trainset.targets[idx] = 5

        client_train_loaders = [torch.utils.data.DataLoader(torch.utils.data.Subset(trainset, indices), batch_size=32, shuffle=True) for indices in client_indices]
        client_test_loaders = [torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False) for _ in range(num_clients)]
        client_models = [copy.deepcopy(global_model) for _ in range(num_clients)]

        # Perform local training and compute SHAP values
        client_losses = []

        for i, train_loader in enumerate(client_train_loaders):
            print(f"\tTraining Client {i + 1}/{num_clients}")
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(client_models[i].parameters(), lr=0.001)
            loss = client_training(train_loader, client_models[i], criterion, optimizer, num_local_epochs)
            client_losses.append(loss)

            # Update previous client losses
            previous_client_losses[i].append(loss)
            
            
            

        # Concept drift detection using ADWIN, DDM, and EDDM
        if global_epoch >= 5 and global_epoch <= 28:
            detected_drift_clients_ddm = []
            detected_drift_clients_eddm = []
            detected_drift_clients_hddm = []

            for i, losses in enumerate(client_losses):
                for loss in losses:
                    hddm_detectors[i].add_element(loss)
                    ddm_detectors[i].add_element(loss)
                    eddm_detectors[i].add_element(loss)

                    if hddm_detectors[i].detected_change():
                        detected_drift_clients_hddm.append(i)
                    if ddm_detectors[i].detected_change():
                        detected_drift_clients_ddm.append(i)
                    if eddm_detectors[i].detected_change():
                        detected_drift_clients_eddm.append(i)
                        
                        
                    
            detected_drift_clients_combined = list(set(  detected_drift_clients_hddm + detected_drift_clients_ddm + detected_drift_clients_eddm))
            print(f"ddm:{detected_drift_clients_ddm}, eddm:{detected_drift_clients_eddm}, hddm{detected_drift_clients_hddm}, combined{detected_drift_clients_combined}")
            print(f"metrics:{metrics}")
            


            for detector_name, detected_drift_clients in zip(['DDM', 'EDDM', 'HDDM', 'Combined'], [detected_drift_clients_ddm, detected_drift_clients_eddm, detected_drift_clients_hddm, detected_drift_clients_combined]):
                for client_id in range(num_clients):
                    ground_truth_drift = (client_id in rotation_drift_clients) and (global_epoch >= 19) and (global_epoch <= 29)
                    detected_drift = client_id in detected_drift_clients

                    if detected_drift and ground_truth_drift:
                        metrics[detector_name]['TP'] += 1
                    elif not detected_drift and not ground_truth_drift:
                        metrics[detector_name]['TN'] += 1
                    elif detected_drift and not ground_truth_drift:
                        metrics[detector_name]['FP'] += 1
                    elif not detected_drift and ground_truth_drift:
                        metrics[detector_name]['FN'] += 1

                    if detected_drift == ground_truth_drift:
                        print(f"Global Epoch {global_epoch + 1}, Client {client_id + 1}: {detector_name} Drift detection is accurate.")
                    else:
                        print(f"Global Epoch {global_epoch + 1}, Client {client_id + 1}: {detector_name} Drift detection is inaccurate.")

        # Aggregate client models into global model
        print("\tAggregating client models")
        global_model = aggregate_models(global_model, client_models)

    # Test models on each client
    accuracies = []
    for i, test_loader in enumerate(client_test_loaders):
        print(f"Testing Client {i + 1}/{num_clients}")
        accuracy = client_testing(test_loader, global_model)
        accuracies.append(accuracy)
        print(f"\tAccuracy for Client {i + 1}/{num_clients}: {accuracy}")

    # Calculate performance metrics of drift detection
    for detector_name in ['DDM', 'EDDM','HDDM', 'Combined']:
        TP = metrics[detector_name]['TP']
        TN = metrics[detector_name]['TN']
        FP = metrics[detector_name]['FP']
        FN = metrics[detector_name]['FN']

        accuracy = (TP + TN) / (TP + TN + FP + FN)
        precision = TP / (TP + FP) if (TP + FP) > 0 else 0
        recall = TP / (TP + FN) if (TP + FN) > 0 else 0
        f1_score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
        
        print(f"Drift Detection metrics::: true_positives:{TP}, true_negatives:{TN}, false_positives:{FP}, false_negatives:{FN}")
        print(f"Drift Detection Performance ({detector_name}):\nAccuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1_score}")

    return accuracies

# Aggregation of models' weights using FedAvg
def aggregate_models(global_model, client_models):
    global_dict = global_model.state_dict()
    for k in global_dict.keys():
        global_dict[k] = torch.stack([client_model.state_dict()[k].float() for client_model in client_models], 0).mean(0)
    global_model.load_state_dict(global_dict)
    return global_model

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Example usage
if __name__ == "__main__":
    client_accuracies = federated_learning(num_clients=60, num_local_epochs=1, num_global_epochs=40)
    print("Client Accuracies:", client_accuracies)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 33618212.99it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 988136.83it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 9371825.00it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 3819272.01it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Global Epoch 1/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 49.7998705804348, Accuracy: 0.507
# 	Training Client 2/60
# Epoch 1/1, Loss: 48.39897897839546, Accuracy: 0.551
# 	Training Client 3/60
# Epoch 1/1, Loss: 47.44576150178909, Accuracy: 0.507
# 	Training Client 4/60
# Epoch 1/1, Loss: 47.85296183824539, Accuracy: 0.533
# 	Training Client 5/60
# Epoch 1/1, Loss: 50.38479936122894, Accuracy: 0.516
# 	Training Client 6/60
# Epoch 1/1, Loss: 48.611885249614716, Accuracy: 0.528
# 	Training Client 7/60
# Epoch 1/1, Loss: 51.794359147548676, Accuracy: 0.464
# 	Training Client 8/60
# Epoch 1/1, Loss: 52.096949100494385, Accuracy: 0.494
# 	Training Client 9/60
# Epoch 1/1, Loss: 51.13297080993652, Accuracy: 0.525
# 	Training Client 10/60
# Epoch 1/1, Loss: 47.53140366077423, Accuracy: 0.56
# 	Training Client 11/60
# Epoch 1/1, Loss: 47.49449124932289, Accuracy: 0.564
# 	Training Client 12/60
# Epoch 1/1, Loss: 50.82881420850754, Accuracy: 0.507
# 	Training Client 13/60
# Epoch 1/1, Loss: 48.96703243255615, Accuracy: 0.523
# 	Training Client 14/60
# Epoch 1/1, Loss: 49.117168724536896, Accuracy: 0.519
# 	Training Client 15/60
# Epoch 1/1, Loss: 49.613831251859665, Accuracy: 0.525
# 	Training Client 16/60
# Epoch 1/1, Loss: 48.9167814552784, Accuracy: 0.529
# 	Training Client 17/60
# Epoch 1/1, Loss: 51.72508454322815, Accuracy: 0.49
# 	Training Client 18/60
# Epoch 1/1, Loss: 46.537873566150665, Accuracy: 0.545
# 	Training Client 19/60
# Epoch 1/1, Loss: 49.01320117712021, Accuracy: 0.527
# 	Training Client 20/60
# Epoch 1/1, Loss: 45.85374763607979, Accuracy: 0.561
# 	Training Client 21/60
# Epoch 1/1, Loss: 48.13542225956917, Accuracy: 0.564
# 	Training Client 22/60
# Epoch 1/1, Loss: 50.44376394152641, Accuracy: 0.551
# 	Training Client 23/60
# Epoch 1/1, Loss: 48.300307869911194, Accuracy: 0.519
# 	Training Client 24/60
# Epoch 1/1, Loss: 45.26660233736038, Accuracy: 0.584
# 	Training Client 25/60
# Epoch 1/1, Loss: 48.68524241447449, Accuracy: 0.531
# 	Training Client 26/60
# Epoch 1/1, Loss: 50.26375928521156, Accuracy: 0.529
# 	Training Client 27/60
# Epoch 1/1, Loss: 45.40280057489872, Accuracy: 0.546
# 	Training Client 28/60
# Epoch 1/1, Loss: 47.82523036003113, Accuracy: 0.544
# 	Training Client 29/60
# Epoch 1/1, Loss: 46.58313363790512, Accuracy: 0.547
# 	Training Client 30/60
# Epoch 1/1, Loss: 52.72194463014603, Accuracy: 0.481
# 	Training Client 31/60
# Epoch 1/1, Loss: 51.96819931268692, Accuracy: 0.494
# 	Training Client 32/60
# Epoch 1/1, Loss: 47.51566997170448, Accuracy: 0.536
# 	Training Client 33/60
# Epoch 1/1, Loss: 46.18019366264343, Accuracy: 0.549
# 	Training Client 34/60
# Epoch 1/1, Loss: 48.15187531709671, Accuracy: 0.54
# 	Training Client 35/60
# Epoch 1/1, Loss: 51.58582353591919, Accuracy: 0.505
# 	Training Client 36/60
# Epoch 1/1, Loss: 48.31639263033867, Accuracy: 0.531
# 	Training Client 37/60
# Epoch 1/1, Loss: 47.08530479669571, Accuracy: 0.546
# 	Training Client 38/60
# Epoch 1/1, Loss: 47.66308429837227, Accuracy: 0.53
# 	Training Client 39/60
# Epoch 1/1, Loss: 49.697618901729584, Accuracy: 0.508
# 	Training Client 40/60
# Epoch 1/1, Loss: 51.90636247396469, Accuracy: 0.492
# 	Training Client 41/60
# Epoch 1/1, Loss: 47.237168818712234, Accuracy: 0.548
# 	Training Client 42/60
# Epoch 1/1, Loss: 48.58057403564453, Accuracy: 0.539
# 	Training Client 43/60
# Epoch 1/1, Loss: 49.48986053466797, Accuracy: 0.523
# 	Training Client 44/60
# Epoch 1/1, Loss: 49.60144221782684, Accuracy: 0.517
# 	Training Client 45/60
# Epoch 1/1, Loss: 49.00686949491501, Accuracy: 0.558
# 	Training Client 46/60
# Epoch 1/1, Loss: 49.83794987201691, Accuracy: 0.495
# 	Training Client 47/60
# Epoch 1/1, Loss: 50.637565433979034, Accuracy: 0.516
# 	Training Client 48/60
# Epoch 1/1, Loss: 49.976088643074036, Accuracy: 0.512
# 	Training Client 49/60
# Epoch 1/1, Loss: 49.92930555343628, Accuracy: 0.533
# 	Training Client 50/60
# Epoch 1/1, Loss: 49.35827985405922, Accuracy: 0.504
# 	Training Client 51/60
# Epoch 1/1, Loss: 49.32155907154083, Accuracy: 0.499
# 	Training Client 52/60
# Epoch 1/1, Loss: 47.953457057476044, Accuracy: 0.522
# 	Training Client 53/60
# Epoch 1/1, Loss: 49.096336513757706, Accuracy: 0.525
# 	Training Client 54/60
# Epoch 1/1, Loss: 48.72912558913231, Accuracy: 0.53
# 	Training Client 55/60
# Epoch 1/1, Loss: 50.65841090679169, Accuracy: 0.502
# 	Training Client 56/60
# Epoch 1/1, Loss: 46.879148334264755, Accuracy: 0.548
# 	Training Client 57/60
# Epoch 1/1, Loss: 52.85367524623871, Accuracy: 0.489
# 	Training Client 58/60
# Epoch 1/1, Loss: 49.51780867576599, Accuracy: 0.525
# 	Training Client 59/60
# Epoch 1/1, Loss: 49.49495869874954, Accuracy: 0.544
# 	Training Client 60/60
# Epoch 1/1, Loss: 47.236832827329636, Accuracy: 0.551
# 	Aggregating client models
# Global Epoch 2/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 18.747329115867615, Accuracy: 0.822
# 	Training Client 2/60
# Epoch 1/1, Loss: 19.578819900751114, Accuracy: 0.81
# 	Training Client 3/60
# Epoch 1/1, Loss: 18.41065476834774, Accuracy: 0.817
# 	Training Client 4/60
# Epoch 1/1, Loss: 20.069906920194626, Accuracy: 0.819
# 	Training Client 5/60
# Epoch 1/1, Loss: 18.288382202386856, Accuracy: 0.816
# 	Training Client 6/60
# Epoch 1/1, Loss: 18.505726516246796, Accuracy: 0.825
# 	Training Client 7/60
# Epoch 1/1, Loss: 18.26301033049822, Accuracy: 0.81
# 	Training Client 8/60
# Epoch 1/1, Loss: 18.266528844833374, Accuracy: 0.822
# 	Training Client 9/60
# Epoch 1/1, Loss: 19.421951189637184, Accuracy: 0.799
# 	Training Client 10/60
# Epoch 1/1, Loss: 17.650615215301514, Accuracy: 0.815
# 	Training Client 11/60
# Epoch 1/1, Loss: 17.947282522916794, Accuracy: 0.81
# 	Training Client 12/60
# Epoch 1/1, Loss: 18.02963562309742, Accuracy: 0.84
# 	Training Client 13/60
# Epoch 1/1, Loss: 18.310375571250916, Accuracy: 0.833
# 	Training Client 14/60
# Epoch 1/1, Loss: 16.758917525410652, Accuracy: 0.831
# 	Training Client 15/60
# Epoch 1/1, Loss: 19.308261588215828, Accuracy: 0.81
# 	Training Client 16/60
# Epoch 1/1, Loss: 18.144258096814156, Accuracy: 0.81
# 	Training Client 17/60
# Epoch 1/1, Loss: 20.517715603113174, Accuracy: 0.802
# 	Training Client 18/60
# Epoch 1/1, Loss: 18.42021158337593, Accuracy: 0.815
# 	Training Client 19/60
# Epoch 1/1, Loss: 17.00630209594965, Accuracy: 0.827
# 	Training Client 20/60
# Epoch 1/1, Loss: 18.29637584090233, Accuracy: 0.814
# 	Training Client 21/60
# Epoch 1/1, Loss: 18.05847954750061, Accuracy: 0.827
# 	Training Client 22/60
# Epoch 1/1, Loss: 19.489416226744652, Accuracy: 0.82
# 	Training Client 23/60
# Epoch 1/1, Loss: 18.55821865797043, Accuracy: 0.827
# 	Training Client 24/60
# Epoch 1/1, Loss: 16.271729201078415, Accuracy: 0.847
# 	Training Client 25/60
# Epoch 1/1, Loss: 18.388835608959198, Accuracy: 0.81
# 	Training Client 26/60
# Epoch 1/1, Loss: 17.531817585229874, Accuracy: 0.844
# 	Training Client 27/60
# Epoch 1/1, Loss: 17.86878477036953, Accuracy: 0.828
# 	Training Client 28/60
# Epoch 1/1, Loss: 19.08134862780571, Accuracy: 0.818
# 	Training Client 29/60
# Epoch 1/1, Loss: 18.79690557718277, Accuracy: 0.816
# 	Training Client 30/60
# Epoch 1/1, Loss: 19.14837610721588, Accuracy: 0.809
# 	Training Client 31/60
# Epoch 1/1, Loss: 18.738821983337402, Accuracy: 0.814
# 	Training Client 32/60
# Epoch 1/1, Loss: 18.923307843506336, Accuracy: 0.808
# 	Training Client 33/60
# Epoch 1/1, Loss: 19.036626085639, Accuracy: 0.817
# 	Training Client 34/60
# Epoch 1/1, Loss: 18.58782795071602, Accuracy: 0.828
# 	Training Client 35/60
# Epoch 1/1, Loss: 18.708833307027817, Accuracy: 0.822
# 	Training Client 36/60
# Epoch 1/1, Loss: 18.932549715042114, Accuracy: 0.824
# 	Training Client 37/60
# Epoch 1/1, Loss: 17.924872390925884, Accuracy: 0.825
# 	Training Client 38/60
# Epoch 1/1, Loss: 15.42277979850769, Accuracy: 0.847
# 	Training Client 39/60
# Epoch 1/1, Loss: 18.657226085662842, Accuracy: 0.815
# 	Training Client 40/60
# Epoch 1/1, Loss: 17.569369480013847, Accuracy: 0.827
# 	Training Client 41/60
# Epoch 1/1, Loss: 18.57801929116249, Accuracy: 0.814
# 	Training Client 42/60
# Epoch 1/1, Loss: 18.728981092572212, Accuracy: 0.829
# 	Training Client 43/60
# Epoch 1/1, Loss: 18.799657322466373, Accuracy: 0.821
# 	Training Client 44/60
# Epoch 1/1, Loss: 17.49684238433838, Accuracy: 0.83
# 	Training Client 45/60
# Epoch 1/1, Loss: 18.835917189717293, Accuracy: 0.828
# 	Training Client 46/60
# Epoch 1/1, Loss: 18.927096590399742, Accuracy: 0.813
# 	Training Client 47/60
# Epoch 1/1, Loss: 18.90012226998806, Accuracy: 0.826
# 	Training Client 48/60
# Epoch 1/1, Loss: 16.487412083894014, Accuracy: 0.854
# 	Training Client 49/60
# Epoch 1/1, Loss: 19.229317247867584, Accuracy: 0.818
# 	Training Client 50/60
# Epoch 1/1, Loss: 19.587856620550156, Accuracy: 0.814
# 	Training Client 51/60
# Epoch 1/1, Loss: 19.208343774080276, Accuracy: 0.812
# 	Training Client 52/60
# Epoch 1/1, Loss: 16.852145433425903, Accuracy: 0.828
# 	Training Client 53/60
# Epoch 1/1, Loss: 19.231063038110733, Accuracy: 0.817
# 	Training Client 54/60
# Epoch 1/1, Loss: 17.974320590496063, Accuracy: 0.819
# 	Training Client 55/60
# Epoch 1/1, Loss: 18.64983706921339, Accuracy: 0.804
# 	Training Client 56/60
# Epoch 1/1, Loss: 20.53317752480507, Accuracy: 0.799
# 	Training Client 57/60
# Epoch 1/1, Loss: 18.441883623600006, Accuracy: 0.83
# 	Training Client 58/60
# Epoch 1/1, Loss: 18.81112563610077, Accuracy: 0.832
# 	Training Client 59/60
# Epoch 1/1, Loss: 18.702544257044792, Accuracy: 0.806
# 	Training Client 60/60
# Epoch 1/1, Loss: 17.888263180851936, Accuracy: 0.824
# 	Aggregating client models
# Global Epoch 3/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 12.295296251773834, Accuracy: 0.873
# 	Training Client 2/60
# Epoch 1/1, Loss: 13.045458748936653, Accuracy: 0.878
# 	Training Client 3/60
# Epoch 1/1, Loss: 12.837978817522526, Accuracy: 0.877
# 	Training Client 4/60
# Epoch 1/1, Loss: 12.26183108985424, Accuracy: 0.884
# 	Training Client 5/60
# Epoch 1/1, Loss: 11.925712034106255, Accuracy: 0.885
# 	Training Client 6/60
# Epoch 1/1, Loss: 11.875531256198883, Accuracy: 0.892
# 	Training Client 7/60
# Epoch 1/1, Loss: 10.861133888363838, Accuracy: 0.904
# 	Training Client 8/60
# Epoch 1/1, Loss: 10.803138956427574, Accuracy: 0.901
# 	Training Client 9/60
# Epoch 1/1, Loss: 11.465467996895313, Accuracy: 0.889
# 	Training Client 10/60
# Epoch 1/1, Loss: 10.346550039947033, Accuracy: 0.911
# 	Training Client 11/60
# Epoch 1/1, Loss: 11.08924002200365, Accuracy: 0.891
# 	Training Client 12/60
# Epoch 1/1, Loss: 10.252232272177935, Accuracy: 0.894
# 	Training Client 13/60
# Epoch 1/1, Loss: 12.224988147616386, Accuracy: 0.883
# 	Training Client 14/60
# Epoch 1/1, Loss: 9.946478731930256, Accuracy: 0.9
# 	Training Client 15/60
# Epoch 1/1, Loss: 10.602016057819128, Accuracy: 0.905
# 	Training Client 16/60
# Epoch 1/1, Loss: 10.49705721065402, Accuracy: 0.901
# 	Training Client 17/60
# Epoch 1/1, Loss: 10.624632447957993, Accuracy: 0.896
# 	Training Client 18/60
# Epoch 1/1, Loss: 10.904075011610985, Accuracy: 0.892
# 	Training Client 19/60
# Epoch 1/1, Loss: 10.03357869759202, Accuracy: 0.903
# 	Training Client 20/60
# Epoch 1/1, Loss: 11.92626667022705, Accuracy: 0.886
# 	Training Client 21/60
# Epoch 1/1, Loss: 12.266853645443916, Accuracy: 0.881
# 	Training Client 22/60
# Epoch 1/1, Loss: 12.444428406655788, Accuracy: 0.898
# 	Training Client 23/60
# Epoch 1/1, Loss: 12.96469134092331, Accuracy: 0.886
# 	Training Client 24/60
# Epoch 1/1, Loss: 10.53382059931755, Accuracy: 0.903
# 	Training Client 25/60
# Epoch 1/1, Loss: 10.735023111104965, Accuracy: 0.904
# 	Training Client 26/60
# Epoch 1/1, Loss: 10.751599768176675, Accuracy: 0.889
# 	Training Client 27/60
# Epoch 1/1, Loss: 9.84237965196371, Accuracy: 0.906
# 	Training Client 28/60
# Epoch 1/1, Loss: 11.805642507970333, Accuracy: 0.898
# 	Training Client 29/60
# Epoch 1/1, Loss: 11.035595960915089, Accuracy: 0.903
# 	Training Client 30/60
# Epoch 1/1, Loss: 12.58207406103611, Accuracy: 0.864
# 	Training Client 31/60
# Epoch 1/1, Loss: 10.654961884021759, Accuracy: 0.903
# 	Training Client 32/60
# Epoch 1/1, Loss: 12.660315945744514, Accuracy: 0.874
# 	Training Client 33/60
# Epoch 1/1, Loss: 11.827251598238945, Accuracy: 0.892
# 	Training Client 34/60
# Epoch 1/1, Loss: 13.478627562522888, Accuracy: 0.869
# 	Training Client 35/60
# Epoch 1/1, Loss: 12.964808873832226, Accuracy: 0.878
# 	Training Client 36/60
# Epoch 1/1, Loss: 9.672054670751095, Accuracy: 0.916
# 	Training Client 37/60
# Epoch 1/1, Loss: 11.71575117111206, Accuracy: 0.88
# 	Training Client 38/60
# Epoch 1/1, Loss: 11.087152428925037, Accuracy: 0.899
# 	Training Client 39/60
# Epoch 1/1, Loss: 12.656044155359268, Accuracy: 0.874
# 	Training Client 40/60
# Epoch 1/1, Loss: 11.664708957076073, Accuracy: 0.887
# 	Training Client 41/60
# Epoch 1/1, Loss: 12.56020137667656, Accuracy: 0.882
# 	Training Client 42/60
# Epoch 1/1, Loss: 11.471806704998016, Accuracy: 0.885
# 	Training Client 43/60
# Epoch 1/1, Loss: 10.76485200226307, Accuracy: 0.902
# 	Training Client 44/60
# Epoch 1/1, Loss: 10.954641669988632, Accuracy: 0.886
# 	Training Client 45/60
# Epoch 1/1, Loss: 10.915179833769798, Accuracy: 0.894
# 	Training Client 46/60
# Epoch 1/1, Loss: 12.63754153251648, Accuracy: 0.872
# 	Training Client 47/60
# Epoch 1/1, Loss: 11.193643018603325, Accuracy: 0.902
# 	Training Client 48/60
# Epoch 1/1, Loss: 10.85308887064457, Accuracy: 0.896
# 	Training Client 49/60
# Epoch 1/1, Loss: 11.87527385354042, Accuracy: 0.884
# 	Training Client 50/60
# Epoch 1/1, Loss: 12.178227664902806, Accuracy: 0.879
# 	Training Client 51/60
# Epoch 1/1, Loss: 12.032220214605331, Accuracy: 0.873
# 	Training Client 52/60
# Epoch 1/1, Loss: 10.383138246834278, Accuracy: 0.898
# 	Training Client 53/60
# Epoch 1/1, Loss: 12.562425196170807, Accuracy: 0.864
# 	Training Client 54/60
# Epoch 1/1, Loss: 11.59540756046772, Accuracy: 0.892
# 	Training Client 55/60
# Epoch 1/1, Loss: 11.69704519957304, Accuracy: 0.896
# 	Training Client 56/60
# Epoch 1/1, Loss: 11.304620392620564, Accuracy: 0.898
# 	Training Client 57/60
# Epoch 1/1, Loss: 12.637806601822376, Accuracy: 0.878
# 	Training Client 58/60
# Epoch 1/1, Loss: 11.410504475235939, Accuracy: 0.897
# 	Training Client 59/60
# Epoch 1/1, Loss: 11.766601651906967, Accuracy: 0.901
# 	Training Client 60/60
# Epoch 1/1, Loss: 11.623847112059593, Accuracy: 0.897
# 	Aggregating client models
# Global Epoch 4/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 8.914263814687729, Accuracy: 0.917
# 	Training Client 2/60
# Epoch 1/1, Loss: 9.7349346652627, Accuracy: 0.918
# 	Training Client 3/60
# Epoch 1/1, Loss: 9.166395630687475, Accuracy: 0.908
# 	Training Client 4/60
# Epoch 1/1, Loss: 9.942910708487034, Accuracy: 0.908
# 	Training Client 5/60
# Epoch 1/1, Loss: 8.022675212472677, Accuracy: 0.925
# 	Training Client 6/60
# Epoch 1/1, Loss: 8.181379422545433, Accuracy: 0.927
# 	Training Client 7/60
# Epoch 1/1, Loss: 8.313000690191984, Accuracy: 0.915
# 	Training Client 8/60
# Epoch 1/1, Loss: 7.907945550978184, Accuracy: 0.927
# 	Training Client 9/60
# Epoch 1/1, Loss: 8.440671555697918, Accuracy: 0.922
# 	Training Client 10/60
# Epoch 1/1, Loss: 7.174994356930256, Accuracy: 0.937
# 	Training Client 11/60
# Epoch 1/1, Loss: 8.11023709923029, Accuracy: 0.92
# 	Training Client 12/60
# Epoch 1/1, Loss: 7.446154298260808, Accuracy: 0.947
# 	Training Client 13/60
# Epoch 1/1, Loss: 8.477958805859089, Accuracy: 0.915
# 	Training Client 14/60
# Epoch 1/1, Loss: 7.221231575123966, Accuracy: 0.918
# 	Training Client 15/60
# Epoch 1/1, Loss: 7.970668189227581, Accuracy: 0.935
# 	Training Client 16/60
# Epoch 1/1, Loss: 7.963180832564831, Accuracy: 0.915
# 	Training Client 17/60
# Epoch 1/1, Loss: 7.887287802994251, Accuracy: 0.926
# 	Training Client 18/60
# Epoch 1/1, Loss: 8.774997930973768, Accuracy: 0.911
# 	Training Client 19/60
# Epoch 1/1, Loss: 7.957942567765713, Accuracy: 0.932
# 	Training Client 20/60
# Epoch 1/1, Loss: 7.999684475362301, Accuracy: 0.925
# 	Training Client 21/60
# Epoch 1/1, Loss: 8.433240033686161, Accuracy: 0.931
# 	Training Client 22/60
# Epoch 1/1, Loss: 9.91548117250204, Accuracy: 0.912
# 	Training Client 23/60
# Epoch 1/1, Loss: 9.525734171271324, Accuracy: 0.917
# 	Training Client 24/60
# Epoch 1/1, Loss: 7.8834074810147285, Accuracy: 0.93
# 	Training Client 25/60
# Epoch 1/1, Loss: 8.766502914950252, Accuracy: 0.917
# 	Training Client 26/60
# Epoch 1/1, Loss: 8.512636084109545, Accuracy: 0.917
# 	Training Client 27/60
# Epoch 1/1, Loss: 7.651088289916515, Accuracy: 0.916
# 	Training Client 28/60
# Epoch 1/1, Loss: 9.285648196935654, Accuracy: 0.927
# 	Training Client 29/60
# Epoch 1/1, Loss: 8.236347015947104, Accuracy: 0.926
# 	Training Client 30/60
# Epoch 1/1, Loss: 8.091017663478851, Accuracy: 0.924
# 	Training Client 31/60
# Epoch 1/1, Loss: 8.383674716576934, Accuracy: 0.922
# 	Training Client 32/60
# Epoch 1/1, Loss: 9.139249697327614, Accuracy: 0.915
# 	Training Client 33/60
# Epoch 1/1, Loss: 8.88526375591755, Accuracy: 0.923
# 	Training Client 34/60
# Epoch 1/1, Loss: 8.328273136168718, Accuracy: 0.919
# 	Training Client 35/60
# Epoch 1/1, Loss: 8.82106463238597, Accuracy: 0.916
# 	Training Client 36/60
# Epoch 1/1, Loss: 7.984014254063368, Accuracy: 0.922
# 	Training Client 37/60
# Epoch 1/1, Loss: 8.826857812702656, Accuracy: 0.92
# 	Training Client 38/60
# Epoch 1/1, Loss: 7.4731144569814205, Accuracy: 0.941
# 	Training Client 39/60
# Epoch 1/1, Loss: 7.975706767290831, Accuracy: 0.932
# 	Training Client 40/60
# Epoch 1/1, Loss: 8.40110931918025, Accuracy: 0.92
# 	Training Client 41/60
# Epoch 1/1, Loss: 9.566559843719006, Accuracy: 0.913
# 	Training Client 42/60
# Epoch 1/1, Loss: 8.300552900880575, Accuracy: 0.921
# 	Training Client 43/60
# Epoch 1/1, Loss: 9.159531638026237, Accuracy: 0.91
# 	Training Client 44/60
# Epoch 1/1, Loss: 8.916426293551922, Accuracy: 0.916
# 	Training Client 45/60
# Epoch 1/1, Loss: 8.240387681871653, Accuracy: 0.931
# 	Training Client 46/60
# Epoch 1/1, Loss: 9.441495111212134, Accuracy: 0.902
# 	Training Client 47/60
# Epoch 1/1, Loss: 8.270463641732931, Accuracy: 0.926
# 	Training Client 48/60
# Epoch 1/1, Loss: 7.579845332540572, Accuracy: 0.923
# 	Training Client 49/60
# Epoch 1/1, Loss: 9.086601465940475, Accuracy: 0.916
# 	Training Client 50/60
# Epoch 1/1, Loss: 10.300699949264526, Accuracy: 0.914
# 	Training Client 51/60
# Epoch 1/1, Loss: 9.903965540230274, Accuracy: 0.91
# 	Training Client 52/60
# Epoch 1/1, Loss: 7.841305606067181, Accuracy: 0.933
# 	Training Client 53/60
# Epoch 1/1, Loss: 9.340847969055176, Accuracy: 0.911
# 	Training Client 54/60
# Epoch 1/1, Loss: 9.288372475653887, Accuracy: 0.919
# 	Training Client 55/60
# Epoch 1/1, Loss: 8.141922727227211, Accuracy: 0.923
# 	Training Client 56/60
# Epoch 1/1, Loss: 9.151631511747837, Accuracy: 0.916
# 	Training Client 57/60
# Epoch 1/1, Loss: 9.051953479647636, Accuracy: 0.911
# 	Training Client 58/60
# Epoch 1/1, Loss: 10.02817665785551, Accuracy: 0.913
# 	Training Client 59/60
# Epoch 1/1, Loss: 7.059716641902924, Accuracy: 0.93
# 	Training Client 60/60
# Epoch 1/1, Loss: 8.059797249734402, Accuracy: 0.923
# 	Aggregating client models
# Global Epoch 5/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 7.774105276912451, Accuracy: 0.933
# 	Training Client 2/60
# Epoch 1/1, Loss: 9.01716004498303, Accuracy: 0.913
# 	Training Client 3/60
# Epoch 1/1, Loss: 6.852221896871924, Accuracy: 0.936
# 	Training Client 4/60
# Epoch 1/1, Loss: 7.599094962701201, Accuracy: 0.926
# 	Training Client 5/60
# Epoch 1/1, Loss: 5.870659276843071, Accuracy: 0.935
# 	Training Client 6/60
# Epoch 1/1, Loss: 7.113850947469473, Accuracy: 0.937
# 	Training Client 7/60
# Epoch 1/1, Loss: 6.085805482696742, Accuracy: 0.941
# 	Training Client 8/60
# Epoch 1/1, Loss: 6.847624845802784, Accuracy: 0.937
# 	Training Client 9/60
# Epoch 1/1, Loss: 6.915633991360664, Accuracy: 0.936
# 	Training Client 10/60
# Epoch 1/1, Loss: 6.136712286621332, Accuracy: 0.94
# 	Training Client 11/60
# Epoch 1/1, Loss: 6.699737932533026, Accuracy: 0.929
# 	Training Client 12/60
# Epoch 1/1, Loss: 6.2259892746806145, Accuracy: 0.946
# 	Training Client 13/60
# Epoch 1/1, Loss: 7.303414709866047, Accuracy: 0.927
# 	Training Client 14/60
# Epoch 1/1, Loss: 6.310938075184822, Accuracy: 0.935
# 	Training Client 15/60
# Epoch 1/1, Loss: 6.065560817718506, Accuracy: 0.948
# 	Training Client 16/60
# Epoch 1/1, Loss: 7.149277448654175, Accuracy: 0.945
# 	Training Client 17/60
# Epoch 1/1, Loss: 5.7967588528990746, Accuracy: 0.946
# 	Training Client 18/60
# Epoch 1/1, Loss: 6.293442647904158, Accuracy: 0.941
# 	Training Client 19/60
# Epoch 1/1, Loss: 6.305529396981001, Accuracy: 0.946
# 	Training Client 20/60
# Epoch 1/1, Loss: 5.683483435772359, Accuracy: 0.95
# 	Training Client 21/60
# Epoch 1/1, Loss: 7.542990427464247, Accuracy: 0.941
# 	Training Client 22/60
# Epoch 1/1, Loss: 7.765243865549564, Accuracy: 0.941
# 	Training Client 23/60
# Epoch 1/1, Loss: 6.685595940798521, Accuracy: 0.93
# 	Training Client 24/60
# Epoch 1/1, Loss: 6.371750175952911, Accuracy: 0.937
# 	Training Client 25/60
# Epoch 1/1, Loss: 7.070403225719929, Accuracy: 0.928
# 	Training Client 26/60
# Epoch 1/1, Loss: 6.7359291687607765, Accuracy: 0.922
# 	Training Client 27/60
# Epoch 1/1, Loss: 6.222724499180913, Accuracy: 0.931
# 	Training Client 28/60
# Epoch 1/1, Loss: 7.275445371866226, Accuracy: 0.933
# 	Training Client 29/60
# Epoch 1/1, Loss: 7.442729689180851, Accuracy: 0.921
# 	Training Client 30/60
# Epoch 1/1, Loss: 6.421743825078011, Accuracy: 0.936
# 	Training Client 31/60
# Epoch 1/1, Loss: 7.16829277575016, Accuracy: 0.936
# 	Training Client 32/60
# Epoch 1/1, Loss: 6.45246753282845, Accuracy: 0.944
# 	Training Client 33/60
# Epoch 1/1, Loss: 7.532169688493013, Accuracy: 0.938
# 	Training Client 34/60
# Epoch 1/1, Loss: 7.601455749943852, Accuracy: 0.927
# 	Training Client 35/60
# Epoch 1/1, Loss: 7.368849646300077, Accuracy: 0.93
# 	Training Client 36/60
# Epoch 1/1, Loss: 5.579421451315284, Accuracy: 0.943
# 	Training Client 37/60
# Epoch 1/1, Loss: 7.479570493102074, Accuracy: 0.932
# 	Training Client 38/60
# Epoch 1/1, Loss: 6.0862405970692635, Accuracy: 0.949
# 	Training Client 39/60
# Epoch 1/1, Loss: 7.1572599448263645, Accuracy: 0.934
# 	Training Client 40/60
# Epoch 1/1, Loss: 6.537221856415272, Accuracy: 0.935
# 	Training Client 41/60
# Epoch 1/1, Loss: 8.289316199719906, Accuracy: 0.92
# 	Training Client 42/60
# Epoch 1/1, Loss: 6.539851747453213, Accuracy: 0.93
# 	Training Client 43/60
# Epoch 1/1, Loss: 7.212056189775467, Accuracy: 0.927
# 	Training Client 44/60
# Epoch 1/1, Loss: 7.630407691001892, Accuracy: 0.922
# 	Training Client 45/60
# Epoch 1/1, Loss: 6.391421850770712, Accuracy: 0.941
# 	Training Client 46/60
# Epoch 1/1, Loss: 8.146764695644379, Accuracy: 0.921
# 	Training Client 47/60
# Epoch 1/1, Loss: 7.584826774895191, Accuracy: 0.934
# 	Training Client 48/60
# Epoch 1/1, Loss: 6.490717336535454, Accuracy: 0.936
# 	Training Client 49/60
# Epoch 1/1, Loss: 7.684645585715771, Accuracy: 0.924
# 	Training Client 50/60
# Epoch 1/1, Loss: 7.8027298003435135, Accuracy: 0.926
# 	Training Client 51/60
# Epoch 1/1, Loss: 6.7276424411684275, Accuracy: 0.933
# 	Training Client 52/60
# Epoch 1/1, Loss: 6.998314369469881, Accuracy: 0.934
# 	Training Client 53/60
# Epoch 1/1, Loss: 6.84547071158886, Accuracy: 0.935
# 	Training Client 54/60
# Epoch 1/1, Loss: 7.188080191612244, Accuracy: 0.927
# 	Training Client 55/60
# Epoch 1/1, Loss: 7.396577015519142, Accuracy: 0.94
# 	Training Client 56/60
# Epoch 1/1, Loss: 7.414220619946718, Accuracy: 0.934
# 	Training Client 57/60
# Epoch 1/1, Loss: 7.3478812500834465, Accuracy: 0.931
# 	Training Client 58/60
# Epoch 1/1, Loss: 7.601806670427322, Accuracy: 0.933
# 	Training Client 59/60
# Epoch 1/1, Loss: 6.203405454754829, Accuracy: 0.939
# 	Training Client 60/60
# Epoch 1/1, Loss: 7.217474486678839, Accuracy: 0.924
# 	Aggregating client models
# Global Epoch 6/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 6.363677324727178, Accuracy: 0.937
# 	Training Client 2/60
# Epoch 1/1, Loss: 6.641729420050979, Accuracy: 0.935
# 	Training Client 3/60
# Epoch 1/1, Loss: 6.432878136634827, Accuracy: 0.938
# 	Training Client 4/60
# Epoch 1/1, Loss: 6.345865083858371, Accuracy: 0.933
# 	Training Client 5/60
# Epoch 1/1, Loss: 5.212507588788867, Accuracy: 0.942
# 	Training Client 6/60
# Epoch 1/1, Loss: 6.178151153028011, Accuracy: 0.942
# 	Training Client 7/60
# Epoch 1/1, Loss: 6.25427483022213, Accuracy: 0.937
# 	Training Client 8/60
# Epoch 1/1, Loss: 7.080744728446007, Accuracy: 0.939
# 	Training Client 9/60
# Epoch 1/1, Loss: 5.7750733233988285, Accuracy: 0.95
# 	Training Client 10/60
# Epoch 1/1, Loss: 5.067729997448623, Accuracy: 0.95
# 	Training Client 11/60
# Epoch 1/1, Loss: 6.80338566750288, Accuracy: 0.933
# 	Training Client 12/60
# Epoch 1/1, Loss: 5.59979185461998, Accuracy: 0.946
# 	Training Client 13/60
# Epoch 1/1, Loss: 5.415284723043442, Accuracy: 0.951
# 	Training Client 14/60
# Epoch 1/1, Loss: 5.230284394696355, Accuracy: 0.953
# 	Training Client 15/60
# Epoch 1/1, Loss: 5.47905997466296, Accuracy: 0.947
# 	Training Client 16/60
# Epoch 1/1, Loss: 5.20901395380497, Accuracy: 0.944
# 	Training Client 17/60
# Epoch 1/1, Loss: 5.199578952044249, Accuracy: 0.947
# 	Training Client 18/60
# Epoch 1/1, Loss: 5.286968495696783, Accuracy: 0.953
# 	Training Client 19/60
# Epoch 1/1, Loss: 4.950258865952492, Accuracy: 0.956
# 	Training Client 20/60
# Epoch 1/1, Loss: 5.3221799954771996, Accuracy: 0.95
# 	Training Client 21/60
# Epoch 1/1, Loss: 6.245202410966158, Accuracy: 0.948
# 	Training Client 22/60
# Epoch 1/1, Loss: 8.525413952767849, Accuracy: 0.926
# 	Training Client 23/60
# Epoch 1/1, Loss: 7.297486549243331, Accuracy: 0.932
# 	Training Client 24/60
# Epoch 1/1, Loss: 5.248422736302018, Accuracy: 0.952
# 	Training Client 25/60
# Epoch 1/1, Loss: 6.264839123934507, Accuracy: 0.941
# 	Training Client 26/60
# Epoch 1/1, Loss: 5.952580569311976, Accuracy: 0.941
# 	Training Client 27/60
# Epoch 1/1, Loss: 5.676608670502901, Accuracy: 0.938
# 	Training Client 28/60
# Epoch 1/1, Loss: 6.4778848849236965, Accuracy: 0.937
# 	Training Client 29/60
# Epoch 1/1, Loss: 5.626107532531023, Accuracy: 0.936
# 	Training Client 30/60
# Epoch 1/1, Loss: 5.581090051680803, Accuracy: 0.946
# 	Training Client 31/60
# Epoch 1/1, Loss: 6.315743260085583, Accuracy: 0.943
# 	Training Client 32/60
# Epoch 1/1, Loss: 6.143984273076057, Accuracy: 0.942
# 	Training Client 33/60
# Epoch 1/1, Loss: 6.953668609261513, Accuracy: 0.945
# 	Training Client 34/60
# Epoch 1/1, Loss: 7.3164161667227745, Accuracy: 0.929
# 	Training Client 35/60
# Epoch 1/1, Loss: 6.309148656204343, Accuracy: 0.945
# 	Training Client 36/60
# Epoch 1/1, Loss: 4.744781915098429, Accuracy: 0.944
# 	Training Client 37/60
# Epoch 1/1, Loss: 5.66261599957943, Accuracy: 0.95
# 	Training Client 38/60
# Epoch 1/1, Loss: 5.144652120769024, Accuracy: 0.955
# 	Training Client 39/60
# Epoch 1/1, Loss: 6.39467203989625, Accuracy: 0.939
# 	Training Client 40/60
# Epoch 1/1, Loss: 6.619809027761221, Accuracy: 0.936
# 	Training Client 41/60
# Epoch 1/1, Loss: 7.010040000081062, Accuracy: 0.931
# 	Training Client 42/60
# Epoch 1/1, Loss: 6.893062941730022, Accuracy: 0.94
# 	Training Client 43/60
# Epoch 1/1, Loss: 6.265800379216671, Accuracy: 0.938
# 	Training Client 44/60
# Epoch 1/1, Loss: 5.654302418231964, Accuracy: 0.941
# 	Training Client 45/60
# Epoch 1/1, Loss: 6.459203574806452, Accuracy: 0.935
# 	Training Client 46/60
# Epoch 1/1, Loss: 6.588772788643837, Accuracy: 0.942
# 	Training Client 47/60
# Epoch 1/1, Loss: 5.5360570177435875, Accuracy: 0.941
# 	Training Client 48/60
# Epoch 1/1, Loss: 5.608031500130892, Accuracy: 0.946
# 	Training Client 49/60
# Epoch 1/1, Loss: 6.622958853840828, Accuracy: 0.938
# 	Training Client 50/60
# Epoch 1/1, Loss: 6.275463643018156, Accuracy: 0.937
# 	Training Client 51/60
# Epoch 1/1, Loss: 5.531059225089848, Accuracy: 0.942
# 	Training Client 52/60
# Epoch 1/1, Loss: 5.557939823716879, Accuracy: 0.946
# 	Training Client 53/60
# Epoch 1/1, Loss: 5.964796636253595, Accuracy: 0.946
# 	Training Client 54/60
# Epoch 1/1, Loss: 6.2830589059740305, Accuracy: 0.942
# 	Training Client 55/60
# Epoch 1/1, Loss: 5.929605823010206, Accuracy: 0.941
# 	Training Client 56/60
# Epoch 1/1, Loss: 6.761337131261826, Accuracy: 0.943
# 	Training Client 57/60
# Epoch 1/1, Loss: 7.183363690972328, Accuracy: 0.937
# 	Training Client 58/60
# Epoch 1/1, Loss: 6.714569892734289, Accuracy: 0.937
# 	Training Client 59/60
# Epoch 1/1, Loss: 5.165963713079691, Accuracy: 0.946
# 	Training Client 60/60
# Epoch 1/1, Loss: 6.37248345836997, Accuracy: 0.937
# ddm:[], eddm:[], hddm[], combined[]
# metrics:{'HDDM': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}, 'DDM': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}, 'EDDM': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}, 'Combined': {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}}
# Global Epoch 6, Client 1: DDM Drift detection is accurate.
# Global Epoch 6, Client 2: DDM Drift detection is accurate.
# Global Epoch 6, Client 3: DDM Drift detection is accurate.
# Global Epoch 6, Client 4: DDM Drift detection is accurate.
# Global Epoch 6, Client 5: DDM Drift detection is accurate.
# Global Epoch 6, Client 6: DDM Drift detection is accurate.
# Global Epoch 6, Client 7: DDM Drift detection is accurate.
# Global Epoch 6, Client 8: DDM Drift detection is accurate.
# Global Epoch 6, Client 9: DDM Drift detection is accurate.
# Global Epoch 6, Client 10: DDM Drift detection is accurate.
# Global Epoch 6, Client 11: DDM Drift detection is accurate.
# Global Epoch 6, Client 12: DDM Drift detection is accurate.
# Global Epoch 6, Client 13: DDM Drift detection is accurate.
# Global Epoch 6, Client 14: DDM Drift detection is accurate.
# Global Epoch 6, Client 15: DDM Drift detection is accurate.
# Global Epoch 6, Client 16: DDM Drift detection is accurate.
# Global Epoch 6, Client 17: DDM Drift detection is accurate.
# Global Epoch 6, Client 18: DDM Drift detection is accurate.
# Global Epoch 6, Client 19: DDM Drift detection is accurate.
# Global Epoch 6, Client 20: DDM Drift detection is accurate.
# Global Epoch 6, Client 21: DDM Drift detection is accurate.
# Global Epoch 6, Client 22: DDM Drift detection is accurate.
# Global Epoch 6, Client 23: DDM Drift detection is accurate.
# Global Epoch 6, Client 24: DDM Drift detection is accurate.
# Global Epoch 6, Client 25: DDM Drift detection is accurate.
# Global Epoch 6, Client 26: DDM Drift detection is accurate.
# Global Epoch 6, Client 27: DDM Drift detection is accurate.
# Global Epoch 6, Client 28: DDM Drift detection is accurate.
# Global Epoch 6, Client 29: DDM Drift detection is accurate.
# Global Epoch 6, Client 30: DDM Drift detection is accurate.
# Global Epoch 6, Client 31: DDM Drift detection is accurate.
# Global Epoch 6, Client 32: DDM Drift detection is accurate.
# Global Epoch 6, Client 33: DDM Drift detection is accurate.
# Global Epoch 6, Client 34: DDM Drift detection is accurate.
# Global Epoch 6, Client 35: DDM Drift detection is accurate.
# Global Epoch 6, Client 36: DDM Drift detection is accurate.
# Global Epoch 6, Client 37: DDM Drift detection is accurate.
# Global Epoch 6, Client 38: DDM Drift detection is accurate.
# Global Epoch 6, Client 39: DDM Drift detection is accurate.
# Global Epoch 6, Client 40: DDM Drift detection is accurate.
# Global Epoch 6, Client 41: DDM Drift detection is accurate.
# Global Epoch 6, Client 42: DDM Drift detection is accurate.
# Global Epoch 6, Client 43: DDM Drift detection is accurate.
# Global Epoch 6, Client 44: DDM Drift detection is accurate.
# Global Epoch 6, Client 45: DDM Drift detection is accurate.
# Global Epoch 6, Client 46: DDM Drift detection is accurate.
# Global Epoch 6, Client 47: DDM Drift detection is accurate.
# Global Epoch 6, Client 48: DDM Drift detection is accurate.
# Global Epoch 6, Client 49: DDM Drift detection is accurate.
# Global Epoch 6, Client 50: DDM Drift detection is accurate.
# Global Epoch 6, Client 51: DDM Drift detection is accurate.
# Global Epoch 6, Client 52: DDM Drift detection is accurate.
# Global Epoch 6, Client 53: DDM Drift detection is accurate.
# Global Epoch 6, Client 54: DDM Drift detection is accurate.
# Global Epoch 6, Client 55: DDM Drift detection is accurate.
# Global Epoch 6, Client 56: DDM Drift detection is accurate.
# Global Epoch 6, Client 57: DDM Drift detection is accurate.
# Global Epoch 6, Client 58: DDM Drift detection is accurate.
# Global Epoch 6, Client 59: DDM Drift detection is accurate.
# Global Epoch 6, Client 60: DDM Drift detection is accurate.
# Global Epoch 6, Client 1: EDDM Drift detection is accurate.
# Global Epoch 6, Client 2: EDDM Drift detection is accurate.
# Global Epoch 6, Client 3: EDDM Drift detection is accurate.
# Global Epoch 6, Client 4: EDDM Drift detection is accurate.
# Global Epoch 6, Client 5: EDDM Drift detection is accurate.
# Global Epoch 6, Client 6: EDDM Drift detection is accurate.
# Global Epoch 6, Client 7: EDDM Drift detection is accurate.
# Global Epoch 6, Client 8: EDDM Drift detection is accurate.
# Global Epoch 6, Client 9: EDDM Drift detection is accurate.
# Global Epoch 6, Client 10: EDDM Drift detection is accurate.
# Global Epoch 6, Client 11: EDDM Drift detection is accurate.
# Global Epoch 6, Client 12: EDDM Drift detection is accurate.
# Global Epoch 6, Client 13: EDDM Drift detection is accurate.
# Global Epoch 6, Client 14: EDDM Drift detection is accurate.
# Global Epoch 6, Client 15: EDDM Drift detection is accurate.
# Global Epoch 6, Client 16: EDDM Drift detection is accurate.
# Global Epoch 6, Client 17: EDDM Drift detection is accurate.
# Global Epoch 6, Client 18: EDDM Drift detection is accurate.
# Global Epoch 6, Client 19: EDDM Drift detection is accurate.
# Global Epoch 6, Client 20: EDDM Drift detection is accurate.
# Global Epoch 6, Client 21: EDDM Drift detection is accurate.
# Global Epoch 6, Client 22: EDDM Drift detection is accurate.
# Global Epoch 6, Client 23: EDDM Drift detection is accurate.
# Global Epoch 6, Client 24: EDDM Drift detection is accurate.
# Global Epoch 6, Client 25: EDDM Drift detection is accurate.
# Global Epoch 6, Client 26: EDDM Drift detection is accurate.
# Global Epoch 6, Client 27: EDDM Drift detection is accurate.
# Global Epoch 6, Client 28: EDDM Drift detection is accurate.
# Global Epoch 6, Client 29: EDDM Drift detection is accurate.
# Global Epoch 6, Client 30: EDDM Drift detection is accurate.
# Global Epoch 6, Client 31: EDDM Drift detection is accurate.
# Global Epoch 6, Client 32: EDDM Drift detection is accurate.
# Global Epoch 6, Client 33: EDDM Drift detection is accurate.
# Global Epoch 6, Client 34: EDDM Drift detection is accurate.
# Global Epoch 6, Client 35: EDDM Drift detection is accurate.
# Global Epoch 6, Client 36: EDDM Drift detection is accurate.
# Global Epoch 6, Client 37: EDDM Drift detection is accurate.
# Global Epoch 6, Client 38: EDDM Drift detection is accurate.
# Global Epoch 6, Client 39: EDDM Drift detection is accurate.
# Global Epoch 6, Client 40: EDDM Drift detection is accurate.
# Global Epoch 6, Client 41: EDDM Drift detection is accurate.
# Global Epoch 6, Client 42: EDDM Drift detection is accurate.
# Global Epoch 6, Client 43: EDDM Drift detection is accurate.
# Global Epoch 6, Client 44: EDDM Drift detection is accurate.
# Global Epoch 6, Client 45: EDDM Drift detection is accurate.
# Global Epoch 6, Client 46: EDDM Drift detection is accurate.
# Global Epoch 6, Client 47: EDDM Drift detection is accurate.
# Global Epoch 6, Client 48: EDDM Drift detection is accurate.
# Global Epoch 6, Client 49: EDDM Drift detection is accurate.
# Global Epoch 6, Client 50: EDDM Drift detection is accurate.
# Global Epoch 6, Client 51: EDDM Drift detection is accurate.
# Global Epoch 6, Client 52: EDDM Drift detection is accurate.
# Global Epoch 6, Client 53: EDDM Drift detection is accurate.
# Global Epoch 6, Client 54: EDDM Drift detection is accurate.
# Global Epoch 6, Client 55: EDDM Drift detection is accurate.
# Global Epoch 6, Client 56: EDDM Drift detection is accurate.
# Global Epoch 6, Client 57: EDDM Drift detection is accurate.
# Global Epoch 6, Client 58: EDDM Drift detection is accurate.
# Global Epoch 6, Client 59: EDDM Drift detection is accurate.
# Global Epoch 6, Client 60: EDDM Drift detection is accurate.
# Global Epoch 6, Client 1: HDDM Drift detection is accurate.
# Global Epoch 6, Client 2: HDDM Drift detection is accurate.
# Global Epoch 6, Client 3: HDDM Drift detection is accurate.
# Global Epoch 6, Client 4: HDDM Drift detection is accurate.
# Global Epoch 6, Client 5: HDDM Drift detection is accurate.
# Global Epoch 6, Client 6: HDDM Drift detection is accurate.
# Global Epoch 6, Client 7: HDDM Drift detection is accurate.
# Global Epoch 6, Client 8: HDDM Drift detection is accurate.
# Global Epoch 6, Client 9: HDDM Drift detection is accurate.
# Global Epoch 6, Client 10: HDDM Drift detection is accurate.
# Global Epoch 6, Client 11: HDDM Drift detection is accurate.
# Global Epoch 6, Client 12: HDDM Drift detection is accurate.
# Global Epoch 6, Client 13: HDDM Drift detection is accurate.
# Global Epoch 6, Client 14: HDDM Drift detection is accurate.
# Global Epoch 6, Client 15: HDDM Drift detection is accurate.
# Global Epoch 6, Client 16: HDDM Drift detection is accurate.
# Global Epoch 6, Client 17: HDDM Drift detection is accurate.
# Global Epoch 6, Client 18: HDDM Drift detection is accurate.
# Global Epoch 6, Client 19: HDDM Drift detection is accurate.
# Global Epoch 6, Client 20: HDDM Drift detection is accurate.
# Global Epoch 6, Client 21: HDDM Drift detection is accurate.
# Global Epoch 6, Client 22: HDDM Drift detection is accurate.
# Global Epoch 6, Client 23: HDDM Drift detection is accurate.
# Global Epoch 6, Client 24: HDDM Drift detection is accurate.
# Global Epoch 6, Client 25: HDDM Drift detection is accurate.
# Global Epoch 6, Client 26: HDDM Drift detection is accurate.
# Global Epoch 6, Client 27: HDDM Drift detection is accurate.
# Global Epoch 6, Client 28: HDDM Drift detection is accurate.
# Global Epoch 6, Client 29: HDDM Drift detection is accurate.
# Global Epoch 6, Client 30: HDDM Drift detection is accurate.
# Global Epoch 6, Client 31: HDDM Drift detection is accurate.
# Global Epoch 6, Client 32: HDDM Drift detection is accurate.
# Global Epoch 6, Client 33: HDDM Drift detection is accurate.
# Global Epoch 6, Client 34: HDDM Drift detection is accurate.
# Global Epoch 6, Client 35: HDDM Drift detection is accurate.
# Global Epoch 6, Client 36: HDDM Drift detection is accurate.
# Global Epoch 6, Client 37: HDDM Drift detection is accurate.
# Global Epoch 6, Client 38: HDDM Drift detection is accurate.
# Global Epoch 6, Client 39: HDDM Drift detection is accurate.
# Global Epoch 6, Client 40: HDDM Drift detection is accurate.
# Global Epoch 6, Client 41: HDDM Drift detection is accurate.
# Global Epoch 6, Client 42: HDDM Drift detection is accurate.
# Global Epoch 6, Client 43: HDDM Drift detection is accurate.
# Global Epoch 6, Client 44: HDDM Drift detection is accurate.
# Global Epoch 6, Client 45: HDDM Drift detection is accurate.
# Global Epoch 6, Client 46: HDDM Drift detection is accurate.
# Global Epoch 6, Client 47: HDDM Drift detection is accurate.
# Global Epoch 6, Client 48: HDDM Drift detection is accurate.
# Global Epoch 6, Client 49: HDDM Drift detection is accurate.
# Global Epoch 6, Client 50: HDDM Drift detection is accurate.
# Global Epoch 6, Client 51: HDDM Drift detection is accurate.
# Global Epoch 6, Client 52: HDDM Drift detection is accurate.
# Global Epoch 6, Client 53: HDDM Drift detection is accurate.
# Global Epoch 6, Client 54: HDDM Drift detection is accurate.
# Global Epoch 6, Client 55: HDDM Drift detection is accurate.
# Global Epoch 6, Client 56: HDDM Drift detection is accurate.
# Global Epoch 6, Client 57: HDDM Drift detection is accurate.
# Global Epoch 6, Client 58: HDDM Drift detection is accurate.
# Global Epoch 6, Client 59: HDDM Drift detection is accurate.
# Global Epoch 6, Client 60: HDDM Drift detection is accurate.
# Global Epoch 6, Client 1: Combined Drift detection is accurate.
# Global Epoch 6, Client 2: Combined Drift detection is accurate.
# Global Epoch 6, Client 3: Combined Drift detection is accurate.
# Global Epoch 6, Client 4: Combined Drift detection is accurate.
# Global Epoch 6, Client 5: Combined Drift detection is accurate.
# Global Epoch 6, Client 6: Combined Drift detection is accurate.
# Global Epoch 6, Client 7: Combined Drift detection is accurate.
# Global Epoch 6, Client 8: Combined Drift detection is accurate.
# Global Epoch 6, Client 9: Combined Drift detection is accurate.
# Global Epoch 6, Client 10: Combined Drift detection is accurate.
# Global Epoch 6, Client 11: Combined Drift detection is accurate.
# Global Epoch 6, Client 12: Combined Drift detection is accurate.
# Global Epoch 6, Client 13: Combined Drift detection is accurate.
# Global Epoch 6, Client 14: Combined Drift detection is accurate.
# Global Epoch 6, Client 15: Combined Drift detection is accurate.
# Global Epoch 6, Client 16: Combined Drift detection is accurate.
# Global Epoch 6, Client 17: Combined Drift detection is accurate.
# Global Epoch 6, Client 18: Combined Drift detection is accurate.
# Global Epoch 6, Client 19: Combined Drift detection is accurate.
# Global Epoch 6, Client 20: Combined Drift detection is accurate.
# Global Epoch 6, Client 21: Combined Drift detection is accurate.
# Global Epoch 6, Client 22: Combined Drift detection is accurate.
# Global Epoch 6, Client 23: Combined Drift detection is accurate.
# Global Epoch 6, Client 24: Combined Drift detection is accurate.
# Global Epoch 6, Client 25: Combined Drift detection is accurate.
# Global Epoch 6, Client 26: Combined Drift detection is accurate.
# Global Epoch 6, Client 27: Combined Drift detection is accurate.
# Global Epoch 6, Client 28: Combined Drift detection is accurate.
# Global Epoch 6, Client 29: Combined Drift detection is accurate.
# Global Epoch 6, Client 30: Combined Drift detection is accurate.
# Global Epoch 6, Client 31: Combined Drift detection is accurate.
# Global Epoch 6, Client 32: Combined Drift detection is accurate.
# Global Epoch 6, Client 33: Combined Drift detection is accurate.
# Global Epoch 6, Client 34: Combined Drift detection is accurate.
# Global Epoch 6, Client 35: Combined Drift detection is accurate.
# Global Epoch 6, Client 36: Combined Drift detection is accurate.
# Global Epoch 6, Client 37: Combined Drift detection is accurate.
# Global Epoch 6, Client 38: Combined Drift detection is accurate.
# Global Epoch 6, Client 39: Combined Drift detection is accurate.
# Global Epoch 6, Client 40: Combined Drift detection is accurate.
# Global Epoch 6, Client 41: Combined Drift detection is accurate.
# Global Epoch 6, Client 42: Combined Drift detection is accurate.
# Global Epoch 6, Client 43: Combined Drift detection is accurate.
# Global Epoch 6, Client 44: Combined Drift detection is accurate.
# Global Epoch 6, Client 45: Combined Drift detection is accurate.
# Global Epoch 6, Client 46: Combined Drift detection is accurate.
# Global Epoch 6, Client 47: Combined Drift detection is accurate.
# Global Epoch 6, Client 48: Combined Drift detection is accurate.
# Global Epoch 6, Client 49: Combined Drift detection is accurate.
# Global Epoch 6, Client 50: Combined Drift detection is accurate.
# Global Epoch 6, Client 51: Combined Drift detection is accurate.
# Global Epoch 6, Client 52: Combined Drift detection is accurate.
# Global Epoch 6, Client 53: Combined Drift detection is accurate.
# Global Epoch 6, Client 54: Combined Drift detection is accurate.
# Global Epoch 6, Client 55: Combined Drift detection is accurate.
# Global Epoch 6, Client 56: Combined Drift detection is accurate.
# Global Epoch 6, Client 57: Combined Drift detection is accurate.
# Global Epoch 6, Client 58: Combined Drift detection is accurate.
# Global Epoch 6, Client 59: Combined Drift detection is accurate.
# Global Epoch 6, Client 60: Combined Drift detection is accurate.
# 	Aggregating client models
# Global Epoch 7/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 5.4118113331496716, Accuracy: 0.944
# 	Training Client 2/60
# Epoch 1/1, Loss: 6.3397312350571156, Accuracy: 0.938
# 	Training Client 3/60
# Epoch 1/1, Loss: 5.946367513388395, Accuracy: 0.94
# 	Training Client 4/60
# Epoch 1/1, Loss: 5.481394208967686, Accuracy: 0.948
# 	Training Client 5/60
# Epoch 1/1, Loss: 4.271591464057565, Accuracy: 0.961
# 	Training Client 6/60
# Epoch 1/1, Loss: 6.040884837508202, Accuracy: 0.941
# 	Training Client 7/60
# Epoch 1/1, Loss: 4.459015596657991, Accuracy: 0.959
# 	Training Client 8/60
# Epoch 1/1, Loss: 5.532014515949413, Accuracy: 0.945
# 	Training Client 9/60
# Epoch 1/1, Loss: 4.623525104485452, Accuracy: 0.958
# 	Training Client 10/60
# Epoch 1/1, Loss: 4.101422791369259, Accuracy: 0.958
# 	Training Client 11/60
# Epoch 1/1, Loss: 4.936446614563465, Accuracy: 0.955
# 	Training Client 12/60
# Epoch 1/1, Loss: 5.341717334464192, Accuracy: 0.95
# 	Training Client 13/60
# Epoch 1/1, Loss: 5.135091163218021, Accuracy: 0.949
# 	Training Client 14/60
# Epoch 1/1, Loss: 4.419642163440585, Accuracy: 0.955
# 	Training Client 15/60
# Epoch 1/1, Loss: 4.73590750573203, Accuracy: 0.956
# 	Training Client 16/60
# Epoch 1/1, Loss: 4.7618870455771685, Accuracy: 0.961
# 	Training Client 17/60
# Epoch 1/1, Loss: 5.10338533250615, Accuracy: 0.957
# 	Training Client 18/60
# Epoch 1/1, Loss: 4.991641831584275, Accuracy: 0.954
# 	Training Client 19/60
# Epoch 1/1, Loss: 4.672539414837956, Accuracy: 0.955
# 	Training Client 20/60
# Epoch 1/1, Loss: 5.122693564742804, Accuracy: 0.945
# 	Training Client 21/60
# Epoch 1/1, Loss: 5.965230710804462, Accuracy: 0.943
# 	Training Client 22/60
# Epoch 1/1, Loss: 6.787252351641655, Accuracy: 0.943
# 	Training Client 23/60
# Epoch 1/1, Loss: 5.4998835902661085, Accuracy: 0.94
# 	Training Client 24/60
# Epoch 1/1, Loss: 4.284177593886852, Accuracy: 0.955
# 	Training Client 25/60
# Epoch 1/1, Loss: 5.067853845655918, Accuracy: 0.948
# 	Training Client 26/60
# Epoch 1/1, Loss: 5.603482914157212, Accuracy: 0.946
# 	Training Client 27/60
# Epoch 1/1, Loss: 5.453316053375602, Accuracy: 0.953
# 	Training Client 28/60
# Epoch 1/1, Loss: 5.546990990638733, Accuracy: 0.95
# 	Training Client 29/60
# Epoch 1/1, Loss: 5.885101541876793, Accuracy: 0.943
# 	Training Client 30/60
# Epoch 1/1, Loss: 5.2298514526337385, Accuracy: 0.942
# 	Training Client 31/60
# Epoch 1/1, Loss: 5.360101862810552, Accuracy: 0.95
# 	Training Client 32/60
# Epoch 1/1, Loss: 5.636919759213924, Accuracy: 0.949
# 	Training Client 33/60
# Epoch 1/1, Loss: 5.502225615084171, Accuracy: 0.953
# 	Training Client 34/60
# Epoch 1/1, Loss: 5.844246685504913, Accuracy: 0.945
# 	Training Client 35/60
# Epoch 1/1, Loss: 5.685020539909601, Accuracy: 0.952
# 	Training Client 36/60
# Epoch 1/1, Loss: 4.3543835915625095, Accuracy: 0.958
# 	Training Client 37/60
# Epoch 1/1, Loss: 5.448723245412111, Accuracy: 0.954
# 	Training Client 38/60
# Epoch 1/1, Loss: 4.07818637508899, Accuracy: 0.97
# 	Training Client 39/60
# Epoch 1/1, Loss: 6.242428825236857, Accuracy: 0.946
# 	Training Client 40/60
# Epoch 1/1, Loss: 5.9411020539700985, Accuracy: 0.939
# 	Training Client 41/60
# Epoch 1/1, Loss: 5.044107690453529, Accuracy: 0.947
# 	Training Client 42/60
# Epoch 1/1, Loss: 5.607373189181089, Accuracy: 0.947
# 	Training Client 43/60
# Epoch 1/1, Loss: 5.681517055258155, Accuracy: 0.942
# 	Training Client 44/60
# Epoch 1/1, Loss: 5.677078828215599, Accuracy: 0.943
# 	Training Client 45/60
# Epoch 1/1, Loss: 5.293145316652954, Accuracy: 0.946
# 	Training Client 46/60
# Epoch 1/1, Loss: 5.36605834774673, Accuracy: 0.952
# 	Training Client 47/60
# Epoch 1/1, Loss: 5.93381910584867, Accuracy: 0.95
# 	Training Client 48/60
# Epoch 1/1, Loss: 3.749983225017786, Accuracy: 0.963
# 	Training Client 49/60
# Epoch 1/1, Loss: 6.572003200650215, Accuracy: 0.942
# 	Training Client 50/60
# Epoch 1/1, Loss: 5.5630995742976665, Accuracy: 0.946
# 	Training Client 51/60
# ...
# Epoch 1/1, Loss: 8.866720452904701, Accuracy: 0.916
# 	Training Client 34/60
# Epoch 1/1, Loss: 3.50537560461089, Accuracy: 0.966
# 	Training Client 35/60
# Epoch 1/1, Loss: 3.6235296016093343, Accuracy: 0.977
# 	Training Client 36/60
# Epoch 1/1, Loss: 6.487525066360831, Accuracy: 0.927
# 	Training Client 37/60
# Epoch 1/1, Loss: 2.820886736502871, Accuracy: 0.966
# 	Training Client 38/60
# Epoch 1/1, Loss: 8.960377763956785, Accuracy: 0.919
# 	Training Client 39/60
# Epoch 1/1, Loss: 8.849879644811153, Accuracy: 0.921
# 	Training Client 40/60
# Epoch 1/1, Loss: 4.047520293854177, Accuracy: 0.96
# 	Training Client 41/60
# Epoch 1/1, Loss: 2.7222740914439783, Accuracy: 0.974
# 	Training Client 42/60
# Epoch 1/1, Loss: 9.029330346733332, Accuracy: 0.919
# 	Training Client 43/60
# Epoch 1/1, Loss: 8.566323302686214, Accuracy: 0.914
# 	Training Client 44/60
# Epoch 1/1, Loss: 8.064297396689653, Accuracy: 0.923
# 	Training Client 45/60
# Epoch 1/1, Loss: 2.2931878455128754, Accuracy: 0.976
# 	Training Client 46/60
# Epoch 1/1, Loss: 2.7340084967727307, Accuracy: 0.974
# 	Training Client 47/60
# Epoch 1/1, Loss: 8.029552850872278, Accuracy: 0.929
# 	Training Client 48/60
# Epoch 1/1, Loss: 8.368399493396282, Accuracy: 0.922
# 	Training Client 49/60
# Epoch 1/1, Loss: 8.6871757209301, Accuracy: 0.911
# 	Training Client 50/60
# Epoch 1/1, Loss: 3.1287989309057593, Accuracy: 0.971
# 	Training Client 51/60
# Epoch 1/1, Loss: 8.435512136667967, Accuracy: 0.922
# 	Training Client 52/60
# Epoch 1/1, Loss: 6.933372888714075, Accuracy: 0.937
# 	Training Client 53/60
# Epoch 1/1, Loss: 3.2103632783982903, Accuracy: 0.968
# 	Training Client 54/60
# Epoch 1/1, Loss: 3.918568435125053, Accuracy: 0.974
# 	Training Client 55/60
# Epoch 1/1, Loss: 3.5744480484863743, Accuracy: 0.966
# 	Training Client 56/60
# Epoch 1/1, Loss: 3.4657387044280767, Accuracy: 0.971
# 	Training Client 57/60
# Epoch 1/1, Loss: 10.982704058289528, Accuracy: 0.9
# 	Training Client 58/60
# Epoch 1/1, Loss: 7.280735783278942, Accuracy: 0.926
# 	Training Client 59/60
# Epoch 1/1, Loss: 8.91890187188983, Accuracy: 0.919
# 	Training Client 60/60
# Epoch 1/1, Loss: 3.0328191783846705, Accuracy: 0.972
# 	Aggregating client models
# Global Epoch 39/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 3.0026087288642884, Accuracy: 0.978
# 	Training Client 2/60
# Epoch 1/1, Loss: 9.104331500828266, Accuracy: 0.914
# 	Training Client 3/60
# Epoch 1/1, Loss: 9.970721393823624, Accuracy: 0.919
# 	Training Client 4/60
# Epoch 1/1, Loss: 2.495635743951425, Accuracy: 0.975
# 	Training Client 5/60
# Epoch 1/1, Loss: 7.712926680222154, Accuracy: 0.923
# 	Training Client 6/60
# Epoch 1/1, Loss: 8.20562956109643, Accuracy: 0.919
# 	Training Client 7/60
# Epoch 1/1, Loss: 7.967539474368095, Accuracy: 0.925
# 	Training Client 8/60
# Epoch 1/1, Loss: 2.6832784184080083, Accuracy: 0.978
# 	Training Client 9/60
# Epoch 1/1, Loss: 2.6241316467057914, Accuracy: 0.975
# 	Training Client 10/60
# Epoch 1/1, Loss: 7.616471827030182, Accuracy: 0.92
# 	Training Client 11/60
# Epoch 1/1, Loss: 8.323395259678364, Accuracy: 0.915
# 	Training Client 12/60
# Epoch 1/1, Loss: 2.759670822531916, Accuracy: 0.974
# 	Training Client 13/60
# Epoch 1/1, Loss: 2.8564567968714982, Accuracy: 0.974
# 	Training Client 14/60
# Epoch 1/1, Loss: 7.058032244443893, Accuracy: 0.935
# 	Training Client 15/60
# Epoch 1/1, Loss: 2.7117122560739517, Accuracy: 0.976
# 	Training Client 16/60
# Epoch 1/1, Loss: 7.728617664426565, Accuracy: 0.917
# 	Training Client 17/60
# Epoch 1/1, Loss: 2.287373050523456, Accuracy: 0.971
# 	Training Client 18/60
# Epoch 1/1, Loss: 2.6701915342127904, Accuracy: 0.978
# 	Training Client 19/60
# Epoch 1/1, Loss: 2.6654259994611493, Accuracy: 0.971
# 	Training Client 20/60
# Epoch 1/1, Loss: 2.9288628050126135, Accuracy: 0.975
# 	Training Client 21/60
# Epoch 1/1, Loss: 8.742745034396648, Accuracy: 0.913
# 	Training Client 22/60
# Epoch 1/1, Loss: 8.113423403352499, Accuracy: 0.92
# 	Training Client 23/60
# Epoch 1/1, Loss: 3.1128767458721995, Accuracy: 0.972
# 	Training Client 24/60
# Epoch 1/1, Loss: 8.018446322530508, Accuracy: 0.917
# 	Training Client 25/60
# Epoch 1/1, Loss: 8.9320672377944, Accuracy: 0.91
# 	Training Client 26/60
# Epoch 1/1, Loss: 2.987622054060921, Accuracy: 0.973
# 	Training Client 27/60
# Epoch 1/1, Loss: 3.3172686125617474, Accuracy: 0.97
# 	Training Client 28/60
# Epoch 1/1, Loss: 2.8204865122097544, Accuracy: 0.976
# 	Training Client 29/60
# Epoch 1/1, Loss: 9.169565577059984, Accuracy: 0.919
# 	Training Client 30/60
# Epoch 1/1, Loss: 2.727211015764624, Accuracy: 0.973
# 	Training Client 31/60
# Epoch 1/1, Loss: 3.3698948682285845, Accuracy: 0.974
# 	Training Client 32/60
# Epoch 1/1, Loss: 9.780576944351196, Accuracy: 0.913
# 	Training Client 33/60
# Epoch 1/1, Loss: 8.57233502715826, Accuracy: 0.924
# 	Training Client 34/60
# Epoch 1/1, Loss: 3.9935214977595024, Accuracy: 0.962
# 	Training Client 35/60
# Epoch 1/1, Loss: 3.212772368453443, Accuracy: 0.967
# 	Training Client 36/60
# Epoch 1/1, Loss: 6.22695979103446, Accuracy: 0.934
# 	Training Client 37/60
# Epoch 1/1, Loss: 2.8767780009366106, Accuracy: 0.978
# 	Training Client 38/60
# Epoch 1/1, Loss: 9.465868826955557, Accuracy: 0.923
# 	Training Client 39/60
# Epoch 1/1, Loss: 7.950107257813215, Accuracy: 0.925
# 	Training Client 40/60
# Epoch 1/1, Loss: 3.2620355342514813, Accuracy: 0.974
# 	Training Client 41/60
# Epoch 1/1, Loss: 2.562914534821175, Accuracy: 0.971
# 	Training Client 42/60
# Epoch 1/1, Loss: 8.10719233006239, Accuracy: 0.929
# 	Training Client 43/60
# Epoch 1/1, Loss: 7.582840399816632, Accuracy: 0.914
# 	Training Client 44/60
# Epoch 1/1, Loss: 7.734244458377361, Accuracy: 0.924
# 	Training Client 45/60
# Epoch 1/1, Loss: 3.0039774211181793, Accuracy: 0.975
# 	Training Client 46/60
# Epoch 1/1, Loss: 2.5272581721656024, Accuracy: 0.977
# 	Training Client 47/60
# Epoch 1/1, Loss: 7.900318086147308, Accuracy: 0.921
# 	Training Client 48/60
# Epoch 1/1, Loss: 7.780580025166273, Accuracy: 0.93
# 	Training Client 49/60
# Epoch 1/1, Loss: 8.00631758198142, Accuracy: 0.923
# 	Training Client 50/60
# Epoch 1/1, Loss: 2.9209380766842514, Accuracy: 0.97
# 	Training Client 51/60
# Epoch 1/1, Loss: 8.440993819385767, Accuracy: 0.918
# 	Training Client 52/60
# Epoch 1/1, Loss: 7.071398597210646, Accuracy: 0.924
# 	Training Client 53/60
# Epoch 1/1, Loss: 3.3819976993836462, Accuracy: 0.964
# 	Training Client 54/60
# Epoch 1/1, Loss: 3.4050569254977745, Accuracy: 0.973
# 	Training Client 55/60
# Epoch 1/1, Loss: 2.9941628478700295, Accuracy: 0.967
# 	Training Client 56/60
# Epoch 1/1, Loss: 4.069069337681867, Accuracy: 0.967
# 	Training Client 57/60
# Epoch 1/1, Loss: 9.6219078078866, Accuracy: 0.918
# 	Training Client 58/60
# Epoch 1/1, Loss: 6.889845795929432, Accuracy: 0.926
# 	Training Client 59/60
# Epoch 1/1, Loss: 8.598328068852425, Accuracy: 0.915
# 	Training Client 60/60
# Epoch 1/1, Loss: 3.0647940768976696, Accuracy: 0.971
# 	Aggregating client models
# Global Epoch 40/40
# 	Training Client 1/60
# Epoch 1/1, Loss: 3.025587049953174, Accuracy: 0.97
# 	Training Client 2/60
# Epoch 1/1, Loss: 8.0648148432374, Accuracy: 0.922
# 	Training Client 3/60
# Epoch 1/1, Loss: 9.606871537864208, Accuracy: 0.919
# 	Training Client 4/60
# Epoch 1/1, Loss: 2.7388364527141675, Accuracy: 0.97
# 	Training Client 5/60
# Epoch 1/1, Loss: 7.379400637000799, Accuracy: 0.931
# 	Training Client 6/60
# Epoch 1/1, Loss: 8.354996092617512, Accuracy: 0.928
# 	Training Client 7/60
# Epoch 1/1, Loss: 8.02071713656187, Accuracy: 0.921
# 	Training Client 8/60
# Epoch 1/1, Loss: 2.798652859404683, Accuracy: 0.976
# 	Training Client 9/60
# Epoch 1/1, Loss: 2.307138956549352, Accuracy: 0.979
# 	Training Client 10/60
# Epoch 1/1, Loss: 7.658557303249836, Accuracy: 0.917
# 	Training Client 11/60
# Epoch 1/1, Loss: 8.4611481949687, Accuracy: 0.917
# 	Training Client 12/60
# Epoch 1/1, Loss: 2.1952285586121434, Accuracy: 0.974
# 	Training Client 13/60
# Epoch 1/1, Loss: 2.8834000186470803, Accuracy: 0.976
# 	Training Client 14/60
# Epoch 1/1, Loss: 7.058488745242357, Accuracy: 0.932
# 	Training Client 15/60
# Epoch 1/1, Loss: 2.928933149552904, Accuracy: 0.978
# 	Training Client 16/60
# Epoch 1/1, Loss: 7.9814571142196655, Accuracy: 0.92
# 	Training Client 17/60
# Epoch 1/1, Loss: 2.20307528237754, Accuracy: 0.979
# 	Training Client 18/60
# Epoch 1/1, Loss: 2.9918288990156725, Accuracy: 0.968
# 	Training Client 19/60
# Epoch 1/1, Loss: 2.9745558493304998, Accuracy: 0.975
# 	Training Client 20/60
# Epoch 1/1, Loss: 3.097448308893945, Accuracy: 0.975
# 	Training Client 21/60
# Epoch 1/1, Loss: 8.019549004733562, Accuracy: 0.925
# 	Training Client 22/60
# Epoch 1/1, Loss: 7.8409507647156715, Accuracy: 0.926
# 	Training Client 23/60
# Epoch 1/1, Loss: 3.5725585124455392, Accuracy: 0.97
# 	Training Client 24/60
# Epoch 1/1, Loss: 7.675344817340374, Accuracy: 0.924
# 	Training Client 25/60
# Epoch 1/1, Loss: 9.041503503918648, Accuracy: 0.911
# 	Training Client 26/60
# Epoch 1/1, Loss: 2.513547499609558, Accuracy: 0.974
# 	Training Client 27/60
# Epoch 1/1, Loss: 2.718725152197294, Accuracy: 0.975
# 	Training Client 28/60
# Epoch 1/1, Loss: 2.7754062947351485, Accuracy: 0.971
# 	Training Client 29/60
# Epoch 1/1, Loss: 9.039891354739666, Accuracy: 0.914
# 	Training Client 30/60
# Epoch 1/1, Loss: 3.228685550042428, Accuracy: 0.968
# 	Training Client 31/60
# Epoch 1/1, Loss: 3.188680691702757, Accuracy: 0.971
# 	Training Client 32/60
# Epoch 1/1, Loss: 8.54960148781538, Accuracy: 0.918
# 	Training Client 33/60
# Epoch 1/1, Loss: 8.328237526118755, Accuracy: 0.928
# 	Training Client 34/60
# Epoch 1/1, Loss: 3.5084563333075494, Accuracy: 0.968
# 	Training Client 35/60
# Epoch 1/1, Loss: 3.1021190802566707, Accuracy: 0.973
# 	Training Client 36/60
# Epoch 1/1, Loss: 6.274071093648672, Accuracy: 0.937
# 	Training Client 37/60
# Epoch 1/1, Loss: 3.1348660476505756, Accuracy: 0.973
# 	Training Client 38/60
# Epoch 1/1, Loss: 8.585184767842293, Accuracy: 0.915
# 	Training Client 39/60
# Epoch 1/1, Loss: 7.839925363659859, Accuracy: 0.929
# 	Training Client 40/60
# Epoch 1/1, Loss: 2.8514475929550827, Accuracy: 0.973
# 	Training Client 41/60
# Epoch 1/1, Loss: 2.1153576044016518, Accuracy: 0.979
# 	Training Client 42/60
# Epoch 1/1, Loss: 7.915983011946082, Accuracy: 0.923
# 	Training Client 43/60
# Epoch 1/1, Loss: 7.8000877015292645, Accuracy: 0.915
# 	Training Client 44/60
# Epoch 1/1, Loss: 7.800097212195396, Accuracy: 0.932
# 	Training Client 45/60
# Epoch 1/1, Loss: 2.7693710092789843, Accuracy: 0.975
# 	Training Client 46/60
# Epoch 1/1, Loss: 2.4686619818094186, Accuracy: 0.978
# 	Training Client 47/60
# Epoch 1/1, Loss: 7.785742204636335, Accuracy: 0.921
# 	Training Client 48/60
# Epoch 1/1, Loss: 7.283445090055466, Accuracy: 0.938
# 	Training Client 49/60
# Epoch 1/1, Loss: 8.588767915964127, Accuracy: 0.918
# 	Training Client 50/60
# Epoch 1/1, Loss: 3.3446915255117347, Accuracy: 0.97
# 	Training Client 51/60
# Epoch 1/1, Loss: 8.418081764131784, Accuracy: 0.927
# 	Training Client 52/60
# Epoch 1/1, Loss: 6.4410898350179195, Accuracy: 0.938
# 	Training Client 53/60
# Epoch 1/1, Loss: 2.7829156570369378, Accuracy: 0.973
# 	Training Client 54/60
# Epoch 1/1, Loss: 3.412553662317805, Accuracy: 0.974
# 	Training Client 55/60
# Epoch 1/1, Loss: 3.2394453612796497, Accuracy: 0.964
# 	Training Client 56/60
# Epoch 1/1, Loss: 3.944084454094991, Accuracy: 0.971
# 	Training Client 57/60
# Epoch 1/1, Loss: 9.176881182938814, Accuracy: 0.917
# 	Training Client 58/60
# Epoch 1/1, Loss: 6.1217574714683, Accuracy: 0.933
# 	Training Client 59/60
# Epoch 1/1, Loss: 7.7629717122763395, Accuracy: 0.926
# 	Training Client 60/60
# Epoch 1/1, Loss: 2.669251317558519, Accuracy: 0.972
# 	Aggregating client models
# Testing Client 1/60
# 	Accuracy for Client 1/60: 0.9609
# Testing Client 2/60
# 	Accuracy for Client 2/60: 0.9609
# Testing Client 3/60
# 	Accuracy for Client 3/60: 0.9609
# Testing Client 4/60
# 	Accuracy for Client 4/60: 0.9609
# Testing Client 5/60
# 	Accuracy for Client 5/60: 0.9609
# Testing Client 6/60
# 	Accuracy for Client 6/60: 0.9609
# Testing Client 7/60
# 	Accuracy for Client 7/60: 0.9609
# Testing Client 8/60
# 	Accuracy for Client 8/60: 0.9609
# Testing Client 9/60
# 	Accuracy for Client 9/60: 0.9609
# Testing Client 10/60
# 	Accuracy for Client 10/60: 0.9609
# Testing Client 11/60
# 	Accuracy for Client 11/60: 0.9609
# Testing Client 12/60
# 	Accuracy for Client 12/60: 0.9609
# Testing Client 13/60
# 	Accuracy for Client 13/60: 0.9609
# Testing Client 14/60
# 	Accuracy for Client 14/60: 0.9609
# Testing Client 15/60
# 	Accuracy for Client 15/60: 0.9609
# Testing Client 16/60
# 	Accuracy for Client 16/60: 0.9609
# Testing Client 17/60
# 	Accuracy for Client 17/60: 0.9609
# Testing Client 18/60
# 	Accuracy for Client 18/60: 0.9609
# Testing Client 19/60
# 	Accuracy for Client 19/60: 0.9609
# Testing Client 20/60
# 	Accuracy for Client 20/60: 0.9609
# Testing Client 21/60
# 	Accuracy for Client 21/60: 0.9609
# Testing Client 22/60
# 	Accuracy for Client 22/60: 0.9609
# Testing Client 23/60
# 	Accuracy for Client 23/60: 0.9609
# Testing Client 24/60
# 	Accuracy for Client 24/60: 0.9609
# Testing Client 25/60
# 	Accuracy for Client 25/60: 0.9609
# Testing Client 26/60
# 	Accuracy for Client 26/60: 0.9609
# Testing Client 27/60
# 	Accuracy for Client 27/60: 0.9609
# Testing Client 28/60
# 	Accuracy for Client 28/60: 0.9609
# Testing Client 29/60
# 	Accuracy for Client 29/60: 0.9609
# Testing Client 30/60
# 	Accuracy for Client 30/60: 0.9609
# Testing Client 31/60
# 	Accuracy for Client 31/60: 0.9609
# Testing Client 32/60
# 	Accuracy for Client 32/60: 0.9609
# Testing Client 33/60
# 	Accuracy for Client 33/60: 0.9609
# Testing Client 34/60
# 	Accuracy for Client 34/60: 0.9609
# Testing Client 35/60
# 	Accuracy for Client 35/60: 0.9609
# Testing Client 36/60
# 	Accuracy for Client 36/60: 0.9609
# Testing Client 37/60
# 	Accuracy for Client 37/60: 0.9609
# Testing Client 38/60
# 	Accuracy for Client 38/60: 0.9609
# Testing Client 39/60
# 	Accuracy for Client 39/60: 0.9609
# Testing Client 40/60
# 	Accuracy for Client 40/60: 0.9609
# Testing Client 41/60
# 	Accuracy for Client 41/60: 0.9609
# Testing Client 42/60
# 	Accuracy for Client 42/60: 0.9609
# Testing Client 43/60
# 	Accuracy for Client 43/60: 0.9609
# Testing Client 44/60
# 	Accuracy for Client 44/60: 0.9609
# Testing Client 45/60
# 	Accuracy for Client 45/60: 0.9609
# Testing Client 46/60
# 	Accuracy for Client 46/60: 0.9609
# Testing Client 47/60
# 	Accuracy for Client 47/60: 0.9609
# Testing Client 48/60
# 	Accuracy for Client 48/60: 0.9609
# Testing Client 49/60
# 	Accuracy for Client 49/60: 0.9609
# Testing Client 50/60
# 	Accuracy for Client 50/60: 0.9609
# Testing Client 51/60
# 	Accuracy for Client 51/60: 0.9609
# Testing Client 52/60
# 	Accuracy for Client 52/60: 0.9609
# Testing Client 53/60
# 	Accuracy for Client 53/60: 0.9609
# Testing Client 54/60
# 	Accuracy for Client 54/60: 0.9609
# Testing Client 55/60
# 	Accuracy for Client 55/60: 0.9609
# Testing Client 56/60
# 	Accuracy for Client 56/60: 0.9609
# Testing Client 57/60
# 	Accuracy for Client 57/60: 0.9609
# Testing Client 58/60
# 	Accuracy for Client 58/60: 0.9609
# Testing Client 59/60
# 	Accuracy for Client 59/60: 0.9609
# Testing Client 60/60
# 	Accuracy for Client 60/60: 0.9609
# Drift Detection metrics::: true_positives:31, true_negatives:1140, false_positives:0, false_negatives:269
# Drift Detection Performance (DDM):
# Accuracy: 0.8131944444444444
# Precision: 1.0
# Recall: 0.10333333333333333
# F1 Score: 0.18731117824773413
# Drift Detection metrics::: true_positives:0, true_negatives:1140, false_positives:0, false_negatives:300
# Drift Detection Performance (EDDM):
# Accuracy: 0.7916666666666666
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# Drift Detection metrics::: true_positives:31, true_negatives:1140, false_positives:0, false_negatives:269
# Drift Detection Performance (HDDM):
# Accuracy: 0.8131944444444444
# Precision: 1.0
# Recall: 0.10333333333333333
# F1 Score: 0.18731117824773413
# Drift Detection metrics::: true_positives:62, true_negatives:1140, false_positives:0, false_negatives:238
# Drift Detection Performance (Combined):
# Accuracy: 0.8347222222222223
# Precision: 1.0
# Recall: 0.20666666666666667
# F1 Score: 0.3425414364640884
# Client Accuracies: [0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609, 0.9609]
